# %% [markdown]
# # Imports

# %%
import sklearn
import pandas as pd
import numpy as np
import re
import plotly.graph_objects as go
import plotly.express as px
import plotly
import math

# %% [markdown]
# # Reading Data

# %%
df_17 = pd.read_csv('./Dataset/FIFA17_official_data.csv')
df_18 = pd.read_csv('./Dataset/FIFA18_official_data.csv')
df_19 = pd.read_csv('./Dataset/FIFA19_official_data.csv')
df_20 = pd.read_csv('./Dataset/FIFA20_official_data.csv')
df_21 = pd.read_csv('./Dataset/FIFA21_official_data.csv')
df_22 = pd.read_csv('./Dataset/FIFA22_official_data.csv')
datalist = [df_17,df_18,df_19,df_20,df_21,df_22]

# %%
df_22.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating', 'Release Clause',
#        'DefensiveAwareness'],
#       dtype='object')

# %% [markdown]
# # Cleaning Data

# %%
curr_set = df_17
for next_set in datalist[1:]:
    print(set(next_set) - set(curr_set))
    curr_set = next_set

for dataset in datalist:
    if 'Release Clause' in list(dataset.columns):
        dataset.drop("Release Clause", axis = 1, inplace = True)
    if 'DefensiveAwareness' in list(dataset.columns):
        dataset.drop("DefensiveAwareness", axis = 1, inplace = True)
print("--------------------")
curr_set = df_17
for next_set in datalist[1:]:
    print(set(next_set) - set(curr_set))
    curr_set = next_set
# Out:
# {'Release Clause'}
# set()
# {'DefensiveAwareness'}
# set()
# set()
# --------------------
# set()
# set()
# set()
# set()
# set()

# %%
#Now we can join the datasets\
F_all_df = pd.concat(datalist, ignore_index=True)
F_all_df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Best Overall Rating'],
#       dtype='object')

# %%
Unimportant_features  = ["Photo", "Flag", "Club Logo", "Wage", "Special", "International Reputation", "Work Rate", "Body Type", "Real Face", "Jersey Number", "Contract Valid Until", "Best Overall Rating","Joined","Loaned From"]
F_all_df.drop(Unimportant_features, axis = 1, inplace = True)
F_all_df["Ovr_pot"] = (F_all_df["Overall"] + F_all_df["Potential"])/2

# %%
# One-hot encode Preferred_foot
F_all_df = pd.get_dummies(F_all_df, columns = ["Preferred Foot"])
F_all_df
# Out:
#             ID            Name  Age Nationality  Overall  Potential  \
# 0       176580       L. Suárez   29     Uruguay       92         92
# 1       178518   R. Nainggolan   28     Belgium       86         86
# 2       181872        A. Vidal   29       Chile       87         87
# 3       197445        D. Alaba   24     Austria       86         89
# 4       195864        P. Pogba   23      France       88         94
# ...        ...             ...  ...         ...      ...        ...
# 104347  240558   18 L. Clayton   17     England       53         70
# 104348  262846        �. Dobre   20     Romania       53         63
# 104349  241317  21 Xue Qinghao   19    China PR       47         60
# 104350  259646       A. Shaikh   18       India       47         67
# 104351  178453   07 A. Censori   17       Italy       28         38
#
#                          Club   Value  Weak Foot  Skill Moves  ...  \
# 0                FC Barcelona    €83M        4.0          4.0  ...
# 1                        Roma  €37.5M        3.0          3.0  ...
# 2           FC Bayern München  €41.5M        4.0          3.0  ...
# 3           FC Bayern München  €41.5M        4.0          3.0  ...
# 4           Manchester United  €71.5M        4.0          5.0  ...
# ...                       ...     ...        ...          ...  ...
# 104347        Cheltenham Town   €100K        2.0          1.0  ...
# 104348  FC Academica Clinceni   €180K        2.0          1.0  ...
# 104349    Shanghai Shenhua FC   €100K        2.0          1.0  ...
# 104350     ATK Mohun Bagan FC   €110K        3.0          1.0  ...
# 104351                 Arezzo      €0        2.0          1.0  ...
#
#        SlidingTackle GKDiving GKHandling  GKKicking  GKPositioning  \
# 0               38.0     27.0       25.0       31.0           33.0
# 1               88.0     11.0       11.0       14.0            8.0
# 2               84.0      4.0        2.0        4.0            2.0
# 3               83.0      5.0        7.0       14.0           15.0
# 4               73.0      5.0        6.0        2.0            4.0
# ...              ...      ...        ...        ...            ...
# 104347          12.0     55.0       54.0       52.0           50.0
# 104348          12.0     57.0       52.0       53.0           48.0
# 104349           9.0     49.0       48.0       45.0           38.0
# 104350          13.0     49.0       41.0       39.0           45.0
# 104351           NaN      7.0        1.0       36.0            6.0
#
#         GKReflexes  Best Position  Ovr_pot  Preferred Foot_Left  \
# 0             37.0             ST     92.0                    0
# 1             11.0            CDM     86.0                    0
# 2              4.0            CDM     87.0                    0
# 3              9.0             LB     87.5                    1
# 4              3.0            CAM     91.0                    0
# ...            ...            ...      ...                  ...
# 104347        59.0             GK     61.5                    0
# 104348        58.0             GK     58.0                    0
# 104349        52.0             GK     53.5                    0
# 104350        49.0             GK     57.0                    0
# 104351         9.0             ST     33.0                    0
#
#         Preferred Foot_Right
# 0                          1
# 1                          1
# 2                          1
# 3                          0
# 4                          1
# ...                      ...
# 104347                     1
# 104348                     1
# 104349                     1
# 104350                     1
# 104351                     1
#
# [104352 rows x 51 columns]

# %%
detailed_features = ['Age','Overall', 'Potential', 'Weak Foot', 'Skill Moves', 'Height', 'Weight', 'Crossing', 'Finishing',
       'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
       'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes', "Ovr_pot", 'Preferred Foot_Left', 'Preferred Foot_Right']

# %%
F_all_df[detailed_features] = F_all_df[detailed_features].fillna(0)
F_all_df
# Out:
#             ID            Name  Age Nationality  Overall  Potential  \
# 0       176580       L. Suárez   29     Uruguay       92         92
# 1       178518   R. Nainggolan   28     Belgium       86         86
# 2       181872        A. Vidal   29       Chile       87         87
# 3       197445        D. Alaba   24     Austria       86         89
# 4       195864        P. Pogba   23      France       88         94
# ...        ...             ...  ...         ...      ...        ...
# 104347  240558   18 L. Clayton   17     England       53         70
# 104348  262846        �. Dobre   20     Romania       53         63
# 104349  241317  21 Xue Qinghao   19    China PR       47         60
# 104350  259646       A. Shaikh   18       India       47         67
# 104351  178453   07 A. Censori   17       Italy       28         38
#
#                          Club   Value  Weak Foot  Skill Moves  ...  \
# 0                FC Barcelona    €83M        4.0          4.0  ...
# 1                        Roma  €37.5M        3.0          3.0  ...
# 2           FC Bayern München  €41.5M        4.0          3.0  ...
# 3           FC Bayern München  €41.5M        4.0          3.0  ...
# 4           Manchester United  €71.5M        4.0          5.0  ...
# ...                       ...     ...        ...          ...  ...
# 104347        Cheltenham Town   €100K        2.0          1.0  ...
# 104348  FC Academica Clinceni   €180K        2.0          1.0  ...
# 104349    Shanghai Shenhua FC   €100K        2.0          1.0  ...
# 104350     ATK Mohun Bagan FC   €110K        3.0          1.0  ...
# 104351                 Arezzo      €0        2.0          1.0  ...
#
#        SlidingTackle GKDiving GKHandling  GKKicking  GKPositioning  \
# 0               38.0     27.0       25.0       31.0           33.0
# 1               88.0     11.0       11.0       14.0            8.0
# 2               84.0      4.0        2.0        4.0            2.0
# 3               83.0      5.0        7.0       14.0           15.0
# 4               73.0      5.0        6.0        2.0            4.0
# ...              ...      ...        ...        ...            ...
# 104347          12.0     55.0       54.0       52.0           50.0
# 104348          12.0     57.0       52.0       53.0           48.0
# 104349           9.0     49.0       48.0       45.0           38.0
# 104350          13.0     49.0       41.0       39.0           45.0
# 104351           0.0      7.0        1.0       36.0            6.0
#
#         GKReflexes  Best Position  Ovr_pot  Preferred Foot_Left  \
# 0             37.0             ST     92.0                    0
# 1             11.0            CDM     86.0                    0
# 2              4.0            CDM     87.0                    0
# 3              9.0             LB     87.5                    1
# 4              3.0            CAM     91.0                    0
# ...            ...            ...      ...                  ...
# 104347        59.0             GK     61.5                    0
# 104348        58.0             GK     58.0                    0
# 104349        52.0             GK     53.5                    0
# 104350        49.0             GK     57.0                    0
# 104351         9.0             ST     33.0                    0
#
#         Preferred Foot_Right
# 0                          1
# 1                          1
# 2                          1
# 3                          0
# 4                          1
# ...                      ...
# 104347                     1
# 104348                     1
# 104349                     1
# 104350                     1
# 104351                     1
#
# [104352 rows x 51 columns]

# %%
# Clean height column
feet_inches_re = re.compile(r"(\d)'(\d+)")

# Define a function to convert feet'inches to cm
def feet_inches_to_cm(s):
    match = feet_inches_re.match(s)
    if match:
        feet = int(match.group(1))
        inches = int(match.group(2))
        return round((feet*12 + inches) * 2.54, 2)
    else:
        return float(s.replace('cm', ''))
F_all_df['Height'] = pd.to_numeric(F_all_df['Height'].apply(feet_inches_to_cm))

# %%
F_all_df['Height'].value_counts()
# Out:
# 182.88    13593
# 177.80    12221
# 175.26    10661
# 180.34    10380
# 187.96     9448
#           ...
# 159.00        3
# 156.00        2
# 155.00        1
# 157.00        1
# 206.00        1
# Name: Height, Length: 71, dtype: int64

# %%
# Clean Weight Column
def convert_weight(weight_str):
    if 'kg' in weight_str:
        # If weight is in kg, remove the 'kg' suffix and return as float
        return float(weight_str.replace('kg', ''))
    elif 'lbs' in weight_str:
        # If weight is in lbs, convert to kg and return as float
        return float(weight_str.replace('lbs', '')) * 0.453592
    else:
        print("oops")
        # Return NaN if weight format is not recognized
        return pd.np.nan

# Apply the function to the Weight column and create a new column 'Weight_kg'
F_all_df['Weight'] = F_all_df['Weight'].apply(convert_weight)

# %%
F_all_df['Weight'].value_counts()
# Out:
# 69.853168     7042
# 74.842680     6815
# 79.832192     4958
# 72.121128     4800
# 78.017824     4717
#               ...
# 104.000000       1
# 51.000000        1
# 53.000000        1
# 48.080752        1
# 105.000000       1
# Name: Weight, Length: 117, dtype: int64

# %%
# Define a function to convert cost to millions
def convert_cost(cost_str):
    if 'M' in cost_str:
        # If cost is in millions, remove the '$' and 'M' suffix and return as float
        return float(cost_str.replace('€', '').replace('M', ''))
    elif 'K' in cost_str:
        # If cost is in thousands, remove the '$' and 'K' suffix, divide by 1000, and return as float
        return float(cost_str.replace('€', '').replace('K', '')) / 1000
    # else:
    #     # Return NaN if cost format is not recognized
    #     return pd.np.nan

# Apply the function to the Cost column and create a new column 'Cost_millions'
F_all_df['Value'] = F_all_df['Value'].apply(convert_cost)

# %% [markdown]
# # Feature Creation - BMI

# %%
F_all_df['Bmi'] = F_all_df['Weight'] / (F_all_df['Height']/100)**2

# %%
F_all_df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Weak Foot', 'Skill Moves', 'Position', 'Height', 'Weight',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Ovr_pot', 'Preferred Foot_Left',
#        'Preferred Foot_Right', 'Bmi'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
# fig = go.Figure()

# fig = go.Figure(data=go.Scatter(
#     x = df_20['Overall'],
#     y = df_20['Value'],
#     mode='markers',
#     marker=dict(
#         size=16,
#         color=df_20['Age'], #set color equal to a variable
#         colorscale='Plasma', # one of plotly colorscales
#         showscale=True
#     ),
#     text= df_20['Name'],
# ))

# fig.update_layout(title='Styled Scatter Plot (colored by Age) year 2020 - Overall Rating vs Value in Euros',
#                   xaxis_title='Overall Rating',
#                   yaxis_title='Value in Euros',
#                   paper_bgcolor='rgba(0,0,0,0)',
#                   plot_bgcolor='rgba(0,0,0,0)',
#                   font=dict(family='Cambria, monospace', size=12, color='#000000'))
# fig.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = sklearn.preprocessing.StandardScaler()
F_norm_df = F_all_df.copy(deep = True)
F_norm_df[detailed_features] = scaler.fit_transform(F_norm_df[detailed_features].to_numpy())
F_norm_df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Weak Foot', 'Skill Moves', 'Position', 'Height', 'Weight',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Ovr_pot', 'Preferred Foot_Left',
#        'Preferred Foot_Right', 'Bmi'],
#       dtype='object')

# %%
df_22 = F_all_df.tail(df_22.shape[0])

# %%
df_22
# Out:
#             ID             Name  Age Nationality  Overall  Potential  \
# 87642   212198  Bruno Fernandes   26    Portugal       88         89
# 87643   209658      L. Goretzka   26     Germany       87         88
# 87644   176580        L. Suárez   34     Uruguay       88         88
# 87645   192985     K. De Bruyne   30     Belgium       91         91
# 87646   224334         M. Acuña   29   Argentina       84         84
# ...        ...              ...  ...         ...      ...        ...
# 104347  240558    18 L. Clayton   17     England       53         70
# 104348  262846         �. Dobre   20     Romania       53         63
# 104349  241317   21 Xue Qinghao   19    China PR       47         60
# 104350  259646        A. Shaikh   18       India       47         67
# 104351  178453    07 A. Censori   17       Italy       28         38
#
#                          Club   Value  Weak Foot  Skill Moves  ... GKDiving  \
# 87642       Manchester United  107.50        3.0          4.0  ...     12.0
# 87643       FC Bayern München   93.00        4.0          3.0  ...     13.0
# 87644      Atlético de Madrid   44.50        4.0          3.0  ...     27.0
# 87645         Manchester City  125.50        5.0          4.0  ...     15.0
# 87646              Sevilla FC   37.00        3.0          4.0  ...      8.0
# ...                       ...     ...        ...          ...  ...      ...
# 104347        Cheltenham Town    0.10        2.0          1.0  ...     55.0
# 104348  FC Academica Clinceni    0.18        2.0          1.0  ...     57.0
# 104349    Shanghai Shenhua FC    0.10        2.0          1.0  ...     49.0
# 104350     ATK Mohun Bagan FC    0.11        3.0          1.0  ...     49.0
# 104351                 Arezzo     NaN        2.0          1.0  ...      7.0
#
#         GKHandling  GKKicking  GKPositioning  GKReflexes  Best Position  \
# 87642         14.0       15.0            8.0        14.0            CAM
# 87643          8.0       15.0           11.0         9.0             CM
# 87644         25.0       31.0           33.0        37.0             ST
# 87645         13.0        5.0           10.0        13.0             CM
# 87646         14.0       13.0           13.0        14.0             LB
# ...            ...        ...            ...         ...            ...
# 104347        54.0       52.0           50.0        59.0             GK
# 104348        52.0       53.0           48.0        58.0             GK
# 104349        48.0       45.0           38.0        52.0             GK
# 104350        41.0       39.0           45.0        49.0             GK
# 104351         1.0       36.0            6.0         9.0             ST
#
#         Ovr_pot  Preferred Foot_Left  Preferred Foot_Right        Bmi
# 87642      88.5                    0                     1  21.534908
# 87643      87.5                    0                     1  22.955684
# 87644      88.0                    0                     1  25.057360
# 87645      91.0                    0                     1  21.366869
# 87646      84.0                    1                     0  23.323418
# ...         ...                  ...                   ...        ...
# 104347     61.5                    0                     1  22.634676
# 104348     58.0                    0                     1  22.850462
# 104349     53.5                    0                     1  21.913580
# 104350     57.0                    0                     1  21.389756
# 104351     33.0                    0                     1  22.024323
#
# [16710 rows x 52 columns]

# %%
# fig = go.Figure()
# sample = F_norm_df.sort_values(by='Ovr_pot')

# fig.add_trace(go.Box(
#     x = sample['Ovr_pot'],
#     y = sample['Bmi'],
#     name="Suspected Outliers",
#     boxpoints='suspectedoutliers', # only suspected outliers
#     marker=dict(
#         size=12,
#         color='rgb(251, 158, 58)',
#         outliercolor='rgba(216, 87, 107, 0.6)',
#         line=dict(
#             outliercolor='rgba(216, 87, 107, 0.6)',
#             outlierwidth=2)),
#     line_color='rgb(73, 3, 159)',
#     text= sample['Name']
# ))

# fig.update_layout(title='Styled Box Plot (with Suspected Outliers) - Overall Rating vs BMI',
#                   xaxis_title='Overall Rating',
#                   yaxis_title='BMI',
#                   paper_bgcolor='rgba(0,0,0,0)',
#                   plot_bgcolor='rgba(0,0,0,0)',
#                   font=dict(family='Cambria, monospace', size=12, color='#000000'),
#                   xaxis_rangeslider_visible=True)
# fig.show()

# %%
F_norm_df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Weak Foot', 'Skill Moves', 'Position', 'Height', 'Weight',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Ovr_pot', 'Preferred Foot_Left',
#        'Preferred Foot_Right', 'Bmi'],
#       dtype='object')

# %%
F_norm_df["Best Position"].value_counts()
# Out:
# CB     20687
# ST     15332
# CAM    12517
# GK     10890
# RM      8359
# CDM     7824
# CM      6018
# RB      5116
# LB      4840
# LM      4711
# RW      2656
# RWB     1861
# LWB     1779
# LW      1279
# CF       480
# LF         2
# SW         1
# Name: Best Position, dtype: int64

# %% [markdown]
# # Strikers

# %%
striker_df = F_norm_df[(F_norm_df["Best Position"] == "ST") | (F_norm_df["Best Position"] == "CF") | (F_norm_df["Best Position"] == "LF")]
striker_df  =  striker_df.reset_index(drop = True)
striker_df
# Out:
#            ID                Name       Age          Nationality   Overall  \
# 0      176580           L. Suárez  0.873366              Uruguay  3.647373
# 1      173731             G. Bale  0.249592                Wales  3.360388
# 2       20801   Cristiano Ronaldo  1.289216             Portugal  3.934357
# 3      184941          A. Sánchez  0.457517                Chile  3.073404
# 4       54050           W. Rooney  1.081291              England  2.212450
# ...       ...                 ...       ...                  ...       ...
# 15809  262034            R. Mahon -1.413805  Republic of Ireland -2.666287
# 15810  259650            F. Molla -1.205880                India -2.809779
# 15811  161659           07 Danilo -0.166257               Brazil -0.370411
# 15812  150597       09 J. Moukoko -0.374181             Congo DR -1.805333
# 15813  178453       07 A. Censori -1.621729                Italy -5.536132
#
#        Potential                         Club  Value  Weak Foot  Skill Moves  \
# 0       3.353318                 FC Barcelona  83.00   1.552616     2.090192
# 1       3.020577                  Real Madrid  72.00   0.053943     2.090192
# 2       3.686059                  Real Madrid  87.00   1.552616     3.387573
# 3       2.687836                      Arsenal  55.00   0.053943     2.090192
# 4       1.689612            Manchester United  18.50   1.552616     0.792811
# ...          ...                          ...    ...        ...          ...
# 15809  -1.970541                  Bohemian FC   0.11   0.053943    -0.504570
# 15810  -0.805947           ATK Mohun Bagan FC   0.13  -1.444731    -0.504570
# 15811  -0.805947  Gallos Blancos de Querétaro    NaN   0.053943    -1.801951
# 15812  -1.637800                          NaN    NaN   0.053943    -1.801951
# 15813  -5.630694                       Arezzo    NaN  -1.444731    -1.801951
#
#        ...  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0      ...  0.618657    0.538418   0.922738       1.007493    1.168766
# 1      ... -0.071239   -0.062607  -0.302515      -0.658054   -0.584877
# 2      ... -0.531171   -0.303018  -0.057464      -0.122700   -0.302032
# 3      ... -0.358697   -0.363120  -0.057464      -0.241667   -0.188893
# 4      ... -0.358697   -0.303018  -0.179990      -0.479603   -0.528308
# ...    ...       ...         ...        ...            ...         ...
# 15809  ... -0.531171   -0.122710  -0.608828      -0.479603   -0.075755
# 15810  ... -0.473679   -0.603530  -0.118727      -0.301151   -0.132324
# 15811  ... -0.301205   -0.603530   2.515567      -0.063216   -0.245462
# 15812  ... -0.473679    0.538418   1.474102       0.531623    0.489936
# 15813  ... -0.531171   -0.904043   1.229051      -0.598570   -0.415170
#
#        Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                 ST  3.876224            -0.558918              0.558918
# 1                 ST  3.536013             1.789172             -1.789172
# 2                 ST  4.216436            -0.558918              0.558918
# 3                 ST  3.195802            -0.558918              0.558918
# 4                 ST  2.175168            -0.558918              0.558918
# ...              ...       ...                  ...                   ...
# 15809             ST -2.587790             1.789172             -1.789172
# 15810             ST -2.077473            -0.558918              0.558918
# 15811             ST -0.631575             1.789172             -1.789172
# 15812             ST -1.907368            -0.558918              0.558918
# 15813             ST -6.160009            -0.558918              0.558918
#
#              Bmi
# 0      25.768347
# 1      22.106529
# 2      23.220144
# 3      21.456996
# 4      27.024076
# ...          ...
# 15809  20.549887
# 15810  24.304618
# 15811  24.930748
# 15812  23.503556
# 15813  22.024323
#
# [15814 rows x 52 columns]

# %%
ST_detailed_features = ['Weak Foot', 'Skill Moves', 'Height', 'Weight','Bmi', 'Crossing', 'Finishing',
       'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
       'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle']

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
X = striker_df[ST_detailed_features].to_numpy()
y = striker_df["Ovr_pot"].to_numpy()
# define feature selection
fs = SelectKBest(score_func=f_regression, k = 10)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
np.sort(fs.scores_)
# Out:
# array([5.64069079e+00, 6.01175039e+01, 1.15560838e+02, 2.47649992e+02,
#        3.93058587e+02, 4.06505762e+02, 9.81697813e+02, 1.11763132e+03,
#        1.14061688e+03, 1.18550313e+03, 1.23847753e+03, 1.43281252e+03,
#        1.45863958e+03, 2.17451588e+03, 2.75182023e+03, 2.87025967e+03,
#        4.27010137e+03, 4.41289126e+03, 5.73828589e+03, 5.77270709e+03,
#        6.38939382e+03, 6.72582876e+03, 6.82025961e+03, 7.05054983e+03,
#        1.01421237e+04, 1.12446741e+04, 1.53094768e+04, 2.02789365e+04,
#        2.03344285e+04, 2.53797729e+04, 2.61312201e+04, 3.10141541e+04,
#        4.00066369e+04, 4.20135489e+04])

# %%
ST_essential_ft = list(fs.get_feature_names_out(ST_detailed_features))
ST_essential_ft
# Out:
# ['Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'BallControl',
#  'Reactions',
#  'ShotPower',
#  'LongShots',
#  'Positioning']

# %% [markdown]
# # Wingers

# %%
wingers_df = F_norm_df[(F_norm_df["Best Position"] == "LW") | (F_norm_df["Best Position"] == "RW")]
wingers_df  =  wingers_df.reset_index(drop = True)
wingers_df
# Out:
#           ID            Name       Age          Nationality   Overall  \
# 0     190871          Neymar -0.166257               Brazil  3.647373
# 1     193130     A. Schürrle  0.041668              Germany  2.068958
# 2     209331        M. Salah -0.166257                Egypt  2.212450
# 3     222492         L. Sané -0.997955              Germany  2.212450
# 4     185020   José Callejón  0.873366                Spain  2.355942
# ...      ...             ...       ...                  ...       ...
# 3930  248281   20 D. Borrero -1.621729             Colombia -1.518349
# 3931  263090          J. Eng -1.829654               Norway -1.948825
# 3932  264675      J. Dickman -0.997955               Sweden -2.092318
# 3933  261677       R. O'Kane -1.621729  Republic of Ireland -2.235810
# 3934  256458       K. Swaleh -1.413805               Norway -2.379302
#
#       Potential                         Club   Value  Weak Foot  Skill Moves  \
# 0      3.686059                 FC Barcelona  106.00   3.051289     3.387573
# 1      1.689612            Borussia Dortmund   19.00   1.552616     0.792811
# 2      2.188724                         Roma   26.00  -1.444731     2.090192
# 3      3.186947              Manchester City   31.00   0.053943     0.792811
# 4      1.855983                       Napoli   22.50  -1.444731     0.792811
# ...         ...                          ...     ...        ...          ...
# 3930   0.525018  Club Independiente Santa Fe    0.18   0.053943     0.792811
# 3931   0.691388            Vålerenga Fotball    0.30   0.053943     0.792811
# 3932  -0.805947              FC Nordsjælland    0.19   0.053943    -0.504570
# 3933   0.525018                   Dundalk FC    0.18  -1.444731    -0.504570
# 3934  -0.306835                FK Bodø/Glimt    0.13   0.053943    -0.504570
#
#       ...  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0     ... -0.416188   -0.423223  -0.057464      -0.063216   -0.302032
# 1     ... -0.531171   -0.303018  -0.241252      -0.420119   -0.245462
# 2     ... -0.128731   -0.122710  -0.425040      -0.301151   -0.132324
# 3     ... -0.473679   -0.242915  -0.425040      -0.420119   -0.132324
# 4     ... -0.473679   -0.663633  -0.118727      -0.301151   -0.302032
# ...   ...       ...         ...        ...            ...         ...
# 3930  ... -0.243714   -0.423223  -0.425040      -0.658054   -0.188893
# 3931  ... -0.358697   -0.363120  -0.547565      -0.360635   -0.641446
# 3932  ... -0.128731   -0.062607  -0.241252      -0.539087   -0.584877
# 3933  ... -0.301205   -0.242915  -0.118727      -0.360635   -0.584877
# 3934  ... -0.301205   -0.122710  -0.179990      -0.598570   -0.471739
#
#       Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                LW  4.046330            -0.558918              0.558918
# 1                RW  2.090115            -0.558918              0.558918
# 2                RW  2.430326             1.789172             -1.789172
# 3                LW  2.940643             1.789172             -1.789172
# 4                RW  2.345273            -0.558918              0.558918
# ...             ...       ...                  ...                   ...
# 3930             RW -0.631575            -0.558918              0.558918
# 3931             RW -0.801681            -0.558918              0.558918
# 3932             RW -1.652209            -0.558918              0.558918
# 3933             RW -1.056840            -0.558918              0.558918
# 3934             RW -1.567157            -0.558918              0.558918
#
#             Bmi
# 0     22.150882
# 1     22.106529
# 2     23.479935
# 3     22.784644
# 4     23.100839
# ...         ...
# 3930  21.847009
# 3931  24.074074
# 3932  22.582709
# 3933  20.904195
# 3934  20.761246
#
# [3935 rows x 52 columns]

# %%
Wing_detailed_features = ['Weak Foot', 'Skill Moves', 'Height', 'Weight','Bmi', 'Crossing', 'Finishing',
       'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
       'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle']

# %%
X = wingers_df[Wing_detailed_features].to_numpy()
y = wingers_df["Ovr_pot"].to_numpy()
# define feature selection
fs = SelectKBest(score_func=f_regression, k = 10)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
np.sort(fs.scores_)
# Out:
# array([3.29880469e-01, 5.27755587e-01, 8.70543243e+00, 1.32447941e+01,
#        6.81219680e+01, 1.19319356e+02, 1.32405108e+02, 1.34820032e+02,
#        1.37514990e+02, 1.77184397e+02, 3.17072084e+02, 4.35849248e+02,
#        5.42156511e+02, 6.62702856e+02, 9.30597672e+02, 9.44008964e+02,
#        9.93276607e+02, 1.00458747e+03, 1.08758829e+03, 1.39182558e+03,
#        1.97523922e+03, 2.13570267e+03, 2.29758520e+03, 2.36690811e+03,
#        2.72262854e+03, 3.30209508e+03, 3.65653954e+03, 4.27979708e+03,
#        4.32607549e+03, 4.84295923e+03, 5.10712658e+03, 5.82370202e+03,
#        1.13580208e+04, 1.14027090e+04])

# %%
Wing_essential_ft = list(fs.get_feature_names_out(Wing_detailed_features))
Wing_essential_ft
# Out:
# ['Crossing',
#  'Finishing',
#  'ShortPassing',
#  'Dribbling',
#  'BallControl',
#  'Reactions',
#  'ShotPower',
#  'LongShots',
#  'Positioning',
#  'Vision']

# %% [markdown]
# # Midfield

# %%
mids_df = F_norm_df[(F_norm_df["Best Position"] == "RM") | (F_norm_df["Best Position"] == "CM") | (F_norm_df["Best Position"] == "CDM") | (F_norm_df["Best Position"] == "LM")]
mids_df  =  mids_df.reset_index(drop = True)
mids_df
# Out:
#            ID              Name       Age          Nationality   Overall  \
# 0      178518     R. Nainggolan  0.665442              Belgium  2.786419
# 1      181872          A. Vidal  0.873366                Chile  2.929911
# 2      177003         L. Modrić  1.081291              Croatia  3.216896
# 3      173210      C. Marchisio  1.081291                Italy  2.786419
# 4      139997           D. Srna  1.912989              Croatia  2.068958
# ...       ...               ...       ...                  ...       ...
# 26907    4174        07 P. Sarr  0.665442              Senegal -0.226918
# 26908  246839     21 C. Bargary -1.205880  Republic of Ireland -2.235810
# 26909  235352   18 T. Käßemodel  0.665442              Germany -2.953271
# 26910    4373    07 S. Valakari  1.705065              Finland -0.083426
# 26911   19334  10 I. Baraclough  2.744688              England -3.240256
#
#        Potential               Club  Value  Weak Foot  Skill Moves  ...  \
# 0       2.355094               Roma  37.50   0.053943     0.792811  ...
# 1       2.521465  FC Bayern München  41.50   1.552616     0.792811  ...
# 2       2.854206        Real Madrid  54.00   1.552616     2.090192  ...
# 3       2.355094           Juventus  35.00   1.552616     2.090192  ...
# 4       1.523241   Shakhtar Donetsk   4.80   0.053943     0.792811  ...
# ...          ...                ...    ...        ...          ...  ...
# 26907  -0.306835  Stade Brestois 29    NaN   0.053943    -1.801951  ...
# 26908  -0.805947          Cork City   0.15   0.053943    -0.504570  ...
# 26909  -4.299729  FC Erzgebirge Aue   0.03   0.053943    -0.504570  ...
# 26910  -0.805947          FC Dallas    NaN   0.053943    -1.801951  ...
# 26911  -1.138688                NaN    NaN   0.053943    -1.801951  ...
#
#        GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0     -0.301205   -0.303018  -0.118727      -0.479603   -0.302032
# 1     -0.703645   -0.843941  -0.731353      -0.836506   -0.698015
# 2     -0.186222   -0.423223  -0.547565      -0.122700   -0.415170
# 3     -0.703645   -0.783838  -0.731353      -0.836506   -0.698015
# 4     -0.358697   -0.363120  -0.608828      -0.598570   -0.245462
# ...         ...         ...        ...            ...         ...
# 26907 -0.416188   -0.242915   3.189456      -0.479603   -0.302032
# 26908 -0.358697   -0.603530  -0.302515      -0.598570   -0.641446
# 26909 -0.358697   -0.242915  -0.608828      -0.182184   -0.584877
# 26910 -0.588662   -0.783838   2.270516      -0.598570   -0.754585
# 26911 -0.646154    0.237905   1.841678       0.234203    0.207091
#
#        Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                CDM  2.855590            -0.558918              0.558918
# 1                CDM  3.025696            -0.558918              0.558918
# 2                 CM  3.365907            -0.558918              0.558918
# 3                 CM  2.855590            -0.558918              0.558918
# 4                 CM  2.005062            -0.558918              0.558918
# ...              ...       ...                  ...                   ...
# 26907            CDM -0.291364            -0.558918              0.558918
# 26908             RM -1.737262            -0.558918              0.558918
# 26909             CM -3.948636            -0.558918              0.558918
# 26910            CDM -0.461470             1.789172             -1.789172
# 26911             CM -2.502738             1.789172             -1.789172
#
#              Bmi
# 0      21.117175
# 1      23.012574
# 2      21.117175
# 3      22.454694
# 4      22.813872
# ...          ...
# 26907  23.456790
# 26908  21.777553
# 26909  25.059307
# 26910  26.753864
# 26911  23.666910
#
# [26912 rows x 52 columns]

# %%
Mid_detailed_features = ['Weak Foot', 'Skill Moves', 'Height', 'Weight','Bmi', 'Crossing', 'Finishing',
       'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
       'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle']

# %%
X = mids_df[Mid_detailed_features].to_numpy()
y = mids_df["Ovr_pot"].to_numpy()
# define feature selection
fs = SelectKBest(score_func=f_regression, k = 10)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
Mid_essential_ft = list(fs.get_feature_names_out(Mid_detailed_features))
Mid_essential_ft
# Out:
# ['ShortPassing',
#  'Dribbling',
#  'LongPassing',
#  'BallControl',
#  'Reactions',
#  'ShotPower',
#  'LongShots',
#  'Positioning',
#  'Vision',
#  'Composure']

# %% [markdown]
# # CAM

# %%
cam_df = F_norm_df[(F_norm_df["Best Position"] == "CAM")]
cam_df  =  cam_df.reset_index(drop = True)
cam_df
# Out:
#            ID           Name       Age          Nationality   Overall  \
# 0      195864       P. Pogba -0.374181               France  3.073404
# 1       20289       Y. Touré  1.705065          Ivory Coast  2.499435
# 2      189509         Thiago  0.041668                Spain  2.786419
# 3      171877      M. Hamšik  0.665442             Slovakia  2.786419
# 4      180206      M. Pjanić  0.249592   Bosnia Herzegovina  2.642927
# ...       ...            ...       ...                  ...       ...
# 12512  252881   21 H. Hopper -1.205880              England -2.379302
# 12513  243725     D. Collins -0.997955  Republic of Ireland -2.809779
# 12514  259857       A. Majok -0.997955          South Sudan -2.379302
# 12515  261748  C. McLaughlin -1.205880  Republic of Ireland -2.235810
# 12516  261818   R. Gallagher -0.997955  Republic of Ireland -2.809779
#
#        Potential               Club  Value  Weak Foot  Skill Moves  ...  \
# 0       3.686059  Manchester United  71.50   1.552616     3.387573  ...
# 1       2.022353    Manchester City  18.00   1.552616     0.792811  ...
# 2       2.687836  FC Bayern München  46.00   0.053943     3.387573  ...
# 3       2.355094             Napoli  37.50   1.552616     0.792811  ...
# 4       2.355094           Juventus  37.50   1.552616     2.090192  ...
# ...          ...                ...    ...        ...          ...  ...
# 12512  -0.805947           Rochdale   0.12  -1.444731    -0.504570  ...
# 12513  -2.636023       Sligo Rovers   0.10   0.053943    -0.504570  ...
# 12514  -0.805947  Western United FC   0.12  -1.444731    -0.504570  ...
# 12515  -2.136912         Derry City   0.13   0.053943     0.792811  ...
# 12516  -1.804170         Finn Harps   0.11   0.053943    -0.504570  ...
#
#        GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0     -0.646154   -0.603530  -0.853879      -0.717538   -0.754585
# 1     -0.186222   -0.122710  -0.608828      -0.241667   -0.471739
# 2     -0.588662   -0.303018  -0.547565      -0.420119   -0.188893
# 3     -0.473679   -0.603530  -0.731353      -0.122700   -0.132324
# 4     -0.531171   -0.543428  -0.179990      -0.539087   -0.471739
# ...         ...         ...        ...            ...         ...
# 12512 -0.473679   -0.543428  -0.670091      -0.479603   -0.358601
# 12513 -0.588662   -0.423223  -0.670091      -0.182184   -0.471739
# 12514 -0.473679   -0.303018  -0.363777      -0.479603   -0.358601
# 12515 -0.243714   -0.423223  -0.302515      -0.122700   -0.528308
# 12516 -0.128731   -0.363120  -0.547565      -0.182184   -0.471739
#
#        Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                CAM  3.706119            -0.558918              0.558918
# 1                CAM  2.515379            -0.558918              0.558918
# 2                CAM  3.025696            -0.558918              0.558918
# 3                CAM  2.855590            -0.558918              0.558918
# 4                CAM  2.770538            -0.558918              0.558918
# ...              ...       ...                  ...                   ...
# 12512            CAM -1.822315            -0.558918              0.558918
# 12513            CAM -3.013055            -0.558918              0.558918
# 12514            CAM -1.822315            -0.558918              0.558918
# 12515            CAM -2.417685             1.789172             -1.789172
# 12516            CAM -2.587790            -0.558918              0.558918
#
#              Bmi
# 0      23.123158
# 1      25.421414
# 2      22.741573
# 3      23.598381
# 4      21.478402
# ...          ...
# 12512  21.877551
# 12513  22.460034
# 12514  21.132713
# 12515  22.857143
# 12516  22.839506
#
# [12517 rows x 52 columns]

# %%
Cam_detailed_features = ['Weak Foot', 'Skill Moves', 'Height', 'Weight','Bmi', 'Crossing', 'Finishing',
       'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
       'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle']

# %%
X = cam_df[Cam_detailed_features].to_numpy()
y = cam_df["Ovr_pot"].to_numpy()
# define feature selection
fs = SelectKBest(score_func=f_regression, k = 10)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
Cam_essential_ft = list(fs.get_feature_names_out(Cam_detailed_features))
Cam_essential_ft
# Out:
# ['Crossing',
#  'Finishing',
#  'ShortPassing',
#  'Dribbling',
#  'Curve',
#  'BallControl',
#  'Reactions',
#  'LongShots',
#  'Positioning',
#  'Vision']

# %% [markdown]
# # Defenders

# %%
centrebacks_df = F_norm_df[(F_norm_df["Best Position"] == "CB")]
centrebacks_df  = centrebacks_df.reset_index(drop = True)
centrebacks_df
# Out:
#            ID            Name       Age          Nationality   Overall  \
# 0      185103      A. Kolarov  1.081291               Serbia  1.925466
# 1      155862    Sergio Ramos  1.081291                Spain  3.216896
# 2      164240    Thiago Silva  1.289216               Brazil  3.216896
# 3      179944      David Luiz  0.873366               Brazil  2.499435
# 4      205600       S. Umtiti -0.582106               France  2.355942
# ...       ...             ...       ...                  ...       ...
# 20682  164945  07 Nuno Mendes  0.665442             Portugal  0.634035
# 20683  252561        Zhang Yu -1.413805             China PR -2.379302
# 20684  262041      P. Maguire -1.413805  Republic of Ireland -2.522794
# 20685  239427     21 A. Ajeti -0.374181          Switzerland -1.805333
# 20686  220806    16 E. Redman -1.413805                Wales -3.240256
#
#        Potential                  Club  Value  Weak Foot  Skill Moves  ...  \
# 0       1.356871       Manchester City  10.00   0.053943    -0.504570  ...
# 1       2.854206           Real Madrid  43.50   0.053943     0.792811  ...
# 2       2.854206   Paris Saint-Germain  39.50   0.053943     0.792811  ...
# 3       2.022353               Chelsea  22.00   0.053943     0.792811  ...
# 4       2.687836          FC Barcelona  27.00   0.053943    -0.504570  ...
# ...          ...                   ...    ...        ...          ...  ...
# 20682  -0.306835  US Créteil-Lusitanos    NaN   0.053943    -1.801951  ...
# 20683  -0.473206              Hebei FC   0.11  -1.444731    -0.504570  ...
# 20684  -0.805947          Sligo Rovers   0.11   0.053943    -0.504570  ...
# 20685  -1.804170    FC St. Gallen 1879   0.20   0.053943    -0.504570  ...
# 20686  -2.469653        Newport County   0.05  -1.444731    -0.504570  ...
#
#        GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0     -0.013748   -0.062607  -0.486303      -0.003732   -0.584877
# 1     -0.301205   -0.483325  -0.425040      -0.539087   -0.302032
# 2     -0.416188   -0.242915  -0.670091      -0.420119   -0.358601
# 3     -0.301205   -0.242915  -0.363777      -0.539087   -0.132324
# 4     -0.071239   -0.363120  -0.118727      -0.241667   -0.075755
# ...         ...         ...        ...            ...         ...
# 20682 -0.301205   -0.242915   0.616425      -0.182184   -0.188893
# 20683 -0.646154   -0.182813  -0.241252      -0.658054   -0.075755
# 20684 -0.186222   -0.663633  -0.057464      -0.539087   -0.584877
# 20685 -0.128731   -0.182813  -0.363777      -0.420119   -0.358601
# 20686 -0.186222   -0.543428   0.003798      -0.420119   -0.528308
#
#        Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                 CB  1.834957             1.789172             -1.789172
# 1                 CB  3.365907            -0.558918              0.558918
# 2                 CB  3.365907            -0.558918              0.558918
# 3                 CB  2.515379            -0.558918              0.558918
# 4                 CB  2.770538             1.789172             -1.789172
# ...              ...       ...                  ...                   ...
# 20682             CB  0.218953            -0.558918              0.558918
# 20683             CB -1.652209            -0.558918              0.558918
# 20684             CB -1.907368            -0.558918              0.558918
# 20685             CB -1.992421             1.789172             -1.789172
# 20686             CB -3.183160            -0.558918              0.558918
#
#              Bmi
# 0      23.495549
# 1      22.377775
# 2      23.598381
# 3      23.752331
# 4      22.377775
# ...          ...
# 20682  24.075474
# 20683  21.132713
# 20684  20.233553
# 20685  23.702162
# 20686  23.924858
#
# [20687 rows x 52 columns]

# %%
Def_detailed_features = ['Weak Foot', 'Skill Moves', 'Height', 'Weight','Bmi', 'Crossing', 'Finishing',
       'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
       'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle']

# %%
X = centrebacks_df[Def_detailed_features].to_numpy()
y = centrebacks_df["Ovr_pot"].to_numpy()
# define feature selection
fs = SelectKBest(score_func=f_regression, k = 10)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
np.sort(fs.scores_)
# Out:
# array([3.65345458e+01, 5.69809956e+01, 3.27125902e+02, 3.33799277e+02,
#        3.94357894e+02, 4.06366012e+02, 4.20283099e+02, 5.74432383e+02,
#        1.00840274e+03, 1.08777661e+03, 1.25534166e+03, 1.30754510e+03,
#        1.31132367e+03, 1.48923981e+03, 1.65545309e+03, 1.82432936e+03,
#        1.93064956e+03, 1.96564543e+03, 2.04720323e+03, 2.23125685e+03,
#        3.29979350e+03, 4.40809608e+03, 4.78511333e+03, 5.21453946e+03,
#        9.82067628e+03, 1.13220423e+04, 1.15921133e+04, 1.40356844e+04,
#        1.65498676e+04, 2.95708181e+04, 3.14012974e+04, 3.48146197e+04,
#        4.66352331e+04, 6.80187994e+04])

# %%
Def_essential_ft = list(fs.get_feature_names_out(Def_detailed_features))
Def_essential_ft
# Out:
# ['HeadingAccuracy',
#  'ShortPassing',
#  'LongPassing',
#  'BallControl',
#  'Reactions',
#  'Aggression',
#  'Interceptions',
#  'Composure',
#  'StandingTackle',
#  'SlidingTackle']

# %% [markdown]
# # Fullbacks

# %%
fullbacks_df = F_norm_df[(F_norm_df["Best Position"] == "LB") | (F_norm_df["Best Position"] == "RB") | (F_norm_df["Best Position"] == "LWB") | (F_norm_df["Best Position"] == "RWB")]
fullbacks_df  = fullbacks_df.reset_index(drop = True)
fullbacks_df
# Out:
#            ID          Name       Age Nationality   Overall  Potential  \
# 0      197445      D. Alaba -0.166257     Austria  2.786419   2.854206
# 1      203551   A. Florenzi  0.041668       Italy  2.212450   2.188724
# 2      163631     L. Baines  1.289216     England  2.355942   1.855983
# 3      189332    Jordi Alba  0.457517       Spain  2.786419   2.355094
# 4      146530    Dani Alves  1.705065      Brazil  2.499435   2.022353
# ...       ...           ...       ...         ...       ...        ...
# 13591  248815     K. Berkoe -1.205880     England -1.948825  -1.138688
# 13592  261549    B. Ganesan -1.205880       India -2.666287  -1.804170
# 13593  260767      Z. Bello -1.621729   Australia -2.379302  -0.306835
# 13594  252466   21 D. Bouah -1.413805       Italy -2.522794  -0.805947
# 13595  260623  21 M. Wright  1.705065     England -2.809779  -4.133359
#
#                     Club   Value  Weak Foot  Skill Moves  ...  GKDiving  \
# 0      FC Bayern München  41.500   1.552616     0.792811  ... -0.646154
# 1                   Roma  20.500   0.053943     0.792811  ... -0.416188
# 2                Everton  14.500   0.053943     0.792811  ... -0.473679
# 3           FC Barcelona  31.500   0.053943     0.792811  ... -0.186222
# 4               Juventus  12.500   0.053943     0.792811  ... -0.646154
# ...                  ...     ...        ...          ...  ...       ...
# 13591       Salford City   0.210   0.053943    -0.504570  ... -0.416188
# 13592      Chennaiyin FC   0.110   0.053943    -0.504570  ... -0.128731
# 13593  Melbourne Victory   0.120   0.053943    -0.504570  ... -0.531171
# 13594               Roma   0.110  -1.444731    -0.504570  ... -0.128731
# 13595       Crawley Town   0.025  -2.943404    -0.504570  ... -0.128731
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes  Best Position  \
# 0       -0.543428  -0.118727      -0.063216   -0.415170             LB
# 1       -0.483325  -0.363777      -0.301151   -0.358601             RB
# 2       -0.062607  -0.363777      -0.182184   -0.245462            LWB
# 3       -0.062607  -0.179990      -0.598570   -0.188893            LWB
# 4       -0.303018  -0.425040      -0.598570   -0.528308            RWB
# ...           ...        ...            ...         ...            ...
# 13591   -0.543428  -0.547565      -0.479603   -0.188893             LB
# 13592   -0.303018  -0.179990      -0.598570   -0.584877             RB
# 13593   -0.423223  -0.547565      -0.479603   -0.415170             RB
# 13594   -0.663633  -0.302515      -0.182184   -0.302032             RB
# 13595   -0.423223  -0.118727      -0.479603   -0.641446             LB
#
#         Ovr_pot  Preferred Foot_Left  Preferred Foot_Right        Bmi
# 0      3.110749             1.789172             -1.789172  23.430985
# 1      2.430326            -0.558918              0.558918  22.503074
# 2      2.345273             1.789172             -1.789172  24.119543
# 3      2.855590             1.789172             -1.789172  23.493061
# 4      2.515379            -0.558918              0.558918  22.807169
# ...         ...                  ...                   ...        ...
# 13591 -1.737262             1.789172             -1.789172  20.515086
# 13592 -2.502738            -0.558918              0.558918  19.814053
# 13593 -1.567157            -0.558918              0.558918  21.857278
# 13594 -1.907368            -0.558918              0.558918  23.620288
# 13595 -3.778530             1.789172             -1.789172  25.564954
#
# [13596 rows x 52 columns]

# %%
Def_detailed_features = ['Weak Foot', 'Skill Moves', 'Height', 'Weight','Bmi', 'Crossing', 'Finishing',
       'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
       'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle']

# %%
X = fullbacks_df[Def_detailed_features].to_numpy()
y = fullbacks_df["Ovr_pot"].to_numpy()
# define feature selection
fs = SelectKBest(score_func=f_regression, k = 10)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
Fullback_essential_ft = list(fs.get_feature_names_out(Def_detailed_features))
Fullback_essential_ft
# Out:
# ['Crossing',
#  'ShortPassing',
#  'Dribbling',
#  'LongPassing',
#  'BallControl',
#  'Reactions',
#  'Interceptions',
#  'Composure',
#  'StandingTackle',
#  'SlidingTackle']

# %% [markdown]
# # Goalkeeper

# %%
gk_df = F_norm_df[(F_norm_df["Best Position"] == "GK")]
gk_df  = gk_df.reset_index(drop = True)
gk_df
# Out:
#            ID              Name       Age Nationality   Overall  Potential  \
# 0      230167     Mateus Tangil  0.665442      Brazil  0.060066  -0.805947
# 1      230318     Nelsildo Reis  0.665442      Brazil  1.351496   0.691388
# 2      167495          M. Neuer  1.081291     Germany  3.647373   3.353318
# 3      230171   Carlos Travisso  1.497140      Brazil -0.513903  -1.471429
# 4      230322      Teixe Gaúcho  0.665442      Brazil -1.374856  -2.469653
# ...       ...               ...       ...         ...       ...        ...
# 10885  251433           B. Voll -0.997955     Germany -1.231364  -0.473206
# 10886  240558     18 L. Clayton -1.621729     England -1.948825  -0.306835
# 10887  262846          �. Dobre -0.997955     Romania -1.948825  -1.471429
# 10888  241317    21 Xue Qinghao -1.205880    China PR -2.809779  -1.970541
# 10889  259646         A. Shaikh -1.413805       India -2.809779  -0.805947
#
#                         Club   Value  Weak Foot  Skill Moves  ...  GKDiving  \
# 0           Atlético Mineiro   0.625   0.053943    -1.801951  ...  2.860822
# 1              Internacional   4.600   0.053943    -1.801951  ...  3.435736
# 2          FC Bayern München  69.500   1.552616    -1.801951  ...  4.183124
# 3                   Botafogo   0.250   0.053943    -1.801951  ...  2.975805
# 4                Ponte Preta   0.100  -1.444731    -1.801951  ...  3.090788
# ...                      ...     ...        ...          ...  ...       ...
# 10885     F.C. Hansa Rostock   0.375  -1.444731    -1.801951  ...  2.458382
# 10886        Cheltenham Town   0.100  -1.444731    -1.801951  ...  2.228417
# 10887  FC Academica Clinceni   0.180  -1.444731    -1.801951  ...  2.343399
# 10888    Shanghai Shenhua FC   0.100  -1.444731    -1.801951  ...  1.883468
# 10889     ATK Mohun Bagan FC   0.110   0.053943    -1.801951  ...  1.883468
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes  Best Position  \
# 0        3.122829   2.883143       2.851492    3.148685             GK
# 1        3.663752   3.740820       3.565298    3.261823             GK
# 2        4.445085   4.843547       4.457556    4.110360             GK
# 3        1.620264   2.944405       2.851492    3.148685             GK
# 4        2.341495   2.331779       1.483364    2.582993             GK
# ...           ...        ...            ...         ...            ...
# 10885    2.642008   2.454304       2.316138    2.526424             GK
# 10886    2.281393   2.209254       2.018719    2.413286             GK
# 10887    2.161187   2.270516       1.899751    2.356717             GK
# 10888    1.920777   1.780415       1.304912    2.017302             GK
# 10889    1.500059   1.412839       1.721299    1.847595             GK
#
#         Ovr_pot  Preferred Foot_Left  Preferred Foot_Right        Bmi
# 0     -0.376417            -0.558918              0.558918  24.009113
# 1      1.154534            -0.558918              0.558918  24.248069
# 2      3.876224            -0.558918              0.558918  24.709662
# 3     -1.056840            -0.558918              0.558918  23.012574
# 4     -2.077473            -0.558918              0.558918  23.238767
# ...         ...                  ...                   ...        ...
# 10885 -0.971787            -0.558918              0.558918  22.353715
# 10886 -1.311998            -0.558918              0.558918  22.634676
# 10887 -1.907368            -0.558918              0.558918  22.850462
# 10888 -2.672843            -0.558918              0.558918  21.913580
# 10889 -2.077473            -0.558918              0.558918  21.389756
#
# [10890 rows x 52 columns]

# %%
Gk_detailed_features = ['Height', 'Weight','Bmi', 'ShortPassing', 'Volleys', 'Curve','Agility', 'Reactions', 'Balance',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
        'Positioning', 'Vision', 'Composure','GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
gk_df[gk_df["ID"]==167495]
# Out:
#           ID       Name       Age Nationality   Overall  Potential  \
# 2     167495   M. Neuer  1.081291     Germany  3.647373   3.353318
# 1995  167495   M. Neuer  1.289216     Germany  3.647373   3.353318
# 4040  167495   M. Neuer  1.497140     Germany  3.073404   2.687836
# 6098  167495   M. Neuer  1.705065     Germany  3.216896   2.854206
# 7744  167495   M. Neuer  1.912989     Germany  3.216896   2.854206
# 9346  167495   M. Neuer  2.120914     Germany  3.360388   3.020577
#
#                    Club  Value  Weak Foot  Skill Moves  ...  GKDiving  \
# 2     FC Bayern München   69.5   1.552616    -1.801951  ...  4.183124
# 1995  FC Bayern München   61.0   1.552616    -1.801951  ...  4.298107
# 4040  FC Bayern München   34.0   1.552616    -1.801951  ...  4.125633
# 6098  FC Bayern München   36.0   1.552616    -1.801951  ...  4.068142
# 7744  FC Bayern München   29.0   1.552616    -1.801951  ...  4.068142
# 9346  FC Bayern München   13.5   1.552616    -1.801951  ...  4.125633
#
#       GKHandling  GKKicking  GKPositioning  GKReflexes  Best Position  \
# 2       4.445085   4.843547       4.457556    4.110360             GK
# 1995    4.445085   4.843547       4.457556    4.110360             GK
# 4040    4.204675   4.537234       4.100653    3.997221             GK
# 6098    4.264777   4.598497       4.160137    3.997221             GK
# 7744    4.264777   4.598497       4.160137    4.110360             GK
# 9346    4.324880   4.598497       4.338588    4.053791             GK
#
#        Ovr_pot  Preferred Foot_Left  Preferred Foot_Right        Bmi
# 2     3.876224            -0.558918              0.558918  24.709662
# 1995  3.876224            -0.558918              0.558918  24.709662
# 4040  3.195802            -0.558918              0.558918  24.709662
# 6098  3.365907            -0.558918              0.558918  24.709662
# 7744  3.365907            -0.558918              0.558918  24.709662
# 9346  3.536013            -0.558918              0.558918  24.967113
#
# [6 rows x 52 columns]

# %%
X = gk_df[Gk_detailed_features].to_numpy()
y = gk_df["Ovr_pot"].to_numpy()
# define feature selection
fs = SelectKBest(score_func=f_regression, k = 10)
# apply feature selection
X_selected = fs.fit_transform(X, y)

# %%
Gk_essential_ft = list(fs.get_feature_names_out(Gk_detailed_features))
Gk_essential_ft
# Out:
# ['Agility',
#  'Reactions',
#  'Jumping',
#  'Vision',
#  'Composure',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes']

# %% [markdown]
# # Finalizing all dataframes

# %%
# gk_df=gk_df[Gk_essential_ft]
# fullbacks_df = fullbacks_df[Fullback_essential_ft]
# centrebacks_df = centrebacks_df[Def_essential_ft]
# cam_df = cam_df[Cam_essential_ft]
# mids_df = mids_df[Mid_essential_ft]
# wingers_df = wingers_df[Wing_essential_ft]
# striker_df= striker_df[ST_essential_ft]

# %%
# F_all_df["Club"].unique().shape

# %%
# F_all_df[(F_all_df["Club"] == "Manchester United")].columns

# %%
all_clubs = list(F_all_df["Club"].unique())

# %%
all_clubs
# Out:
# ['FC Barcelona',
#  'Roma',
#  'FC Bayern München',
#  'Manchester United',
#  'Real Madrid',
#  'Everton',
#  'Juventus',
#  'Shakhtar Donetsk',
#  'AS Monaco',
#  'VfL Wolfsburg',
#  'Milan',
#  'Olympique de Marseille',
#  'Olympique Lyonnais',
#  'Beşiktaş JK',
#  'Manchester City',
#  'Liverpool',
#  'FC Rostov',
#  'Tottenham Hotspur',
#  'Sporting CP',
#  'Arsenal',
#  'Paris Saint-Germain',
#  'Napoli',
#  nan,
#  'FC Schalke 04',
#  'OGC Nice',
#  'SL Benfica',
#  'Borussia Dortmund',
#  'UD Las Palmas',
#  'FC Porto',
#  'Lazio',
#  'Borussia Mönchengladbach',
#  'PFC CSKA Moscow',
#  'Chievo Verona',
#  'Chelsea',
#  'Leicester City',
#  'Lokomotiv Moscow',
#  'Atlético Madrid',
#  'Sevilla FC',
#  'Crystal Palace',
#  'Chicago Fire',
#  'Genoa',
#  'Bournemouth',
#  'Club Athletico Paranaense',
#  'Athletic Club de Bilbao',
#  'Montpellier HSC',
#  'West Ham United',
#  'SV Werder Bremen',
#  'Villarreal CF',
#  'Zenit St. Petersburg',
#  '1. FC Köln',
#  'Stoke City',
#  'Inter',
#  'Valencia CF',
#  'Southampton',
#  'Watford',
#  'Club Brugge KV',
#  'FC Krasnodar',
#  'LOSC Lille',
#  'Feyenoord',
#  'RC Celta',
#  'Toronto FC',
#  'AS Saint-Étienne',
#  'RSC Anderlecht',
#  'Spartak Moscow',
#  'PSV',
#  'Udinese',
#  'Ajax',
#  'San Lorenzo de Almagro',
#  'Hamburger SV',
#  'Trabzonspor',
#  'Fiorentina',
#  'Grêmio',
#  'Aston Villa',
#  'Torino',
#  'Burnley',
#  'Montreal Impact',
#  'Standard de Liège',
#  'Swansea City',
#  'Hertha BSC',
#  'Monterrey',
#  'Racing Club',
#  'KAA Gent',
#  'Universidad de Chile',
#  'FC Basel 1893',
#  'Sunderland',
#  'TSG 1899 Hoffenheim',
#  'Bayer 04 Leverkusen',
#  'Granada CF',
#  'Vitória Guimarães',
#  'Deportivo de La Coruña',
#  'Birmingham City',
#  'Bologna',
#  'Club Atlético Lanús',
#  'Internacional',
#  'Osmanlıspor',
#  'VfB Stuttgart',
#  'SV Darmstadt 98',
#  'Toulouse Football Club',
#  '1. FSV Mainz 05',
#  'Levante UD',
#  'Fenerbahçe SK',
#  'Malmö FF',
#  'FC Sion',
#  'Vitesse',
#  'Cagliari',
#  'LA Galaxy',
#  'Norwich City',
#  'Legia Warszawa',
#  'Guadalajara',
#  'Tigres U.A.N.L.',
#  'Newcastle United',
#  'Angers SCO',
#  'Rosenborg BK',
#  'FC Utrecht',
#  'Fluminense',
#  'Sampdoria',
#  'Al Ahli',
#  'Galatasaray SK',
#  'Bursaspor',
#  'Medipol Başakşehir FK',
#  'RCD Espanyol',
#  'Seattle Sounders FC',
#  'SD Eibar',
#  'Atiker Konyaspor',
#  'Al Nassr',
#  'Sheffield Wednesday',
#  'Real Betis',
#  'FC Dallas',
#  'FC Augsburg',
#  'Kawasaki Frontale',
#  'Derby County',
#  'Huddersfield Town',
#  'Rubin Kazan',
#  'Boca Juniors',
#  'Atalanta',
#  'Vissel Kobe',
#  'Sporting Kansas City',
#  'Stade Rennais FC',
#  'FC St. Gallen',
#  'Sassuolo',
#  'Universidad Católica',
#  'Málaga CF',
#  'Joinville',
#  'RB Leipzig',
#  'FC Ingolstadt 04',
#  'Deportivo Alavés',
#  'Hull City',
#  'Çaykur Rizespor',
#  'Olympiacos CFP',
#  'Colo-Colo',
#  'CD Leganés',
#  'Club América',
#  'Antalyaspor',
#  'Kayserispor',
#  'Clube Sport Marítimo',
#  'Middlesbrough',
#  'Independiente',
#  'Getafe CF',
#  'Palmeiras',
#  'Panathinaikos FC',
#  'CA Osasuna',
#  'Hellas Verona',
#  'AZ Alkmaar',
#  'Real Sociedad',
#  'West Bromwich Albion',
#  'FC Metz',
#  'FC Girondins de Bordeaux',
#  'Al Hilal',
#  'Club León',
#  'IF Elfsborg',
#  'Gimnàstic de Tarragona',
#  'Brescia',
#  'Colorado Rapids',
#  'En Avant de Guingamp',
#  'PAOK',
#  'Kasimpaşa SK',
#  'KV Oostende',
#  'Philadelphia Union',
#  'Goiás',
#  'Reading',
#  'Eintracht Braunschweig',
#  'KRC Genk',
#  'Deportivo Toluca',
#  'Empoli',
#  'Djurgårdens IF',
#  'River Plate',
#  'Santos',
#  'Eintracht Frankfurt',
#  'U.N.A.M.',
#  'Orlando Pirates',
#  'Kalmar FF',
#  'Once Caldas',
#  'Brighton & Hove Albion',
#  'Club Tijuana',
#  'New York City FC',
#  'Al Shabab',
#  'Independiente Medellín',
#  'Pogoń Szczecin',
#  'Odds BK',
#  'Sporting Club de Bastia',
#  'Sangju Sangmu FC',
#  'Fulham',
#  'Cesena',
#  'Pachuca',
#  'Akhisar Belediyespor',
#  'Strømsgodset IF',
#  'Football Bourg En Bresse Peronnas 01',
#  'FC Ufa',
#  'New York Red Bulls',
#  'SC Braga',
#  'Atlético Nacional',
#  'Santos Laguna',
#  'América FC (Minas Gerais)',
#  'Gimnasia y Esgrima La Plata',
#  'Jeju United FC',
#  'Stade Malherbe Caen',
#  'FC Paços de Ferreira',
#  'Vitória',
#  'Rayo Vallecano',
#  'Pohang Steelers',
#  'Brøndby IF',
#  'Kashiwa Reysol',
#  'Estudiantes de La Plata',
#  'Bolton Wanderers',
#  'Lech Poznań',
#  "Newell's Old Boys",
#  'Elche CF',
#  'Northampton Town',
#  'Gençlerbirliği SK',
#  'Hannover 96',
#  'Columbus Crew SC',
#  'Tiburones Rojos de Veracruz',
#  'Celtic',
#  'Jaguares de Chiapas',
#  'Rionegro Águilas',
#  'SC Freiburg',
#  'VfL Bochum 1848',
#  'Gamba Osaka',
#  'PEC Zwolle',
#  'Portland Timbers',
#  'Rio Ave FC',
#  'Botafogo',
#  'Kaizer Chiefs',
#  'FC Lorient',
#  'CD Tenerife',
#  'Club Atlas',
#  '1. FC Union Berlin',
#  'FC Nantes',
#  'Amkar Perm',
#  'US Salernitana 1919',
#  'Atlético Mineiro',
#  'Terek Grozny',
#  'Ternana',
#  'Pescara',
#  'SC Heerenveen',
#  'Bristol City',
#  'Inverness Caledonian Thistle',
#  'Alanyaspor',
#  'FC Groningen',
#  'UD Almería',
#  'Vancouver Whitecaps FC',
#  'Dijon FCO',
#  'Vitória de Setúbal',
#  'Sport Club do Recife',
#  'ADO Den Haag',
#  'FC København',
#  'Moreirense FC',
#  'SD Huesca',
#  'Coritiba',
#  'CD Numancia',
#  'Kardemir Karabükspor',
#  'Palermo',
#  'Crotone',
#  'Wellington Phoenix',
#  'Orlando City SC',
#  'Real Sporting de Gijón',
#  'Brentford',
#  'Albirex Niigata',
#  'New England Revolution',
#  'RC Strasbourg Alsace',
#  'Trapani',
#  'Defensa y Justicia',
#  'Nottingham Forest',
#  'Stade Lavallois Mayenne FC',
#  'Real Zaragoza',
#  'Os Belenenses',
#  'CD Mirandés',
#  'FC Red Bull Salzburg',
#  'São Paulo',
#  'Girona FC',
#  'Wolverhampton Wanderers',
#  'Perth Glory',
#  'Querétaro',
#  'KV Kortrijk',
#  'Junior FC',
#  'Arsenal Tula',
#  'Stade de Reims',
#  '1. FC Nürnberg',
#  'RCD Mallorca',
#  'CD Feirense',
#  'Boavista FC',
#  'Monarcas Morelia',
#  'KVC Westerlo',
#  'Preston North End',
#  'Grasshopper Club Zürich',
#  'Sporting de Charleroi',
#  'Bari',
#  'Urawa Red Diamonds',
#  'FC Orenburg',
#  'Millonarios FC',
#  'Leeds United',
#  'Estoril Praia',
#  'Godoy Cruz',
#  'SV Zulte-Waregem',
#  'Korona Kielce',
#  'Gaziantepspor',
#  'Fortuna Düsseldorf',
#  'GD Chaves',
#  'Jagiellonia Białystok',
#  'FC Erzgebirge Aue',
#  'Cardiff City',
#  'Racing Club de Lens',
#  'DSC Arminia Bielefeld',
#  'Atlético Bucaramanga',
#  'Heracles Almelo',
#  'FC Arouca',
#  'Sint-Truidense VV',
#  'Plymouth Argyle',
#  'Rosario Central',
#  'SG Dynamo Dresden',
#  'DC United',
#  'Port Vale',
#  'FC Ural Yekaterinburg',
#  'Sporting Lokeren',
#  'Melbourne City FC',
#  'Ulsan Hyundai FC',
#  'Aarhus GF',
#  'FC Seoul',
#  'Cruz Azul',
#  'KV Mechelen',
#  'Cruzeiro',
#  'Sheffield United',
#  'Bury',
#  'AS Nancy Lorraine',
#  'St. Johnstone FC',
#  'FC St. Pauli',
#  'Independiente Santa Fe',
#  'Club Atlético Huracán',
#  'Karlsruher SC',
#  'Sydney FC',
#  'Carpi',
#  'Valenciennes FC',
#  'Jeonbuk Hyundai Motors',
#  'Chamois Niortais Football Club',
#  'Figueirense',
#  'Aalborg BK',
#  'Pisa',
#  'San Luis de Quillota',
#  'Real Valladolid CF',
#  'La Equidad',
#  'CD Universidad de Concepción',
#  'Bristol Rovers',
#  'Club Atlético Talleres',
#  'FC Pro Vercelli 1892',
#  'CD Tondela',
#  'CD Nacional',
#  'Houston Dynamo',
#  'IFK Göteborg',
#  'Kashima Antlers',
#  'Unión Española',
#  '1. FC Kaiserslautern',
#  'Suwon Samsung Bluewings',
#  'Gillingham',
#  'FC Twente',
#  'Nîmes Olympique',
#  'Dundee FC',
#  'FC Midtjylland',
#  'SK Brann',
#  'Seongnam FC',
#  'SK Rapid Wien',
#  'Cracovia',
#  'FC Würzburger Kickers',
#  'Puebla FC',
#  'Silkeborg IF',
#  'Wisła Kraków',
#  'Omiya Ardija',
#  'Wolfsberger AC',
#  'Ascoli',
#  'TSV 1860 München',
#  'FK Austria Wien',
#  'Club Atlético Aldosivi',
#  'Cádiz CF',
#  'Real Oviedo',
#  'Brisbane Roar',
#  'Vasco da Gama',
#  'Rangers FC',
#  'Excelsior',
#  'Real Salt Lake',
#  'UCAM Murcia CF',
#  'BK Häcken',
#  'AC Ajaccio',
#  'Vålerenga Fotball',
#  'Deportivo Cali',
#  'Ipswich Town',
#  'Benevento',
#  'Molde FK',
#  'BSC Young Boys',
#  'Sparta Rotterdam',
#  'SPAL',
#  'Santa Cruz',
#  'Viking FK',
#  'Millwall',
#  'Unión de Santa Fe',
#  'Grimsby Town',
#  'Santiago Wanderers',
#  'Willem II',
#  'Suwon FC',
#  'Lechia Gdańsk',
#  'Fleetwood Town',
#  'Club Atlético Sarmiento',
#  'Notts County',
#  'Blackburn Rovers',
#  'Jeonnam Dragons',
#  'Deportivo Pasto',
#  'Perugia',
#  'Southend United',
#  'Zagłębie Lubin',
#  'Queens Park Rangers',
#  'Ponte Preta',
#  'Novara',
#  'Patriotas Boyacá FC',
#  'Adanaspor',
#  'FC Tokyo',
#  'Wigan Athletic',
#  'SpVgg Greuther Fürth',
#  'Júbilo Iwata',
#  'Avellino',
#  'Club Atlético Banfield',
#  'FC Sochaux-Montbéliard',
#  'Criciúma',
#  'Hamilton Academical FC',
#  'Waasland-Beveren',
#  'Chapecoense',
#  'Córdoba CF',
#  'Sanfrecce Hiroshima',
#  'FC Tom Tomsk',
#  'CD Lugo',
#  'FC Vaduz',
#  'Belgrano de Córdoba',
#  'Charlton Athletic',
#  'FC Lausanne-Sport',
#  'Heart of Midlothian',
#  'Aalesunds FK',
#  'SønderjyskE',
#  'Bruk-Bet Termalica Nieciecza',
#  'Frosinone',
#  'Shrewsbury',
#  'Stade Brestois 29',
#  'Jaguares de Córdoba',
#  'Club Atlético Tigre',
#  'NEC Nijmegen',
#  'AIK',
#  'Melbourne Victory',
#  'Barnsley',
#  'GFC Ajaccio',
#  'Vicenza',
#  'Deportes Tolima',
#  'ESTAC Troyes',
#  'Go Ahead Eagles',
#  'Al Fateh',
#  'Al Taawoun',
#  '1. FC Heidenheim 1846',
#  'Adelaide United',
#  'Deportes Iquique',
#  'Lillestrøm SK',
#  'Club Atlético Colón',
#  'Spezia',
#  'FC Admira Wacker Mödling',
#  'Atlético Tucumán',
#  'FC Anzhi Makhachkala',
#  'FK Haugesund',
#  'Rotherham United',
#  'Hammarby IF',
#  'KAS Eupen',
#  'US Orléans Loiret Football',
#  'Club Atlético Temperley',
#  'Clermont Foot 63',
#  'Club Olimpo',
#  'AD Alcorcón',
#  'Audax Italiano',
#  'Milton Keynes Dons',
#  'Roda JC Kerkrade',
#  'FC Lugano',
#  'Coventry City',
#  'Oxford United',
#  'Cortuluá',
#  'Western Sydney Wanderers',
#  'Club Necaxa',
#  'Bradford City',
#  'Vélez Sarsfield',
#  'Al Ittihad',
#  'Rochdale',
#  'Nagoya Grampus',
#  'Colchester United',
#  'Östersunds FK',
#  'CF Reus Deportiu',
#  'Piast Gliwice',
#  'Aberdeen',
#  'CD Huachipato',
#  'Lyngby BK',
#  'SCR Altach',
#  'Esbjerg fB',
#  'SV Mattersburg',
#  'Ettifaq FC',
#  'Al Qadisiyah',
#  'Wisła Płock',
#  'Sagan Tosu',
#  'HJK Helsinki',
#  'IFK Norrköping',
#  'Latina',
#  'Mansfield Town',
#  'SV Ried',
#  'Blackpool',
#  'Yokohama F. Marinos',
#  'Avaí FC',
#  'SK Sturm Graz',
#  'Incheon United FC',
#  'Red Star FC',
#  'Sarpsborg 08 FF',
#  'Cittadella',
#  'Arsenal de Sarandí',
#  'GwangJu FC',
#  'Ross County FC',
#  'Leyton Orient',
#  'Scunthorpe United',
#  'Randers FC',
#  'Doncaster Rovers',
#  'Sevilla Atlético',
#  'Odense Boldklub',
#  'FC Thun',
#  'Atlético de Rafaela',
#  'Morecambe',
#  'Burton Albion',
#  'Helsingborgs IF',
#  'Stabæk Fotball',
#  'San Jose Earthquakes',
#  'Oldham Athletic',
#  'Walsall',
#  'FC Luzern',
#  'Tromsø IL',
#  'CD Antofagasta',
#  'Ventforet Kofu',
#  'Quilmes Atlético Club',
#  'SV Sandhausen',
#  'San Martín de San Juan',
#  "CD O'Higgins",
#  'CD Palestino',
#  'Cambridge United',
#  'Örebro SK',
#  'FC Nordsjælland',
#  'Peterborough United',
#  'Portsmouth',
#  'Le Havre AC',
#  'Jönköpings Södra IF',
#  'Śląsk Wrocław',
#  'Royal Excel Mouscron',
#  'Kilmarnock',
#  'Al Khaleej',
#  'Cork City',
#  'Atlético Huila',
#  'Stevenage',
#  'Krylya Sovetov Samara',
#  'AC Horsens',
#  'Swindon Town',
#  "St. Patrick's Athletic",
#  'Chesterfield',
#  'Wycombe Wanderers',
#  'Partick Thistle FC',
#  'Amiens SC',
#  'Arka Gdynia',
#  'Górnik Łęczna',
#  'Patronato',
#  'AJ Auxerre',
#  'Sligo Rovers',
#  'GIF Sundsvall',
#  'CD Everton de Viña del Mar',
#  'Motherwell',
#  'Crewe Alexandra',
#  'Luton Town',
#  'Al Wehda',
#  'AFC Wimbledon',
#  'IK Start',
#  'Sogndal Fotball',
#  'Tours FC',
#  'Alianza Petrolera',
#  'Boyacá Chicó FC',
#  'Vegalta Sendai',
#  'Virtus Entella',
#  'Al Faisaly',
#  'Dundalk',
#  'CD Cobresal',
#  'Exeter City',
#  'Carlisle United',
#  'Newcastle Jets',
#  'Crawley Town',
#  'Yeovil Town',
#  'FK Bodø/Glimt',
#  'Gefle IF',
#  'Newport County',
#  'Hartlepool United',
#  'Derry City',
#  'Al Raed',
#  'Cheltenham Town',
#  'Central Coast Mariners',
#  'Shamrock Rovers',
#  'Club Deportes Temuco',
#  'Avispa Fukuoka',
#  'Envigado FC',
#  'Falkenbergs FF',
#  'Bray Wanderers',
#  'Viborg FF',
#  'Ruch Chorzów',
#  'Accrington Stanley',
#  'Shonan Bellmare',
#  'Galway United',
#  'SKN St. Pölten',
#  'Fortaleza CEIF',
#  'Al Batin',
#  'Finn Harps',
#  'Barnet',
#  'Bohemian FC',
#  'Longford Town',
#  'Wexford Youths',
#  'AEK Athens',
#  'Lobos BUAP',
#  'Sivasspor',
#  'Royal Antwerp FC',
#  'AFC Eskilstuna',
#  'Dinamo Moscow',
#  'América de Cali',
#  'CD Aves',
#  'Göztepe SK',
#  'NAC Breda',
#  'Atlanta United',
#  'MSV Duisburg',
#  'Parma',
#  'Sparta Praha',
#  'Atlético Clube Goianiense',
#  'VVV-Venlo',
#  'Cultural Leonesa',
#  'Cerezo Osaka',
#  'Hibernian',
#  'US Quevilly Rouen Métropole',
#  'US Cremonese',
#  'Portimonense SC',
#  'FC Tosno',
#  'SSV Jahn Regensburg',
#  'Venezia FC',
#  'Argentinos Juniors',
#  'Minnesota United FC',
#  'La Berrichonne de Châteauroux',
#  'Yeni Malatyaspor',
#  'Foggia',
#  'Sandecja Nowy Sącz',
#  'Albacete BP',
#  'SKA Khabarovsk',
#  '1. FC Magdeburg',
#  'FC Barcelona B',
#  'SC Preußen Münster',
#  'SG Sonnenhof Großaspach',
#  'Holstein Kiel',
#  'Lincoln City',
#  'Sandefjord Fotball',
#  'Al Fayha',
#  'Shimizu S-Pulse',
#  'VfL Osnabrück',
#  'VfL Sportfreunde Lotte',
#  'Gangwon FC',
#  'Ohod Club',
#  'FC Zürich',
#  'Hallescher FC',
#  'Chemnitzer FC',
#  'IK Sirius',
#  'FSV Zwickau',
#  'SV Meppen',
#  'LASK Linz',
#  'SC Paderborn 07',
#  'Hokkaido Consadole Sapporo',
#  'Górnik Zabrze',
#  'SV Werder Bremen II',
#  'FC Rot-Weiß Erfurt',
#  'SC Fortuna Köln',
#  'SpVgg Unterhaching',
#  'Lorca FC',
#  'VfR Aalen',
#  'Curicó Unido',
#  'SV Wehen Wiesbaden',
#  'Hobro IK',
#  'Kristiansund BK',
#  'Paris FC',
#  'FC Hansa Rostock',
#  'Daegu FC',
#  'Chacarita Juniors',
#  'Forest Green Rovers',
#  'Halmstads BK',
#  'FC Carl Zeiss Jena',
#  'Limerick FC',
#  'Drogheda United',
#  'FC Helsingør',
#  'Tigres FC',
#  'Guangzhou Evergrande Taobao FC',
#  'Dalian YiFang FC',
#  'Guangzhou R&F FC',
#  'Shanghai SIPG FC',
#  'Beijing Sinobo Guoan FC',
#  'Hebei China Fortune FC',
#  'Beijing Renhe FC',
#  'Bahia',
#  'Tianjin TEDA FC',
#  'Viktoria Plzeň',
#  'Jiangsu Suning FC',
#  'Dynamo Kyiv',
#  'Shanghai Greenland Shenhua FC',
#  'MKE Ankaragücü',
#  'SK Slavia Praha',
#  'Los Angeles FC',
#  'Shandong Luneng TaiShan FC',
#  'Chongqing Dangdai Lifan FC SWM Team',
#  'Cosenza',
#  'Al Hazem',
#  'Dinamo Zagreb',
#  'Paraná',
#  'Tianjin Quanjian FC',
#  'Padova',
#  'BB Erzurumspor',
#  'Zagłębie Sosnowiec',
#  'Neuchâtel Xamax',
#  'Livorno',
#  'Henan Jianye FC',
#  'Fortuna Sittard',
#  'Grenoble Foot 38',
#  'CF Rayo Majadahonda',
#  'Santa Clara',
#  'FC Emmen',
#  'San Martin de Tucumán',
#  'V-Varen Nagasaki',
#  'Ceará Sporting Club',
#  'St. Mirren',
#  'KSV Cercle Brugge',
#  'Lecce',
#  'Ranheim Fotball',
#  'Unión La Calera',
#  'KFC Uerdingen 05',
#  'Vejle Boldklub',
#  'Livingston FC',
#  'FC Energie Cottbus',
#  'Gyeongnam FC',
#  'AS Béziers',
#  'Extremadura UD',
#  'Miedź Legnica',
#  'Macclesfield Town',
#  'De Graafschap',
#  'Vendsyssel FF',
#  'Tranmere Rovers',
#  'FC Wacker Innsbruck',
#  'Guizhou Hengfeng FC',
#  'Trelleborgs FF',
#  'Dalkurd FF',
#  'Changchun Yatai FC',
#  'IF Brommapojkarna',
#  'Itagüí Leones FC',
#  'TSV Hartberg',
#  'Waterford FC',
#  'CSA - AL',
#  'Olimpia Asunción',
#  'Denizlispor',
#  'Independiente del Valle',
#  'Atlético de San Luis',
#  'LDU Quito',
#  'Shenzhen FC',
#  'Famalicão',
#  'Sol de América',
#  'FC Juárez',
#  'Pordenone',
#  'CFR Cluj',
#  'Fortaleza',
#  'Castellammare di Stabia',
#  'Astra Giurgiu',
#  'Universitatea Craiova',
#  'FC Cincinnati',
#  'Flamengo',
#  'Peñarol',
#  'Nacional de Montevideo',
#  'Deportivo Binacional',
#  'Club Bolívar',
#  'Central Córdoba',
#  'Al Ain FC',
#  'Club Libertad',
#  'FCSB (Steaua)',
#  'FC Viitorul',
#  'SD Ponferradina',
#  'RKC Waalwijk',
#  'Wuhan Zall',
#  'Gil Vicente FC',
#  'Gazişehir Gaziantep F.K.',
#  'FC Botoşani',
#  'CF Fuenlabrada',
#  'UE Llagostera',
#  'Oriente Petrolero',
#  'Western United FC',
#  'Damac FC',
#  'Barcelona Sporting Club',
#  'Catania',
#  'Sepsi OSK',
#  'Club Guaraní',
#  'Salford City',
#  'Real Madrid Castilla',
#  'Raków Częstochowa',
#  'Delfín SC',
#  'Sport Huancayo',
#  'Kuban Krasnodar',
#  'SV Waldhof Mannheim',
#  'Unión Magdalena',
#  'Melgar FBC',
#  'SD Aucas',
#  'Nacional Asunción',
#  'Politehnica Iaşi',
#  'Coquimbo Unido',
#  'Alianza Lima',
#  'Emelec',
#  'Bayern München II',
#  'FC Voluntari',
#  'Viktoria Köln',
#  'Servette FC',
#  'Club Atlético Grau',
#  'Dinamo Bucureşti',
#  'Gaz Metan Mediaş',
#  'Liverpool Fútbol Club',
#  'Racing Santander',
#  'Le Mans FC',
#  'Jorge Wilstermann',
#  'Club Plaza Colonia',
#  'Cusco FC',
#  'Mjøndalen IF',
#  'Oita Trinita',
#  'AC Arles Avignon',
#  'River Plate Montevideo',
#  'El Nacional',
#  'FC Chambly Oise',
#  'Matsumoto Yamaga',
#  'Chindia Târgovişte',
#  'Nacional Potosí',
#  'Corinthians',
#  'Universidad Católica del Ecuador',
#  'WSG Tirol',
#  'Daejeon Citizen',
#  'Centro Atlético Fénix',
#  'Academica Clinceni',
#  'Always Ready',
#  'Abha Club',
#  'Associação Académica de Coimbra',
#  'Dundee United',
#  'Como',
#  'Al Adalah',
#  'River Plate Asunción',
#  'FC Hermannstadt',
#  'Club Blooming',
#  'UC AlbinoLeffe',
#  'Estudiantes de Mérida',
#  'Caracas FC',
#  'AC Mineros de Guayana',
#  'LKS Lodz',
#  'Rodez Aveyron Football',
#  'Rangers de Talca',
#  'Aragua FC',
#  'Grosseto',
#  'UCD AFC',
#  'Llaneros de Guanare',
#  'Estudiantes Tecos',
#  'Lierse SK',
#  'Dynamo České Budějovice',
#  'Cúcuta Deportivo',
#  'Leones Negros de la UdeG',
#  '111648',
#  'Åtvidabergs FF',
#  'Sportivo Luqueño',
#  'Mersin İdman Yurdu',
#  'GKS Bełchatów',
#  'Zamora FC',
#  'Clube Náutico Capibaribe',
#  'Najran SC',
#  'Sandnes Ulf',
#  'RC Recreativo de Huelva',
#  'Torquay United',
#  'Podbeskidzie Bielsko-Biała',
#  'Al Nahdha Dammam',
#  'US Créteil-Lusitanos',
#  'Atlante',
#  'UD Vecindario',
#  'FC Cartagena',
#  'Arezzo',
#  'Inter Miami',
#  'AC Monza',
#  'Fatih Karagümrük S.K.',
#  'Qingdao Huanghai F.C.',
#  'Shijiazhuang Ever Bright F.C.',
#  'Farense',
#  'Hatayspor',
#  'Oceânico FC',
#  'Mazatlán FC',
#  'Beerschot AC',
#  'C.D. Castellón',
#  'VfB Lübeck',
#  'Oud-Heverlee Leuven',
#  'Volga Nizhny Novgorod',
#  'UD Logroñés',
#  'Busan IPark',
#  'Nashville SC',
#  'Pau FC',
#  'Dorados de Sinaloa',
#  'Yokohama FC',
#  'CE Sabadell FC',
#  'Stal Mielec',
#  'UTA Arad',
#  'Barrow',
#  '1. FC Saarbrücken',
#  'Macarthur FC',
#  'Türkgücü München',
#  'Harrogate Town',
#  'Mjällby AIF',
#  'FC Argeș',
#  'SC Verl',
#  '113974',
#  'Varbergs BoIS',
#  'USL Dunkerque',
#  'Alemannia Aachen',
#  'Shelbourne FC',
#  'Hércules CF',
#  '114912',
#  'Warta Poznań',
#  'União de Leiria',
#  'Siena',
#  'Santo André',
#  'KSV 1919',
#  'CF Estrela da Amadora',
#  'CD Trofense',
#  'Sakaryaspor',
#  'Atlético de Madrid',
#  'Real Madrid CF',
#  'Real Betis Balompié',
#  'AC Milan',
#  'Beijing Guoan FC',
#  'Unión Deportiva Almería',
#  'Shanghai Port FC',
#  'Montpellier Hérault SC',
#  'Levante Unión Deportiva',
#  'RB Bragantino',
#  'Unión Deportiva Las Palmas',
#  'Guangzhou City',
#  'Jiangsu FC',
#  'Udinese Calcio',
#  'Shanghai Shenhua FC',
#  'TSG Hoffenheim',
#  'Torino F.C.',
#  'Guangzhou FC',
#  'RCD Espanyol de Barcelona',
#  'Club Olimpia',
#  'RC Celta de Vigo',
#  'Inter Miami CF',
#  'Al Ain',
#  'Spartak Moskva',
#  'Gallos Blancos de Querétaro',
#  'Sport-Club Freiburg',
#  'Hebei FC',
#  'Adana Demirspor',
#  'Club Atlético Independiente',
#  'İstanbul Başakşehir FK',
#  'Clube Atlético Mineiro',
#  'CF Monterrey ',
#  'F.C. København',
#  'FC Lokomotiv Moscow',
#  'U.C. Sampdoria',
#  'AFC Bournemouth',
#  'Fútbol Club Juárez',
#  'AC Sparta Praha',
#  'FC Viktoria Plzeň',
#  'Columbus Crew',
#  'Atakaş Hatayspor',
#  'Sport Club Corinthians Paulista',
#  'U.S. Sassuolo Calcio',
#  'Yukatel Kayserispor',
#  'Demir Grup Sivasspor',
#  'İttifak Holding Konyaspor',
#  'Shandong Taishan',
#  'Qingdao FC',
#  'Austin FC',
#  'Club Atlético Central Córdoba',
#  'Orlando City Soccer Club',
#  'N.E.C. Nijmegen',
#  'Tianjin Jinmen Tiger FC',
#  ...]

# %% [markdown]
# # Previous players in a club

# %%
# strikers_in_club={}

# for club in all_clubs:
#     all_features = striker_df[striker_df["Club"] == club]
#     essential_features = all_features[ST_essential_ft]
#     weights_vector=[]
#     for i in essential_features:
#         if essential_features[i].std() !=0:
#             weights_vector.append(1/essential_features[i].std())
#         else:
#             weights_vector.append(0)
#     # print(weights_vector)
#     strikers_in_club[club] = weights_vector

# %% [markdown]
# # Get weights of a particular position for all clubs
#
# Weights are how dense the essential feature is. This is reciprocal of standard deviation

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
def get_pos_weights(pos_df,pos_essential_ft):
    pos_players_in_club={}

    for club in all_clubs:
        all_features = pos_df[pos_df["Club"] == club]
        all_features = all_features.sort_values('Ovr_pot',ascending = False).head(20)
        essential_features = all_features[pos_essential_ft]
        weights_vector=[]
        sum = 0
        for i in essential_features:
            if essential_features[i].std() != 0:
                weights_vector.append(1/essential_features[i].std())
                sum += 1/essential_features[i].std()
            else:
                weights_vector.append(0)
                sum += 0
        # print(pos_essential_ft,club,weights_vector)
        if(sum != 0):
            for x in range(len(weights_vector)):
                weights_vector[x] = weights_vector[x] / sum
        pos_players_in_club[club] = weights_vector
        #print(sum)
    np_array = np.empty((0,len(pos_essential_ft)))
    for club in all_clubs:
        n_row = np.array(pos_players_in_club[club])
        n_row.shape = (1,len(pos_essential_ft))
        np_array = np.append(np_array, n_row, axis = 0)
    scaler = StandardScaler()
    np_array = scaler.fit_transform(np_array)
    count = 0
    for club in all_clubs:
        scaler = MinMaxScaler()
        n_ar = np_array[count]
        n_ar.shape = (len(pos_essential_ft),1)
        n_ar = scaler.fit_transform(n_ar)
        n_ar.shape = (len(pos_essential_ft),)
        pos_players_in_club[club] = (n_ar/np.sum(n_ar)).tolist()
        count += 1

    return pos_players_in_club

# %% [markdown]
# # Extracting Common features across positions

# %%
pos_essential_features = [ST_essential_ft,Wing_essential_ft,Mid_essential_ft,Cam_essential_ft,Def_essential_ft,Fullback_essential_ft]
# common_features =   []
# d={}
# for i in pos_essential_features:
#     for j in i:
#         if j not in d:
#             d[j]=1
#         else:
#             d[j]+=1

# for i in d:
#     if d[i]==len(pos_essential_features):
#         common_features.append(i)

#Can be optimized 

#basically removing all common features from the essential features of a position
# for i in common_features:
#     ST_essential_ft.remove(i)
#     Wing_essential_ft.remove(i)
#     Mid_essential_ft.remove(i)
#     Cam_essential_ft.remove(i)
#     Def_essential_ft.remove(i)
#     Fullback_essential_ft.remove(i)
    # Gk_essential_ft.remove(i)

# %%
# common_features

# %%
#common_features.extend(["Age", "Height", "Weight", "Weak Foot"])
common_features = (["Age"])

# %% [markdown]
# More features to be appended to common features.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = sklearn.preprocessing.MinMaxScaler()
F_std_df = F_all_df.copy(deep = True)
F_std_df[detailed_features] = scaler.fit_transform(F_std_df[detailed_features].to_numpy())
F_std_df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Club',
#        'Value', 'Weak Foot', 'Skill Moves', 'Position', 'Height', 'Weight',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'Best Position', 'Ovr_pot', 'Preferred Foot_Left',
#        'Preferred Foot_Right', 'Bmi'],
#       dtype='object')

# %% [markdown]
# # Weights per Position

# %%
striker_df = F_std_df[(F_std_df["Best Position"] == "ST") | (F_std_df["Best Position"] == "CF") | (F_std_df["Best Position"] == "LF")]
striker_df  =  striker_df.reset_index(drop = True)
striker_df
# Out:
#            ID                Name       Age          Nationality   Overall  \
# 0      176580           L. Suárez  0.358974              Uruguay  0.969697
# 1      173731             G. Bale  0.282051                Wales  0.939394
# 2       20801   Cristiano Ronaldo  0.410256             Portugal  1.000000
# 3      184941          A. Sánchez  0.307692                Chile  0.909091
# 4       54050           W. Rooney  0.384615              England  0.818182
# ...       ...                 ...       ...                  ...       ...
# 15809  262034            R. Mahon  0.076923  Republic of Ireland  0.303030
# 15810  259650            F. Molla  0.102564                India  0.287879
# 15811  161659           07 Danilo  0.230769               Brazil  0.545455
# 15812  150597       09 J. Moukoko  0.205128             Congo DR  0.393939
# 15813  178453       07 A. Censori  0.051282                Italy  0.000000
#
#        Potential                         Club  Value  Weak Foot  Skill Moves  \
# 0       0.947368                 FC Barcelona  83.00       0.75         0.75
# 1       0.912281                  Real Madrid  72.00       0.50         0.75
# 2       0.982456                  Real Madrid  87.00       0.75         1.00
# 3       0.877193                      Arsenal  55.00       0.50         0.75
# 4       0.771930            Manchester United  18.50       0.75         0.50
# ...          ...                          ...    ...        ...          ...
# 15809   0.385965                  Bohemian FC   0.11       0.50         0.25
# 15810   0.508772           ATK Mohun Bagan FC   0.13       0.25         0.25
# 15811   0.508772  Gallos Blancos de Querétaro    NaN       0.50         0.00
# 15812   0.421053                          NaN    NaN       0.50         0.00
# 15813   0.000000                       Arezzo    NaN       0.25         0.00
#
#        ...  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0      ...  0.288889    0.263736   0.319149       0.347826    0.391304
# 1      ...  0.155556    0.153846   0.106383       0.043478    0.054348
# 2      ...  0.066667    0.109890   0.148936       0.141304    0.108696
# 3      ...  0.100000    0.098901   0.148936       0.119565    0.130435
# 4      ...  0.100000    0.109890   0.127660       0.076087    0.065217
# ...    ...       ...         ...        ...            ...         ...
# 15809  ...  0.066667    0.142857   0.053191       0.076087    0.152174
# 15810  ...  0.077778    0.054945   0.138298       0.108696    0.141304
# 15811  ...  0.111111    0.054945   0.595745       0.152174    0.119565
# 15812  ...  0.077778    0.263736   0.414894       0.260870    0.260870
# 15813  ...  0.066667    0.000000   0.372340       0.054348    0.086957
#
#        Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                 ST  0.967213                  0.0                   1.0
# 1                 ST  0.934426                  1.0                   0.0
# 2                 ST  1.000000                  0.0                   1.0
# 3                 ST  0.901639                  0.0                   1.0
# 4                 ST  0.803279                  0.0                   1.0
# ...              ...       ...                  ...                   ...
# 15809             ST  0.344262                  1.0                   0.0
# 15810             ST  0.393443                  0.0                   1.0
# 15811             ST  0.532787                  1.0                   0.0
# 15812             ST  0.409836                  0.0                   1.0
# 15813             ST  0.000000                  0.0                   1.0
#
#              Bmi
# 0      25.768347
# 1      22.106529
# 2      23.220144
# 3      21.456996
# 4      27.024076
# ...          ...
# 15809  20.549887
# 15810  24.304618
# 15811  24.930748
# 15812  23.503556
# 15813  22.024323
#
# [15814 rows x 52 columns]

# %%
df_22_std = F_std_df.tail(df_22.shape[0])

# %%
wingers_df = F_std_df[(F_std_df["Best Position"] == "LW") | (F_std_df["Best Position"] == "RW")]
wingers_df  =  wingers_df.reset_index(drop = True)
wingers_df
# Out:
#           ID            Name       Age          Nationality   Overall  \
# 0     190871          Neymar  0.230769               Brazil  0.969697
# 1     193130     A. Schürrle  0.256410              Germany  0.803030
# 2     209331        M. Salah  0.230769                Egypt  0.818182
# 3     222492         L. Sané  0.128205              Germany  0.818182
# 4     185020   José Callejón  0.358974                Spain  0.833333
# ...      ...             ...       ...                  ...       ...
# 3930  248281   20 D. Borrero  0.051282             Colombia  0.424242
# 3931  263090          J. Eng  0.025641               Norway  0.378788
# 3932  264675      J. Dickman  0.128205               Sweden  0.363636
# 3933  261677       R. O'Kane  0.051282  Republic of Ireland  0.348485
# 3934  256458       K. Swaleh  0.076923               Norway  0.333333
#
#       Potential                         Club   Value  Weak Foot  Skill Moves  \
# 0      0.982456                 FC Barcelona  106.00       1.00         1.00
# 1      0.771930            Borussia Dortmund   19.00       0.75         0.50
# 2      0.824561                         Roma   26.00       0.25         0.75
# 3      0.929825              Manchester City   31.00       0.50         0.50
# 4      0.789474                       Napoli   22.50       0.25         0.50
# ...         ...                          ...     ...        ...          ...
# 3930   0.649123  Club Independiente Santa Fe    0.18       0.50         0.50
# 3931   0.666667            Vålerenga Fotball    0.30       0.50         0.50
# 3932   0.508772              FC Nordsjælland    0.19       0.50         0.25
# 3933   0.649123                   Dundalk FC    0.18       0.25         0.25
# 3934   0.561404                FK Bodø/Glimt    0.13       0.50         0.25
#
#       ...  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0     ...  0.088889    0.087912   0.148936       0.152174    0.108696
# 1     ...  0.066667    0.109890   0.117021       0.086957    0.119565
# 2     ...  0.144444    0.142857   0.085106       0.108696    0.141304
# 3     ...  0.077778    0.120879   0.085106       0.086957    0.141304
# 4     ...  0.077778    0.043956   0.138298       0.108696    0.108696
# ...   ...       ...         ...        ...            ...         ...
# 3930  ...  0.122222    0.087912   0.085106       0.043478    0.130435
# 3931  ...  0.100000    0.098901   0.063830       0.097826    0.043478
# 3932  ...  0.144444    0.153846   0.117021       0.065217    0.054348
# 3933  ...  0.111111    0.120879   0.138298       0.097826    0.054348
# 3934  ...  0.111111    0.142857   0.127660       0.054348    0.076087
#
#       Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                LW  0.983607                  0.0                   1.0
# 1                RW  0.795082                  0.0                   1.0
# 2                RW  0.827869                  1.0                   0.0
# 3                LW  0.877049                  1.0                   0.0
# 4                RW  0.819672                  0.0                   1.0
# ...             ...       ...                  ...                   ...
# 3930             RW  0.532787                  0.0                   1.0
# 3931             RW  0.516393                  0.0                   1.0
# 3932             RW  0.434426                  0.0                   1.0
# 3933             RW  0.491803                  0.0                   1.0
# 3934             RW  0.442623                  0.0                   1.0
#
#             Bmi
# 0     22.150882
# 1     22.106529
# 2     23.479935
# 3     22.784644
# 4     23.100839
# ...         ...
# 3930  21.847009
# 3931  24.074074
# 3932  22.582709
# 3933  20.904195
# 3934  20.761246
#
# [3935 rows x 52 columns]

# %%
mids_df = F_std_df[(F_std_df["Best Position"] == "RM") | (F_std_df["Best Position"] == "CM") | (F_std_df["Best Position"] == "CDM") | (F_norm_df["Best Position"] == "LM")]
mids_df  =  mids_df.reset_index(drop = True)
mids_df
# Out:
#            ID              Name       Age          Nationality   Overall  \
# 0      178518     R. Nainggolan  0.333333              Belgium  0.878788
# 1      181872          A. Vidal  0.358974                Chile  0.893939
# 2      177003         L. Modrić  0.384615              Croatia  0.924242
# 3      173210      C. Marchisio  0.384615                Italy  0.878788
# 4      139997           D. Srna  0.487179              Croatia  0.803030
# ...       ...               ...       ...                  ...       ...
# 26907    4174        07 P. Sarr  0.333333              Senegal  0.560606
# 26908  246839     21 C. Bargary  0.102564  Republic of Ireland  0.348485
# 26909  235352   18 T. Käßemodel  0.333333              Germany  0.272727
# 26910    4373    07 S. Valakari  0.461538              Finland  0.575758
# 26911   19334  10 I. Baraclough  0.589744              England  0.242424
#
#        Potential               Club  Value  Weak Foot  Skill Moves  ...  \
# 0       0.842105               Roma  37.50       0.50         0.50  ...
# 1       0.859649  FC Bayern München  41.50       0.75         0.50  ...
# 2       0.894737        Real Madrid  54.00       0.75         0.75  ...
# 3       0.842105           Juventus  35.00       0.75         0.75  ...
# 4       0.754386   Shakhtar Donetsk   4.80       0.50         0.50  ...
# ...          ...                ...    ...        ...          ...  ...
# 26907   0.561404  Stade Brestois 29    NaN       0.50         0.00  ...
# 26908   0.508772          Cork City   0.15       0.50         0.25  ...
# 26909   0.140351  FC Erzgebirge Aue   0.03       0.50         0.25  ...
# 26910   0.508772          FC Dallas    NaN       0.50         0.00  ...
# 26911   0.473684                NaN    NaN       0.50         0.00  ...
#
#        GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0      0.111111    0.109890   0.138298       0.076087    0.108696
# 1      0.033333    0.010989   0.031915       0.010870    0.032609
# 2      0.133333    0.087912   0.063830       0.141304    0.086957
# 3      0.033333    0.021978   0.031915       0.010870    0.032609
# 4      0.100000    0.098901   0.053191       0.054348    0.119565
# ...         ...         ...        ...            ...         ...
# 26907  0.088889    0.120879   0.712766       0.076087    0.108696
# 26908  0.100000    0.054945   0.106383       0.054348    0.043478
# 26909  0.100000    0.120879   0.053191       0.130435    0.054348
# 26910  0.055556    0.021978   0.553191       0.054348    0.021739
# 26911  0.044444    0.208791   0.478723       0.206522    0.206522
#
#        Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                CDM  0.868852                  0.0                   1.0
# 1                CDM  0.885246                  0.0                   1.0
# 2                 CM  0.918033                  0.0                   1.0
# 3                 CM  0.868852                  0.0                   1.0
# 4                 CM  0.786885                  0.0                   1.0
# ...              ...       ...                  ...                   ...
# 26907            CDM  0.565574                  0.0                   1.0
# 26908             RM  0.426230                  0.0                   1.0
# 26909             CM  0.213115                  0.0                   1.0
# 26910            CDM  0.549180                  1.0                   0.0
# 26911             CM  0.352459                  1.0                   0.0
#
#              Bmi
# 0      21.117175
# 1      23.012574
# 2      21.117175
# 3      22.454694
# 4      22.813872
# ...          ...
# 26907  23.456790
# 26908  21.777553
# 26909  25.059307
# 26910  26.753864
# 26911  23.666910
#
# [26912 rows x 52 columns]

# %%
cam_df = F_std_df[(F_std_df["Best Position"] == "CAM")]
cam_df  =  cam_df.reset_index(drop = True)
cam_df
# Out:
#            ID           Name       Age          Nationality   Overall  \
# 0      195864       P. Pogba  0.205128               France  0.909091
# 1       20289       Y. Touré  0.461538          Ivory Coast  0.848485
# 2      189509         Thiago  0.256410                Spain  0.878788
# 3      171877      M. Hamšik  0.333333             Slovakia  0.878788
# 4      180206      M. Pjanić  0.282051   Bosnia Herzegovina  0.863636
# ...       ...            ...       ...                  ...       ...
# 12512  252881   21 H. Hopper  0.102564              England  0.333333
# 12513  243725     D. Collins  0.128205  Republic of Ireland  0.287879
# 12514  259857       A. Majok  0.128205          South Sudan  0.333333
# 12515  261748  C. McLaughlin  0.102564  Republic of Ireland  0.348485
# 12516  261818   R. Gallagher  0.128205  Republic of Ireland  0.287879
#
#        Potential               Club  Value  Weak Foot  Skill Moves  ...  \
# 0       0.982456  Manchester United  71.50       0.75         1.00  ...
# 1       0.807018    Manchester City  18.00       0.75         0.50  ...
# 2       0.877193  FC Bayern München  46.00       0.50         1.00  ...
# 3       0.842105             Napoli  37.50       0.75         0.50  ...
# 4       0.842105           Juventus  37.50       0.75         0.75  ...
# ...          ...                ...    ...        ...          ...  ...
# 12512   0.508772           Rochdale   0.12       0.25         0.25  ...
# 12513   0.315789       Sligo Rovers   0.10       0.50         0.25  ...
# 12514   0.508772  Western United FC   0.12       0.25         0.25  ...
# 12515   0.368421         Derry City   0.13       0.50         0.50  ...
# 12516   0.403509         Finn Harps   0.11       0.50         0.25  ...
#
#        GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0      0.044444    0.054945   0.010638       0.032609    0.021739
# 1      0.133333    0.142857   0.053191       0.119565    0.076087
# 2      0.055556    0.109890   0.063830       0.086957    0.130435
# 3      0.077778    0.054945   0.031915       0.141304    0.141304
# 4      0.066667    0.065934   0.127660       0.065217    0.076087
# ...         ...         ...        ...            ...         ...
# 12512  0.077778    0.065934   0.042553       0.076087    0.097826
# 12513  0.055556    0.087912   0.042553       0.130435    0.076087
# 12514  0.077778    0.109890   0.095745       0.076087    0.097826
# 12515  0.122222    0.087912   0.106383       0.141304    0.065217
# 12516  0.144444    0.098901   0.063830       0.130435    0.076087
#
#        Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                CAM  0.950820                  0.0                   1.0
# 1                CAM  0.836066                  0.0                   1.0
# 2                CAM  0.885246                  0.0                   1.0
# 3                CAM  0.868852                  0.0                   1.0
# 4                CAM  0.860656                  0.0                   1.0
# ...              ...       ...                  ...                   ...
# 12512            CAM  0.418033                  0.0                   1.0
# 12513            CAM  0.303279                  0.0                   1.0
# 12514            CAM  0.418033                  0.0                   1.0
# 12515            CAM  0.360656                  1.0                   0.0
# 12516            CAM  0.344262                  0.0                   1.0
#
#              Bmi
# 0      23.123158
# 1      25.421414
# 2      22.741573
# 3      23.598381
# 4      21.478402
# ...          ...
# 12512  21.877551
# 12513  22.460034
# 12514  21.132713
# 12515  22.857143
# 12516  22.839506
#
# [12517 rows x 52 columns]

# %%
centrebacks_df = F_std_df[(F_std_df["Best Position"] == "CB")]
centrebacks_df  = centrebacks_df.reset_index(drop = True)
centrebacks_df
# Out:
#            ID            Name       Age          Nationality   Overall  \
# 0      185103      A. Kolarov  0.384615               Serbia  0.787879
# 1      155862    Sergio Ramos  0.384615                Spain  0.924242
# 2      164240    Thiago Silva  0.410256               Brazil  0.924242
# 3      179944      David Luiz  0.358974               Brazil  0.848485
# 4      205600       S. Umtiti  0.179487               France  0.833333
# ...       ...             ...       ...                  ...       ...
# 20682  164945  07 Nuno Mendes  0.333333             Portugal  0.651515
# 20683  252561        Zhang Yu  0.076923             China PR  0.333333
# 20684  262041      P. Maguire  0.076923  Republic of Ireland  0.318182
# 20685  239427     21 A. Ajeti  0.205128          Switzerland  0.393939
# 20686  220806    16 E. Redman  0.076923                Wales  0.242424
#
#        Potential                  Club  Value  Weak Foot  Skill Moves  ...  \
# 0       0.736842       Manchester City  10.00       0.50         0.25  ...
# 1       0.894737           Real Madrid  43.50       0.50         0.50  ...
# 2       0.894737   Paris Saint-Germain  39.50       0.50         0.50  ...
# 3       0.807018               Chelsea  22.00       0.50         0.50  ...
# 4       0.877193          FC Barcelona  27.00       0.50         0.25  ...
# ...          ...                   ...    ...        ...          ...  ...
# 20682   0.561404  US Créteil-Lusitanos    NaN       0.50         0.00  ...
# 20683   0.543860              Hebei FC   0.11       0.25         0.25  ...
# 20684   0.508772          Sligo Rovers   0.11       0.50         0.25  ...
# 20685   0.403509    FC St. Gallen 1879   0.20       0.50         0.25  ...
# 20686   0.333333        Newport County   0.05       0.25         0.25  ...
#
#        GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0      0.166667    0.153846   0.074468       0.163043    0.054348
# 1      0.111111    0.076923   0.085106       0.065217    0.108696
# 2      0.088889    0.120879   0.042553       0.086957    0.097826
# 3      0.111111    0.120879   0.095745       0.065217    0.141304
# 4      0.155556    0.098901   0.138298       0.119565    0.152174
# ...         ...         ...        ...            ...         ...
# 20682  0.111111    0.120879   0.265957       0.130435    0.130435
# 20683  0.044444    0.131868   0.117021       0.043478    0.152174
# 20684  0.133333    0.043956   0.148936       0.065217    0.054348
# 20685  0.144444    0.131868   0.095745       0.086957    0.097826
# 20686  0.133333    0.065934   0.159574       0.086957    0.065217
#
#        Best Position   Ovr_pot  Preferred Foot_Left  Preferred Foot_Right  \
# 0                 CB  0.770492                  1.0                   0.0
# 1                 CB  0.918033                  0.0                   1.0
# 2                 CB  0.918033                  0.0                   1.0
# 3                 CB  0.836066                  0.0                   1.0
# 4                 CB  0.860656                  1.0                   0.0
# ...              ...       ...                  ...                   ...
# 20682             CB  0.614754                  0.0                   1.0
# 20683             CB  0.434426                  0.0                   1.0
# 20684             CB  0.409836                  0.0                   1.0
# 20685             CB  0.401639                  1.0                   0.0
# 20686             CB  0.286885                  0.0                   1.0
#
#              Bmi
# 0      23.495549
# 1      22.377775
# 2      23.598381
# 3      23.752331
# 4      22.377775
# ...          ...
# 20682  24.075474
# 20683  21.132713
# 20684  20.233553
# 20685  23.702162
# 20686  23.924858
#
# [20687 rows x 52 columns]

# %%
fullbacks_df = F_std_df[(F_std_df["Best Position"] == "LB") | (F_std_df["Best Position"] == "RB") | (F_std_df["Best Position"] == "LWB") | (F_std_df["Best Position"] == "RWB")]
fullbacks_df  = fullbacks_df.reset_index(drop = True)
fullbacks_df
# Out:
#            ID          Name       Age Nationality   Overall  Potential  \
# 0      197445      D. Alaba  0.230769     Austria  0.878788   0.894737
# 1      203551   A. Florenzi  0.256410       Italy  0.818182   0.824561
# 2      163631     L. Baines  0.410256     England  0.833333   0.789474
# 3      189332    Jordi Alba  0.307692       Spain  0.878788   0.842105
# 4      146530    Dani Alves  0.461538      Brazil  0.848485   0.807018
# ...       ...           ...       ...         ...       ...        ...
# 13591  248815     K. Berkoe  0.102564     England  0.378788   0.473684
# 13592  261549    B. Ganesan  0.102564       India  0.303030   0.403509
# 13593  260767      Z. Bello  0.051282   Australia  0.333333   0.561404
# 13594  252466   21 D. Bouah  0.076923       Italy  0.318182   0.508772
# 13595  260623  21 M. Wright  0.461538     England  0.287879   0.157895
#
#                     Club   Value  Weak Foot  Skill Moves  ...  GKDiving  \
# 0      FC Bayern München  41.500       0.75         0.50  ...  0.044444
# 1                   Roma  20.500       0.50         0.50  ...  0.088889
# 2                Everton  14.500       0.50         0.50  ...  0.077778
# 3           FC Barcelona  31.500       0.50         0.50  ...  0.133333
# 4               Juventus  12.500       0.50         0.50  ...  0.044444
# ...                  ...     ...        ...          ...  ...       ...
# 13591       Salford City   0.210       0.50         0.25  ...  0.088889
# 13592      Chennaiyin FC   0.110       0.50         0.25  ...  0.144444
# 13593  Melbourne Victory   0.120       0.50         0.25  ...  0.066667
# 13594               Roma   0.110       0.25         0.25  ...  0.144444
# 13595       Crawley Town   0.025       0.00         0.25  ...  0.144444
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes  Best Position  \
# 0        0.065934   0.138298       0.152174    0.086957             LB
# 1        0.076923   0.095745       0.108696    0.097826             RB
# 2        0.153846   0.095745       0.130435    0.119565            LWB
# 3        0.153846   0.127660       0.054348    0.130435            LWB
# 4        0.109890   0.085106       0.054348    0.065217            RWB
# ...           ...        ...            ...         ...            ...
# 13591    0.065934   0.063830       0.076087    0.130435             LB
# 13592    0.109890   0.127660       0.054348    0.054348             RB
# 13593    0.087912   0.063830       0.076087    0.086957             RB
# 13594    0.043956   0.106383       0.130435    0.108696             RB
# 13595    0.087912   0.138298       0.076087    0.043478             LB
#
#         Ovr_pot  Preferred Foot_Left  Preferred Foot_Right        Bmi
# 0      0.893443                  1.0                   0.0  23.430985
# 1      0.827869                  0.0                   1.0  22.503074
# 2      0.819672                  1.0                   0.0  24.119543
# 3      0.868852                  1.0                   0.0  23.493061
# 4      0.836066                  0.0                   1.0  22.807169
# ...         ...                  ...                   ...        ...
# 13591  0.426230                  1.0                   0.0  20.515086
# 13592  0.352459                  0.0                   1.0  19.814053
# 13593  0.442623                  0.0                   1.0  21.857278
# 13594  0.409836                  0.0                   1.0  23.620288
# 13595  0.229508                  1.0                   0.0  25.564954
#
# [13596 rows x 52 columns]

# %%
gk_df = F_std_df[(F_std_df["Best Position"] == "GK")]
gk_df  = gk_df.reset_index(drop = True)
gk_df
# Out:
#            ID              Name       Age Nationality   Overall  Potential  \
# 0      230167     Mateus Tangil  0.333333      Brazil  0.590909   0.508772
# 1      230318     Nelsildo Reis  0.333333      Brazil  0.727273   0.666667
# 2      167495          M. Neuer  0.384615     Germany  0.969697   0.947368
# 3      230171   Carlos Travisso  0.435897      Brazil  0.530303   0.438596
# 4      230322      Teixe Gaúcho  0.333333      Brazil  0.439394   0.333333
# ...       ...               ...       ...         ...       ...        ...
# 10885  251433           B. Voll  0.128205     Germany  0.454545   0.543860
# 10886  240558     18 L. Clayton  0.051282     England  0.378788   0.561404
# 10887  262846          �. Dobre  0.128205     Romania  0.378788   0.438596
# 10888  241317    21 Xue Qinghao  0.102564    China PR  0.287879   0.385965
# 10889  259646         A. Shaikh  0.076923       India  0.287879   0.508772
#
#                         Club   Value  Weak Foot  Skill Moves  ...  GKDiving  \
# 0           Atlético Mineiro   0.625       0.50          0.0  ...  0.722222
# 1              Internacional   4.600       0.50          0.0  ...  0.833333
# 2          FC Bayern München  69.500       0.75          0.0  ...  0.977778
# 3                   Botafogo   0.250       0.50          0.0  ...  0.744444
# 4                Ponte Preta   0.100       0.25          0.0  ...  0.766667
# ...                      ...     ...        ...          ...  ...       ...
# 10885     F.C. Hansa Rostock   0.375       0.25          0.0  ...  0.644444
# 10886        Cheltenham Town   0.100       0.25          0.0  ...  0.600000
# 10887  FC Academica Clinceni   0.180       0.25          0.0  ...  0.622222
# 10888    Shanghai Shenhua FC   0.100       0.25          0.0  ...  0.533333
# 10889     ATK Mohun Bagan FC   0.110       0.50          0.0  ...  0.533333
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes  Best Position  \
# 0        0.736264   0.659574       0.684783    0.771739             GK
# 1        0.835165   0.808511       0.815217    0.793478             GK
# 2        0.978022   1.000000       0.978261    0.956522             GK
# 3        0.461538   0.670213       0.684783    0.771739             GK
# 4        0.593407   0.563830       0.434783    0.663043             GK
# ...           ...        ...            ...         ...            ...
# 10885    0.648352   0.585106       0.586957    0.652174             GK
# 10886    0.582418   0.542553       0.532609    0.630435             GK
# 10887    0.560440   0.553191       0.510870    0.619565             GK
# 10888    0.516484   0.468085       0.402174    0.554348             GK
# 10889    0.439560   0.404255       0.478261    0.521739             GK
#
#         Ovr_pot  Preferred Foot_Left  Preferred Foot_Right        Bmi
# 0      0.557377                  0.0                   1.0  24.009113
# 1      0.704918                  0.0                   1.0  24.248069
# 2      0.967213                  0.0                   1.0  24.709662
# 3      0.491803                  0.0                   1.0  23.012574
# 4      0.393443                  0.0                   1.0  23.238767
# ...         ...                  ...                   ...        ...
# 10885  0.500000                  0.0                   1.0  22.353715
# 10886  0.467213                  0.0                   1.0  22.634676
# 10887  0.409836                  0.0                   1.0  22.850462
# 10888  0.336066                  0.0                   1.0  21.913580
# 10889  0.393443                  0.0                   1.0  21.389756
#
# [10890 rows x 52 columns]

# %%
import pickle

# %%
# striker_weights_per_club = get_pos_weights(striker_df,ST_essential_ft)
# with open('./rec_actual_data/striker_weights_per_club.pkl', 'wb') as f:
#     pickle.dump(striker_weights_per_club, f)

# %%
# wing_weights_per_club = get_pos_weights(wingers_df,Wing_essential_ft)
# with open('./rec_actual_data/wing_weights_per_club.pkl', 'wb') as f:
#     pickle.dump(wing_weights_per_club, f)

# %%
# mid_weights_per_club = get_pos_weights(mids_df,Mid_essential_ft)
# with open('./rec_actual_data/mid_weights_per_club.pkl', 'wb') as f:
#     pickle.dump(mid_weights_per_club, f)

# %%
# cam_weights_per_club = get_pos_weights(cam_df,Cam_essential_ft)
# with open('./rec_actual_data/cam_weights_per_club.pkl', 'wb') as f:
#     pickle.dump(cam_weights_per_club, f)

# %%
# def_weights_per_club = get_pos_weights(centrebacks_df,Def_essential_ft)
# with open('./rec_actual_data/def_weights_per_club.pkl', 'wb') as f:
#     pickle.dump(def_weights_per_club, f)

# %%
# fullback_weights_per_club = get_pos_weights(fullbacks_df,Fullback_essential_ft)
# with open('./rec_actual_data/fullback_weights_per_club.pkl', 'wb') as f:
#     pickle.dump(fullback_weights_per_club, f)

# %%
# gk_weights_per_club = get_pos_weights(gk_df,Gk_essential_ft)
# with open('./rec_actual_data/gk_weights_per_club.pkl', 'wb') as f:
#     pickle.dump(gk_weights_per_club, f)

# %%
with open('./rec_actual_data/striker_weights_per_club.pkl', 'rb') as f:
    striker_weights_per_club = pickle.load(f)
with open('./rec_actual_data/wing_weights_per_club.pkl', 'rb') as f:
    wing_weights_per_club = pickle.load(f)
with open('./rec_actual_data/mid_weights_per_club.pkl', 'rb') as f:
    mid_weights_per_club = pickle.load(f)
with open('./rec_actual_data/cam_weights_per_club.pkl', 'rb') as f:
    cam_weights_per_club = pickle.load(f)
with open('./rec_actual_data/def_weights_per_club.pkl', 'rb') as f:
    def_weights_per_club = pickle.load(f)
with open('./rec_actual_data/fullback_weights_per_club.pkl', 'rb') as f:
    fullback_weights_per_club = pickle.load(f)
with open('./rec_actual_data/gk_weights_per_club.pkl', 'rb') as f:
    gk_weights_per_club = pickle.load(f)

# %%
def_weights_per_club["Manchester City"]
# Out:
# [0.018194460400936793,
#  0.0594368703809399,
#  0.12955076619515993,
#  0.0,
#  0.017439970311683515,
#  0.014098389492373327,
#  0.014152447948403,
#  0.34553191118853094,
#  0.21356399259180298,
#  0.1880311914901696]

# %% [markdown]
# # Common features weights

# %%
# common_club_philosophy = get_pos_weights(F_std_df,common_features)

# %%
# common_club_philosophy

# %% [markdown]
# # Current players in a club weighted rating

# %% [markdown]
# Get all current players of a club -  use df_22 as it is the most current season.
# Then according to the player's overall rating give them weights and come up with a weighted average for the club.

# %%
def get_cur_pos_philosophy(cur_season_df, club , pos_list,pos_essential_ft):# pos list will be ["LW","RW"] for WING
    club_df = cur_season_df[cur_season_df["Club"]==club]
    pos_df=club_df[club_df['Best Position'].isin(pos_list)]
    essential_df = pos_df[pos_essential_ft]
    #print(essential_df)
    cur_players = np.array(essential_df)
    denom=0
    num = np.zeros(shape = (cur_players.shape[1]))
    
    for i in range(cur_players.shape[0]):
        # print(pos_df.iloc[i])
        overall_rating = pos_df.iloc[i]["Ovr_pot"]
        #np.apply_along_axis(my_func, 0, overall_rating)
        
        # print("Overall rating: ", overall_rating)
        
        if(overall_rating >= 85):
            w = 20
        elif (overall_rating >= 80):
            w = 16
        elif(overall_rating >= 75):
            w = 8
        elif(overall_rating >= 70):
            w = 2
        else:
            w = 1
        denom+=w
        num+=w * cur_players[i]
        # print(num)
    
        
        

    return num/denom

# %%
get_cur_pos_philosophy(F_std_df,"Manchester City", ["CB"],Def_essential_ft)
# Out:
# array([0.77608696, 0.72588706, 0.69046443, 0.69182991, 0.67481884,
#        0.77058279, 0.77940503, 0.72859704, 0.83301481, 0.79610984])

# %% [markdown]
# # Position similarity of a new player

# %% [markdown]
# similarity is basically the weighted average of the difference in new_player's attributes and current club players' attributes.

# %%
from numpy import inf
from sklearn.preprocessing import normalize
def club_pos_sim(new_player,pos_essential_features,pos_weights_per_club, means, club_cur = None):
    new_player = np.array(new_player[pos_essential_features])
    new_player.shape = [new_player.shape[0],1]
    new_player = normalize(new_player, axis = 0)
    new_player.shape = [new_player.shape[0],]
    
    #print(new_player)
    
    # print(new_player.shape)
    # print(new_player)
    
    
    #club_cur  = get_cur_pos_philosophy(F_std_df,club,pos_list,pos_essential_features)
    club_cur.shape = [club_cur.shape[0],1]
    club_cur = normalize(club_cur, axis = 0)
    club_cur.shape = [club_cur.shape[0],]
    # print(club_cur)
    weighted_dot = np.sum(pos_weights_per_club * (new_player-means) * (club_cur-means))
    # diffs = np.reciprocal(np.square(np.array(new_player - club_cur)))
    # diffs[diffs == inf] = 10
    # #print(diffs)
    # pos_sim = diffs.dot(pos_weights_per_club[club])
    mag_1 = np.sqrt(np.dot(pos_weights_per_club, np.square(new_player - means)))
    mag_2 = np.sqrt(np.dot(pos_weights_per_club, np.square(club_cur - means)))
    pos_sim = weighted_dot/(mag_1 * mag_2)

    return pos_sim

# %%
# new_player = df_22_std[df_22_std["ID"]==234576]#suarez
# # pos_np = pos_df.to_numpy()
# # pos_np = normalize(pos_np)
# # means = np.mean(pos_np, axis = 0)
# pos_sim = club_pos_sim(new_player,"Manchester City", ["CB"],Def_essential_ft,def_weights_per_club)

# %%
# pos_sim

# %%
def club_pos_mag(new_player,pos_essential_features,pos_weights_per_club):

    new_player = np.array(new_player[pos_essential_features])

    #new_player.shape = [new_player.shape[1],1]
    mag_1 = np.sqrt(np.dot(pos_weights_per_club, np.square(new_player)))

    return mag_1

# %%
# new_player = df_22_std[df_22_std["ID"]==220806]#suarez
# pos_mag = club_pos_mag(new_player,"Manchester United",Def_essential_ft,def_weights_per_club)

# %%
# pos_mag

# %%
# ar_1 = np.array([1,2,3])
# ar_1.shape = [1,3]
# ar_2 = np.array([1,2,3])
# ar_1.shape = [1,3]
# ar_3 = np.array([1,2,3])
# ar_1.shape = [1,3]
# ar_1 * ar_2 * ar_3
# (ar_1).shape

# %%
# n_p = np.array(new_player[Def_essential_ft])
# n_p.shape = [13,]
# np.sqrt(np.sum(def_weights_per_club["FC Barcelona"] * np.square(n_p)))

# %%
# def get_cur_philosophy(cur_season_df,  club ,common_features):# pos list will be ["LW","RW"] for WING
#     club_df = cur_season_df[cur_season_df["Club"]==club]
#     #pos_df=club_df[club_df['Best Position'].isin(pos_list)]
#     essential_df = club_df[common_features]

#     cur_players = np.array(essential_df)
#     denom=0
#     num = np.zeros(shape = (cur_players.shape[1]))
#     for i in range(cur_players.shape[0]):
#         # print(pos_df.iloc[i])
#         overall_rating = club_df.iloc[i]["Ovr_pot"]
#         #np.apply_along_axis(my_func, 0, overall_rating)
        
#         # print("Overall rating: ", overall_rating)
        
#         if(overall_rating >= 85):
#             w = 20
#         elif (overall_rating >= 80):
#             w = 16
#         elif(overall_rating >= 75):
#             w = 8
#         elif(overall_rating >= 70):
#             w = 2
#         else:
#             w = 1
#         denom+=w
#         num+=w * cur_players[i]
#         # print(num)
    
        
        

#     return num/denom

# %%
# get_cur_philosophy(F_std_df, "Manchester City", common_features)

# %% [markdown]
# ## Similarity with common features/ common club philosophy

# %%
# from numpy import inf
# #new_player = df_22[df_22["ID"]==176580]#suarez
# def club_common_sim(new_player,club,common_features, common_club_philosophy):
#     new_player = df_22[df_22["ID"] == new_player["ID"]]
#     new_player = np.array(new_player[common_features])
#     #new_player.shape = [new_player.shape[1],]
#     club_cur  = get_cur_philosophy(F_all_df,club,common_features)
#     #print(np.reciprocal((new_player - club_cur)))
#     diffs = np.reciprocal(np.absolute(np.array(new_player - club_cur)))
#     diffs[diffs == inf] = 1
#     #print(diffs)
#     club_sim = diffs
#     #club_sim/=sum(common_club_philosophy[club])
#     print(club_sim)
#     return (club_sim)

# %%
# common_club_philosophy["Manchester City"]

# %%
# new_player = df_22[df_22["ID"]==197061]

# club_sim = club_common_sim(new_player,"Manchester City",common_features, common_club_philosophy)
# club_sim

# %%
# df_22[df_22["ID"]==203574]

# %%
# get_cur_philosophy(F_all_df,"Manchester City",common_features)

# %% [markdown]
# # Recommendation based on similarity only

# %%
def get_player_recs(df,club,pos_list, pos_essential_features,pos_weights_per_club,lambda1 = 0.73,lambda2 = 0.37, age_min = 21, age_max = 29, val = 60):
    pos_df=df[df['Best Position'].isin(pos_list)]
    essential_df = pos_df[pos_essential_features]
    # common_club_df = pos_df[common_club_features]
    d={}
    player_list = []
    min_sim = inf
    max_sim = -inf
    min_mag = inf
    max_mag = -inf
    #sum_sim = 0
    #sum_mag = 0
    # min_club = inf
    # max_club = -inf
    pos_np = essential_df.to_numpy()
    pos_np = normalize(pos_np)
    means = np.mean(pos_np, axis = 0)
    club_cur  = get_cur_pos_philosophy(F_std_df,club,pos_list,pos_essential_features)
    for i in range(pos_df.shape[0]):
        new_player = pos_df.iloc[i]
        pos_sim = club_pos_sim(new_player,pos_essential_features,pos_weights_per_club[club], means, club_cur = club_cur)
        if(min_sim > pos_sim): min_sim = pos_sim
        if(max_sim < pos_sim): max_sim = pos_sim
        #sum_sim += pos_sim
        pos_mag = club_pos_mag(new_player,pos_essential_features,pos_weights_per_club[club])
        if(min_mag > pos_mag): min_mag = pos_mag
        if(max_mag < pos_mag): max_mag = pos_mag
        #sum_mag += pos_mag
        #print(pos_sim, pos_mag)
        #club_sim = club_common_sim(new_player,club,common_club_features, common_club_philosophy)
        #print(club_sim)
        # if(min_club > club_sim): min_club = club_sim
        # if(max_club < club_sim): max_club = club_sim
        #sim = lambda1*pos_sim + lambda2*pos_mag
        d[str(new_player["ID"])] = [pos_sim, pos_mag]
        player_list.append(new_player["ID"])
    # mean_sim = sum_sim/pos_df.shape[0]
    # mean_mag = sum_mag/pos_df.shape[0]
    # dev_sum_sim = 0
    # dev_sum_mag = 0
    d_final = {}
    # for id in player_list:
    #     dev_sum_sim += (d[str(id)][0]- mean_sim)**2
    #     dev_sum_mag += (d[str(id)][1]- mean_mag)**2
    # std_sim = math.sqrt(dev_sum_sim/(pos_df.shape[0]-1))
    # std_mag = math.sqrt(dev_sum_mag/(pos_df.shape[0]-1))
    # min_sim = mean_sim - std_sim
    # min_mag = mean_mag - std_mag
    #print(min_sim, min_mag)
    for id in player_list:
        d[str(id)] = [(d[str(id)][0] - min_sim)/(max_sim - min_sim), (d[str(id)][1] - min_mag)/(max_mag - min_mag)]
        d_final[str(id)] = lambda1*d[str(id)][0] + lambda2*d[str(id)][1]
        #print(id, d[str(id)][0], d[str(id)][1])
    player_list.sort(key = lambda x: d_final[str(x)],reverse = True)
    new_list = [[df[df["ID"] == j]["Name"],j, d[str(j)]] for j in player_list[:] if ((float(df_22[df_22["ID"] == j]["Age"]) >= age_min) and (float(df_22[df_22["ID"] == j]["Age"]) <= age_max) and (float(df[df["ID"] == j]["Value"]) <= val) and ((df[df["ID"] == j]["Club"].values[0] != club)))]
    return new_list

# %%
get_player_recs(df_22_std,"Manchester United",["CB"],Def_essential_ft,def_weights_per_club, age_min = 23, age_max = 27, val = 100)
# Out:
# [[94676    J. O'Connell
#   Name: Name, dtype: object,
#   212300,
#   [0.9963346855375808, 0.732298102137154]],
#  [89593    E. Álvarez
#   Name: Name, dtype: object,
#   235844,
#   [0.9428996902756273, 0.7775594166559227]],
#  [93661    Lucas Veríssimo
#   Name: Name, dtype: object,
#   235688,
#   [0.9224039433778747, 0.7927007759471565]],
#  [89999    K. Zouma
#   Name: Name, dtype: object,
#   204311,
#   [0.893383459520244, 0.8129638454404429]],
#  [89216    P. Kimpembe
#   Name: Name, dtype: object,
#   225850,
#   [0.8449390461272022, 0.9013912681363256]],
#  [89003    E. Dier
#   Name: Name, dtype: object,
#   202335,
#   [0.8838388840383722, 0.816401309046566]],
#  [94722    K. Hause
#   Name: Name, dtype: object,
#   210635,
#   [0.9601953058734722, 0.6630365865280212]],
#  [98781    D. Baumgartner
#   Name: Name, dtype: object,
#   229818,
#   [1.0, 0.5640625350345524]],
#  [97487    J. Komar
#   Name: Name, dtype: object,
#   222428,
#   [0.9326845717410062, 0.6835006089547178]],
#  [88494    L. Hernández
#   Name: Name, dtype: object,
#   220814,
#   [0.8281856484961314, 0.8822565935427991]],
#  [96727    Fábio Cardoso
#   Name: Name, dtype: object,
#   213917,
#   [0.9116289014220642, 0.7055433111826274]],
#  [91237    B. Godfrey
#   Name: Name, dtype: object,
#   225793,
#   [0.9023251476983023, 0.7232879264088667]],
#  [89628    P. Díaz
#   Name: Name, dtype: object,
#   214436,
#   [0.8881109968947057, 0.7335694077618332]],
#  [96340    N. Süle
#   Name: Name, dtype: object,
#   212190,
#   [0.8235968394829065, 0.8541802774732047]],
#  [88220    R. Bensebaini
#   Name: Name, dtype: object,
#   224196,
#   [0.8549252914133619, 0.787605591032129]],
#  [95256    Gabriel
#   Name: Name, dtype: object,
#   232580,
#   [0.8465606985225731, 0.7980081775426966]],
#  [92887    Diego Llorente
#   Name: Name, dtype: object,
#   212602,
#   [0.8529138426941854, 0.7849271418335361]],
#  [93735    P. Ciss
#   Name: Name, dtype: object,
#   250858,
#   [0.9294379396988954, 0.6252266300874895]],
#  [91707    Kelivelson
#   Name: Name, dtype: object,
#   230452,
#   [0.8952802995463283, 0.6871899901557031]],
#  [97222    Domingos Duarte
#   Name: Name, dtype: object,
#   234835,
#   [0.8415250196176393, 0.7916064179182033]],
#  [96325    Vincente Dourado
#   Name: Name, dtype: object,
#   230285,
#   [0.8617869662239023, 0.7491908304169166]],
#  [96323    J. Rasmussen
#   Name: Name, dtype: object,
#   234827,
#   [0.8945759267892899, 0.6829791877367082]],
#  [93501    D. Sánchez
#   Name: Name, dtype: object,
#   220793,
#   [0.8298920239800802, 0.8090067863561838]],
#  [94130    Marcão
#   Name: Name, dtype: object,
#   234426,
#   [0.8651858550756496, 0.7340926328589993]],
#  [94814    Luiz Felipe
#   Name: Name, dtype: object,
#   236355,
#   [0.85027103238742, 0.7611410564261]],
#  [90102    L. Tousart
#   Name: Name, dtype: object,
#   227234,
#   [0.8525030980776133, 0.7449922068242019]],
#  [88397    Éder Militão
#   Name: Name, dtype: object,
#   240130,
#   [0.7969512172918451, 0.8437865023618571]],
#  [95786    Edgar
#   Name: Name, dtype: object,
#   247500,
#   [0.8722576530050238, 0.6910715899081105]],
#  [99051    M. Robinson
#   Name: Name, dtype: object,
#   237255,
#   [0.9335490812538784, 0.5597894285434243]],
#  [100542    M. Erlić
#   Name: Name, dtype: object,
#   244456,
#   [0.8998070458027906, 0.6232266322225896]],
#  [90198    D. Amartey
#   Name: Name, dtype: object,
#   212883,
#   [0.848141357580935, 0.7217400365159056]],
#  [90421    M. Holgate
#   Name: Name, dtype: object,
#   225024,
#   [0.8188786179990087, 0.7771110088619329]],
#  [95733    D. Heintz
#   Name: Name, dtype: object,
#   206198,
#   [0.8633941420306497, 0.6875159529231963]],
#  [95126    A. Walkes
#   Name: Name, dtype: object,
#   232252,
#   [0.9365660546631732, 0.5356621987735541]],
#  [90721    18 Mauro
#   Name: Name, dtype: object,
#   203434,
#   [0.8615472130101037, 0.6788307797368235]],
#  [93473    J. Andersen
#   Name: Name, dtype: object,
#   224221,
#   [0.8231913002807694, 0.7537393550242791]],
#  [95109    Vallejo
#   Name: Name, dtype: object,
#   225161,
#   [0.8288138739798806, 0.7390073557485426]],
#  [92711    S. Gigot
#   Name: Name, dtype: object,
#   219581,
#   [0.8187006322238021, 0.7546575519800632]],
#  [91461    C. Söyüncü
#   Name: Name, dtype: object,
#   232119,
#   [0.7795072205511304, 0.8316832098298995]],
#  [98418    T. Phete
#   Name: Name, dtype: object,
#   231688,
#   [0.8923780732917098, 0.6024287678505366]],
#  [89694    D. Kohr
#   Name: Name, dtype: object,
#   212212,
#   [0.8331457548577088, 0.715585876216813]],
#  [99667    A. Miron
#   Name: Name, dtype: object,
#   248002,
#   [0.9445985960407631, 0.4927540851340742]],
#  [98402    Pablo Marí
#   Name: Name, dtype: object,
#   206654,
#   [0.8180203130100205, 0.7365107149163532]],
#  [94714    K. Rekik
#   Name: Name, dtype: object,
#   205193,
#   [0.8262730552280072, 0.7171635981180206]],
#  [100303    L. Abubakar
#   Name: Name, dtype: object,
#   237214,
#   [0.9093208770646356, 0.5471882829051332]],
#  [88495    Mario Hermoso
#   Name: Name, dtype: object,
#   229668,
#   [0.7553077919175806, 0.8504062912882222]],
#  [96951    Dani Calvo
#   Name: Name, dtype: object,
#   219180,
#   [0.874364069268592, 0.6033303349741965]],
#  [93233    Joaquín
#   Name: Name, dtype: object,
#   232132,
#   [0.8130359707094648, 0.7223052426467557]],
#  [99299    G. Maripán
#   Name: Name, dtype: object,
#   219145,
#   [0.7992611301859731, 0.7475690535790442]],
#  [88373    S. Umtiti
#   Name: Name, dtype: object,
#   205600,
#   [0.7687828006999387, 0.7921070002648924]],
#  [93553    M. Niakhaté
#   Name: Name, dtype: object,
#   225859,
#   [0.8141608417748337, 0.7015961199758897]],
#  [91213    O. Alderete
#   Name: Name, dtype: object,
#   240359,
#   [0.8080817452246375, 0.7105204231231791]],
#  [94910    R. Khedira
#   Name: Name, dtype: object,
#   211999,
#   [0.7993111567687984, 0.7267859624235352]],
#  [96182    21 V. Jovanović
#   Name: Name, dtype: object,
#   233219,
#   [0.8285382952927448, 0.6667977123349982]],
#  [89881    D. Martínez
#   Name: Name, dtype: object,
#   241569,
#   [0.8045718203130975, 0.7126488287156946]],
#  [96885    B. Gimber
#   Name: Name, dtype: object,
#   228883,
#   [0.8836136639275198, 0.5558062013028126]],
#  [101464    H. Araki
#   Name: Name, dtype: object,
#   247266,
#   [0.8848340050531449, 0.5487934300139851]],
#  [96279    Murilo
#   Name: Name, dtype: object,
#   240115,
#   [0.8053627163773696, 0.7011842267769404]],
#  [92524    K. N'Doram
#   Name: Name, dtype: object,
#   229011,
#   [0.8443932350309653, 0.6231905844224731]],
#  [95238    J. Knight
#   Name: Name, dtype: object,
#   237213,
#   [0.8886111675846413, 0.5356293306905806]],
#  [94832    F. Wadja
#   Name: Name, dtype: object,
#   240454,
#   [0.8880718035036919, 0.5316946833008392]],
#  [87860    W. Ndidi
#   Name: Name, dtype: object,
#   226790,
#   [0.690323449333382, 0.9203355854910604]],
#  [100736    21 P. Gouano
#   Name: Name, dtype: object,
#   204886,
#   [0.8337878804949804, 0.6371300199742259]],
#  [92358    Rúben Semedo
#   Name: Name, dtype: object,
#   216778,
#   [0.7767475864931219, 0.7454688422021114]],
#  [91701    C. Mbemba
#   Name: Name, dtype: object,
#   210897,
#   [0.7579001023719201, 0.7769612558272474]],
#  [95157    Z. Al Sahafi
#   Name: Name, dtype: object,
#   231821,
#   [0.8959770574128387, 0.5036107033580431]],
#  [92413    R. Yates
#   Name: Name, dtype: object,
#   235642,
#   [0.8401487853946816, 0.6121317597572089]],
#  [93404    N. Aguerd
#   Name: Name, dtype: object,
#   244749,
#   [0.7859109145196501, 0.7161817658491686]],
#  [99330    C. Salcedo
#   Name: Name, dtype: object,
#   212888,
#   [0.8135966832362074, 0.6606353581032726]],
#  [91964    F. Ricca
#   Name: Name, dtype: object,
#   232437,
#   [0.8167865254423061, 0.6506438498047751]],
#  [95227    21 Y. Vorogovskiy
#   Name: Name, dtype: object,
#   251266,
#   [0.8630962528617298, 0.5498094873299009]],
#  [94491    L. Takács
#   Name: Name, dtype: object,
#   253695,
#   [0.8173851768730689, 0.6361050414184323]],
#  [101366    J. Cascante
#   Name: Name, dtype: object,
#   242533,
#   [0.851985990536594, 0.5586110330793346]],
#  [97542    M. Brizuela
#   Name: Name, dtype: object,
#   252168,
#   [0.8158707657612261, 0.6284543890007451]],
#  [94956    21 U. Spajić
#   Name: Name, dtype: object,
#   215892,
#   [0.7848922863033434, 0.6893109740058135]],
#  [97885    21 V. Lystsov
#   Name: Name, dtype: object,
#   212341,
#   [0.8873634338151904, 0.48668187581913946]],
#  [89591    P. McNair
#   Name: Name, dtype: object,
#   213697,
#   [0.8087736190784246, 0.6407694060549699]],
#  [96868    Ferro
#   Name: Name, dtype: object,
#   242236,
#   [0.7445945825692166, 0.7672499333728127]],
#  [88253    D. Zakaria
#   Name: Name, dtype: object,
#   229261,
#   [0.7195708168949692, 0.8157038140130344]],
#  [90131    D. Luckassen
#   Name: Name, dtype: object,
#   224242,
#   [0.8307656366283122, 0.5943405967860359]],
#  [94888    A. Briançon
#   Name: Name, dtype: object,
#   223138,
#   [0.7925907307875762, 0.6676148840806141]],
#  [100680    F. Sierralta
#   Name: Name, dtype: object,
#   228681,
#   [0.8235862839922937, 0.605365913962372]],
#  [99864    H. Martínez
#   Name: Name, dtype: object,
#   235665,
#   [0.8913526521041913, 0.47017085212826804]],
#  [92281    J. Gomez
#   Name: Name, dtype: object,
#   225100,
#   [0.7076125440829759, 0.8236723218454948]],
#  [89974    Yeray
#   Name: Name, dtype: object,
#   227950,
#   [0.6994100106836549, 0.8379086483754202]],
#  [94625    21 Bruno Viana
#   Name: Name, dtype: object,
#   234226,
#   [0.746462719081861, 0.7448823020916547]],
#  [95056    N. Milenković
#   Name: Name, dtype: object,
#   238095,
#   [0.760107968238612, 0.7176384478095229]],
#  [91494    A. Barboza
#   Name: Name, dtype: object,
#   229749,
#   [0.7507857426287069, 0.7344032652254256]],
#  [100283    E. Godoy
#   Name: Name, dtype: object,
#   215178,
#   [0.8392867363607674, 0.5503538568931661]],
#  [95894    B. Blasi
#   Name: Name, dtype: object,
#   231538,
#   [0.8163176634924741, 0.5948519587357516]],
#  [88259    Palhinha
#   Name: Name, dtype: object,
#   229391,
#   [0.663874952721629, 0.8916361125855765]],
#  [88841    A. Laporte
#   Name: Name, dtype: object,
#   212218,
#   [0.6537663347199998, 0.9101552844944683]],
#  [92613    I. Šunjić
#   Name: Name, dtype: object,
#   244271,
#   [0.7761429850292352, 0.6682399560798717]],
#  [93617    A. Romagnoli
#   Name: Name, dtype: object,
#   210413,
#   [0.6782581218249543, 0.8601041419613713]],
#  [92692    He Chao
#   Name: Name, dtype: object,
#   224470,
#   [0.8371743323905543, 0.5454986401832927]],
#  [95305    Nathan
#   Name: Name, dtype: object,
#   225529,
#   [0.8165771337129033, 0.5786146967209667]],
#  [94558    David García
#   Name: Name, dtype: object,
#   225341,
#   [0.7189765137471525, 0.7646555770874703]],
#  [95111    21 A. Nkaka
#   Name: Name, dtype: object,
#   229040,
#   [0.8469504252121088, 0.5093208957812848]],
#  [92497    P. Hatzidiakos
#   Name: Name, dtype: object,
#   229150,
#   [0.788197692692516, 0.62503801992207]],
#  [96937    David Goldar
#   Name: Name, dtype: object,
#   222407,
#   [0.824087136364031, 0.5487503093851059]],
#  [94875    A. Erlingmark
#   Name: Name, dtype: object,
#   238270,
#   [0.8146760012511777, 0.5651108303671225]],
#  [93333    J. Elez
#   Name: Name, dtype: object,
#   218341,
#   [0.8320267783202292, 0.5303501955735936]],
#  [96839    Sori Mané
#   Name: Name, dtype: object,
#   251504,
#   [0.799801274022741, 0.5898463259336403]],
#  [89095    J. Stones
#   Name: Name, dtype: object,
#   203574,
#   [0.6582238614238155, 0.8610485411398431]],
#  [93316    M. Udol
#   Name: Name, dtype: object,
#   229236,
#   [0.7797761542903461, 0.6201595143915177]],
#  [93090    W. Hoedt
#   Name: Name, dtype: object,
#   216774,
#   [0.7364707668841219, 0.7054571411350491]],
#  [94510    A. Frías
#   Name: Name, dtype: object,
#   251886,
#   [0.7409450700333989, 0.6966085621445378]],
#  [93369    J. Robinson
#   Name: Name, dtype: object,
#   199027,
#   [0.7711898766383899, 0.6362626301737774]],
#  [100019    M. Andersen
#   Name: Name, dtype: object,
#   228419,
#   [0.7549021081695296, 0.6678098637601607]],
#  [89354    L. Romo
#   Name: Name, dtype: object,
#   243015,
#   [0.7292715982461311, 0.7177957830627809]],
#  [88013    Marquinhos
#   Name: Name, dtype: object,
#   207865,
#   [0.6144522279831313, 0.9438673627577375]],
#  [94155    M. Loum
#   Name: Name, dtype: object,
#   245021,
#   [0.7478742174102389, 0.6777902702752543]],
#  [94106    Aritz Elustondo
#   Name: Name, dtype: object,
#   226221,
#   [0.6974474082040889, 0.7766778556014069]],
#  [95441    E. Lomotey
#   Name: Name, dtype: object,
#   243995,
#   [0.8149104222960493, 0.5432077474091618]],
#  [99250    A. Disasi
#   Name: Name, dtype: object,
#   229942,
#   [0.726231446917218, 0.7177650264617892]],
#  [96243    M. Kilman
#   Name: Name, dtype: object,
#   245336,
#   [0.7892272691598627, 0.5933830326800804]],
#  [93146    P. Dawidowicz
#   Name: Name, dtype: object,
#   213404,
#   [0.7350647284249593, 0.6961929616581759]],
#  [101467    Pedrão
#   Name: Name, dtype: object,
#   258356,
#   [0.8080322658124507, 0.5521209200420417]],
#  [89666    C. Paterson
#   Name: Name, dtype: object,
#   210724,
#   [0.7761472935218355, 0.6114537247594922]],
#  [90125    S. Vegas
#   Name: Name, dtype: object,
#   219087,
#   [0.7353693408995907, 0.6836242547793474]],
#  [96538    S. O'Neill
#   Name: Name, dtype: object,
#   211581,
#   [0.8436302444469372, 0.4660772862079771]],
#  [96217    A. Mumin
#   Name: Name, dtype: object,
#   235662,
#   [0.8025282139600324, 0.5466428118012419]],
#  [90273    Gregore
#   Name: Name, dtype: object,
#   251410,
#   [0.7331015558529816, 0.6758028064242356]],
#  [97616    A. Pérez
#   Name: Name, dtype: object,
#   221312,
#   [0.7710203792418331, 0.5996363783847423]],
#  [95284    J. Nikolaou
#   Name: Name, dtype: object,
#   238619,
#   [0.7904161564779608, 0.560684533930711]],
#  [93822    M. Friedl
#   Name: Name, dtype: object,
#   237595,
#   [0.7396366032523476, 0.6571301791781233]],
#  [99108    Javi Sánchez
#   Name: Name, dtype: object,
#   245238,
#   [0.7634707030892441, 0.6088414569559712]],
#  [88614    N. Mukiele
#   Name: Name, dtype: object,
#   226166,
#   [0.6564925500401286, 0.8190754262625618]],
#  [95268    Glauder
#   Name: Name, dtype: object,
#   239608,
#   [0.7764211529503001, 0.5798061231457182]],
#  [99761    N. Phillips
#   Name: Name, dtype: object,
#   240926,
#   [0.7323063649692467, 0.6641091603271037]],
#  [91024    A. Djiku
#   Name: Name, dtype: object,
#   212219,
#   [0.7113354258592102, 0.7047569658415668]],
#  [96310    A. Dźwigała
#   Name: Name, dtype: object,
#   211362,
#   [0.8045093149477527, 0.5199866135152179]],
#  [92212    D. Hovorka
#   Name: Name, dtype: object,
#   240033,
#   [0.7092916712185199, 0.7066418204349912]],
#  [98794    Lyanco
#   Name: Name, dtype: object,
#   230672,
#   [0.739237747098351, 0.6467014474136479]],
#  [98379    A. Groiß
#   Name: Name, dtype: object,
#   245719,
#   [0.8058384277105985, 0.5126932257548471]],
#  [94333    L. Abram
#   Name: Name, dtype: object,
#   234178,
#   [0.7065210947001599, 0.7038713393391893]],
#  [98133    Relu
#   Name: Name, dtype: object,
#   248070,
#   [0.8357959892634772, 0.44491904102120094]],
#  [98817    A. Al Amri
#   Name: Name, dtype: object,
#   241197,
#   [0.7357481411464643, 0.6418677727909556]],
#  [96454    A. Esiti
#   Name: Name, dtype: object,
#   220921,
#   [0.7253450115282059, 0.6612470489907295]],
#  [91945    R. Bauer
#   Name: Name, dtype: object,
#   223765,
#   [0.7343323474444973, 0.6428470094362829]],
#  [99733    T. Iwanami
#   Name: Name, dtype: object,
#   232894,
#   [0.7870874109807381, 0.5359726811009866]],
#  [93690    D. Cavaré
#   Name: Name, dtype: object,
#   219803,
#   [0.8043091915246336, 0.501606009631656]],
#  [92695    J. Giménez
#   Name: Name, dtype: object,
#   216460,
#   [0.6103142876687264, 0.8822155167022308]],
#  [92459    A. Öztürk
#   Name: Name, dtype: object,
#   202889,
#   [0.7381039851735809, 0.6293311213916164]],
#  [96884    N. Casale
#   Name: Name, dtype: object,
#   239770,
#   [0.8109735001206853, 0.4847082785291548]],
#  [94304    J. Rodríguez
#   Name: Name, dtype: object,
#   244950,
#   [0.7143187827081982, 0.6730062990035149]],
#  [97445    D. Iorfa
#   Name: Name, dtype: object,
#   218658,
#   [0.7433541570010477, 0.614200613392539]],
#  [91543    E. Konsa
#   Name: Name, dtype: object,
#   227678,
#   [0.6740532989403005, 0.7494123937918196]],
#  [94630    S. Memišević
#   Name: Name, dtype: object,
#   235544,
#   [0.7223852372376045, 0.6526402614682975]],
#  [100615    Iván Márquez
#   Name: Name, dtype: object,
#   220385,
#   [0.8104626805481153, 0.47736607481772003]],
#  [96667    B. Kwiecień
#   Name: Name, dtype: object,
#   212736,
#   [0.7869523089448158, 0.5186571153224073]],
#  [100470    18 R. Brown
#   Name: Name, dtype: object,
#   203059,
#   [0.8571414690502667, 0.3786990690810179]],
#  [96014    M. Adams
#   Name: Name, dtype: object,
#   242708,
#   [0.7731369248870007, 0.5442682177003921]],
#  [96706    Jorge Meré
#   Name: Name, dtype: object,
#   223033,
#   [0.7259316655642559, 0.6366099888885727]],
#  [91899    H. Choudhury
#   Name: Name, dtype: object,
#   228332,
#   [0.6812179821426444, 0.7221171309835535]],
#  [96584    W. Zahibo
#   Name: Name, dtype: object,
#   206207,
#   [0.7821953803092749, 0.5221786382139588]],
#  [96922    L. Fröde
#   Name: Name, dtype: object,
#   227932,
#   [0.7578764901309066, 0.5701343721834146]],
#  [89061    M. Ginter
#   Name: Name, dtype: object,
#   207862,
#   [0.6211707839261263, 0.8395483358884588]],
#  [97721    21 M. Barać
#   Name: Name, dtype: object,
#   244648,
#   [0.7601803733777988, 0.5648559829427882]],
#  [88925    K. Ayhan
#   Name: Name, dtype: object,
#   207790,
#   [0.6764583038206299, 0.725551467565143]],
#  [91439    C. Romero
#   Name: Name, dtype: object,
#   232488,
#   [0.6100823530020103, 0.8548134066252028]],
#  [98100    Willyan
#   Name: Name, dtype: object,
#   251901,
#   [0.7306201980980149, 0.6165243073971703]],
#  [91923    A. Matusiwa
#   Name: Name, dtype: object,
#   239356,
#   [0.6881133313980335, 0.6988589300042866]],
#  [94397    D. Ćaleta-Car
#   Name: Name, dtype: object,
#   225263,
#   [0.6486421103322084, 0.775772096072569]],
#  [93245    20 U. Agbo
#   Name: Name, dtype: object,
#   226289,
#   [0.7377354137091787, 0.5999385173218634]],
#  [101768    A. Jackson
#   Name: Name, dtype: object,
#   204219,
#   [0.8051731975620307, 0.4654940540753905]],
#  [97771    P. Cissé
#   Name: Name, dtype: object,
#   228386,
#   [0.6819603979256312, 0.7083778433168233]],
#  [92396    A. Tuanzebe
#   Name: Name, dtype: object,
#   231485,
#   [0.6878619495191614, 0.6923593974144892]],
#  [97688    L. Jäger
#   Name: Name, dtype: object,
#   223427,
#   [0.7779125700982699, 0.513518827563236]],
#  [98076    L. Mühl
#   Name: Name, dtype: object,
#   233960,
#   [0.7516421349430351, 0.5593135362334671]],
#  [89236    Núrio Fortuna
#   Name: Name, dtype: object,
#   221994,
#   [0.7255204780133813, 0.6098154516557884]],
#  [89504    D. Bronn
#   Name: Name, dtype: object,
#   235565,
#   [0.682527665942575, 0.6943128325189489]],
#  [91838    M. Wöber
#   Name: Name, dtype: object,
#   231838,
#   [0.6888528603824468, 0.6813937636045831]],
#  [99004    L. Samson
#   Name: Name, dtype: object,
#   234282,
#   [0.7649293071369216, 0.5302470480460478]],
#  [91066    Fali
#   Name: Name, dtype: object,
#   229628,
#   [0.6709086286000038, 0.7127791005981983]],
#  [90872    A. Artean
#   Name: Name, dtype: object,
#   248111,
#   [0.7538871323946303, 0.5459809717113355]],
#  [98558    G. Magnani
#   Name: Name, dtype: object,
#   242392,
#   [0.701321546840712, 0.646944794680048]],
#  [95490    R. Krauße
#   Name: Name, dtype: object,
#   232406,
#   [0.7231562944779122, 0.6017579004791521]],
#  [90931    L. Donnelly
#   Name: Name, dtype: object,
#   215820,
#   [0.7736324922297915, 0.5005699042123634]],
#  [94238    Y. Mina
#   Name: Name, dtype: object,
#   220523,
#   [0.624225237780093, 0.7927262755408742]],
#  [100777    Philipe Sampaio
#   Name: Name, dtype: object,
#   224376,
#   [0.7219823806096478, 0.5995849148993548]],
#  [96830    T. Lockyer
#   Name: Name, dtype: object,
#   211363,
#   [0.7305857937874896, 0.5809775098613825]],
#  [98161    C. Awaziem
#   Name: Name, dtype: object,
#   232693,
#   [0.6948016513369685, 0.650443821281987]],
#  [96683    Catena
#   Name: Name, dtype: object,
#   243976,
#   [0.6943525627822278, 0.6505027346414585]],
#  [90775    J. Foyth
#   Name: Name, dtype: object,
#   237221,
#   [0.6793794038027245, 0.6799772477206979]],
#  [99369    Unai Núñez
#   Name: Name, dtype: object,
#   240900,
#   [0.6245688018423468, 0.7877985846778479]],
#  [89760    21 B. Addae
#   Name: Name, dtype: object,
#   210429,
#   [0.7447163412905417, 0.5478416804645062]],
#  [99322    J. Bednarek
#   Name: Name, dtype: object,
#   220570,
#   [0.6529422649143433, 0.7287007620711174]],
#  [89985    K. Amian
#   Name: Name, dtype: object,
#   231235,
#   [0.6967428423553524, 0.641002143282187]],
#  [97826    G. Rea
#   Name: Name, dtype: object,
#   215570,
#   [0.7118003016788069, 0.6106947223826356]],
#  [96946    M. Hofmann
#   Name: Name, dtype: object,
#   215370,
#   [0.7289451906920223, 0.5752765859127252]],
#  [97432    K. Omeruo
#   Name: Name, dtype: object,
#   207624,
#   [0.6697067736092575, 0.6890357426755942]],
#  [90028    A. Diallo
#   Name: Name, dtype: object,
#   225711,
#   [0.6259282802581727, 0.7748677476894841]],
#  [100811    Ivanildo Fernandes
#   Name: Name, dtype: object,
#   244963,
#   [0.7039573776323461, 0.6198996565249288]],
#  [90354    T. Fosu-Mensah
#   Name: Name, dtype: object,
#   232270,
#   [0.6856561419979142, 0.6547437643167595]],
#  [100438    B. Passi
#   Name: Name, dtype: object,
#   237368,
#   [0.7746913503501512, 0.477504914446162]],
#  [91835    F. Miguel
#   Name: Name, dtype: object,
#   226130,
#   [0.7068730991641251, 0.6108905032905116]],
#  [88541    Juiano Mestres
#   Name: Name, dtype: object,
#   230225,
#   [0.5903724103075753, 0.8398267122042608]],
#  [98441    Verdasca
#   Name: Name, dtype: object,
#   233413,
#   [0.7649716649526408, 0.4944380494244179]],
#  [98521    21 G. Conti
#   Name: Name, dtype: object,
#   221219,
#   [0.6845850977214926, 0.6529842016690527]],
#  [89398    M. Akanji
#   Name: Name, dtype: object,
#   229237,
#   [0.6217427962929147, 0.7766899711260385]],
#  [97911    J. Lascelles
#   Name: Name, dtype: object,
#   203487,
#   [0.641198645486673, 0.7380750356455021]],
#  [94099    Robson Bambu
#   Name: Name, dtype: object,
#   256343,
#   [0.709331801312382, 0.6015924028127054]],
#  [93960    16 Breno
#   Name: Name, dtype: object,
#   180955,
#   [0.6804994097817813, 0.6569011696015635]],
#  [101076    Rodrigo Ely
#   Name: Name, dtype: object,
#   202445,
#   [0.6722957974137178, 0.6712963775193636]],
#  [98163    E. Cabaco
#   Name: Name, dtype: object,
#   236331,
#   [0.6534979636156254, 0.7069922080960594]],
#  [90738    Calero
#   Name: Name, dtype: object,
#   240289,
#   [0.6519011954113649, 0.7098191484843153]],
#  [95228    A. Çankaya
#   Name: Name, dtype: object,
#   258725,
#   [0.7268199645790595, 0.5616185750688402]],
#  [102152    21 Javi Jiménez
#   Name: Name, dtype: object,
#   237032,
#   [0.7640170776230965, 0.48645328183528314]],
#  [95569    21 K. Mets
#   Name: Name, dtype: object,
#   226506,
#   [0.7438807642829222, 0.5261218063619271]],
#  [89937    F. Guilbert
#   Name: Name, dtype: object,
#   227222,
#   [0.6496644243085183, 0.7076125759615585]],
#  [97387    G. Ferrari
#   Name: Name, dtype: object,
#   245439,
#   [0.7340086135999985, 0.5402275670940647]],
#  [95540    J. Glesnes
#   Name: Name, dtype: object,
#   233400,
#   [0.7191787579265184, 0.5671227483898756]],
#  [94349    R. Lauritsen
#   Name: Name, dtype: object,
#   225948,
#   [0.669225835215729, 0.6654053659951857]],
#  [90375    Rúben Vezo
#   Name: Name, dtype: object,
#   215399,
#   [0.6367164777061999, 0.7274959566666367]],
#  [91458    J. Escobar
#   Name: Name, dtype: object,
#   247881,
#   [0.6617753093675159, 0.67753137060232]],
#  [91797    20 L. Hyam
#   Name: Name, dtype: object,
#   194792,
#   [0.7403934012063861, 0.5224155562980058]],
#  [97013    B. Engels
#   Name: Name, dtype: object,
#   210828,
#   [0.6497952875538161, 0.7008643363667263]],
#  [96676    A. Hanche-Olsen
#   Name: Name, dtype: object,
#   228518,
#   [0.7059130790797504, 0.5892997404495826]],
#  [98268    L. Magallán
#   Name: Name, dtype: object,
#   211263,
#   [0.6921395795973028, 0.6157137772001101]],
#  [97937    N. De Medina
#   Name: Name, dtype: object,
#   229107,
#   [0.7527342384480545, 0.495454096128343]],
#  [93750    F. Arce
#   Name: Name, dtype: object,
#   222379,
#   [0.7404676497958457, 0.5180232574186857]],
#  [97662    21 R. Gelmi
#   Name: Name, dtype: object,
#   227700,
#   [0.7492869854584867, 0.499564486348911]],
#  [94935    P. Jaroszyński
#   Name: Name, dtype: object,
#   219661,
#   [0.7395777688841259, 0.5157367898819175]],
#  [97902    Rodri Tarín
#   Name: Name, dtype: object,
#   228828,
#   [0.7076420911780901, 0.5785054748026869]],
#  [97548    Maracás
#   Name: Name, dtype: object,
#   251681,
#   [0.6721100477454993, 0.6476936044101149]],
#  [92686    19 S. Medojević
#   Name: Name, dtype: object,
#   207523,
#   [0.6769920843380903, 0.6344052540968798]],
#  [96381    S. Sinyan
#   Name: Name, dtype: object,
#   233820,
#   [0.7463241365487118, 0.4971744134572722]],
#  [91716    Dória
#   Name: Name, dtype: object,
#   209329,
#   [0.6340573683058407, 0.7166886002078879]],
#  [94610    21 Park Dong Jin
#   Name: Name, dtype: object,
#   233279,
#   [0.7087291650118613, 0.5690013409264972]],
#  [96803    J. Lucumí
#   Name: Name, dtype: object,
#   231207,
#   [0.6567321478479691, 0.6706231231579952]],
#  [97618    C. Akas
#   Name: Name, dtype: object,
#   241765,
#   [0.7548410158758615, 0.47540891325453144]],
#  [91896    J. Fulton
#   Name: Name, dtype: object,
#   221890,
#   [0.6524480180245905, 0.677375206536397]],
#  [88999    L. Martínez Quarta
#   Name: Name, dtype: object,
#   228708,
#   [0.621796880396442, 0.7370954623267022]],
#  [100489    Tobias Figueiredo
#   Name: Name, dtype: object,
#   212231,
#   [0.6743214505197261, 0.6308727508482237]],
#  [99847    Rodrigo Becão
#   Name: Name, dtype: object,
#   238621,
#   [0.6389254289230762, 0.6998382067548274]],
#  [94809    G. Mancini
#   Name: Name, dtype: object,
#   229582,
#   [0.583660413499306, 0.8083665887255944]],
#  [99789    A. Ale
#   Name: Name, dtype: object,
#   254603,
#   [0.736825808656894, 0.5060506845097744]],
#  [92529    21 T. Lam
#   Name: Name, dtype: object,
#   208018,
#   [0.705682526588641, 0.5672787483750419]],
#  [90602    N. Stark
#   Name: Name, dtype: object,
#   212977,
#   [0.6295463990535016, 0.7167532775156116]],
#  [99711    F. Brorsson
#   Name: Name, dtype: object,
#   226523,
#   [0.7182888647335297, 0.5415930093114963]],
#  [90045    J. Denayer
#   Name: Name, dtype: object,
#   220182,
#   [0.5886902363955683, 0.7962692131559619]],
#  [99049    M. James
#   Name: Name, dtype: object,
#   227847,
#   [0.7374585519652072, 0.5019452510354079]],
#  [100443    C. Burgess
#   Name: Name, dtype: object,
#   216744,
#   [0.7314928522612709, 0.5122903385818214]],
#  [96989    A. Gogić
#   Name: Name, dtype: object,
#   216526,
#   [0.6829067557661535, 0.6076335856230304]],
#  [98893    E. Palmer-Brown
#   Name: Name, dtype: object,
#   219461,
#   [0.7243219584833311, 0.5240225584074782]],
#  [102445    A. Halme
#   Name: Name, dtype: object,
#   234290,
#   [0.7295606724951574, 0.5096523029933621]],
#  [97702    N. Rapp
#   Name: Name, dtype: object,
#   227511,
#   [0.6971683333950878, 0.5719009896968181]],
#  [96672    B. White
#   Name: Name, dtype: object,
#   231936,
#   [0.622420999983206, 0.7179479146627066]],
#  [94539    J. Martínez
#   Name: Name, dtype: object,
#   254891,
#   [0.666530559421048, 0.6299326146614341]],
#  [96576    I. Nedelcearu
#   Name: Name, dtype: object,
#   242614,
#   [0.6584765132712591, 0.6448812891445348]],
#  [90188    C. Lenglet
#   Name: Name, dtype: object,
#   220440,
#   [0.5703968920106034, 0.8181075139967519]],
#  [93062    F. Tomori
#   Name: Name, dtype: object,
#   232756,
#   [0.5907709208490615, 0.7759400430894385]],
#  [99576    M. Siby
#   Name: Name, dtype: object,
#   246549,
#   [0.7678849331262018, 0.42609104037935164]],
#  [89065    D. Hancko
#   Name: Name, dtype: object,
#   247103,
#   [0.6326974092133746, 0.6927059685095378]],
#  [101615    J. Elliott
#   Name: Name, dtype: object,
#   238008,
#   [0.6672703952036786, 0.6231225768874316]],
#  [100820    Bruno Wilson
#   Name: Name, dtype: object,
#   236924,
#   [0.6838294933701181, 0.589868924134418]],
#  [98053    W. Faes
#   Name: Name, dtype: object,
#   235036,
#   [0.6473594551583502, 0.6605760077087487]],
#  [100189    21 S. Perić
#   Name: Name, dtype: object,
#   244496,
#   [0.7425750275644912, 0.4723093374050223]],
#  [99748    M. Heylen
#   Name: Name, dtype: object,
#   212120,
#   [0.6767724696884482, 0.6014794500406329]],
#  [99084    A. Karazor
#   Name: Name, dtype: object,
#   239096,
#   [0.6700530850911194, 0.6133737860084557]],
#  [99188    J. Simpson
#   Name: Name, dtype: object,
#   230882,
#   [0.7095852426157262, 0.5346106312486564]],
#  [95440    J. Hanson
#   Name: Name, dtype: object,
#   213376,
#   [0.7209518447709864, 0.5115388314522258]],
#  [100456    21 E. Amor
#   Name: Name, dtype: object,
#   226170,
#   [0.6595485318751007, 0.6312774213193835]],
#  [92802    16 R. Strasser
#   Name: Name, dtype: object,
#   190604,
#   [0.7267977613173875, 0.4983915844358825]],
#  [96165    K. Tshiembe
#   Name: Name, dtype: object,
#   238725,
#   [0.7162278024412482, 0.5183515799982736]],
#  [95234    21 T. Lapslie
#   Name: Name, dtype: object,
#   213635,
#   [0.7334971765054431, 0.4834547716243647]],
#  [95734    21 J. Flanagan
#   Name: Name, dtype: object,
#   201999,
#   [0.6581144317868651, 0.628626678876489]],
#  [101040    F. Mayembo
#   Name: Name, dtype: object,
#   232136,
#   [0.7131991280296228, 0.5161394259045796]],
#  [99704    E. Segura
#   Name: Name, dtype: object,
#   237245,
#   [0.6822742252953595, 0.5765859998216625]],
#  [95297    R. Holding
#   Name: Name, dtype: object,
#   228295,
#   [0.5955186795029118, 0.7468063930535596]],
#  [90753    Li Ang
#   Name: Name, dtype: object,
#   224690,
#   [0.7243457418722216, 0.4891393563819386]],
#  [99884    M. Diaby
#   Name: Name, dtype: object,
#   248831,
#   [0.6176619935697987, 0.6990139719615668]],
#  [91819    21 W. Cartagena
#   Name: Name, dtype: object,
#   221664,
#   [0.6691049082215487, 0.5971797873918712]],
#  [94211    Marlon
#   Name: Name, dtype: object,
#   215703,
#   [0.6427498322926696, 0.6460024556206482]],
#  [92566    C. Montes
#   Name: Name, dtype: object,
#   229980,
#   [0.6177720069530573, 0.6949902947407833]],
#  [100540    M. Miazga
#   Name: Name, dtype: object,
#   215565,
#   [0.6349321296566104, 0.6585374456165577]],
#  [98396    21 E. Dabo
#   Name: Name, dtype: object,
#   228836,
#   [0.7656326200715335, 0.39984965512704634]],
#  [96489    Diego González
#   Name: Name, dtype: object,
#   227106,
#   [0.6594324076281987, 0.6091140463120647]],
#  [91677    Alfa Semedo
#   Name: Name, dtype: object,
#   239641,
#   [0.6613587868748305, 0.6046904792106601]],
#  [97633    G. Fechner
#   Name: Name, dtype: object,
#   233880,
#   [0.7182056786507116, 0.4924810067933631]],
#  [99548    S. Knežević
#   Name: Name, dtype: object,
#   234817,
#   [0.6865410195548833, 0.5540308036249]],
#  [93121    T. Payne
#   Name: Name, dtype: object,
#   209361,
#   [0.6921225901803248, 0.5406992026670556]],
#  [96302    I. Diop
#   Name: Name, dtype: object,
#   231633,
#   [0.5893839288956328, 0.7411855368117544]],
#  [97450    M. Fofana
#   Name: Name, dtype: object,
#   235849,
#   [0.6597584998653, 0.6015770295907754]],
#  [97372    J. de Wijs
#   Name: Name, dtype: object,
#   224186,
#   [0.663295002733032, 0.5937190883797874]],
#  [96363    W. Harding
#   Name: Name, dtype: object,
#   228225,
#   [0.7135752188275769, 0.4907006559372391]],
#  [95736    M. Helik
#   Name: Name, dtype: object,
#   219293,
#   [0.6411639315769048, 0.6333901981823216]],
#  [93346    Nouhou
#   Name: Name, dtype: object,
#   237469,
#   [0.685588935814055, 0.5426228478272013]],
#  [97813    N. Sundberg
#   Name: Name, dtype: object,
#   219950,
#   [0.7091902985462349, 0.495643005427277]],
#  [98504    M. Pongračić
#   Name: Name, dtype: object,
#   238370,
#   [0.6162455500426637, 0.6789061651571295]],
#  [100905    L. Gordinho
#   Name: Name, dtype: object,
#   219664,
#   [0.7391223118674451, 0.43484952878241956]],
#  [95584    C. Zock
#   Name: Name, dtype: object,
#   226550,
#   [0.7216316217801534, 0.4680555801183643]],
#  [98137    F. Aliti
#   Name: Name, dtype: object,
#   221989,
#   [0.7001163555981309, 0.5092374370513423]],
#  [92857    Jaílson
#   Name: Name, dtype: object,
#   234660,
#   [0.6685659975501701, 0.5694494741966415]],
#  [98316    J. Nilsson
#   Name: Name, dtype: object,
#   210802,
#   [0.6323134595484299, 0.6407760755689434]],
#  [90875    Bernardo
#   Name: Name, dtype: object,
#   232805,
#   [0.6417101411034176, 0.6216789242883543]],
#  [100960    M. Fritz
#   Name: Name, dtype: object,
#   239182,
#   [0.7390623641640476, 0.4257218927030096]],
#  [98882    T. Baumgartl
#   Name: Name, dtype: object,
#   223641,
#   [0.6444033776438656, 0.6123347584441299]],
#  [87912    R. Tapia
#   Name: Name, dtype: object,
#   220673,
#   [0.5576816124920996, 0.7812914716674044]],
#  [99255    J. Hoogma
#   Name: Name, dtype: object,
#   231823,
#   [0.6606480152254242, 0.5773361138185991]],
#  [97619    J. Bachmann
#   Name: Name, dtype: object,
#   224094,
#   [0.6863478800089496, 0.526368123304896]],
#  [98639    21 E. Velázquez
#   Name: Name, dtype: object,
#   225299,
#   [0.6439076507134025, 0.6087529846335029]],
#  [97998    José León
#   Name: Name, dtype: object,
#   223120,
#   [0.6962423593921587, 0.5042513538250515]],
#  [94076    S. Sarr
#   Name: Name, dtype: object,
#   230995,
#   [0.6752523389835314, 0.5435292282623144]],
#  [93727    N. Breitenbruch
#   Name: Name, dtype: object,
#   224049,
#   [0.6661013214270411, 0.5606474633803293]],
#  [96897    Lluís López
#   Name: Name, dtype: object,
#   234032,
#   [0.6398992439212197, 0.6113932301788073]],
#  [95754    Pol García
#   Name: Name, dtype: object,
#   211323,
#   [0.648265159872127, 0.5948706627953445]],
#  [95546    J. Castelletto
#   Name: Name, dtype: object,
#   213868,
#   [0.6154264301245059, 0.6595146581880743]],
#  [95977    Kim Min Jae
#   Name: Name, dtype: object,
#   237086,
#   [0.6264367680800784, 0.6357355950952994]],
#  [94947    I. Cissé
#   Name: Name, dtype: object,
#   208309,
#   [0.6768149484587614, 0.5352515384340782]],
#  [99947    M. Naderi
#   Name: Name, dtype: object,
#   244537,
#   [0.7088502984635963, 0.47161945704896985]],
#  [97436    Bremer
#   Name: Name, dtype: object,
#   239580,
#   [0.5839364385958734, 0.718042582317879]],
#  [100383    S. McKenna
#   Name: Name, dtype: object,
#   225974,
#   [0.6372336269796645, 0.6112227197361756]],
#  [95277    21 A. Cistana
#   Name: Name, dtype: object,
#   226260,
#   [0.6430399998186536, 0.5995292482008544]],
#  [99310    L. Šatka
#   Name: Name, dtype: object,
#   209232,
#   [0.6671384960644086, 0.5517741383262609]],
#  [98701    L. Sosa
#   Name: Name, dtype: object,
#   226386,
#   [0.6803186615706649, 0.5253367867778004]],
#  [98978    S. Hatanaka
#   Name: Name, dtype: object,
#   245785,
#   [0.6662828946493841, 0.55300150569259]],
#  [96915    K. Günter
#   Name: Name, dtype: object,
#   204451,
#   [0.6065196272324164, 0.6693118357239922]],
#  [98089    Unai Bilbao
#   Name: Name, dtype: object,
#   229360,
#   [0.6408470718071222, 0.6012013925686198]],
#  [95299    O. Kiomourtzoglou
#   Name: Name, dtype: object,
#   238965,
#   [0.6432391967245447, 0.5930594449884523]],
#  [100072    Jubal
#   Name: Name, dtype: object,
#   217565,
#   [0.6408062850171674, 0.5970638725153651]],
#  [99901    F. Kent
#   Name: Name, dtype: object,
#   220140,
#   [0.6887764226091304, 0.5022657235605372]],
#  [102356    M. Rohr
#   Name: Name, dtype: object,
#   251320,
#   [0.7166824940819394, 0.44709856483059146]],
#  [100067    R. Takao
#   Name: Name, dtype: object,
#   248810,
#   [0.7147014739383243, 0.45057490755534485]],
#  [94651    R. Koch
#   Name: Name, dtype: object,
#   236532,
#   [0.5735128318182569, 0.727407072080863]],
#  [95702    P. Chato
#   Name: Name, dtype: object,
#   244489,
#   [0.7032043801578666, 0.4700141768612617]],
#  [100422    J. Glad
#   Name: Name, dtype: object,
#   222557,
#   [0.6488214561644235, 0.5766258998163633]],
#  [99307    21 D. Wynne
#   Name: Name, dtype: object,
#   226057,
#   [0.7052986743906481, 0.4640088639081557]],
#  [100608    Ygor Nogueira
#   Name: Name, dtype: object,
#   225386,
#   [0.6340008350366316, 0.602471454445924]],
#  [97613    V. Ghiță
#   Name: Name, dtype: object,
#   248105,
#   [0.6734978622605656, 0.5205015526225939]],
#  [94908    E. Cömert
#   Name: Name, dtype: object,
#   233885,
#   [0.6460634781670616, 0.5734588843895443]],
#  [91731    M. Škriniar
#   Name: Name, dtype: object,
#   232363,
#   [0.48676075293351745, 0.8871876916262156]],
#  [98585    S. Svarnas
#   Name: Name, dtype: object,
#   245540,
#   [0.636136451209658, 0.5910599619187568]],
#  [100604    G. Nyamsi
#   Name: Name, dtype: object,
#   239575,
#   [0.6490486765942897, 0.5654115966886025]],
#  [94168    J. Kerr
#   Name: Name, dtype: object,
#   225589,
#   [0.658085249926223, 0.5457247756887302]],
#  [94661    A. Christensen
#   Name: Name, dtype: object,
#   213661,
#   [0.5317977152531702, 0.7937657746859648]],
#  [99358    J. Cooper
#   Name: Name, dtype: object,
#   216481,
#   [0.6274970214246414, 0.6046634871087727]],
#  [98964    D. Lavalée
#   Name: Name, dtype: object,
#   236712,
#   [0.6532676970260363, 0.5510663005073846]],
#  [99741    D. Batubinsika
#   Name: Name, dtype: object,
#   239814,
#   [0.6222144466060664, 0.6096628482992096]],
#  [94578    21 B. Kuscevic
#   Name: Name, dtype: object,
#   225236,
#   [0.6132049092024633, 0.6272843685953808]],
#  [99259    N. Lozano
#   Name: Name, dtype: object,
#   243944,
#   [0.6694486677988529, 0.5155207413505093]],
#  [97118    Pablo Iñiguez
#   Name: Name, dtype: object,
#   206546,
#   [0.6614819470148952, 0.526474343057212]],
#  [99716    H. Moukoudi
#   Name: Name, dtype: object,
#   228732,
#   [0.582063159076011, 0.6825645890873655]],
#  [96996    M. Torres
#   Name: Name, dtype: object,
#   223752,
#   [0.666389560730201, 0.5159981940872493]],
#  [95721    J. Une-Larsson
#   Name: Name, dtype: object,
#   213497,
#   [0.6007703712945766, 0.6452384032901156]],
#  [98434    21 V. Cabrera
#   Name: Name, dtype: object,
#   221619,
#   [0.6309040642566703, 0.5856759057243481]],
#  [91297    18 E. Makeev
#   Name: Name, dtype: object,
#   192155,
#   [0.6340145451341037, 0.5791487722493744]],
#  [98975    G. Henriksson
#   Name: Name, dtype: object,
#   245722,
#   [0.6638312661790915, 0.5176516893117362]],
#  [98707    José Carlos
#   Name: Name, dtype: object,
#   222466,
#   [0.6895026604115253, 0.46662433427553773]],
#  [92366    D. Saddiki
#   Name: Name, dtype: object,
#   243733,
#   [0.6386028272210493, 0.5656489360900613]],
#  [97840    F. Kunze
#   Name: Name, dtype: object,
#   251429,
#   [0.614627848482292, 0.612670537090629]],
#  [99881    J. Novillo
#   Name: Name, dtype: object,
#   246667,
#   [0.6071565539581385, 0.6268673112810208]],
#  [96819    A. Szalai
#   Name: Name, dtype: object,
#   253170,
#   [0.5874457381846511, 0.6650131219945382]],
#  [95512    K. Bryan
#   Name: Name, dtype: object,
#   220197,
#   [0.6872978925027561, 0.46794083452987567]],
#  [99821    D. O'Shaughnessy
#   Name: Name, dtype: object,
#   221486,
#   [0.6819281978763113, 0.47842450936976694]],
#  [94113    M. Heyer
#   Name: Name, dtype: object,
#   238593,
#   [0.6269974398041968, 0.5863245105709964]],
#  [100824    J. Worrall
#   Name: Name, dtype: object,
#   230708,
#   [0.6192651681902439, 0.6012098116936027]],
#  [90666    A. Vallci
#   Name: Name, dtype: object,
#   243661,
#   [0.6042065052250999, 0.630798003750003]],
#  [99317    S. Mai
#   Name: Name, dtype: object,
#   238559,
#   [0.6069520387874213, 0.6242056767523075]],
#  [96324    D. Rugani
#   Name: Name, dtype: object,
#   211320,
#   [0.5496943423428456, 0.736336071363106]],
#  [94793    D. Grétarsson
#   Name: Name, dtype: object,
#   226510,
#   [0.6814234245399873, 0.47461842187800163]],
#  [97276    A. Franco
#   Name: Name, dtype: object,
#   237604,
#   [0.6039925909930531, 0.625205643063896]],
#  [102268    N. Hoffmann
#   Name: Name, dtype: object,
#   231379,
#   [0.701279818968426, 0.4309146922840801]],
#  [100054    A. Nukan
#   Name: Name, dtype: object,
#   200065,
#   [0.6289083236466582, 0.5727955084081007]],
#  [97128    João Basso
#   Name: Name, dtype: object,
#   236255,
#   [0.6289560931398142, 0.5721476163864195]],
#  [97082    R. Becker
#   Name: Name, dtype: object,
#   229610,
#   [0.6751868489477897, 0.4804546139978817]],
#  [93017    J. Rassoul
#   Name: Name, dtype: object,
#   229064,
#   [0.6253436432264657, 0.5782984909407862]],
#  [94782    I. Drešević
#   Name: Name, dtype: object,
#   235519,
#   [0.6326486311764601, 0.5630650339111494]],
#  [93319    M. Senesi
#   Name: Name, dtype: object,
#   236506,
#   [0.5226356854446432, 0.7771676414438003]],
#  [88377    I. Sangaré
#   Name: Name, dtype: object,
#   235173,
#   [0.54576173941083, 0.730303552690965]],
#  [96283    Roberto Soira
#   Name: Name, dtype: object,
#   236190,
#   [0.5680941315268948, 0.6840668127437358]],
#  [99896    Y. Osorio
#   Name: Name, dtype: object,
#   237297,
#   [0.5575128864138259, 0.7037549374017168]],
#  [90313    L. Fomba
#   Name: Name, dtype: object,
#   236721,
#   [0.5962315872177885, 0.6263991033630407]],
#  [97923    Rubén
#   Name: Name, dtype: object,
#   262299,
#   [0.6618316380668003, 0.49355487098436673]],
#  [100555    C. Carter-Vickers
#   Name: Name, dtype: object,
#   228174,
#   [0.6390607974093083, 0.5383627223248095]],
#  [99569    20 A. Buxton
#   Name: Name, dtype: object,
#   204302,
#   [0.7129255430656868, 0.38981885172161024]],
#  [95809    A. Briseño
#   Name: Name, dtype: object,
#   192114,
#   [0.5763785865530852, 0.6585984882967147]],
#  [90632    San Emeterio
#   Name: Name, dtype: object,
#   223654,
#   [0.5589308459267841, 0.6923257700750896]],
#  [94795    K. Akpoguma
#   Name: Name, dtype: object,
#   211856,
#   [0.5825823552890643, 0.6439567613917523]],
#  [98086    J. Jach
#   Name: Name, dtype: object,
#   223306,
#   [0.6794708262754647, 0.4525661968222191]],
#  [93746    V. Lekhal
#   Name: Name, dtype: object,
#   213841,
#   [0.6466955560131319, 0.5146939550836072]],
#  [95587    21 Nélson Monte
#   Name: Name, dtype: object,
#   222598,
#   [0.6054324226753108, 0.5955153374541615]],
#  [100439    S. Wharton
#   Name: Name, dtype: object,
#   231540,
#   [0.6571554107149948, 0.49057507650675825]],
#  [94635    M. Lemos
#   Name: Name, dtype: object,
#   229270,
#   [0.6352782645412507, 0.5334906124187975]],
#  [99286    T. Kacharaba
#   Name: Name, dtype: object,
#   260314,
#   [0.5792546465554095, 0.6434024092024334]],
#  [91942    P. Wiesinger
#   Name: Name, dtype: object,
#   239090,
#   [0.5775573815452524, 0.6455372887487516]],
#  [93089    M. Kempf
#   Name: Name, dtype: object,
#   210719,
#   [0.5405395559521807, 0.7182654238719927]],
#  [98040    J. Tah
#   Name: Name, dtype: object,
#   213331,
#   [0.5258136650539593, 0.7450678575464762]],
#  [98016    T. Cardona
#   Name: Name, dtype: object,
#   229537,
#   [0.5826618953219658, 0.6305905807557611]],
#  [98888    K. Mavropanos
#   Name: Name, dtype: object,
#   242000,
#   [0.5682649483126281, 0.6587914699752914]],
#  [88648    N. Aké
#   Name: Name, dtype: object,
#   208920,
#   [0.5171212158093851, 0.7581594277925182]],
#  [96371    S. Ajayi
#   Name: Name, dtype: object,
#   207952,
#   [0.582194044525204, 0.626857973212466]],
#  [99131    R. Burke
#   Name: Name, dtype: object,
#   221456,
#   [0.6259304777253941, 0.5403592790387507]],
#  [98370    J. van Aken
#   Name: Name, dtype: object,
#   216271,
#   [0.6149235137994253, 0.5596188947028614]],
#  [91373    T. Kehrer
#   Name: Name, dtype: object,
#   226229,
#   [0.536083238342659, 0.7146157405959583]],
#  [93023    20 Marc Muniesa
#   Name: Name, dtype: object,
#   192766,
#   [0.5567224468701107, 0.671758023492874]],
#  [93170    21 S. Lawson
#   Name: Name, dtype: object,
#   245748,
#   [0.6508462727066288, 0.4768228847766032]],
#  [96305    D. Doekhi
#   Name: Name, dtype: object,
#   232658,
#   [0.5873086758351653, 0.6018496219579199]],
#  [101263    P. Barrett
#   Name: Name, dtype: object,
#   205139,
#   [0.6907330779729413, 0.3963860658099544]],
#  [96609    C. Mepham
#   Name: Name, dtype: object,
#   233201,
#   [0.5672545145973085, 0.6395491543982585]],
#  [101089    Guilherme Ramos
#   Name: Name, dtype: object,
#   262869,
#   [0.5879291804242035, 0.595986288948254]],
#  [89644    G. Dzhikiya
#   Name: Name, dtype: object,
#   229773,
#   [0.5222931705726268, 0.7254711424487963]],
#  [100558    Wallace
#   Name: Name, dtype: object,
#   216437,
#   [0.5759206835736806, 0.6174101321929277]],
#  [98299    A. Jones
#   Name: Name, dtype: object,
#   236315,
#   [0.6453467054104661, 0.4784625697074027]],
#  [96138    K. Pedersen
#   Name: Name, dtype: object,
#   234832,
#   [0.5716320945965829, 0.6227344453849433]],
#  [101339    A. Doldán
#   Name: Name, dtype: object,
#   255240,
#   [0.6364162768537899, 0.4938756685717092]],
#  [93513    C. Connolly
#   Name: Name, dtype: object,
#   229605,
#   [0.6235965650368025, 0.5187780483553316]],
#  [93955    M. Valjent
#   Name: Name, dtype: object,
#   219585,
#   [0.5652425655031496, 0.633032585230219]],
#  [99865    F. Romagna
#   Name: Name, dtype: object,
#   226108,
#   [0.5949864153535975, 0.5739764885922027]],
#  [96846    J. Gnagnon
#   Name: Name, dtype: object,
#   231361,
#   [0.5453462388474998, 0.6694934956907738]],
#  [94358    J. Murillo
#   Name: Name, dtype: object,
#   219546,
#   [0.5774068325326203, 0.6024031558417007]],
#  [96681    21 F. Dagerstål
#   Name: Name, dtype: object,
#   224838,
#   [0.6008756981461258, 0.5557173569551901]],
#  [92538    B. Schmitz
#   Name: Name, dtype: object,
#   222692,
#   [0.597942653444305, 0.5604327868370247]],
#  [102166    R. Inniss
#   Name: Name, dtype: object,
#   204499,
#   [0.6184147229846534, 0.5185587468871401]],
#  [95898    A. Maxsø
#   Name: Name, dtype: object,
#   212287,
#   [0.5502449610595046, 0.651698042053112]],
#  [97681    F. Pfanne
#   Name: Name, dtype: object,
#   262635,
#   [0.6098064333555446, 0.5321684265407686]],
#  [99582    Artur Jorge
#   Name: Name, dtype: object,
#   236505,
#   [0.5614215743113375, 0.6225629444074978]],
#  [100632    N. Katić
#   Name: Name, dtype: object,
#   244204,
#   [0.5724076618864422, 0.6000266173070226]],
#  [100474    L. Väisänen
#   Name: Name, dtype: object,
#   234291,
#   [0.6277583330365134, 0.49080344139436277]],
#  [96539    P. Sweeney
#   Name: Name, dtype: object,
#   207646,
#   [0.6733924076526417, 0.3980841773733781]],
#  [99753    M. Flis
#   Name: Name, dtype: object,
#   213855,
#   [0.6461271124138817, 0.4497666888060918]],
#  [102280    T. Anderson
#   Name: Name, dtype: object,
#   209256,
#   [0.6035617235398688, 0.5335458972154675]],
#  [101666    T. Isherwood
#   Name: Name, dtype: object,
#   244192,
#   [0.618806978090134, 0.5034325472137671]],
#  [96123    B. Tuiloma
#   Name: Name, dtype: object,
#   220886,
#   [0.6055663847982862, 0.5285872770203845]],
#  [99841    Insua
#   Name: Name, dtype: object,
#   207431,
#   [0.5658998733042223, 0.6062333230646987]],
#  [92015    N. Elvedi
#   Name: Name, dtype: object,
#   221491,
#   [0.4900039025106555, 0.7535788687961839]],
#  [102219    P. Ndiaye
#   Name: Name, dtype: object,
#   264389,
#   [0.6071276208156835, 0.5223660837813354]],
#  [97952    D. Abels
#   Name: Name, dtype: object,
#   250805,
#   [0.5940429286624505, 0.5481191782823006]],
#  [99793    S. Mmaee
#   Name: Name, dtype: object,
#   224211,
#   [0.6094057526757053, 0.5176032807026185]],
#  [97275    P. Lienhart
#   Name: Name, dtype: object,
#   231366,
#   [0.5074228190881066, 0.7173205486677255]],
#  [101760    Y. N'Diaye
#   Name: Name, dtype: object,
#   257021,
#   [0.6161302383342762, 0.49882275285860606]],
#  [96784    A. Webster
#   Name: Name, dtype: object,
#   207616,
#   [0.5169179506069762, 0.6927982744315985]],
#  [96178    Henrique Gomes
#   Name: Name, dtype: object,
#   251450,
#   [0.5742620051270649, 0.5786504048608611]],
#  [97706    S. Gregersen
#   Name: Name, dtype: object,
#   216730,
#   [0.5697888075936227, 0.5862149529991825]],
#  [98493    E. Zehir
#   Name: Name, dtype: object,
#   242319,
#   [0.6510209133555543, 0.42520833420809934]],
#  [91230    A. Touba
#   Name: Name, dtype: object,
#   236535,
#   [0.6098592880803312, 0.5047140456018582]],
#  [100947    Jorge Fernandes
#   Name: Name, dtype: object,
#   242359,
#   [0.5513420543402522, 0.6197816840121609]],
#  [98818    Buatu
#   Name: Name, dtype: object,
#   209816,
#   [0.5878013719447228, 0.5455541926024198]],
#  [93147    M. Matvienko
#   Name: Name, dtype: object,
#   229528,
#   [0.531343424305042, 0.6538432495666285]],
#  [93122    S. Ingason
#   Name: Name, dtype: object,
#   221422,
#   [0.5173596756228513, 0.6813939452607192]],
#  [97550    M. Pearson
#   Name: Name, dtype: object,
#   208014,
#   [0.5652186385175731, 0.5861785804783682]],
#  [100839    A. Rogel
#   Name: Name, dtype: object,
#   252074,
#   [0.5680027313270043, 0.5804049855785884]],
#  [98462    Vítor Tormena
#   Name: Name, dtype: object,
#   246098,
#   [0.5100486293348491, 0.6941723014480033]],
#  [101616    20 A. Barry
#   Name: Name, dtype: object,
#   209024,
#   [0.6611986598665374, 0.394244757826282]],
#  [98475    A. Ismajli
#   Name: Name, dtype: object,
#   258782,
#   [0.5330698112049229, 0.6461121045025771]],
#  [94177    V. Vevatne
#   Name: Name, dtype: object,
#   214650,
#   [0.5902670553687341, 0.530230553020671]],
#  [93902    J. Van den Bergh
#   Name: Name, dtype: object,
#   246716,
#   [0.552974722886793, 0.6036671948117528]],
#  [99911    J. Aidoo
#   Name: Name, dtype: object,
#   230021,
#   [0.5050749422557196, 0.6979448273467688]],
#  [93410    M. Bălașa
#   Name: Name, dtype: object,
#   220521,
#   [0.5865039446142527, 0.5360825842821678]],
#  [93428    21 L. Spendlhofer
#   Name: Name, dtype: object,
#   208247,
#   [0.5819113034431946, 0.5448721779094782]],
#  [94871    Róber
#   Name: Name, dtype: object,
#   213063,
#   [0.5362442736861126, 0.6343930905330459]],
#  [95211    B. Chardonnet
#   Name: Name, dtype: object,
#   215410,
#   [0.5305088368461481, 0.6455047418956623]],
#  [102001    B. Niňaj
#   Name: Name, dtype: object,
# ...
#   230942,
#   [0.3237724428544599, 0.4437882120281056]],
#  [100899    C. Zesiger
#   Name: Name, dtype: object,
#   236369,
#   [0.2783678596895664, 0.5262583525756102]],
#  [100255    J. Clarke-Salter
#   Name: Name, dtype: object,
#   230774,
#   [0.27739706127498925, 0.5273185481480076]],
#  [102154    A. Maciel
#   Name: Name, dtype: object,
#   240457,
#   [0.33349441339149516, 0.4165054584742924]],
#  [101166    S. Jhingan
#   Name: Name, dtype: object,
#   223763,
#   [0.3136772090047287, 0.45231125765032676]],
#  [101820    M. Kreuzriegler
#   Name: Name, dtype: object,
#   256967,
#   [0.3130942931008296, 0.4530241947116337]],
#  [102409    Diego Alende
#   Name: Name, dtype: object,
#   228707,
#   [0.31618906388260154, 0.4465277240640907]],
#  [101269    Jeong Tae Wook
#   Name: Name, dtype: object,
#   238576,
#   [0.2860173486148677, 0.5052185558216475]],
#  [101572    V. Huerta
#   Name: Name, dtype: object,
#   214404,
#   [0.25543515782025217, 0.5618104794584379]],
#  [95642    A. Ndom
#   Name: Name, dtype: object,
#   231109,
#   [0.325725238821428, 0.42234300304579675]],
#  [97698    21 B. Sanneh
#   Name: Name, dtype: object,
#   220302,
#   [0.2571857681379991, 0.5571584014558902]],
#  [101336    J. Turnbull
#   Name: Name, dtype: object,
#   206170,
#   [0.3225960461413682, 0.42697015130645183]],
#  [101861    Z. Šarlija
#   Name: Name, dtype: object,
#   251343,
#   [0.31468350398257056, 0.4412633635560448]],
#  [97849    S. Lorenz
#   Name: Name, dtype: object,
#   242383,
#   [0.2514448046069709, 0.5615513413301783]],
#  [101647    21 M. Guanini
#   Name: Name, dtype: object,
#   228893,
#   [0.26976593442720526, 0.5192693134173323]],
#  [97673    J. Nyholm
#   Name: Name, dtype: object,
#   237226,
#   [0.28637046639985186, 0.4798413965725264]],
#  [102393    B. Šerbečić
#   Name: Name, dtype: object,
#   242260,
#   [0.3235349467268324, 0.4064956476693824]],
#  [99799    S. Salcedo
#   Name: Name, dtype: object,
#   228730,
#   [0.2610876545529065, 0.5293835630100625]],
#  [101017    Ricardo Santos
#   Name: Name, dtype: object,
#   212090,
#   [0.28457897192963655, 0.48248803819237385]],
#  [100624    R. Bormuth
#   Name: Name, dtype: object,
#   233785,
#   [0.26664209036257436, 0.5176330665967434]],
#  [99621    S. Velkov
#   Name: Name, dtype: object,
#   255211,
#   [0.33339849262459903, 0.38335678078656865]],
#  [102461    R. Diarra
#   Name: Name, dtype: object,
#   229450,
#   [0.36386381674899726, 0.31840363485531664]],
#  [99138    20 J. Blåbjerg
#   Name: Name, dtype: object,
#   213528,
#   [0.34412724119392274, 0.3554832769742852]],
#  [100575    Adrián Diéguez
#   Name: Name, dtype: object,
#   236508,
#   [0.27230661176601667, 0.48809658058458033]],
#  [100215    C. Harries
#   Name: Name, dtype: object,
#   228637,
#   [0.32636119396633373, 0.3794922564320852]],
#  [101952    21 A. Walongwa
#   Name: Name, dtype: object,
#   223873,
#   [0.29149690637228887, 0.448151537409048]],
#  [100234    D. Scarr
#   Name: Name, dtype: object,
#   237943,
#   [0.28999700073695583, 0.44845581570939225]],
#  [101788    H. Lennon
#   Name: Name, dtype: object,
#   220057,
#   [0.3236204833030228, 0.37993882488276326]],
#  [102249    J. Aspropotamitis
#   Name: Name, dtype: object,
#   228191,
#   [0.3122719023119688, 0.40193043590232563]],
#  [101559    D. Del Fabro
#   Name: Name, dtype: object,
#   211067,
#   [0.27641494057821175, 0.46980273618949253]],
#  [98938    R. Nicolaisen
#   Name: Name, dtype: object,
#   235244,
#   [0.26813641944470595, 0.48525134181841495]],
#  [101116    R. Edwards
#   Name: Name, dtype: object,
#   208752,
#   [0.27786637578723766, 0.46430681073384067]],
#  [100557    G. Taft
#   Name: Name, dtype: object,
#   203145,
#   [0.31233056982897583, 0.3954186577437585]],
#  [100065    B. Utvik
#   Name: Name, dtype: object,
#   213864,
#   [0.2637899434399823, 0.4880395694822271]],
#  [101322    R. Popa
#   Name: Name, dtype: object,
#   235277,
#   [0.32220922370674054, 0.3677033367806135]],
#  [101730    M. López Quintana
#   Name: Name, dtype: object,
#   225910,
#   [0.28755481679341605, 0.4356020613796369]],
#  [98408    F. Eboa Eboa
#   Name: Name, dtype: object,
#   239210,
#   [0.26887073335462, 0.47051054438535306]],
#  [101352    S. Kennedy
#   Name: Name, dtype: object,
#   258361,
#   [0.26678414048687726, 0.46770023794060217]],
#  [97243    T. Deng
#   Name: Name, dtype: object,
#   228310,
#   [0.25872229388682394, 0.4831953013336086]],
#  [101692    K. Dimitrov
#   Name: Name, dtype: object,
#   252738,
#   [0.2819028085222374, 0.4344979599211016]],
#  [101009    Elton Monteiro
#   Name: Name, dtype: object,
#   202801,
#   [0.29035502326383317, 0.417643697170005]],
#  [100643    J. Canale
#   Name: Name, dtype: object,
#   253238,
#   [0.2364098331140434, 0.5210706467392907]],
#  [101749    D. Conroy
#   Name: Name, dtype: object,
#   213667,
#   [0.30587331054162104, 0.3829288904874315]],
#  [97067    H. Türkmen
#   Name: Name, dtype: object,
#   243244,
#   [0.23452761205629044, 0.5234501968839441]],
#  [102462    S. Sabetkar
#   Name: Name, dtype: object,
#   261452,
#   [0.3315746676933689, 0.32467685071358554]],
#  [98786    M. Caldara
#   Name: Name, dtype: object,
#   220477,
#   [0.12499889747101858, 0.7316666099430422]],
#  [101950    21 E. Caicedo
#   Name: Name, dtype: object,
#   227398,
#   [0.29754461724632053, 0.3816594628069228]],
#  [102225    M. Malec
#   Name: Name, dtype: object,
#   244755,
#   [0.2631046963349983, 0.4492107415961468]],
#  [101104    A. Calver
#   Name: Name, dtype: object,
#   212535,
#   [0.2854304635281294, 0.40342877028668817]],
#  [101279    S. Nkansah
#   Name: Name, dtype: object,
#   229756,
#   [0.26708562838315064, 0.4374459896888447]],
#  [102865    C. Schoissengeyr
#   Name: Name, dtype: object,
#   229733,
#   [0.25405264332586763, 0.46154351164927376]],
#  [100423    C. Whelan
#   Name: Name, dtype: object,
#   242007,
#   [0.3332156207971954, 0.3048250186092667]],
#  [102224    O. Vanegas
#   Name: Name, dtype: object,
#   255384,
#   [0.3103713084703214, 0.34216230943775666]],
#  [100725    K. Dabila
#   Name: Name, dtype: object,
#   239363,
#   [0.2094233893306909, 0.5406255071906824]],
#  [98380    T. Asta-Buruaga
#   Name: Name, dtype: object,
#   214701,
#   [0.2530504030393921, 0.45363453047184615]],
#  [102099    E. Capradossi
#   Name: Name, dtype: object,
#   215376,
#   [0.19145647861446885, 0.5734712980432909]],
#  [97889    I. Cristea
#   Name: Name, dtype: object,
#   248021,
#   [0.1738032484376676, 0.6046097736544208]],
#  [101363    Dinis Almeida
#   Name: Name, dtype: object,
#   234665,
#   [0.20101638713973896, 0.5446840816223533]],
#  [101669    20 D. Balanta
#   Name: Name, dtype: object,
#   214339,
#   [0.2856016715788299, 0.3776238533731793]],
#  [101959    L. John
#   Name: Name, dtype: object,
#   213893,
#   [0.2814304485628197, 0.3840023095533131]],
#  [101326    R. Hove
#   Name: Name, dtype: object,
#   246759,
#   [0.3111726226731909, 0.3249879509894139]],
#  [101593    D. Kane
#   Name: Name, dtype: object,
#   229206,
#   [0.32518148718152307, 0.29509783113077837]],
#  [93790    Emerson Santos
#   Name: Name, dtype: object,
#   230092,
#   [0.20472615194084268, 0.5292556648345057]],
#  [102493    21 G. Zajkov
#   Name: Name, dtype: object,
#   223568,
#   [0.22098288757304, 0.4940094526830568]],
#  [99550    I. Vujica
#   Name: Name, dtype: object,
#   235054,
#   [0.32279759666158553, 0.2851345066140122]],
#  [101290    E. Haugan
#   Name: Name, dtype: object,
#   223253,
#   [0.25261040605767554, 0.42125608628991096]],
#  [101206    B. Benamar
#   Name: Name, dtype: object,
#   260295,
#   [0.2588510580651317, 0.40189325460040237]],
#  [102203    J. Silva
#   Name: Name, dtype: object,
#   222643,
#   [0.22555482317678788, 0.4622256918410246]],
#  [100265    20 M. Sarr
#   Name: Name, dtype: object,
#   212628,
#   [0.28791199557950153, 0.3390492303929076]],
#  [102090    20 G. Andonian
#   Name: Name, dtype: object,
#   211690,
#   [0.250216339910607, 0.4097840900205595]],
#  [102343    A. Medioub
#   Name: Name, dtype: object,
#   259088,
#   [0.23201408634125759, 0.4420097159482309]],
#  [101530    P. Banggaard
#   Name: Name, dtype: object,
#   212978,
#   [0.23582161666809903, 0.4333392555167619]],
#  [101041    J. Gundersen
#   Name: Name, dtype: object,
#   228238,
#   [0.2531744915029341, 0.3989682315384153]],
#  [101626    L. Gordon
#   Name: Name, dtype: object,
#   232668,
#   [0.21364512573989644, 0.4728869950394231]],
#  [102194    J. Handl
#   Name: Name, dtype: object,
#   248470,
#   [0.20971023577934816, 0.4791739212081093]],
#  [102056    21 Kim Jung Ho
#   Name: Name, dtype: object,
#   243626,
#   [0.2851926262745316, 0.3279445566341461]],
#  [99662    20 A. Öztürk
#   Name: Name, dtype: object,
#   229362,
#   [0.2328691777370787, 0.4306394025705934]],
#  [101713    Kim Jae Woo
#   Name: Name, dtype: object,
#   242082,
#   [0.33363012668525205, 0.2299534007832903]],
#  [101996    M. Platt
#   Name: Name, dtype: object,
#   234261,
#   [0.2554760412633448, 0.37195109173942265]],
#  [102752    A. Xhemajli
#   Name: Name, dtype: object,
#   243981,
#   [0.2507184286144303, 0.3774037328665273]],
#  [97677    S. Findlay
#   Name: Name, dtype: object,
#   227945,
#   [0.17945565982933473, 0.516897060952462]],
#  [96573    O. Ndah
#   Name: Name, dtype: object,
#   264383,
#   [0.17507257201575097, 0.5205103603736942]],
#  [101016    H. McGahey
#   Name: Name, dtype: object,
#   220038,
#   [0.24971227286339123, 0.3609040000090564]],
#  [102550    B. Karamoko
#   Name: Name, dtype: object,
#   226759,
#   [0.22173887106316031, 0.40895902189777833]],
#  [101907    R. Tongyik
#   Name: Name, dtype: object,
#   231678,
#   [0.23292044346426063, 0.3786681643070831]],
#  [100295    21 A. Ajeti
#   Name: Name, dtype: object,
#   203458,
#   [0.2162660187392715, 0.40931219993278933]],
#  [100865    B. Straalman
#   Name: Name, dtype: object,
#   228870,
#   [0.1973447754387096, 0.4371801908745156]],
#  [102817    21 P. Flottmann
#   Name: Name, dtype: object,
#   252093,
#   [0.26724595301382, 0.295054577112215]],
#  [102033    B. Chorbadzhiyski
#   Name: Name, dtype: object,
#   236579,
#   [0.19928305851035577, 0.42679621778273924]],
#  [101649    P. Lemonnier
#   Name: Name, dtype: object,
#   223880,
#   [0.17058025656958, 0.4822143720869147]],
#  [98932    E. Ntim
#   Name: Name, dtype: object,
#   231472,
#   [0.17523223226383824, 0.47229006774857263]],
#  [100569    20 A. Murillo
#   Name: Name, dtype: object,
#   225574,
#   [0.16222763801260404, 0.4952992035777762]],
#  [102745    20 B. Nugent
#   Name: Name, dtype: object,
#   204459,
#   [0.2226169886213586, 0.3757476812204388]],
#  [102607    F. Souza
#   Name: Name, dtype: object,
#   255803,
#   [0.2516642297747799, 0.3111830040392003]],
#  [102009    B. Aloé
#   Name: Name, dtype: object,
#   208834,
#   [0.1753794746552948, 0.46003135709510673]],
#  [103511    21 A. Ajeti
#   Name: Name, dtype: object,
#   239427,
#   [0.27083128374996, 0.27132541465921706]],
#  [100475    M. Rente
#   Name: Name, dtype: object,
#   257957,
#   [0.1736032820380019, 0.457993599200105]],
#  [99489    I. Conté
#   Name: Name, dtype: object,
#   236279,
#   [0.18236163580779108, 0.44026659529134454]],
#  [100131    Hwang Hyun Soo
#   Name: Name, dtype: object,
#   222660,
#   [0.16971908677453515, 0.45889537175804435]],
#  [101382    Bueno
#   Name: Name, dtype: object,
#   232872,
#   [0.18278107266235796, 0.43062364060671976]],
#  [97947    O. Ba
#   Name: Name, dtype: object,
#   240064,
#   [0.08375414665994557, 0.6237270762270491]],
#  [101405    E. Onariase
#   Name: Name, dtype: object,
#   228152,
#   [0.19121338524009823, 0.40294722152979073]],
#  [102424    J. Aguayo
#   Name: Name, dtype: object,
#   258053,
#   [0.22944632464849943, 0.3270313797372078]],
#  [99269    M. Monthé
#   Name: Name, dtype: object,
#   217332,
#   [0.17806054312941183, 0.42665651537634086]],
#  [101838    S. Ngezana
#   Name: Name, dtype: object,
#   235442,
#   [0.1559362090875179, 0.4697477829960115]],
#  [102556    A. Baldwin
#   Name: Name, dtype: object,
#   234940,
#   [0.2461895817253482, 0.2894997187332159]],
#  [102275    19 Robert Costa
#   Name: Name, dtype: object,
#   213745,
#   [0.18517368153252958, 0.40962924471847906]],
#  [102524    A. Karo
#   Name: Name, dtype: object,
#   230703,
#   [0.24605982705541832, 0.28431921316393854]],
#  [102370    R. Cundy
#   Name: Name, dtype: object,
#   229182,
#   [0.19070005576703822, 0.38452849049151333]],
#  [101546    D. Daniels
#   Name: Name, dtype: object,
#   209493,
#   [0.17725119761519356, 0.40149108230987984]],
#  [98685    C. González
#   Name: Name, dtype: object,
#   236020,
#   [0.12131239279390515, 0.5029556335712231]],
#  [102004    W. Aimson
#   Name: Name, dtype: object,
#   218576,
#   [0.16793056316192956, 0.4102979331265556]],
#  [101936    N. Bürgy
#   Name: Name, dtype: object,
#   224426,
#   [0.15353315350038635, 0.4317200306029901]],
#  [98891    D. Guidi
#   Name: Name, dtype: object,
#   244460,
#   [0.12906712657186858, 0.4776465711291394]],
#  [102276    19 Roger Riera
#   Name: Name, dtype: object,
#   224164,
#   [0.1900039629009237, 0.35692517023207665]],
#  [102117    R. Cornwall
#   Name: Name, dtype: object,
#   213502,
#   [0.18312648894002392, 0.36982812703201806]],
#  [101917    J. Kabongo
#   Name: Name, dtype: object,
#   236445,
#   [0.19213380980915964, 0.3418952748563166]],
#  [101167    21 J. Wright
#   Name: Name, dtype: object,
#   214682,
#   [0.1352333973849834, 0.4480582872257752]],
#  [102402    T. Dallison
#   Name: Name, dtype: object,
#   213653,
#   [0.17392551364052455, 0.3694777791803579]],
#  [99052    21 S. Väisänen
#   Name: Name, dtype: object,
#   224436,
#   [0.09706194098913752, 0.5142859921230364]],
#  [102487    21 O. Sowunmi
#   Name: Name, dtype: object,
#   223069,
#   [0.17622666905106546, 0.348574843883084]],
#  [100651    P. Kapp
#   Name: Name, dtype: object,
#   239820,
#   [0.1556361072373474, 0.38687448834852833]],
#  [102541    S. Nattestad
#   Name: Name, dtype: object,
#   217718,
#   [0.16807213123428427, 0.3582473045444803]],
#  [101296    D. Fox
#   Name: Name, dtype: object,
#   231342,
#   [0.12182191230930972, 0.4486500129529163]],
#  [102573    J. García
#   Name: Name, dtype: object,
#   229985,
#   [0.16238256810326607, 0.36633815603587344]],
#  [100711    F. Zorba
#   Name: Name, dtype: object,
#   235939,
#   [0.16984131582345993, 0.35065142314653436]],
#  [101523    A. Grant
#   Name: Name, dtype: object,
#   209210,
#   [0.09969591927776843, 0.4777339693490409]],
#  [102037    R. Leak
#   Name: Name, dtype: object,
#   241894,
#   [0.12282779110947326, 0.42455333057046507]],
#  [101006    C. McCarthy
#   Name: Name, dtype: object,
#   229771,
#   [0.10595908073708989, 0.44593899026282763]],
#  [101231    20 M. Camporese
#   Name: Name, dtype: object,
#   201914,
#   [0.0449766149161947, 0.5563536411055338]],
#  [100826    20 M. Chiosa
#   Name: Name, dtype: object,
#   205911,
#   [0.08231048550225363, 0.47923105843842695]],
#  [102331    20 C. Pérez
#   Name: Name, dtype: object,
#   231711,
#   [0.10500002832907404, 0.4288272120370585]],
#  [102812    18 J. Vergara
#   Name: Name, dtype: object,
#   219184,
#   [0.05163653325142628, 0.5282583832130162]],
#  [102590    G. Cuomo
#   Name: Name, dtype: object,
#   236292,
#   [0.1260325603372395, 0.37205528768126667]],
#  [102255    J. Jones
#   Name: Name, dtype: object,
#   257865,
#   [0.1517974311780796, 0.29838594254730344]],
#  [99121    J. Willis
#   Name: Name, dtype: object,
#   206524,
#   [0.07026941784756627, 0.4329811086236019]],
#  [102120    19 M. Koné
#   Name: Name, dtype: object,
#   209831,
#   [0.11164022141074097, 0.3506601123885403]],
#  [101808    M. Foulds
#   Name: Name, dtype: object,
#   227854,
#   [0.10964781589303071, 0.35390709339373666]],
#  [101997    P. Farquharson
#   Name: Name, dtype: object,
#   260818,
#   [0.10517706479782288, 0.3623206331421165]],
#  [101882    L. Bogdan
#   Name: Name, dtype: object,
#   235261,
#   [0.04349475436902477, 0.48331915747507376]],
#  [100382    20 M. Marcjanik
#   Name: Name, dtype: object,
#   234704,
#   [0.07471291743075807, 0.41741759120291294]],
#  [102217    O. Gonzalez
#   Name: Name, dtype: object,
#   230140,
#   [0.0756543898909774, 0.39394110266380633]],
#  [101927    F. Rawson
#   Name: Name, dtype: object,
#   223852,
#   [0.08360812155420141, 0.3774360399217363]],
#  [102142    21 Eliseo Falcón
#   Name: Name, dtype: object,
#   234788,
#   [0.06726590150588746, 0.39715539340421635]],
#  [102355    21 David Cardoso
#   Name: Name, dtype: object,
#   247198,
#   [0.09689809796200947, 0.32128385435236717]],
#  [102526    L. Edwards
#   Name: Name, dtype: object,
#   229779,
#   [0.11747999246787424, 0.27993672915497114]],
#  [102877    G. Ray
#   Name: Name, dtype: object,
#   203430,
#   [0.10728230056625464, 0.2891271963708773]],
#  [102473    B. Warland
#   Name: Name, dtype: object,
#   225051,
#   [0.04655102795835331, 0.31088671018200625]]]

# %%
get_player_recs(df_22_std,"Manchester City",["CB"],Def_essential_ft,def_weights_per_club, age_min = 23, age_max = 27, val = 100)
# Out:
# [[88013    Marquinhos
#   Name: Name, dtype: object,
#   207865,
#   [0.9734699820138333, 0.976600062995886]],
#  [88259    Palhinha
#   Name: Name, dtype: object,
#   229391,
#   [0.9654394778982303, 0.9046118089021155]],
#  [90045    J. Denayer
#   Name: Name, dtype: object,
#   220182,
#   [0.9971653140353496, 0.8319741716026692]],
#  [94397    D. Ćaleta-Car
#   Name: Name, dtype: object,
#   225263,
#   [0.9808549154073354, 0.8333434129285952]],
#  [88253    D. Zakaria
#   Name: Name, dtype: object,
#   229261,
#   [0.9678491367792008, 0.8550226468446873]],
#  [90188    C. Lenglet
#   Name: Name, dtype: object,
#   220440,
#   [0.9703944645479388, 0.8484182732777651]],
#  [93319    M. Senesi
#   Name: Name, dtype: object,
#   236506,
#   [0.9868618677811424, 0.8115139612316551]],
#  [90028    A. Diallo
#   Name: Name, dtype: object,
#   225711,
#   [0.9697512594697697, 0.8386307754003489]],
#  [88495    Mario Hermoso
#   Name: Name, dtype: object,
#   229668,
#   [0.955976730766929, 0.8583876377351214]],
#  [89216    P. Kimpembe
#   Name: Name, dtype: object,
#   225850,
#   [0.9417003249470859, 0.8816258117763727]],
#  [94661    A. Christensen
#   Name: Name, dtype: object,
#   213661,
#   [0.9643681547107279, 0.8284815031758858]],
#  [98232    T. Adarabioyo
#   Name: Name, dtype: object,
#   222104,
#   [0.995397929496204, 0.7553259614323627]],
#  [94651    R. Koch
#   Name: Name, dtype: object,
#   236532,
#   [0.9850972811197318, 0.767371659707047]],
#  [91543    E. Konsa
#   Name: Name, dtype: object,
#   227678,
#   [0.9635191433607223, 0.788084703516782]],
#  [88377    I. Sangaré
#   Name: Name, dtype: object,
#   235173,
#   [0.9760705716526645, 0.7598792333382401]],
#  [92396    A. Tuanzebe
#   Name: Name, dtype: object,
#   231485,
#   [0.9785323036399647, 0.7546549308498248]],
#  [88999    L. Martínez Quarta
#   Name: Name, dtype: object,
#   228708,
#   [0.9555188674735966, 0.7935126504223631]],
#  [89974    Yeray
#   Name: Name, dtype: object,
#   227950,
#   [0.9374450875499234, 0.8269490826120245]],
#  [97013    B. Engels
#   Name: Name, dtype: object,
#   210828,
#   [0.9717261419973265, 0.7508250157695612]],
#  [94531    B. Davies
#   Name: Name, dtype: object,
#   213017,
#   [0.9968686765221767, 0.6990848220431313]],
#  [94238    Y. Mina
#   Name: Name, dtype: object,
#   220523,
#   [0.9454383540799794, 0.7934126378607188]],
#  [96784    A. Webster
#   Name: Name, dtype: object,
#   207616,
#   [0.9697591744995449, 0.7449823558234612]],
#  [90738    Calero
#   Name: Name, dtype: object,
#   240289,
#   [0.9631821617633938, 0.7540261575412572]],
#  [96672    B. White
#   Name: Name, dtype: object,
#   231936,
#   [0.958760542543809, 0.7626639540109549]],
#  [96609    C. Mepham
#   Name: Name, dtype: object,
#   233201,
#   [0.9992234499204927, 0.6702641095606563]],
#  [88965    Kaimo Lima
#   Name: Name, dtype: object,
#   230381,
#   [0.9526010603258745, 0.7582370172712508]],
#  [94578    21 B. Kuscevic
#   Name: Name, dtype: object,
#   225236,
#   [0.9890043511838285, 0.6759204483497988]],
#  [92566    C. Montes
#   Name: Name, dtype: object,
#   229980,
#   [0.9535130916592268, 0.7438923465265382]],
#  [89065    D. Hancko
#   Name: Name, dtype: object,
#   247103,
#   [0.9538044391730052, 0.7394813791945273]],
#  [88925    K. Ayhan
#   Name: Name, dtype: object,
#   207790,
#   [0.9448072688343961, 0.7489305013666162]],
#  [96868    Ferro
#   Name: Name, dtype: object,
#   242236,
#   [0.9376988532442885, 0.7617990540424802]],
#  [87860    W. Ndidi
#   Name: Name, dtype: object,
#   226790,
#   [0.8663687187746564, 0.9011764962492315]],
#  [95256    Gabriel
#   Name: Name, dtype: object,
#   232580,
#   [0.9218196611966643, 0.7885177077551064]],
#  [89881    D. Martínez
#   Name: Name, dtype: object,
#   241569,
#   [0.9431225479842446, 0.7322752725726464]],
#  [98475    A. Ismajli
#   Name: Name, dtype: object,
#   258782,
#   [0.9744925640470292, 0.6701020907674745]],
#  [98825    C. Starfelt
#   Name: Name, dtype: object,
#   220821,
#   [0.9872622040166706, 0.6416773442565809]],
#  [95109    Vallejo
#   Name: Name, dtype: object,
#   225161,
#   [0.9318854992820785, 0.7507294849661114]],
#  [94601    P. Sandler
#   Name: Name, dtype: object,
#   234679,
#   [0.9550347904659511, 0.702039578954722]],
#  [96803    J. Lucumí
#   Name: Name, dtype: object,
#   231207,
#   [0.9429312005161018, 0.7256423614836623]],
#  [94510    A. Frías
#   Name: Name, dtype: object,
#   251886,
#   [0.942983986489323, 0.7241311501190522]],
#  [91024    A. Djiku
#   Name: Name, dtype: object,
#   212219,
#   [0.9374207665233294, 0.7326455910898706]],
#  [96279    Murilo
#   Name: Name, dtype: object,
#   240115,
#   [0.948202432520958, 0.7070333695802414]],
#  [96881    21 A. Wisdom
#   Name: Name, dtype: object,
#   201908,
#   [0.9741622395161046, 0.6555144968990924]],
#  [89398    M. Akanji
#   Name: Name, dtype: object,
#   229237,
#   [0.9013162988140487, 0.7960285942619962]],
#  [91942    P. Wiesinger
#   Name: Name, dtype: object,
#   239090,
#   [0.9574392686143247, 0.6835532906673492]],
#  [90421    M. Holgate
#   Name: Name, dtype: object,
#   225024,
#   [0.9019737339092014, 0.7923378536601889]],
#  [101615    J. Elliott
#   Name: Name, dtype: object,
#   238008,
#   [0.9582405314366079, 0.6785789013246785]],
#  [95588    J. Gorenc Stanković
#   Name: Name, dtype: object,
#   226129,
#   [0.9349994823986318, 0.7242104309807874]],
#  [89937    F. Guilbert
#   Name: Name, dtype: object,
#   227222,
#   [0.9337630968131524, 0.7213909948947942]],
#  [96426    J. Souttar
#   Name: Name, dtype: object,
#   212516,
#   [0.9708015225207389, 0.6453981059277746]],
#  [90125    S. Vegas
#   Name: Name, dtype: object,
#   219087,
#   [0.942719597280832, 0.7005056799613465]],
#  [89504    D. Bronn
#   Name: Name, dtype: object,
#   235565,
#   [0.9230659431990338, 0.7360508229305961]],
#  [98135    H. Wahl
#   Name: Name, dtype: object,
#   230855,
#   [0.9399018029154642, 0.700601891490564]],
#  [88373    S. Umtiti
#   Name: Name, dtype: object,
#   205600,
#   [0.8930084008426262, 0.7922825167012749]],
#  [96519    M. Mitrović
#   Name: Name, dtype: object,
#   237209,
#   [0.9414954760213932, 0.6926931149773207]],
#  [93617    A. Romagnoli
#   Name: Name, dtype: object,
#   210413,
#   [0.8696787987667713, 0.8342205811730804]],
#  [98462    Vítor Tormena
#   Name: Name, dtype: object,
#   246098,
#   [0.9232934757480411, 0.7283490595771375]],
#  [96846    J. Gnagnon
#   Name: Name, dtype: object,
#   231361,
#   [0.9335088823135557, 0.7072520072779265]],
#  [93940    Tomás Podstawski
#   Name: Name, dtype: object,
#   216449,
#   [0.9685016857229021, 0.6365199689146769]],
#  [96599    A. Çalık
#   Name: Name, dtype: object,
#   223046,
#   [0.9717445270128486, 0.6295629058846955]],
#  [96305    D. Doekhi
#   Name: Name, dtype: object,
#   232658,
#   [0.9545829077237098, 0.6622452433330958]],
#  [90365    G. Silva
#   Name: Name, dtype: object,
#   220702,
#   [0.9501522552623358, 0.6685279575820288]],
#  [95056    N. Milenković
#   Name: Name, dtype: object,
#   238095,
#   [0.9206352486861192, 0.7247972455146972]],
#  [98053    W. Faes
#   Name: Name, dtype: object,
#   235036,
#   [0.9298555409862833, 0.7043405789449841]],
#  [98185    M. Veljković
#   Name: Name, dtype: object,
#   221354,
#   [0.9290534845776934, 0.7047659975978036]],
#  [96681    21 F. Dagerstål
#   Name: Name, dtype: object,
#   224838,
#   [0.9659241303981894, 0.6299696111042448]],
#  [98521    21 G. Conti
#   Name: Name, dtype: object,
#   221219,
#   [0.9392812037025539, 0.6814417216885369]],
#  [99847    Rodrigo Becão
#   Name: Name, dtype: object,
#   238621,
#   [0.9280791346548853, 0.7015239669082111]],
#  [97384    M. Rose
#   Name: Name, dtype: object,
#   212487,
#   [0.9668215379675997, 0.6220304717954921]],
#  [91480    Edgar Ié
#   Name: Name, dtype: object,
#   210520,
#   [0.931180553013661, 0.692079044434458]],
#  [94304    J. Rodríguez
#   Name: Name, dtype: object,
#   244950,
#   [0.9184282192438507, 0.7171959064410345]],
#  [100125    J. Dunne
#   Name: Name, dtype: object,
#   235156,
#   [0.9578233762189563, 0.6385057741955494]],
#  [93092    W. Anton
#   Name: Name, dtype: object,
#   229476,
#   [0.9204514641773637, 0.7104519351180981]],
#  [101850    P. Bochniewicz
#   Name: Name, dtype: object,
#   220230,
#   [0.9475836338262005, 0.6562625939417314]],
#  [95367    D. Granli
#   Name: Name, dtype: object,
#   222472,
#   [0.9853400865117707, 0.5796364094933673]],
#  [94177    V. Vevatne
#   Name: Name, dtype: object,
#   214650,
#   [0.9770303163136657, 0.5947911526872061]],
#  [93256    T. Kongolo
#   Name: Name, dtype: object,
#   203485,
#   [0.9362377987646135, 0.6748380626432895]],
#  [97840    F. Kunze
#   Name: Name, dtype: object,
#   251429,
#   [0.9430211164828803, 0.6595094029081799]],
#  [99250    A. Disasi
#   Name: Name, dtype: object,
#   229942,
#   [0.9066677009619452, 0.7240752108773068]],
#  [91919    B. Rovira
#   Name: Name, dtype: object,
#   225812,
#   [0.941919659974179, 0.654287903938989]],
#  [96928    F. Benković
#   Name: Name, dtype: object,
#   244269,
#   [0.9282525620434585, 0.6809078577259857]],
#  [95992    Pleguezuelo
#   Name: Name, dtype: object,
#   222576,
#   [0.9487515159937472, 0.6386417725725761]],
#  [96340    N. Süle
#   Name: Name, dtype: object,
#   212190,
#   [0.8497234105954705, 0.8302061989627203]],
#  [93147    M. Matvienko
#   Name: Name, dtype: object,
#   229528,
#   [0.9063139421000718, 0.7172404724132416]],
#  [95733    D. Heintz
#   Name: Name, dtype: object,
#   206198,
#   [0.9142532214834416, 0.7000438104807334]],
#  [99920    P. Ceccaroni
#   Name: Name, dtype: object,
#   219956,
#   [0.9764446063797002, 0.5769814174609863]],
#  [97459    L. Krajnc
#   Name: Name, dtype: object,
#   205556,
#   [0.9636341845420369, 0.6014531485972376]],
#  [92005    K. Ajer
#   Name: Name, dtype: object,
#   224258,
#   [0.8932553698777558, 0.7401023902100798]],
#  [95900    J. Duverne
#   Name: Name, dtype: object,
#   229705,
#   [0.9286565384251212, 0.6665398191263768]],
#  [96203    K. Adams Nuhu
#   Name: Name, dtype: object,
#   225673,
#   [0.9301327112638759, 0.6608900335113944]],
#  [94782    I. Drešević
#   Name: Name, dtype: object,
#   235519,
#   [0.941154286283785, 0.6312713220485016]],
#  [93205    Javi Hernández
#   Name: Name, dtype: object,
#   244523,
#   [0.9403359081165771, 0.6285762987340078]],
#  [99827    A. Mawson
#   Name: Name, dtype: object,
#   208534,
#   [0.9237733770803046, 0.6551193073970009]],
#  [95977    Kim Min Jae
#   Name: Name, dtype: object,
#   237086,
#   [0.908116194883286, 0.6834343094974065]],
#  [94714    K. Rekik
#   Name: Name, dtype: object,
#   205193,
#   [0.8845788053178096, 0.7285408352904316]],
#  [99548    S. Knežević
#   Name: Name, dtype: object,
#   234817,
#   [0.9525563543242631, 0.5941203986529963]],
#  [90313    L. Fomba
#   Name: Name, dtype: object,
#   236721,
#   [0.9179617574433601, 0.6614946799286847]],
#  [98552    A. Hack
#   Name: Name, dtype: object,
#   231111,
#   [0.9152659091293861, 0.6636899606908758]],
#  [94113    M. Heyer
#   Name: Name, dtype: object,
#   238593,
#   [0.9209084291009169, 0.6521611638071197]],
#  [99704    E. Segura
#   Name: Name, dtype: object,
#   237245,
#   [0.9266550510658706, 0.6402645087679842]],
#  [94635    M. Lemos
#   Name: Name, dtype: object,
#   229270,
#   [0.9307663132655808, 0.6321030453681996]],
#  [96897    Lluís López
#   Name: Name, dtype: object,
#   234032,
#   [0.9273012776093632, 0.638319022364758]],
#  [91707    Kelivelson
#   Name: Name, dtype: object,
#   230452,
#   [0.8942169859584979, 0.7016756975953529]],
#  [98361    Óscar Gil
#   Name: Name, dtype: object,
#   216461,
#   [0.9634075743405406, 0.5631727534545589]],
#  [96576    I. Nedelcearu
#   Name: Name, dtype: object,
#   242614,
#   [0.904148208645062, 0.6687957508999075]],
#  [89236    Núrio Fortuna
#   Name: Name, dtype: object,
#   221994,
#   [0.9144710900355149, 0.6466058288295229]],
#  [92366    D. Saddiki
#   Name: Name, dtype: object,
#   243733,
#   [0.9311378560839394, 0.6118649010050292]],
#  [101426    N. Tafari
#   Name: Name, dtype: object,
#   256024,
#   [0.9546471765189344, 0.5638543051628481]],
#  [99375    D. Hyam
#   Name: Name, dtype: object,
#   221281,
#   [0.9364516828552886, 0.5976382558897549]],
#  [99299    G. Maripán
#   Name: Name, dtype: object,
#   219145,
#   [0.8620449912540081, 0.7419608731406089]],
#  [100593    R. Ivanov
#   Name: Name, dtype: object,
#   258599,
#   [0.9415516313399054, 0.5834762535917395]],
#  [100540    M. Miazga
#   Name: Name, dtype: object,
#   215565,
#   [0.8960044840168961, 0.6699961567630418]],
#  [91945    R. Bauer
#   Name: Name, dtype: object,
#   223765,
#   [0.901078501097303, 0.6597641663594157]],
#  [100681    J. Whatmough
#   Name: Name, dtype: object,
#   211166,
#   [0.9334810363765734, 0.5947118225698499]],
#  [93501    D. Sánchez
#   Name: Name, dtype: object,
#   220793,
#   [0.8312982349774842, 0.7958599273120719]],
#  [93473    J. Andersen
#   Name: Name, dtype: object,
#   224221,
#   [0.8393368146929064, 0.7795266851859655]],
#  [93017    J. Rassoul
#   Name: Name, dtype: object,
#   229064,
#   [0.9100271750316018, 0.6391792323624629]],
#  [96721    20 D. van Bruggen
#   Name: Name, dtype: object,
#   223813,
#   [0.9428008606512234, 0.5729179974738499]],
#  [100443    C. Burgess
#   Name: Name, dtype: object,
#   216744,
#   [0.9547315791000176, 0.5488157817497531]],
#  [96430    21 J. Hardeveld
#   Name: Name, dtype: object,
#   221986,
#   [0.9364751599503679, 0.5843002637950325]],
#  [95754    Pol García
#   Name: Name, dtype: object,
#   211323,
#   [0.9073943685438466, 0.6412599503891749]],
#  [90375    Rúben Vezo
#   Name: Name, dtype: object,
#   215399,
#   [0.8540372239615518, 0.7465314509504366]],
#  [97080    J. Ruiz
#   Name: Name, dtype: object,
#   234814,
#   [0.9534602549824138, 0.5486296553840911]],
#  [100215    C. Harries
#   Name: Name, dtype: object,
#   228637,
#   [0.9646504892412281, 0.5260842884884376]],
#  [93513    C. Connolly
#   Name: Name, dtype: object,
#   229605,
#   [0.933573559570397, 0.5857435571871482]],
#  [94452    Jorge Sáenz
#   Name: Name, dtype: object,
#   225106,
#   [0.9045595775021124, 0.6429061340259249]],
#  [98018    J. Vollert
#   Name: Name, dtype: object,
#   239668,
#   [0.9738222540606292, 0.49823703135184233]],
#  [89985    K. Amian
#   Name: Name, dtype: object,
#   231235,
#   [0.881762784193206, 0.6773867464059584]],
#  [96703    Eric Curbelo
#   Name: Name, dtype: object,
#   237442,
#   [0.8934114990438777, 0.6543956466021519]],
#  [95132    J. Torunarigha
#   Name: Name, dtype: object,
#   236947,
#   [0.8583564481726615, 0.7223253583021968]],
#  [99753    M. Flis
#   Name: Name, dtype: object,
#   213855,
#   [0.9665339413834548, 0.508612119830955]],
#  [97818    M. Reinthaler
#   Name: Name, dtype: object,
#   224421,
#   [0.9574549442678667, 0.5259724187970141]],
#  [96318    17 A. Tamata
#   Name: Name, dtype: object,
#   202153,
#   [0.9231996198076918, 0.5916299005682143]],
#  [98042    M. Hołownia
#   Name: Name, dtype: object,
#   245129,
#   [0.9431203786270455, 0.5458872051039669]],
#  [98040    J. Tah
#   Name: Name, dtype: object,
#   213331,
#   [0.8347077687533749, 0.7594895099589755]],
#  [100721    I. Paro
#   Name: Name, dtype: object,
#   240312,
#   [0.9355448226489269, 0.5605097172379868]],
#  [96489    Diego González
#   Name: Name, dtype: object,
#   227106,
#   [0.9003082312783515, 0.6260597317151401]],
#  [98226    L. Desmond
#   Name: Name, dtype: object,
#   226728,
#   [0.9463891928172053, 0.5325892008940087]],
#  [93215    20 Renato Neto
#   Name: Name, dtype: object,
#   199663,
#   [0.8847547204711229, 0.653536453234227]],
#  [97434    A. Sørensen
#   Name: Name, dtype: object,
#   221024,
#   [0.9052191682635724, 0.6128354339841692]],
#  [92497    P. Hatzidiakos
#   Name: Name, dtype: object,
#   229150,
#   [0.8781317632261804, 0.6659174474477016]],
#  [101321    H. Kessler
#   Name: Name, dtype: object,
#   255110,
#   [0.91613923883154, 0.5889130620972546]],
#  [95898    A. Maxsø
#   Name: Name, dtype: object,
#   212287,
#   [0.8640589514910074, 0.6899128949221333]],
#  [95540    J. Glesnes
#   Name: Name, dtype: object,
#   233400,
#   [0.9033852702097349, 0.6113763547705273]],
#  [93746    V. Lekhal
#   Name: Name, dtype: object,
#   213841,
#   [0.906266718720987, 0.6047584856924911]],
#  [101472    M. Caufriez
#   Name: Name, dtype: object,
#   228983,
#   [0.910442855533823, 0.5946099209121676]],
#  [91513    Patrick William
#   Name: Name, dtype: object,
#   252150,
#   [0.8838545330831749, 0.6462614684134711]],
#  [90861    R. Rojas
#   Name: Name, dtype: object,
#   246914,
#   [0.8671634008068391, 0.6778443657451638]],
#  [99584    S. Coulibaly
#   Name: Name, dtype: object,
#   231872,
#   [0.9432364967932353, 0.5277056433372647]],
#  [93146    P. Dawidowicz
#   Name: Name, dtype: object,
#   213404,
#   [0.8568054702507856, 0.6962149707299875]],
#  [91677    Alfa Semedo
#   Name: Name, dtype: object,
#   239641,
#   [0.8833029751591416, 0.6436304684765879]],
#  [90273    Gregore
#   Name: Name, dtype: object,
#   251410,
#   [0.8587920845060865, 0.6917292233790575]],
#  [89003    E. Dier
#   Name: Name, dtype: object,
#   202335,
#   [0.8030900055999131, 0.800791342113412]],
#  [98316    J. Nilsson
#   Name: Name, dtype: object,
#   210802,
#   [0.8679420532082424, 0.6726093508282033]],
#  [97417    J. Elvedi
#   Name: Name, dtype: object,
#   256705,
#   [0.9003308149988763, 0.6084553726892824]],
#  [101297    S. McLoughlin
#   Name: Name, dtype: object,
#   241534,
#   [0.9483994466235002, 0.5104314827430754]],
#  [97662    21 R. Gelmi
#   Name: Name, dtype: object,
#   227700,
#   [0.9156935052691819, 0.5698000170081122]],
#  [95119    M. Leitsch
#   Name: Name, dtype: object,
#   234843,
#   [0.8735087250334074, 0.6529974223540506]],
#  [98620    B. Galloway
#   Name: Name, dtype: object,
#   209852,
#   [0.9481235829180273, 0.5056819823545728]],
#  [93245    20 U. Agbo
#   Name: Name, dtype: object,
#   226289,
#   [0.8905205822629991, 0.6185239565762566]],
#  [99218    L. Dietz
#   Name: Name, dtype: object,
#   241995,
#   [0.9233243028817012, 0.5526032974621626]],
#  [90872    A. Artean
#   Name: Name, dtype: object,
#   248111,
#   [0.9060016643861059, 0.5845855953657212]],
#  [100422    J. Glad
#   Name: Name, dtype: object,
#   222557,
#   [0.8986459550672088, 0.5972207114131173]],
#  [93428    21 L. Spendlhofer
#   Name: Name, dtype: object,
#   208247,
#   [0.9044751400474323, 0.5836431581133955]],
#  [91797    20 L. Hyam
#   Name: Name, dtype: object,
#   194792,
#   [0.908221571147397, 0.5731422531270906]],
#  [89591    P. McNair
#   Name: Name, dtype: object,
#   213697,
#   [0.8632449764786413, 0.661765207629891]],
#  [99716    H. Moukoudi
#   Name: Name, dtype: object,
#   228732,
#   [0.8437556484585117, 0.6954475428730635]],
#  [96804    M. Clarke
#   Name: Name, dtype: object,
#   221600,
#   [0.8519805100814566, 0.6768852368502649]],
#  [96123    B. Tuiloma
#   Name: Name, dtype: object,
#   220886,
#   [0.885107188928023, 0.6089765406115981]],
#  [98964    D. Lavalée
#   Name: Name, dtype: object,
#   236712,
#   [0.8830858698801285, 0.6119100071204747]],
#  [95186    R. Pröpper
#   Name: Name, dtype: object,
#   208462,
#   [0.8841419889310197, 0.6059209857879436]],
#  [92686    19 S. Medojević
#   Name: Name, dtype: object,
#   207523,
#   [0.8534803325033108, 0.6650387732449402]],
#  [98402    Pablo Marí
#   Name: Name, dtype: object,
#   206654,
#   [0.8244232315468479, 0.7180688875198616]],
#  [93553    M. Niakhaté
#   Name: Name, dtype: object,
#   225859,
#   [0.8392937538197717, 0.6883920071911854]],
#  [95344    B. Ndoye
#   Name: Name, dtype: object,
#   215495,
#   [0.8951889863131333, 0.5772316662880081]],
#  [98975    G. Henriksson
#   Name: Name, dtype: object,
#   245722,
#   [0.8994700934743431, 0.5677790149295185]],
#  [99138    20 J. Blåbjerg
#   Name: Name, dtype: object,
#   213528,
#   [0.9268219741413523, 0.5137688944760478]],
#  [94710    David Costas
#   Name: Name, dtype: object,
#   219848,
#   [0.8568518307777278, 0.6500675281567913]],
#  [95626    21 E. Fryers
#   Name: Name, dtype: object,
#   206489,
#   [0.9378401966833833, 0.48936172082212964]],
#  [94619    D. Van den Buijs
#   Name: Name, dtype: object,
#   225531,
#   [0.8991084820980313, 0.5599996940298807]],
#  [88614    N. Mukiele
#   Name: Name, dtype: object,
#   226166,
#   [0.7733355968516443, 0.8077988871500257]],
#  [94168    J. Kerr
#   Name: Name, dtype: object,
#   225589,
#   [0.8889293026624676, 0.5792540204193893]],
#  [98299    A. Jones
#   Name: Name, dtype: object,
#   236315,
#   [0.9054555380676365, 0.5457415079774102]],
#  [97590    21 Jemerson
#   Name: Name, dtype: object,
#   215792,
#   [0.8303855542327226, 0.6929924657978686]],
#  [92212    D. Hovorka
#   Name: Name, dtype: object,
#   240033,
#   [0.8260455717898781, 0.7011207253522983]],
#  [97243    T. Deng
#   Name: Name, dtype: object,
#   228310,
#   [0.8993851425363241, 0.5547375398126021]],
#  [94155    M. Loum
#   Name: Name, dtype: object,
#   245021,
#   [0.8396443652238907, 0.6632417090367786]],
#  [93090    W. Hoedt
#   Name: Name, dtype: object,
#   216774,
#   [0.803364848775597, 0.734521136454248]],
#  [99759    S. van Beek
#   Name: Name, dtype: object,
#   213000,
#   [0.839166358323147, 0.663845579623313]],
#  [96312    D. Vavro
#   Name: Name, dtype: object,
#   240988,
#   [0.8492132581094719, 0.6390571127828116]],
#  [95895    M. Angha
#   Name: Name, dtype: object,
#   202803,
#   [0.8847033624920967, 0.5689547791248083]],
#  [100462    21 M. Bürki
#   Name: Name, dtype: object,
#   211438,
#   [0.9153178969879164, 0.5083830125626232]],
#  [101638    E. Moore
#   Name: Name, dtype: object,
#   235263,
#   [0.9036666966052954, 0.5311602285213949]],
#  [99865    F. Romagna
#   Name: Name, dtype: object,
#   226108,
#   [0.8543641165194401, 0.627688464549746]],
#  [96324    D. Rugani
#   Name: Name, dtype: object,
#   211320,
#   [0.8035813191039302, 0.7278127466033436]],
#  [93690    D. Cavaré
#   Name: Name, dtype: object,
#   219803,
#   [0.8970356749289501, 0.542873851688356]],
#  [99821    D. O'Shaughnessy
#   Name: Name, dtype: object,
#   221486,
#   [0.8973507081435195, 0.5417993253735949]],
#  [96323    J. Rasmussen
#   Name: Name, dtype: object,
#   234827,
#   [0.8279466437619759, 0.677366007174289]],
#  [93233    Joaquín
#   Name: Name, dtype: object,
#   232132,
#   [0.8135783241593938, 0.705302988656035]],
#  [99153    R. Marchizza
#   Name: Name, dtype: object,
#   236308,
#   [0.8749146382324539, 0.5832341782855356]],
#  [98196    20 M. Capuano
#   Name: Name, dtype: object,
#   201529,
#   [0.834853840652743, 0.6618365489978123]],
#  [99257    S. Jurić
#   Name: Name, dtype: object,
#   262581,
#   [0.8993283604668939, 0.5335177442070093]],
#  [96029    D. Michalski
#   Name: Name, dtype: object,
#   251764,
#   [0.9252525851022738, 0.4785780476821052]],
#  [98818    Buatu
#   Name: Name, dtype: object,
#   209816,
#   [0.8741459841010892, 0.5787317235902659]],
#  [101016    H. McGahey
#   Name: Name, dtype: object,
#   220038,
#   [0.9175191985006436, 0.4906653487410171]],
#  [101009    Elton Monteiro
#   Name: Name, dtype: object,
#   202801,
#   [0.9096229755673615, 0.5061270198424631]],
#  [98100    Willyan
#   Name: Name, dtype: object,
#   251901,
#   [0.838848734228206, 0.6437117914927536]],
#  [91373    T. Kehrer
#   Name: Name, dtype: object,
#   226229,
#   [0.7924811802523148, 0.7309243440317135]],
#  [93346    Nouhou
#   Name: Name, dtype: object,
#   237469,
#   [0.8681646451185734, 0.5811129629342292]],
#  [98377    I. Näsberg
#   Name: Name, dtype: object,
#   216114,
#   [0.8825979407041794, 0.5524892586694613]],
#  [100504    21 L. López
#   Name: Name, dtype: object,
#   210033,
#   [0.9046907822163704, 0.5078577895314097]],
#  [91716    Dória
#   Name: Name, dtype: object,
#   209329,
#   [0.8095363743072341, 0.6953949459054116]],
#  [100595    21 P. Bijen
#   Name: Name, dtype: object,
#   218047,
#   [0.8703520856964558, 0.5690366196326674]],
#  [102493    21 G. Zajkov
#   Name: Name, dtype: object,
#   223568,
#   [0.8790846197527139, 0.5514063588018177]],
#  [94130    Marcão
#   Name: Name, dtype: object,
#   234426,
#   [0.7900872684502415, 0.7219535986737058]],
#  [100259    M. Hosseini
#   Name: Name, dtype: object,
#   243549,
#   [0.8422030848891846, 0.6172444999734282]],
#  [98639    21 E. Velázquez
#   Name: Name, dtype: object,
#   225299,
#   [0.8194339654724236, 0.6620748200527204]],
#  [93078    W. Dammers
#   Name: Name, dtype: object,
#   223566,
#   [0.8572397303518121, 0.5861927152824392]],
#  [98778    J. Fitzwater
#   Name: Name, dtype: object,
#   231139,
#   [0.8829475340031679, 0.5350656477321878]],
#  [90354    T. Fosu-Mensah
#   Name: Name, dtype: object,
#   232270,
#   [0.8127406986784662, 0.6734300463951067]],
#  [99719    S. Agouzoul
#   Name: Name, dtype: object,
#   251751,
#   [0.853061597905511, 0.5927481223738699]],
#  [100777    Philipe Sampaio
#   Name: Name, dtype: object,
#   224376,
#   [0.8498087254827329, 0.5961627130146361]],
#  [91494    A. Barboza
#   Name: Name, dtype: object,
#   229749,
#   [0.7948271937366762, 0.7043523720016756]],
#  [101041    J. Gundersen
#   Name: Name, dtype: object,
#   228238,
#   [0.904857173580644, 0.48716098723455525]],
#  [99509    L. Boeder
#   Name: Name, dtype: object,
#   225636,
#   [0.9075026328991147, 0.4799983971120826]],
#  [100189    21 S. Perić
#   Name: Name, dtype: object,
#   244496,
#   [0.8935916106584704, 0.5062397926536482]],
#  [100514    C. Hountondji
#   Name: Name, dtype: object,
#   219680,
#   [0.8182123515072497, 0.6546753309992696]],
#  [93902    J. Van den Bergh
#   Name: Name, dtype: object,
#   246716,
#   [0.841974030332003, 0.6076757053571535]],
#  [87912    R. Tapia
#   Name: Name, dtype: object,
#   220673,
#   [0.7332105084094552, 0.8219214857455753]],
#  [91835    F. Miguel
#   Name: Name, dtype: object,
#   226130,
#   [0.8211763002626242, 0.6464892320009065]],
#  [90198    D. Amartey
#   Name: Name, dtype: object,
#   212883,
#   [0.7838106719076886, 0.7200972618900541]],
#  [93661    Lucas Veríssimo
#   Name: Name, dtype: object,
#   235688,
#   [0.7638230231317829, 0.753592840766762]],
#  [88397    Éder Militão
#   Name: Name, dtype: object,
#   240130,
#   [0.7328988658001969, 0.8136638585241879]],
#  [91461    C. Söyüncü
#   Name: Name, dtype: object,
#   232119,
#   [0.7364227085640609, 0.8048024504767703]],
#  [100006    G. Lloris
#   Name: Name, dtype: object,
#   222286,
#   [0.8374388768938492, 0.6052452170974043]],
#  [100765    Jesiel
#   Name: Name, dtype: object,
#   230776,
#   [0.8260053269316114, 0.6268178280792732]],
#  [100044    E. Agbadou
#   Name: Name, dtype: object,
#   258575,
#   [0.8489186769264343, 0.5799885281342155]],
#  [89760    21 B. Addae
#   Name: Name, dtype: object,
#   210429,
#   [0.8545148575772761, 0.5676991214620629]],
#  [94541    C. Halkett
#   Name: Name, dtype: object,
#   222045,
#   [0.8637133358377957, 0.5445743607591425]],
#  [89354    L. Romo
#   Name: Name, dtype: object,
#   243015,
#   [0.7637704406023776, 0.7414776299808996]],
#  [100439    S. Wharton
#   Name: Name, dtype: object,
#   231540,
#   [0.8720441785748692, 0.5265501468896936]],
#  [98942    E. O'Connell
#   Name: Name, dtype: object,
#   221322,
#   [0.8472710445378555, 0.5744464790969318]],
#  [98408    F. Eboa Eboa
#   Name: Name, dtype: object,
#   239210,
#   [0.8639576530552819, 0.5390621596582841]],
#  [89644    G. Dzhikiya
#   Name: Name, dtype: object,
#   229773,
#   [0.7478960108989472, 0.7675177464279049]],
#  [96469    M. Fraser
#   Name: Name, dtype: object,
#   211096,
#   [0.8704072296638568, 0.5245459983595844]],
#  [94888    A. Briançon
#   Name: Name, dtype: object,
#   223138,
#   [0.8068211628601977, 0.648475266979603]],
#  [97889    I. Cristea
#   Name: Name, dtype: object,
#   248021,
#   [0.804455710068365, 0.6509623427245602]],
#  [101322    R. Popa
#   Name: Name, dtype: object,
#   235277,
#   [0.8881268522230681, 0.48539775460091095]],
#  [100634    20 B. San Juan
#   Name: Name, dtype: object,
#   214254,
#   [0.8827814554099188, 0.4953138353567619]],
#  [99662    20 A. Öztürk
#   Name: Name, dtype: object,
#   229362,
#   [0.8562843277851946, 0.5473055851806686]],
#  [97372    J. de Wijs
#   Name: Name, dtype: object,
#   224186,
#   [0.825074576831222, 0.6015589059849357]],
#  [98391    Z. Jules
#   Name: Name, dtype: object,
#   230839,
#   [0.8805143594368423, 0.48498965452198667]],
#  [92679    J. Okumu
#   Name: Name, dtype: object,
#   253073,
#   [0.8081030962486327, 0.6272362782711564]],
#  [101290    E. Haugan
#   Name: Name, dtype: object,
#   223253,
#   [0.857645879044169, 0.528070153446109]],
#  [93170    21 S. Lawson
#   Name: Name, dtype: object,
#   245748,
#   [0.8540521546058222, 0.5351075428482429]],
#  [96302    I. Diop
#   Name: Name, dtype: object,
#   231633,
#   [0.7565729601631891, 0.7272427556685606]],
#  [90931    L. Donnelly
#   Name: Name, dtype: object,
#   215820,
#   [0.8488781369172547, 0.5450762212929106]],
#  [99872    K. Schlotterbeck
#   Name: Name, dtype: object,
#   244068,
#   [0.7870075771938057, 0.6662134898946935]],
#  [96454    A. Esiti
#   Name: Name, dtype: object,
#   220921,
#   [0.7936417786991066, 0.6514961798127459]],
#  [96949    J. Moore-Taylor
#   Name: Name, dtype: object,
#   208645,
#   [0.8673259672481362, 0.503242918528941]],
#  [100960    M. Fritz
#   Name: Name, dtype: object,
#   239182,
#   [0.8747909918196489, 0.4884874872128044]],
#  [101349    M. Pineda
#   Name: Name, dtype: object,
#   255273,
#   [0.8382490425606476, 0.5601671487091072]],
#  [100261    L. Montsma
#   Name: Name, dtype: object,
#   257303,
#   [0.8502343937405646, 0.5364077061000098]],
#  [95569    21 K. Mets
#   Name: Name, dtype: object,
#   226506,
#   [0.8407366482840244, 0.5539069193583557]],
#  [95786    Edgar
#   Name: Name, dtype: object,
#   247500,
#   [0.7829946309969896, 0.6677673138284709]],
#  [99255    J. Hoogma
#   Name: Name, dtype: object,
#   231823,
#   [0.8061823422981145, 0.6219230167289097]],
#  [96788    S. McQueen
#   Name: Name, dtype: object,
#   215756,
#   [0.8676506050931977, 0.4991266288712626]],
#  [96727    Fábio Cardoso
#   Name: Name, dtype: object,
#   213917,
#   [0.7701264127248435, 0.6903054219623755]],
#  [99997    A. Peña
#   Name: Name, dtype: object,
#   230834,
#   [0.8572587222072962, 0.516960712844015]],
#  [99084    A. Karazor
#   Name: Name, dtype: object,
#   239096,
#   [0.8007587924849974, 0.628313541241246]],
#  [93122    S. Ingason
#   Name: Name, dtype: object,
#   221422,
#   [0.7641383253671983, 0.6996419826916528]],
#  [100736    21 P. Gouano
#   Name: Name, dtype: object,
#   204886,
#   [0.8016187311043371, 0.6234629649679809]],
#  [91297    18 E. Makeev
#   Name: Name, dtype: object,
#   192155,
#   [0.8153108026167293, 0.5947226396179692]],
#  [95642    A. Ndom
#   Name: Name, dtype: object,
#   231109,
#   [0.8363586660439979, 0.5513349851446724]],
#  [100278    J. Müller
#   Name: Name, dtype: object,
#   234381,
#   [0.8216962864857653, 0.5795493373311628]],
#  [94221    G. Kalulu
#   Name: Name, dtype: object,
#   238391,
#   [0.8083575134213271, 0.6049292603459461]],
#  [94793    D. Grétarsson
#   Name: Name, dtype: object,
#   226510,
#   [0.8452823336504526, 0.531998841610934]],
#  [90753    Li Ang
#   Name: Name, dtype: object,
#   224690,
#   [0.8336012553693724, 0.5544591085640468]],
#  [97677    S. Findlay
#   Name: Name, dtype: object,
#   227945,
#   [0.8241161409862201, 0.5710032920787698]],
#  [97737    A. Pieper
#   Name: Name, dtype: object,
#   246836,
#   [0.7463262635207105, 0.7237650579180359]],
#  [97504    S. Gartenmann
#   Name: Name, dtype: object,
#   229436,
#   [0.8157375255247764, 0.5859613366600611]],
#  [98685    C. González
#   Name: Name, dtype: object,
#   236020,
#   [0.8106764061048316, 0.5942652771096171]],
#  [93062    F. Tomori
#   Name: Name, dtype: object,
#   232756,
#   [0.715822095068552, 0.7807230775166516]],
#  [93023    20 Marc Muniesa
#   Name: Name, dtype: object,
#   192766,
#   [0.7621329687988474, 0.6881589583367088]],
#  [91622    E. Bailly
#   Name: Name, dtype: object,
#   225508,
#   [0.7116185549990637, 0.7869922361269369]],
#  [92524    K. N'Doram
#   Name: Name, dtype: object,
#   229011,
#   [0.7850137788082001, 0.6420232738025409]],
#  [95587    21 Nélson Monte
#   Name: Name, dtype: object,
#   222598,
#   [0.7944245990707441, 0.6209682505691433]],
#  [96165    K. Tshiembe
#   Name: Name, dtype: object,
#   238725,
#   [0.8292460983908735, 0.5518479224379236]],
#  [96337    21 O. Okungbowa
#   Name: Name, dtype: object,
#   220995,
#   [0.8526034846869608, 0.5023118947767402]],
#  [97732    A. Obileye
#   Name: Name, dtype: object,
#   206073,
#   [0.8577609735960627, 0.4917751066026739]],
#  [100916    D. Gugganig
#   Name: Name, dtype: object,
#   250780,
#   [0.8199758983102348, 0.563598522119085]],
#  [98121    P. Mainka
#   Name: Name, dtype: object,
#   216199,
#   [0.7509457019020794, 0.6995874524689254]],
#  [100557    G. Taft
#   Name: Name, dtype: object,
#   203145,
#   [0.865399481394601, 0.4714786025111369]],
#  [94211    Marlon
#   Name: Name, dtype: object,
#   215703,
#   [0.7645201866061152, 0.6702749949985375]],
#  [96683    Catena
#   Name: Name, dtype: object,
#   243976,
#   [0.7655759458421028, 0.66673059869551]],
#  [89694    D. Kohr
#   Name: Name, dtype: object,
#   212212,
#   [0.7499275506232117, 0.6971642877382047]],
#  [96538    S. O'Neill
#   Name: Name, dtype: object,
#   211581,
#   [0.8407620952157876, 0.5173573013170137]],
#  [101864    K. Rowles
#   Name: Name, dtype: object,
#   233931,
#   [0.8469961807113294, 0.5032574105125698]],
#  [97432    K. Omeruo
#   Name: Name, dtype: object,
#   207624,
#   [0.7481947968599556, 0.6954973356749561]],
#  [88220    R. Bensebaini
#   Name: Name, dtype: object,
#   224196,
#   [0.7110774785884492, 0.7679452347891644]],
#  [96581    A. Okosun
#   Name: Name, dtype: object,
#   239636,
#   [0.8307049620876414, 0.5310224003835444]],
#  [98370    J. van Aken
#   Name: Name, dtype: object,
#   216271,
#   [0.7905742188677534, 0.609571917289604]],
#  [90632    San Emeterio
#   Name: Name, dtype: object,
#   223654,
#   [0.7372473525010674, 0.7103839712399859]],
#  [92358    Rúben Semedo
#   Name: Name, dtype: object,
#   216778,
#   [0.7180134211326425, 0.7470838699241323]],
#  [91896    J. Fulton
#   Name: Name, dtype: object,
#   221890,
#   [0.7434542812966767, 0.6909702659810747]],
#  [100596    B. Ampuero
#   Name: Name, dtype: object,
#   225396,
#   [0.788196235703029, 0.6023156854445878]],
#  [96795    21 M. Leverbe
#   Name: Name, dtype: object,
#   240543,
#   [0.7762566399398948, 0.624379844273408]],
#  [102249    J. Aspropotamitis
#   Name: Name, dtype: object,
#   228191,
#   [0.8416098898979498, 0.49318882683445087]],
#  [92887    Diego Llorente
#   Name: Name, dtype: object,
#   212602,
#   [0.7158342951898117, 0.739703438106363]],
#  [96217    A. Mumin
#   Name: Name, dtype: object,
#   235662,
#   [0.7929486948602809, 0.5870112872661035]],
#  [98707    José Carlos
#   Name: Name, dtype: object,
#   222466,
#   [0.8216656207462165, 0.5291918865016995]],
#  [98938    R. Nicolaisen
#   Name: Name, dtype: object,
#   235244,
#   [0.8174251312276569, 0.5373042172179208]],
#  [92857    Jaílson
#   Name: Name, dtype: object,
#   234660,
#   [0.7799122961859329, 0.610943813739245]],
#  [92538    B. Schmitz
#   Name: Name, dtype: object,
#   222692,
#   [0.7803928837813398, 0.6074494269958637]],
#  [91838    M. Wöber
#   Name: Name, dtype: object,
#   231838,
#   [0.7325006558837537, 0.7014176065005328]],
#  [94935    P. Jaroszyński
#   Name: Name, dtype: object,
#   219661,
#   [0.8034151090237867, 0.5612275066140121]],
#  [99289    J. McCart
#   Name: Name, dtype: object,
#   227951,
#   [0.7995686521451407, 0.5668391966907833]],
#  [90102    L. Tousart
#   Name: Name, dtype: object,
#   227234,
#   [0.7153383963288538, 0.732658111806572]],
#  [95299    O. Kiomourtzoglou
#   Name: Name, dtype: object,
#   238965,
#   [0.7893114693361135, 0.585323985135926]],
#  [102402    T. Dallison
#   Name: Name, dtype: object,
#   213653,
#   [0.8543911831887528, 0.45580527636342794]],
#  [99413    J. Thorniley
#   Name: Name, dtype: object,
#   229349,
#   [0.8001284249412842, 0.5628066809073472]],
#  [101813    S. Simič
#   Name: Name, dtype: object,
#   219591,
#   [0.7668637577459042, 0.6230447330962983]],
#  [96182    21 V. Jovanović
#   Name: Name, dtype: object,
#   233219,
#   [0.7467427303964093, 0.6611632199871091]],
#  [99115    S. Coulibaly
#   Name: Name, dtype: object,
#   244751,
#   [0.7932681677912493, 0.5689557724340878]],
#  [90875    Bernardo
#   Name: Name, dtype: object,
#   232805,
#   [0.744490228984781, 0.6610138793509137]],
#  [96539    P. Sweeney
#   Name: Name, dtype: object,
#   207646,
#   [0.8439958260417108, 0.4602278644420773]],
#  [101593    D. Kane
#   Name: Name, dtype: object,
#   229206,
#   [0.877495230137366, 0.3926525712730601]],
#  [96946    M. Hofmann
#   Name: Name, dtype: object,
#   215370,
#   [0.7686146948781659, 0.6040723702178582]],
#  [96676    A. Hanche-Olsen
#   Name: Name, dtype: object,
#   228518,
#   [0.7714096609616726, 0.5978305872265424]],
#  [92281    J. Gomez
#   Name: Name, dtype: object,
#   225100,
#   [0.6650704755385707, 0.8054458705835671]],
#  [100865    B. Straalman
#   Name: Name, dtype: object,
#   228870,
#   [0.8138794569594673, 0.5111320103975238]],
#  [91230    A. Touba
#   Name: Name, dtype: object,
#   236535,
#   [0.7862994303490493, 0.5652885687862352]],
#  [101616    20 A. Barry
#   Name: Name, dtype: object,
#   209024,
#   [0.8484585903256809, 0.43807029035635653]],
#  [97826    G. Rea
#   Name: Name, dtype: object,
#   215570,
#   [0.7617429468140188, 0.6080407824765858]],
#  [99131    R. Burke
#   Name: Name, dtype: object,
#   221456,
#   [0.7753430583918881, 0.5791364096248944]],
#  [99621    S. Velkov
#   Name: Name, dtype: object,
#   255211,
#   [0.8307764747896436, 0.4696864230307931]],
#  [97118    Pablo Iñiguez
#   Name: Name, dtype: object,
#   206546,
#   [0.7666758517820801, 0.5883030588613476]],
#  [95702    P. Chato
#   Name: Name, dtype: object,
#   244489,
#   [0.8116662234868558, 0.4985433795397261]],
#  [97067    H. Türkmen
#   Name: Name, dtype: object,
#   243244,
#   [0.7643909072821139, 0.5904849293477943]],
#  [96341    T. Hübers
#   Name: Name, dtype: object,
#   234727,
#   [0.7448354293366881, 0.6283534551712767]],
#  [95297    R. Holding
#   Name: Name, dtype: object,
#   228295,
#   [0.6772947240128928, 0.7582496795766481]],
#  [99936    M. Nakkim
#   Name: Name, dtype: object,
#   228091,
#   [0.7980379752464845, 0.5186991861726326]],
#  [99748    M. Heylen
#   Name: Name, dtype: object,
#   212120,
#   [0.7686173162360616, 0.576580150552814]],
#  [100065    B. Utvik
#   Name: Name, dtype: object,
#   213864,
#   [0.7728313533991042, 0.5652485798948095]],
#  [96491    S. Long
#   Name: Name, dtype: object,
#   218591,
#   [0.8131220552312011, 0.4855497574960153]],
#  [93316    M. Udol
#   Name: Name, dtype: object,
#   229236,
#   [0.7394369519005766, 0.6303906454481711]],
#  [90721    18 Mauro
#   Name: Name, dtype: object,
#   203434,
#   [0.7096381217449953, 0.6886469480885224]],
#  [100234    D. Scarr
#   Name: Name, dtype: object,
#   237943,
#   [0.8075426598572301, 0.49518765316083163]],
#  [100555    C. Carter-Vickers
#   Name: Name, dtype: object,
#   228174,
#   [0.7523354646800661, 0.600920746587741]],
#  [97033    Borja López
#   Name: Name, dtype: object,
#   212129,
#   [0.7356027136845792, 0.6329804347157133]],
#  [92529    21 T. Lam
#   Name: Name, dtype: object,
#   208018,
#   [0.7601643798064445, 0.5823596158312058]],
#  [102445    A. Halme
#   Name: Name, dtype: object,
#   234290,
#   [0.7888652054271567, 0.5251146422900554]],
#  [98329    R. Poole
#   Name: Name, dtype: object,
#   225557,
#   [0.7945363206288125, 0.5134583981382089]],
#  [91237    B. Godfrey
#   Name: Name, dtype: object,
#   225793,
#   [0.6894500224636216, 0.7190512344435693]],
#  [100643    J. Canale
#   Name: Name, dtype: object,
#   253238,
#   [0.7571120901028559, 0.5837227321213914]],
#  [97487    J. Komar
#   Name: Name, dtype: object,
#   222428,
#   [0.7140089405869642, 0.6657945097840261]],
#  [100569    20 A. Murillo
#   Name: Name, dtype: object,
#   225574,
#   [0.7677182512215618, 0.5580529006630596]],
#  [101336    J. Turnbull
#   Name: Name, dtype: object,
#   206170,
#   [0.8059671280887739, 0.47699103375033475]],
#  [97911    J. Lascelles
#   Name: Name, dtype: object,
#   203487,
#   [0.6832548270156608, 0.7188501137059883]],
#  [102000    A. Dawa
#   Name: Name, dtype: object,
#   252675,
#   [0.7829360852689271, 0.5152705534331803]],
#  [99899    S. Kersten
#   Name: Name, dtype: object,
#   251754,
#   [0.7470773760754307, 0.5828774036982117]],
#  [94213    J. Hendry
#   Name: Name, dtype: object,
#   225316,
#   [0.7456201641537544, 0.5852600397361004]],
#  [100905    L. Gordinho
#   Name: Name, dtype: object,
#   219664,
#   [0.7990193461150737, 0.4775382008561497]],
#  [95734    21 J. Flanagan
#   Name: Name, dtype: object,
#   201999,
#   [0.7329394074025933, 0.6056926210656424]],
#  [91923    A. Matusiwa
#   Name: Name, dtype: object,
#   239356,
#   [0.6964540608433228, 0.6774433096757118]],
#  [99754    M. Wieteska
#   Name: Name, dtype: object,
#   224302,
#   [0.7296999818270878, 0.6111695850543766]],
#  [90131    D. Luckassen
#   Name: Name, dtype: object,
#   224242,
#   [0.7282296556884831, 0.611106928253803]],
#  [99800    M. Mihojević
#   Name: Name, dtype: object,
#   242412,
#   [0.7314322883015888, 0.6032887315454346]],
#  [101859    21 S. Hajrović
#   Name: Name, dtype: object,
#   202806,
#   [0.7951026503637677, 0.4751020600898714]],
#  [100656    J. Gómez
#   Name: Name, dtype: object,
#   224388,
#   [0.7546494199977757, 0.5523924361467224]],
#  [97926    F. Barba
#   Name: Name, dtype: object,
#   211557,
#   [0.7190421809059374, 0.6194148800885352]],
#  [99711    F. Brorsson
#   Name: Name, dtype: object,
#   226523,
#   [0.7646862807924585, 0.5268431074253369]],
#  [100206    T. Watanabe
#   Name: Name, dtype: object,
#   246826,
#   [0.7416152858054371, 0.5696980445764132]],
#  [98762    Pombaxinho
#   Name: Name, dtype: object,
#   230383,
#   [0.6919169213235453, 0.6672689804273225]],
#  [101167    21 J. Wright
#   Name: Name, dtype: object,
#   214682,
#   [0.7592202745185931, 0.5343112405994934]],
#  [96931    20 O. Fane
#   Name: Name, dtype: object,
#   235627,
#   [0.7846571849217492, 0.4833124019276473]],
#  [98763    D. Fry
#   Name: Name, dtype: object,
#   229682,
#   [0.6981387877920275, 0.6468813588518239]],
#  [100617    J. Pask
#   Name: Name, dtype: object,
#   230942,
#   [0.778483951002912, 0.488019879841228]],
#  [99550    I. Vujica
#   Name: Name, dtype: object,
#   235054,
#   [0.8079492565838448, 0.428628234669632]],
#  [101619    19 E. Suagher
#   Name: Name, dtype: object,
#   216789,
#   [0.7484663412670173, 0.5412453783714469]],
#  [98612    D. Bernard
#   Name: Name, dtype: object,
#   228226,
#   [0.8070159336144888, 0.42479464934926625]],
#  [99765    K. Miller
#   Name: Name, dtype: object,
#   247648,
#   [0.7328954223951409, 0.5697822236308291]],
#  [99884    M. Diaby
#   Name: Name, dtype: object,
#   248831,
#   [0.6689872809633819, 0.6953177504304129]],
#  [89061    M. Ginter
#   Name: Name, dtype: object,
#   207862,
#   [0.5973056941907015, 0.8347271265132221]],
#  [96922    L. Fröde
#   Name: Name, dtype: object,
#   227932,
#   [0.7313212082346771, 0.5682914273112539]],
#  [90602    N. Stark
#   Name: Name, dtype: object,
#   212977,
#   [0.6578802949947006, 0.7122312656375731]],
#  [100119    C. Goode
#   Name: Name, dtype: object,
#   228997,
#   [0.7479800537032258, 0.5331600238082971]],
#  [98882    T. Baumgartl
#   Name: Name, dtype: object,
#   223641,
#   [0.6897827341149986, 0.641592127670901]],
#  [99427    G. Wüthrich
#   Name: Name, dtype: object,
#   220665,
#   [0.7067278838037621, 0.6066317809148756]],
#  [96381    S. Sinyan
#   Name: Name, dtype: object,
#   233820,
#   [0.7548299740292461, 0.5113790515173404]],
#  [91731    M. Škriniar
#   Name: Name, dtype: object,
#   232363,
#   [0.5726639345467356, 0.8701819648131094]],
#  [101277    20 Carlos Blanco
#   Name: Name, dtype: object,
#   224566,
#   [0.7390666925946484, 0.5405386219141565]],
#  [95440    J. Hanson
#   Name: Name, dtype: object,
#   213376,
#   [0.7488726465189821, 0.5203971914516199]],
#  [98396    21 E. Dabo
#   Name: Name, dtype: object,
#   228836,
#   [0.7793329874689062, 0.46014998950303226]],
#  [97723    S. Rosted
#   Name: Name, dtype: object,
#   227362,
#   [0.7118761359158798, 0.5868325919733607]],
#  [97688    L. Jäger
#   Name: Name, dtype: object,
#   223427,
#   [0.740208129373558, 0.5294332534642415]],
#  [97645    I. Kutepov
#   Name: Name, dtype: object,
#   210468,
#   [0.6743946732219992, 0.6586400453391773]],
#  [100474    L. Väisänen
#   Name: Name, dtype: object,
#   234291,
#   [0.7372153929842822, 0.5286701087868116]],
#  [100475    M. Rente
#   Name: Name, dtype: object,
#   257957,
#   [0.7288646772881505, 0.5419446326215921]],
#  [97681    F. Pfanne
#   Name: Name, dtype: object,
#   262635,
#   [0.7316498841133671, 0.5354754892126745]],
#  [89593    E. Álvarez
#   Name: Name, dtype: object,
#   235844,
#   [0.6276186083187553, 0.7383587583183409]],
#  [102090    20 G. Andonian
#   Name: Name, dtype: object,
#   211690,
#   [0.7536537466940665, 0.48941868217826157]],
#  [98137    F. Aliti
#   Name: Name, dtype: object,
#   221989,
#   [0.7466007898119695, 0.5015616738359668]],
#  [97945    T. Thomas
#   Name: Name, dtype: object,
#   225694,
#   [0.7427461620371122, 0.5053507543723076]],
#  [96243    M. Kilman
#   Name: Name, dtype: object,
#   245336,
#   [0.6839421148571818, 0.6194282190595103]],
#  [97160    M. Diakhaby
#   Name: Name, dtype: object,
#   230578,
#   [0.6596539762750508, 0.6651348026046275]],
#  [96773    A. Ferrari
#   Name: Name, dtype: object,
#   219852,
#   [0.6724225723176813, 0.6398770923768784]],
#  [97698    21 B. Sanneh
#   Name: Name, dtype: object,
#   220302,
#   [0.687183770581925, 0.6098102945592797]],
#  [96940    José Amo
#   Name: Name, dtype: object,
#   231320,
#   [0.6906665500672061, 0.6021211536553353]],
#  [92692    He Chao
#   Name: Name, dtype: object,
#   224470,
#   [0.7277262473161821, 0.5274338172646056]],
#  [96584    W. Zahibo
#   Name: Name, dtype: object,
#   206207,
#   [0.7260223492302649, 0.5302611228419659]],
#  [98195    T. Becker
#   Name: Name, dtype: object,
#   254245,
#   [0.7019129132731092, 0.5729474628132643]],
#  [101218    N. Ueda
#   Name: Name, dtype: object,
#   232870,
#   [0.6900907641873564, 0.589500206858251]],
#  [98309    Y. Kimoto
#   Name: Name, dtype: object,
#   237789,
#   [0.7084735491553287, 0.5484599996139734]],
#  [95866    S. Schonlau
#   Name: Name, dtype: object,
#   214948,
#   [0.6394257918081935, 0.6821845924537422]],
#  [98441    Verdasca
#   Name: Name, dtype: object,
#   233413,
#   [0.7252987487286737, 0.5123054806723545]],
#  [96069    F. Uduokhai
#   Name: Name, dtype: object,
#   232144,
#   [0.6018440109952864, 0.7546575199701789]],
#  [99793    S. Mmaee
#   Name: Name, dtype: object,
#   224211,
#   [0.7133248199581848, 0.5345885351595088]],
#  [101231    20 M. Camporese
#   Name: Name, dtype: object,
#   201914,
#   [0.667235749955851, 0.6245693679565733]],
#  [98161    C. Awaziem
#   Name: Name, dtype: object,
#   232693,
#   [0.6565638933100212, 0.6454325989850005]],
#  [100042    18 I. Zuev
#   Name: Name, dtype: object,
#   210610,
#   [0.7359687090818626, 0.48669093886179815]],
#  [101089    Guilherme Ramos
#   Name: Name, dtype: object,
#   262869,
#   [0.6798740331226313, 0.5965551495260968]],
#  [100632    N. Katić
#   Name: Name, dtype: object,
#   244204,
#   [0.6705257860675738, 0.6124298867879948]],
#  [92711    S. Gigot
#   Name: Name, dtype: object,
#   219581,
#   [0.6076394612781276, 0.7360767260935515]],
#  [97548    Maracás
#   Name: Name, dtype: object,
#   251681,
#   [0.6454489675323344, 0.6607664594254709]],
#  [100255    J. Clarke-Salter
#   Name: Name, dtype: object,
#   230774,
#   [0.6758694827871279, 0.5976792511242329]],
#  [98786    M. Caldara
#   Name: Name, dtype: object,
#   220477,
#   [0.5971005342713246, 0.7500235309936787]],
#  [101749    D. Conroy
#   Name: Name, dtype: object,
#   213667,
#   [0.7226083902947147, 0.5003157931140672]],
#  [97908    N. Šipčić
#   Name: Name, dtype: object,
#   252275,
#   [0.691208345090215, 0.5583537995908885]],
#  [92695    J. Giménez
#   Name: Name, dtype: object,
#   216460,
#   [0.5461022544723557, 0.8425197471617316]],
#  [100658    17 T. Thorpe
#   Name: Name, dtype: object,
#   206091,
#   [0.7053022943748298, 0.5259627418932308]],
#  [93320    T. Jedvaj
#   Name: Name, dtype: object,
#   215930,
#   [0.6381266742976011, 0.6577809930434815]],
#  [100265    20 M. Sarr
#   Name: Name, dtype: object,
#   212628,
#   [0.7465782488847219, 0.4432981132983412]],
#  [102107    L. Jürgensen
#   Name: Name, dtype: object,
#   257316,
#   [0.7276012832148636, 0.4766977554409781]],
#  [100184    N. DePuy
#   Name: Name, dtype: object,
#   237215,
#   [0.7267446561272413, 0.4777000511084116]],
#  [93081    W. Janssens
#   Name: Name, dtype: object,
#   234148,
#   [0.6776223183366561, 0.5726928339655908]],
#  [93333    J. Elez
#   Name: Name, dtype: object,
#   218341,
#   [0.6813001830716797, 0.56525850139621]],
#  [98119    A. Sharahili
#   Name: Name, dtype: object,
#   221658,
#   [0.6819065038443805, 0.5630364167716061]],
#  [97616    A. Pérez
#   Name: Name, dtype: object,
#   221312,
#   [0.6680013980957248, 0.5900894168279655]],
#  [97952    D. Abels
#   Name: Name, dtype: object,
#   250805,
#   [0.6753520322021543, 0.5745020485750182]],
#  [102573    J. García
#   Name: Name, dtype: object,
#   229985,
#   [0.7090602637327711, 0.5031138645346515]],
#  [95584    C. Zock
#   Name: Name, dtype: object,
#   226550,
#   [0.7105870507400064, 0.49900603158736956]],
#  [100003    S. Babić
#   Name: Name, dtype: object,
#   235589,
#   [0.6533616650387124, 0.6093999218751603]],
#  [100005    21 M. Diagne
#   Name: Name, dtype: object,
#   220126,
#   [0.6541577723062781, 0.5974691585171732]],
#  [96706    Jorge Meré
#   Name: Name, dtype: object,
#   223033,
#   [0.6311886637936657, 0.6402770289157355]],
#  [96830    T. Lockyer
#   Name: Name, dtype: object,
#   211363,
#   [0.6537619251584718, 0.5851634794890225]],
#  [96371    S. Ajayi
#   Name: Name, dtype: object,
#   207952,
#   [0.6329809772645599, 0.6253562845759896]],
#  [97941    C. Luyindama
#   Name: Name, dtype: object,
#   237556,
#   [0.5937646638725556, 0.7025084485451061]],
#  [99231    B. Cargill
#   Name: Name, dtype: object,
#   215211,
#   [0.6898055819063205, 0.5086320361458286]],
#  [93880    J. Stephens
#   Name: Name, dtype: object,
#   202697,
#   [0.6002673925915755, 0.6768194504667995]],
#  [91701    C. Mbemba
#   Name: Name, dtype: object,
#   210897,
#   [0.5592626180166191, 0.7571856253154925]],
#  [98978    S. Hatanaka
#   Name: Name, dtype: object,
#   245785,
#   [0.6346924817886097, 0.6072229025971561]],
#  [100651    P. Kapp
# ...
#  [91458    J. Escobar
#   Name: Name, dtype: object,
#   247881,
#   [0.13660933221795396, 0.6375725364716318]],
#  [101722    S. Lavelle
#   Name: Name, dtype: object,
#   228928,
#   [0.23066938403465678, 0.45051670815388145]],
#  [98187    Samir
#   Name: Name, dtype: object,
#   215651,
#   [0.13008597999564486, 0.6479413566797111]],
#  [101917    J. Kabongo
#   Name: Name, dtype: object,
#   236445,
#   [0.24785052640425273, 0.4136362127581851]],
#  [94533    Abdu Conté
#   Name: Name, dtype: object,
#   247180,
#   [0.2138401640697169, 0.4787767087923539]],
#  [102729    21 D. Arboleda
#   Name: Name, dtype: object,
#   227740,
#   [0.22787913682144198, 0.4487501861665446]],
#  [100202    G. Miura
#   Name: Name, dtype: object,
#   237429,
#   [0.16164401191660116, 0.5789230238083413]],
#  [96345    D. Rosero
#   Name: Name, dtype: object,
#   215067,
#   [0.18542526320002442, 0.528708180797803]],
#  [100646    I. Łasicki
#   Name: Name, dtype: object,
#   220531,
#   [0.22767542077154354, 0.4446377225584581]],
#  [101670    21 K. Howkins
#   Name: Name, dtype: object,
#   228401,
#   [0.2536671542260599, 0.38689032878598856]],
#  [102056    21 Kim Jung Ho
#   Name: Name, dtype: object,
#   243626,
#   [0.27950716477217186, 0.3340306838597961]],
#  [97974    G. Guiffrey
#   Name: Name, dtype: object,
#   244851,
#   [0.172848646758497, 0.535889662841129]],
#  [102550    B. Karamoko
#   Name: Name, dtype: object,
#   226759,
#   [0.2242742966758922, 0.4332514613142451]],
#  [93955    M. Valjent
#   Name: Name, dtype: object,
#   219585,
#   [0.12327897639094819, 0.6319592843313911]],
#  [97902    Rodri Tarín
#   Name: Name, dtype: object,
#   228828,
#   [0.1644949027066178, 0.5493184708103321]],
#  [97671    E. Martínez
#   Name: Name, dtype: object,
#   253278,
#   [0.1654780241893338, 0.5434169427306614]],
#  [101407    S. Chakla
#   Name: Name, dtype: object,
#   220388,
#   [0.15703374664249406, 0.5576086357265133]],
#  [100575    Adrián Diéguez
#   Name: Name, dtype: object,
#   236508,
#   [0.18140779273324292, 0.5076972696076503]],
#  [101647    21 M. Guanini
#   Name: Name, dtype: object,
#   228893,
#   [0.1791224700694225, 0.5111223659270888]],
#  [98983    J. Onguéné
#   Name: Name, dtype: object,
#   221323,
#   [0.16644579259409312, 0.5340023181547514]],
#  [97302    20 Tiago Ferreira
#   Name: Name, dtype: object,
#   205845,
#   [0.17367112428563808, 0.5079577998521216]],
#  [102255    J. Jones
#   Name: Name, dtype: object,
#   257865,
#   [0.24495781539581343, 0.36508348579687844]],
#  [99947    M. Naderi
#   Name: Name, dtype: object,
#   244537,
#   [0.1958544769408263, 0.46113828471504864]],
#  [100854    S. Bose
#   Name: Name, dtype: object,
#   245165,
#   [0.24250668599124942, 0.36789299243283513]],
#  [100072    Jubal
#   Name: Name, dtype: object,
#   217565,
#   [0.15532214280472265, 0.537442247971646]],
#  [102023    F. Horsfall
#   Name: Name, dtype: object,
#   230677,
#   [0.21145305189795122, 0.4243694015087267]],
#  [99881    J. Novillo
#   Name: Name, dtype: object,
#   246667,
#   [0.14564919290556888, 0.5519418687431344]],
#  [101293    J. Kramer
#   Name: Name, dtype: object,
#   228363,
#   [0.1901219660951183, 0.4632347730171191]],
#  [97923    Rubén
#   Name: Name, dtype: object,
#   262299,
#   [0.16470037451206296, 0.5091895236831594]],
#  [101838    S. Ngezana
#   Name: Name, dtype: object,
#   235442,
#   [0.17641359128650308, 0.483901142721358]],
#  [97849    S. Lorenz
#   Name: Name, dtype: object,
#   242383,
#   [0.1459198086529492, 0.538746143590741]],
#  [99789    A. Ale
#   Name: Name, dtype: object,
#   254603,
#   [0.17444203546052922, 0.4747698273141355]],
#  [99886    T. Hadebe
#   Name: Name, dtype: object,
#   239438,
#   [0.17665156504975296, 0.46707491001437473]],
#  [97706    S. Gregersen
#   Name: Name, dtype: object,
#   216730,
#   [0.14822979850458803, 0.5225510408537908]],
#  [102217    O. Gonzalez
#   Name: Name, dtype: object,
#   230140,
#   [0.1980151957474783, 0.422006437451722]],
#  [100520    20 M. Preston
#   Name: Name, dtype: object,
#   213027,
#   [0.2186849454204846, 0.37917173181901914]],
#  [97618    C. Akas
#   Name: Name, dtype: object,
#   241765,
#   [0.18056214235786758, 0.44912379833017124]],
#  [100426    21 R. Osorio
#   Name: Name, dtype: object,
#   219090,
#   [0.16600685729775166, 0.477685309995728]],
#  [100281    Juan Ibiza
#   Name: Name, dtype: object,
#   245159,
#   [0.13890133704676594, 0.5302737068496183]],
#  [101405    E. Onariase
#   Name: Name, dtype: object,
#   228152,
#   [0.1844175581295729, 0.43186727526596635]],
#  [102152    21 Javi Jiménez
#   Name: Name, dtype: object,
#   237032,
#   [0.1641906240349204, 0.4713679477914732]],
#  [98798    21 J. Rhyner
#   Name: Name, dtype: object,
#   229727,
#   [0.14233770815936753, 0.5103658857987964]],
#  [93960    16 Breno
#   Name: Name, dtype: object,
#   180955,
#   [0.1343711321664525, 0.523950289948419]],
#  [99196    S. Junqua
#   Name: Name, dtype: object,
#   247309,
#   [0.16387329481781424, 0.45904123871384434]],
#  [102206    C. Singh
#   Name: Name, dtype: object,
#   234508,
#   [0.2140433874365538, 0.35817123985000043]],
#  [96884    N. Casale
#   Name: Name, dtype: object,
#   239770,
#   [0.14871658625020437, 0.4870379010630916]],
#  [100615    Iván Márquez
#   Name: Name, dtype: object,
#   220385,
#   [0.16287621816823494, 0.45828958392785707]],
#  [90666    A. Vallci
#   Name: Name, dtype: object,
#   243661,
#   [0.08727630284483877, 0.604384042444752]],
#  [101133    A. Mora
#   Name: Name, dtype: object,
#   242427,
#   [0.13710895625196554, 0.5052075903378753]],
#  [102877    G. Ray
#   Name: Name, dtype: object,
#   203430,
#   [0.21669657076306797, 0.3478197564145095]],
#  [95736    M. Helik
#   Name: Name, dtype: object,
#   219293,
#   [0.11790219598215403, 0.5405875446011902]],
#  [100383    S. McKenna
#   Name: Name, dtype: object,
#   225974,
#   [0.11614565832615462, 0.5411517179207789]],
#  [102667    G. Lillard
#   Name: Name, dtype: object,
#   242707,
#   [0.18410431926462012, 0.4050530987636018]],
#  [99005    G. Corujo
#   Name: Name, dtype: object,
#   253289,
#   [0.08824643573126738, 0.5921123163462048]],
#  [101155    M. Doucouré
#   Name: Name, dtype: object,
#   233728,
#   [0.171286567183664, 0.4231443942270031]],
#  [97542    M. Brizuela
#   Name: Name, dtype: object,
#   252168,
#   [0.09852159396149603, 0.5665157761428101]],
#  [97771    P. Cissé
#   Name: Name, dtype: object,
#   228386,
#   [0.06135749607895881, 0.6326715421846558]],
#  [99259    N. Lozano
#   Name: Name, dtype: object,
#   243944,
#   [0.12322903325066122, 0.5091727088961641]],
#  [101730    M. López Quintana
#   Name: Name, dtype: object,
#   225910,
#   [0.17023875715579984, 0.416311053093499]],
#  [100603    A. Kilgour
#   Name: Name, dtype: object,
#   231107,
#   [0.14139482621647056, 0.47213240703473164]],
#  [100019    M. Andersen
#   Name: Name, dtype: object,
#   228419,
#   [0.0924138155033234, 0.5676145365804369]],
#  [98717    G. Canto
#   Name: Name, dtype: object,
#   227526,
#   [0.1355442783941362, 0.48181006632248313]],
#  [95277    21 A. Cistana
#   Name: Name, dtype: object,
#   226260,
#   [0.0808213144382161, 0.5875357722082307]],
#  [100680    F. Sierralta
#   Name: Name, dtype: object,
#   228681,
#   [0.12020729792059466, 0.5087056238853235]],
#  [102745    20 B. Nugent
#   Name: Name, dtype: object,
#   204459,
#   [0.17054275325571808, 0.40699033161100867]],
#  [100941    F. Kuruçuk
#   Name: Name, dtype: object,
#   257804,
#   [0.11947308332031459, 0.5065909266595378]],
#  [102840    21 C. Montgomery
#   Name: Name, dtype: object,
#   247510,
#   [0.22276404064378488, 0.3015595265563114]],
#  [101296    D. Fox
#   Name: Name, dtype: object,
#   231342,
#   [0.1345567108245423, 0.4716979153507997]],
#  [102276    19 Roger Riera
#   Name: Name, dtype: object,
#   224164,
#   [0.1688661041868819, 0.4015630866545715]],
#  [98380    T. Asta-Buruaga
#   Name: Name, dtype: object,
#   214701,
#   [0.12458958504969275, 0.4871203938544699]],
#  [102355    21 David Cardoso
#   Name: Name, dtype: object,
#   247198,
#   [0.16270415589711995, 0.4114998607995321]],
#  [97282    F. Ananou
#   Name: Name, dtype: object,
#   234668,
#   [0.13890779693367755, 0.4562075000511886]],
#  [100456    21 E. Amor
#   Name: Name, dtype: object,
#   226170,
#   [0.08373550923548108, 0.5629386363633023]],
#  [96178    Henrique Gomes
#   Name: Name, dtype: object,
#   251450,
#   [0.10013569668827961, 0.5288832595471396]],
#  [98701    L. Sosa
#   Name: Name, dtype: object,
#   226386,
#   [0.12243932256198035, 0.4830019014031655]],
#  [100910    M. Ekpiteta
#   Name: Name, dtype: object,
#   250810,
#   [0.11881596274746865, 0.4900064200843065]],
#  [95546    J. Castelletto
#   Name: Name, dtype: object,
#   213868,
#   [0.04347292171577163, 0.6313193952257432]],
#  [101279    S. Nkansah
#   Name: Name, dtype: object,
#   229756,
#   [0.1263777064984457, 0.4671393859119328]],
#  [101001    L. Lindsay
#   Name: Name, dtype: object,
#   215638,
#   [0.10058103810355284, 0.5139642670282503]],
#  [97714    B. Kouyaté
#   Name: Name, dtype: object,
#   247019,
#   [0.04921491903535878, 0.604361715284225]],
#  [102045    Tachi
#   Name: Name, dtype: object,
#   238446,
#   [0.09131041045402778, 0.515646480783832]],
#  [102154    A. Maciel
#   Name: Name, dtype: object,
#   240457,
#   [0.13428681720476537, 0.42981894957207895]],
#  [101339    A. Doldán
#   Name: Name, dtype: object,
#   255240,
#   [0.1017960900414466, 0.49193822736296505]],
#  [100264    C. Gogoua
#   Name: Name, dtype: object,
#   253144,
#   [0.09502169617526696, 0.5022318138126598]],
#  [98234    Juninho
#   Name: Name, dtype: object,
#   231104,
#   [0.056259935298191295, 0.5766076048679181]],
#  [102424    J. Aguayo
#   Name: Name, dtype: object,
#   258053,
#   [0.1444254476355866, 0.4020638772872757]],
#  [100128    J. Laporte
#   Name: Name, dtype: object,
#   228290,
#   [0.0688417582110725, 0.5489965948925493]],
#  [99566    W. Nightingale
#   Name: Name, dtype: object,
#   221538,
#   [0.11453230965109655, 0.45814026198258984]],
#  [99582    Artur Jorge
#   Name: Name, dtype: object,
#   236505,
#   [0.049359059591804845, 0.5862669025325433]],
#  [98152    L. Segovia
#   Name: Name, dtype: object,
#   253344,
#   [0.09200088898073296, 0.50195702430187]],
#  [101950    21 E. Caicedo
#   Name: Name, dtype: object,
#   227398,
#   [0.14991615794939767, 0.3864186441718031]],
#  [101038    T. Ominami
#   Name: Name, dtype: object,
#   232704,
#   [0.13213118053372455, 0.41996187238766125]],
#  [102336    21 L. Morante
#   Name: Name, dtype: object,
#   257076,
#   [0.13930391123822033, 0.40382086447372734]],
#  [96442    M. Komenda
#   Name: Name, dtype: object,
#   224093,
#   [0.08972003472487625, 0.5012278554311962]],
#  [101667    Arambarri
#   Name: Name, dtype: object,
#   254003,
#   [0.0959608008261896, 0.4823216222796034]],
#  [100711    F. Zorba
#   Name: Name, dtype: object,
#   235939,
#   [0.13961497178843324, 0.3945381429879976]],
#  [100951    J. Storey
#   Name: Name, dtype: object,
#   235464,
#   [0.08201070723733403, 0.5077344066519269]],
#  [101040    F. Mayembo
#   Name: Name, dtype: object,
#   232136,
#   [0.09260577283264552, 0.4864293889898122]],
#  [97374    A. Pițian
#   Name: Name, dtype: object,
#   248005,
#   [0.10555548168690385, 0.46084127297994]],
#  [97082    R. Becker
#   Name: Name, dtype: object,
#   229610,
#   [0.11196330906189698, 0.44437752377177336]],
#  [102219    P. Ndiaye
#   Name: Name, dtype: object,
#   264389,
#   [0.09124785357626394, 0.4834389324107457]],
#  [102194    J. Handl
#   Name: Name, dtype: object,
#   248470,
#   [0.08838459990276339, 0.48619853344335495]],
#  [100470    18 R. Brown
#   Name: Name, dtype: object,
#   203059,
#   [0.16867519600097036, 0.31865390636713586]],
#  [97613    V. Ghiță
#   Name: Name, dtype: object,
#   248105,
#   [0.0906460153334997, 0.4720836560373256]],
#  [102708    M. Devlin
#   Name: Name, dtype: object,
#   223265,
#   [0.10973155742112055, 0.4330450961077042]],
#  [98893    E. Palmer-Brown
#   Name: Name, dtype: object,
#   219461,
#   [0.07112832634798669, 0.507831501989848]],
#  [102462    S. Sabetkar
#   Name: Name, dtype: object,
#   261452,
#   [0.13443135337513318, 0.3818915616006506]],
#  [101768    A. Jackson
#   Name: Name, dtype: object,
#   204219,
#   [0.09249573226903597, 0.46405481932594883]],
#  [102268    N. Hoffmann
#   Name: Name, dtype: object,
#   231379,
#   [0.11618687922961542, 0.41268648751142456]],
#  [92802    16 R. Strasser
#   Name: Name, dtype: object,
#   190604,
#   [0.1365199912278345, 0.36700262114803456]],
#  [98069    G. Aguirre
#   Name: Name, dtype: object,
#   232316,
#   [0.07575308425597811, 0.4801827678184089]],
#  [98888    K. Mavropanos
#   Name: Name, dtype: object,
#   242000,
#   [0.02459709906479606, 0.5810059168658291]],
#  [102285    J. Löfgren
#   Name: Name, dtype: object,
#   247042,
#   [0.12567091500257646, 0.37634620378403416]],
#  [102088    S. Raggett
#   Name: Name, dtype: object,
#   238450,
#   [0.10006213676514432, 0.42414862166189404]],
#  [100628    K. Machida
#   Name: Name, dtype: object,
#   232873,
#   [0.08346294735911967, 0.4554797374249338]],
#  [100170    M. Spano Rahou
#   Name: Name, dtype: object,
#   223594,
#   [0.08415920987651763, 0.4453665728279783]],
#  [101803    K. Ford
#   Name: Name, dtype: object,
#   237116,
#   [0.10861674326091728, 0.39130733362496556]],
#  [102596    J. Pestaña
#   Name: Name, dtype: object,
#   238880,
#   [0.11785886944732504, 0.3678767043780877]],
#  [101269    Jeong Tae Wook
#   Name: Name, dtype: object,
#   238576,
#   [0.06063857060928596, 0.4804257385938415]],
#  [101061    C. Kipré
#   Name: Name, dtype: object,
#   235458,
#   [0.04485554162141568, 0.503604121618493]],
#  [102515    G. Mutombo
#   Name: Name, dtype: object,
#   222209,
#   [0.07193819506219558, 0.4500614278231266]],
#  [101481    S. Reddemann
#   Name: Name, dtype: object,
#   235207,
#   [0.09396774173007919, 0.3988035941106054]],
#  [101962    L. Jones
#   Name: Name, dtype: object,
#   215301,
#   [0.06066441155883517, 0.451493617936477]],
#  [101447    D. Cleary
#   Name: Name, dtype: object,
#   233056,
#   [0.05305228466856589, 0.4655607587263577]],
#  [102607    F. Souza
#   Name: Name, dtype: object,
#   255803,
#   [0.10755245330586495, 0.3579159320280609]],
#  [100688    Léo Andrade
#   Name: Name, dtype: object,
#   259771,
#   [0.05892797757772885, 0.4491638265990908]],
#  [102273    T. Datković
#   Name: Name, dtype: object,
#   253147,
#   [0.0692492918507366, 0.4278222794643403]],
#  [100962    21 J. Aja
#   Name: Name, dtype: object,
#   235280,
#   [0.05190144018287119, 0.4579068009907438]],
#  [101211    21 G. Dulanto
#   Name: Name, dtype: object,
#   228733,
#   [0.04825529425679282, 0.4615209693100786]],
#  [101116    R. Edwards
#   Name: Name, dtype: object,
#   208752,
#   [0.03512353316807889, 0.4703596248409442]],
#  [101869    S. Nealis
#   Name: Name, dtype: object,
#   247459,
#   [0.07582430438126049, 0.3886934758574376]],
#  [100423    C. Whelan
#   Name: Name, dtype: object,
#   242007,
#   [0.09114686110520277, 0.357157250043749]],
#  [102564    R. Kikuchi
#   Name: Name, dtype: object,
#   254897,
#   [0.05265281802130037, 0.41845931580080437]],
#  [101748    D. Pines
#   Name: Name, dtype: object,
#   247031,
#   [0.017147399058480867, 0.4844708681179167]],
#  [102752    A. Xhemajli
#   Name: Name, dtype: object,
#   243981,
#   [0.06869515695348313, 0.3794130563972823]],
#  [102166    R. Inniss
#   Name: Name, dtype: object,
#   204499,
#   [0.03417456592052259, 0.4382010261152925]],
#  [102086    P. Adorno
#   Name: Name, dtype: object,
#   255047,
#   [0.04455936938732033, 0.4156693426524038]],
#  [102003    15 S. Faure
#   Name: Name, dtype: object,
#   190163,
#   [0.1485685507201076, 0.1985744397469904]],
#  [102343    A. Medioub
#   Name: Name, dtype: object,
#   259088,
#   [0.027585358766713794, 0.42627786766085946]],
#  [102124    T. Gunte
#   Name: Name, dtype: object,
#   262547,
#   [0.04005950104862349, 0.39712571238096833]],
#  [101571    21 R. Ziegele
#   Name: Name, dtype: object,
#   234861,
#   [0.02600297407544404, 0.4243285859381033]],
#  [102231    P. O'Connor
#   Name: Name, dtype: object,
#   228106,
#   [0.029454006033811014, 0.41269502944725084]],
#  [99462    B. Mugabi
#   Name: Name, dtype: object,
#   209285,
#   [0.01800920881724834, 0.4289936175304819]],
#  [102524    A. Karo
#   Name: Name, dtype: object,
#   230703,
#   [0.05403490663520494, 0.3321260040047068]],
#  [102453    S. Akaydin
#   Name: Name, dtype: object,
#   263021,
#   [0.04415116668331542, 0.3484706393602228]],
#  [101548    21 B. Kyere
#   Name: Name, dtype: object,
#   239149,
#   [0.012381640319884969, 0.36190397934116875]],
#  [101713    Kim Jae Woo
#   Name: Name, dtype: object,
#   242082,
#   [0.042279753126144445, 0.25471396126994317]],
#  [102326    16 J. M'voto
#   Name: Name, dtype: object,
#   184268,
#   [0.050283228104768186, 0.2350632144680806]]]

# %%
get_player_recs(df_22_std,"Liverpool",["CB"],Def_essential_ft,def_weights_per_club)
# Out:
# [[95250    M. Friedrich
#   Name: Name, dtype: object,
#   222493,
#   [0.9394417917096515, 0.6678204382536241]],
#  [96324    D. Rugani
#   Name: Name, dtype: object,
#   211320,
#   [0.908887140066463, 0.6867653728825636]],
#  [97472    B. Mechele
#   Name: Name, dtype: object,
#   212204,
#   [0.9184579634831856, 0.6656141596573523]],
#  [101195    T. Borevković
#   Name: Name, dtype: object,
#   244377,
#   [0.95401578814548, 0.5447607910248718]],
#  [102132    M. Bani
#   Name: Name, dtype: object,
#   224378,
#   [0.9578698655471181, 0.5370035085462195]],
#  [98475    A. Ismajli
#   Name: Name, dtype: object,
#   258782,
#   [0.9170624582736749, 0.6163993325352413]],
#  [99829    S. Posch
#   Name: Name, dtype: object,
#   223671,
#   [0.9367962665654749, 0.5695378034360898]],
#  [101201    M. Bauer
#   Name: Name, dtype: object,
#   245347,
#   [0.9779574106474591, 0.4862397458706619]],
#  [99660    Juande
#   Name: Name, dtype: object,
#   255158,
#   [0.9653591040576562, 0.5089784068944602]],
#  [100899    C. Zesiger
#   Name: Name, dtype: object,
#   236369,
#   [0.9808775661596282, 0.47576077000647726]],
#  [96302    I. Diop
#   Name: Name, dtype: object,
#   231633,
#   [0.8671499413712231, 0.6934471071700027]],
#  [97645    I. Kutepov
#   Name: Name, dtype: object,
#   210468,
#   [0.9121776083828635, 0.5933609034343529]],
#  [97275    P. Lienhart
#   Name: Name, dtype: object,
#   231366,
#   [0.8755250461231393, 0.6631970269780154]],
#  [99379    M. Blažič
#   Name: Name, dtype: object,
#   238945,
#   [0.9304836737946807, 0.5514399184315264]],
#  [98376    R. Knoche
#   Name: Name, dtype: object,
#   203030,
#   [0.8769772786052388, 0.6419464736665256]],
#  [102393    B. Šerbečić
#   Name: Name, dtype: object,
#   242260,
#   [1.0, 0.3918870781786743]],
#  [98775    N. Schlotterbeck
#   Name: Name, dtype: object,
#   247819,
#   [0.9105210038404165, 0.5682196522062753]],
#  [95866    S. Schonlau
#   Name: Name, dtype: object,
#   214948,
#   [0.8962262452125611, 0.5950305286165688]],
#  [94625    21 Bruno Viana
#   Name: Name, dtype: object,
#   234226,
#   [0.8496847945493473, 0.6831879526333624]],
#  [95711    Duirval Diniz
#   Name: Name, dtype: object,
#   230401,
#   [0.8849649078964448, 0.6133449618905576]],
#  [96391    W. Orban
#   Name: Name, dtype: object,
#   204638,
#   [0.8469612863931787, 0.681580556065144]],
#  [97548    Maracás
#   Name: Name, dtype: object,
#   251681,
#   [0.8713894215091079, 0.6327970493249572]],
#  [100202    G. Miura
#   Name: Name, dtype: object,
#   237429,
#   [0.9025362164293935, 0.5611437678816844]],
#  [94099    Robson Bambu
#   Name: Name, dtype: object,
#   256343,
#   [0.8918176138567919, 0.5803583418035216]],
#  [100824    J. Worrall
#   Name: Name, dtype: object,
#   230708,
#   [0.9072839600838557, 0.5452834957814051]],
#  [98932    E. Ntim
#   Name: Name, dtype: object,
#   231472,
#   [0.9560675185396972, 0.44661246732882776]],
#  [94795    K. Akpoguma
#   Name: Name, dtype: object,
#   211856,
#   [0.8576903021818824, 0.6335167273216352]],
#  [97583    D. Zagadou
#   Name: Name, dtype: object,
#   238476,
#   [0.836921425607808, 0.6741274962406939]],
#  [100264    C. Gogoua
#   Name: Name, dtype: object,
#   253144,
#   [0.9594046707435232, 0.43111445545394067]],
#  [100765    Jesiel
#   Name: Name, dtype: object,
#   230776,
#   [0.8977705722813734, 0.5512465865738561]],
#  [97070    V. Alvarado
#   Name: Name, dtype: object,
#   209758,
#   [0.9111721399969502, 0.5163623531623108]],
#  [100733    A. Tanghe
#   Name: Name, dtype: object,
#   255400,
#   [0.9028774762790898, 0.5318708730966171]],
#  [94710    David Costas
#   Name: Name, dtype: object,
#   219848,
#   [0.8660188948307174, 0.6030743117557227]],
#  [96629    A. Appindangoye
#   Name: Name, dtype: object,
#   218353,
#   [0.919334975293447, 0.49702081624898603]],
#  [101755    21 F. Vicari
#   Name: Name, dtype: object,
#   215433,
#   [0.8843318219085181, 0.5645133351985371]],
#  [101008    B. Wilmot
#   Name: Name, dtype: object,
#   238389,
#   [0.904089789903495, 0.5241639076522009]],
#  [101076    Rodrigo Ely
#   Name: Name, dtype: object,
#   202445,
#   [0.8643872523938423, 0.5996465256080871]],
#  [101062    21 César
#   Name: Name, dtype: object,
#   215283,
#   [0.914921821509304, 0.49072686140743516]],
#  [98717    G. Canto
#   Name: Name, dtype: object,
#   227526,
#   [0.9291816575717985, 0.4610058634852629]],
#  [101996    M. Platt
#   Name: Name, dtype: object,
#   234261,
#   [0.9820719108857435, 0.34930873742377005]],
#  [92368    T. Sainsbury
#   Name: Name, dtype: object,
#   199000,
#   [0.8496677267362069, 0.601677106803846]],
#  [100255    J. Clarke-Salter
#   Name: Name, dtype: object,
#   230774,
#   [0.9028265788272262, 0.49503237256699084]],
#  [98886    S. Holmén
#   Name: Name, dtype: object,
#   209063,
#   [0.8583677948224224, 0.5823680032478632]],
#  [97992    21 S. Kverkvelia
#   Name: Name, dtype: object,
#   205469,
#   [0.8870756417256965, 0.5251099725338089]],
#  [100850    T. Inukai
#   Name: Name, dtype: object,
#   237754,
#   [0.9020974768656937, 0.4929028092663833]],
#  [97737    A. Pieper
#   Name: Name, dtype: object,
#   246836,
#   [0.8346028836379564, 0.6234928102912393]],
#  [97874    Pablo Santos
#   Name: Name, dtype: object,
#   239872,
#   [0.8476703810660627, 0.597279521958848]],
#  [98957    A. Poungouras
#   Name: Name, dtype: object,
#   236458,
#   [0.9113789858178237, 0.47128223318837786]],
#  [96341    T. Hübers
#   Name: Name, dtype: object,
#   234727,
#   [0.8506779179724895, 0.5887913684821481]],
#  [99322    J. Bednarek
#   Name: Name, dtype: object,
#   220570,
#   [0.8225571291265882, 0.6398595517118465]],
#  [96279    Murilo
#   Name: Name, dtype: object,
#   240115,
#   [0.8157222346851999, 0.6472495484148639]],
#  [96340    N. Süle
#   Name: Name, dtype: object,
#   212190,
#   [0.7485901308487, 0.779544065366064]],
#  [99195    M. van der Hoorn
#   Name: Name, dtype: object,
#   207725,
#   [0.8919191141016476, 0.4952661070621148]],
#  [99131    R. Burke
#   Name: Name, dtype: object,
#   221456,
#   [0.8729257670400439, 0.5283235073102912]],
#  [97671    E. Martínez
#   Name: Name, dtype: object,
#   253278,
#   [0.862709844863397, 0.5459461563962987]],
#  [99872    K. Schlotterbeck
#   Name: Name, dtype: object,
#   244068,
#   [0.85645563949943, 0.5576579155445576]],
#  [101799    J. Moya
#   Name: Name, dtype: object,
#   232004,
#   [0.9111640314849605, 0.4482657127859654]],
#  [99714    H. Marcelin
#   Name: Name, dtype: object,
#   242603,
#   [0.8589119208318172, 0.5479398518657931]],
#  [97436    Bremer
#   Name: Name, dtype: object,
#   239580,
#   [0.79585719048631, 0.6696409990910428]],
#  [96573    O. Ndah
#   Name: Name, dtype: object,
#   264383,
#   [0.9307838342360798, 0.4033308192337416]],
#  [99847    Rodrigo Becão
#   Name: Name, dtype: object,
#   238621,
#   [0.8123972653326625, 0.6368893096338187]],
#  [97508    J. Vásquez
#   Name: Name, dtype: object,
#   244349,
#   [0.8406277789506966, 0.5785578770025651]],
#  [101352    S. Kennedy
#   Name: Name, dtype: object,
#   258361,
#   [0.9179026978103735, 0.4259083552754561]],
#  [99721    S. Bell
#   Name: Name, dtype: object,
#   198352,
#   [0.8572732954886498, 0.5449336206161554]],
#  [92695    J. Giménez
#   Name: Name, dtype: object,
#   216460,
#   [0.7263398770402426, 0.8001007574344782]],
#  [99567    G. Hall
#   Name: Name, dtype: object,
#   204761,
#   [0.8637279176555321, 0.5286019793632217]],
#  [94238    Y. Mina
#   Name: Name, dtype: object,
#   220523,
#   [0.7578067527827965, 0.7328139685411617]],
#  [101279    S. Nkansah
#   Name: Name, dtype: object,
#   229756,
#   [0.9282708737708971, 0.39604823661602867]],
#  [99191    P. Bauer
#   Name: Name, dtype: object,
#   204496,
#   [0.8317543569377049, 0.5826061202102896]],
#  [89644    G. Dzhikiya
#   Name: Name, dtype: object,
#   229773,
#   [0.7801521430550487, 0.6841863412757295]],
#  [92163    H. Magnússon
#   Name: Name, dtype: object,
#   208522,
#   [0.8047626805485251, 0.631143680900805]],
#  [97773    S. Magkeev
#   Name: Name, dtype: object,
#   252235,
#   [0.8277568992062991, 0.5857536084285736]],
#  [91701    C. Mbemba
#   Name: Name, dtype: object,
#   210897,
#   [0.7596660016656465, 0.7196615631671508]],
#  [95966    C. Nelson
#   Name: Name, dtype: object,
#   200840,
#   [0.872086934739349, 0.49736984340041]],
#  [101523    A. Grant
#   Name: Name, dtype: object,
#   209210,
#   [0.9096023981668456, 0.421113069707642]],
#  [100586    M. Ødegaard
#   Name: Name, dtype: object,
#   202259,
#   [0.914510828423177, 0.4108861421671354]],
#  [98552    A. Hack
#   Name: Name, dtype: object,
#   231111,
#   [0.8308031545519403, 0.5749656994819823]],
#  [91130    21 M. Musacchio
#   Name: Name, dtype: object,
#   186547,
#   [0.7515024796856804, 0.7311202760102246]],
#  [94535    S. Botman
#   Name: Name, dtype: object,
#   251809,
#   [0.7536556831448372, 0.7259945976685016]],
#  [101512    A. MacDonald
#   Name: Name, dtype: object,
#   205655,
#   [0.8818270815505457, 0.47167842595567844]],
#  [88092    M. Hinteregger
#   Name: Name, dtype: object,
#   201922,
#   [0.729635971426885, 0.7677059700391495]],
#  [89999    K. Zouma
#   Name: Name, dtype: object,
#   204311,
#   [0.736948354166211, 0.7463205665638464]],
#  [95648    A. Izzo
#   Name: Name, dtype: object,
#   216145,
#   [0.7459850920239361, 0.7274987434077174]],
#  [99727    G. Edmundson
#   Name: Name, dtype: object,
#   228888,
#   [0.8762332296290248, 0.47043114726845847]],
#  [101036    R. Capellini
#   Name: Name, dtype: object,
#   263550,
#   [0.9356855605778235, 0.3530079938595034]],
#  [100192    Vitao
#   Name: Name, dtype: object,
#   253400,
#   [0.8325795712806484, 0.5555948828544819]],
#  [100015    J. Rodon
#   Name: Name, dtype: object,
#   229266,
#   [0.8003276518416775, 0.6189939492678789]],
#  [93062    F. Tomori
#   Name: Name, dtype: object,
#   232756,
#   [0.7467648641767684, 0.7237686055983598]],
#  [95132    J. Torunarigha
#   Name: Name, dtype: object,
#   236947,
#   [0.783791716328931, 0.6494496563036125]],
#  [96175    F. Ceccherini
#   Name: Name, dtype: object,
#   210964,
#   [0.7960256876342111, 0.6243919271867909]],
#  [98882    T. Baumgartl
#   Name: Name, dtype: object,
#   223641,
#   [0.8074386315504913, 0.6009669046803042]],
#  [98589    S. Barreiro
#   Name: Name, dtype: object,
#   214129,
#   [0.8555709418058314, 0.5032816374936051]],
#  [99328    M. Cacutalua
#   Name: Name, dtype: object,
#   220878,
#   [0.9040206839466711, 0.406896329404032]],
#  [94349    R. Lauritsen
#   Name: Name, dtype: object,
#   225948,
#   [0.8001110534115399, 0.6082917117267054]],
#  [98121    P. Mainka
#   Name: Name, dtype: object,
#   216199,
#   [0.7894048042862907, 0.6256770723279392]],
#  [101552    N. Gyömbér
#   Name: Name, dtype: object,
#   220061,
#   [0.8373681101022057, 0.5300829520407637]],
#  [96932    Lourival Dinisco
#   Name: Name, dtype: object,
#   230415,
#   [0.852399247227398, 0.4954178635801513]],
#  [100417    E. Ersoy
#   Name: Name, dtype: object,
#   224489,
#   [0.8488255324445045, 0.5015964065339432]],
#  [99402    D. Maresic
#   Name: Name, dtype: object,
#   235673,
#   [0.8389010016223387, 0.5210738367252482]],
#  [99358    J. Cooper
#   Name: Name, dtype: object,
#   216481,
#   [0.8174811109010777, 0.5623406580083472]],
#  [100259    M. Hosseini
#   Name: Name, dtype: object,
#   243549,
#   [0.8652301764008667, 0.4670352272622402]],
#  [100537    A. Shabanov
#   Name: Name, dtype: object,
#   244381,
#   [0.8226931274775222, 0.5501342306328814]],
#  [96926    L. Cooper
#   Name: Name, dtype: object,
#   189456,
#   [0.7503631037808925, 0.6923090466579794]],
#  [96599    A. Çalık
#   Name: Name, dtype: object,
#   223046,
#   [0.8226309481847507, 0.5472859245095805]],
#  [98762    Pombaxinho
#   Name: Name, dtype: object,
#   230383,
#   [0.8581529835406475, 0.4766272734071295]],
#  [92711    S. Gigot
#   Name: Name, dtype: object,
#   219581,
#   [0.7344464398303613, 0.7190209506240136]],
#  [101883    F. Torres
#   Name: Name, dtype: object,
#   254959,
#   [0.9273500256055711, 0.33595520371105947]],
#  [89840    J. Koundé
#   Name: Name, dtype: object,
#   241486,
#   [0.6689603105415406, 0.844965445929952]],
#  [97550    M. Pearson
#   Name: Name, dtype: object,
#   208014,
#   [0.8273614125156841, 0.5287657908119958]],
#  [98585    S. Svarnas
#   Name: Name, dtype: object,
#   245540,
#   [0.8226866101826363, 0.5372470055257815]],
#  [102227    B. Tomiak
#   Name: Name, dtype: object,
#   262119,
#   [0.9364924967485718, 0.30626753816898905]],
#  [100593    R. Ivanov
#   Name: Name, dtype: object,
#   258599,
#   [0.8552127811504895, 0.4636501237503498]],
#  [90881    S. de Vrij
#   Name: Name, dtype: object,
#   198176,
#   [0.6604771785555825, 0.8454022688036776]],
#  [100688    Léo Andrade
#   Name: Name, dtype: object,
#   259771,
#   [0.8847246014250416, 0.3997860436248826]],
#  [97128    João Basso
#   Name: Name, dtype: object,
#   236255,
#   [0.7990536937213212, 0.5657851520496298]],
#  [101216    N. Knothe
#   Name: Name, dtype: object,
#   239401,
#   [0.9056383255367472, 0.3534583728983384]],
#  [102729    21 D. Arboleda
#   Name: Name, dtype: object,
#   227740,
#   [0.9083685347957369, 0.34762984907850264]],
#  [98784    R. Le Normand
#   Name: Name, dtype: object,
#   233486,
#   [0.725405645336847, 0.7082025926846666]],
#  [91623    M. Keane
#   Name: Name, dtype: object,
#   207599,
#   [0.69114461173861, 0.7703765704998234]],
#  [95729    Édundo Oliveira
#   Name: Name, dtype: object,
#   230389,
#   [0.7838942604697764, 0.5854496445628308]],
#  [102315    J. Olowu
#   Name: Name, dtype: object,
#   241864,
#   [0.9377628808312393, 0.28145873706778274]],
#  [101738    H. Carter
#   Name: Name, dtype: object,
#   242751,
#   [0.8853692955635711, 0.3846548873032164]],
#  [101747    S. Çiftpınar
#   Name: Name, dtype: object,
#   239050,
#   [0.8733007679067455, 0.40767719552526827]],
#  [100080    K. Dermaku
#   Name: Name, dtype: object,
#   230143,
#   [0.8488062689264769, 0.45556153564826773]],
#  [102247    A. Sylla
#   Name: Name, dtype: object,
#   256743,
#   [0.9497693396643397, 0.2558211116044308]],
#  [101336    J. Turnbull
#   Name: Name, dtype: object,
#   206170,
#   [0.8674930614908701, 0.4173351862724027]],
#  [101060    M. Burda
#   Name: Name, dtype: object,
#   244383,
#   [0.8040895157182589, 0.5404205123903015]],
#  [100569    20 A. Murillo
#   Name: Name, dtype: object,
#   225574,
#   [0.8543911829178676, 0.4343175517919659]],
#  [95699    J. Brooks
#   Name: Name, dtype: object,
#   204082,
#   [0.7089588242029689, 0.7204492301018572]],
#  [101820    M. Kreuzriegler
#   Name: Name, dtype: object,
#   256967,
#   [0.874070502591452, 0.39105343095856937]],
#  [101596    21 Álex Zalaya
#   Name: Name, dtype: object,
#   235224,
#   [0.8684496881108471, 0.4012003346759796]],
#  [102311    P. Kalambayi
#   Name: Name, dtype: object,
#   233383,
#   [0.8909170920175946, 0.3563947825021726]],
#  [102424    J. Aguayo
#   Name: Name, dtype: object,
#   258053,
#   [0.9465264706964059, 0.24631239811819094]],
#  [102520    C. Maghoma
#   Name: Name, dtype: object,
#   231144,
#   [0.9086636196442941, 0.3208180340793004]],
#  [99654    M. Camara
#   Name: Name, dtype: object,
#   244401,
#   [0.8018628212450655, 0.5314506815182537]],
#  [100869    N. Ferraresi
#   Name: Name, dtype: object,
#   246388,
#   [0.7932953699908687, 0.5472412043840555]],
#  [100097    B. Gibson
#   Name: Name, dtype: object,
#   200408,
#   [0.769346380225261, 0.5940295185515388]],
#  [98786    M. Caldara
#   Name: Name, dtype: object,
#   220477,
#   [0.7309925712234805, 0.6696407144444882]],
#  [100708    N. Pérez
#   Name: Name, dtype: object,
#   244206,
#   [0.7317345928689859, 0.6676153664845961]],
#  [101231    20 M. Camporese
#   Name: Name, dtype: object,
#   201914,
#   [0.8120359612760562, 0.5072997010594673]],
#  [101927    F. Rawson
#   Name: Name, dtype: object,
#   223852,
#   [0.8831466042328528, 0.36659304165696727]],
#  [100596    B. Ampuero
#   Name: Name, dtype: object,
#   225396,
#   [0.8253532135817317, 0.47972260336900896]],
#  [102402    T. Dallison
#   Name: Name, dtype: object,
#   213653,
#   [0.8880744225809795, 0.35462134720263394]],
#  [101572    V. Huerta
#   Name: Name, dtype: object,
#   214404,
#   [0.8488564367021395, 0.4305563143779237]],
#  [88541    Juiano Mestres
#   Name: Name, dtype: object,
#   230225,
#   [0.6877218851518461, 0.7465866582539348]],
#  [101976    V. Ozornwafor
#   Name: Name, dtype: object,
#   251258,
#   [0.8972470283730098, 0.3329681553946739]],
#  [101752    M. Al Fatil
#   Name: Name, dtype: object,
#   210134,
#   [0.8243395050282296, 0.4765102255077628]],
#  [89061    M. Ginter
#   Name: Name, dtype: object,
#   207862,
#   [0.6470718944884242, 0.8249479194927332]],
#  [98040    J. Tah
#   Name: Name, dtype: object,
#   213331,
#   [0.7106637766601989, 0.6955089384947183]],
#  [101739    A. Deneumostier
#   Name: Name, dtype: object,
#   254176,
#   [0.855786947746353, 0.40907205621857445]],
#  [99716    H. Moukoudi
#   Name: Name, dtype: object,
#   228732,
#   [0.7343736046045682, 0.6476008412653709]],
#  [95962    Alson Botelho
#   Name: Name, dtype: object,
#   230253,
#   [0.7444735226551676, 0.6257703563182762]],
#  [95206    K. Itakura
#   Name: Name, dtype: object,
#   233152,
#   [0.7341181412686677, 0.6453599280086109]],
#  [102203    J. Silva
#   Name: Name, dtype: object,
#   222643,
#   [0.8669809133969468, 0.38274232292014765]],
#  [93661    Lucas Veríssimo
#   Name: Name, dtype: object,
#   235688,
#   [0.6877871353696573, 0.7362657728257403]],
#  [101363    Dinis Almeida
#   Name: Name, dtype: object,
#   234665,
#   [0.7899327713662766, 0.5314568852555798]],
#  [90666    A. Vallci
#   Name: Name, dtype: object,
#   243661,
#   [0.7710772152434566, 0.5679601598562175]],
#  [100651    P. Kapp
#   Name: Name, dtype: object,
#   239820,
#   [0.8640124396809811, 0.3824416938811852]],
#  [102493    21 G. Zajkov
#   Name: Name, dtype: object,
#   223568,
#   [0.8291756827033475, 0.4507108785284577]],
#  [101412    21 Jeong Seung Hyun
#   Name: Name, dtype: object,
#   227790,
#   [0.8340671647677367, 0.4405764796251241]],
#  [102454    C. Masterson
#   Name: Name, dtype: object,
#   232102,
#   [0.9124187044245559, 0.2859561126800925]],
#  [100933    T. Knipping
#   Name: Name, dtype: object,
#   211723,
#   [0.8099203743740099, 0.48706383313818774]],
#  [102017    S. Foss
#   Name: Name, dtype: object,
#   242975,
#   [0.8764237984573678, 0.3548007694002751]],
#  [101720    J. Boller
#   Name: Name, dtype: object,
#   247409,
#   [0.8955223902989073, 0.3161090543984133]],
#  [99299    G. Maripán
#   Name: Name, dtype: object,
#   219145,
#   [0.707001466187257, 0.6875288870629771]],
#  [100710    P. Downing
#   Name: Name, dtype: object,
#   192496,
#   [0.8459925160249732, 0.40907900007392917]],
#  [101540    M. Jenz
#   Name: Name, dtype: object,
#   241494,
#   [0.8526853167738065, 0.3942732428812648]],
#  [98424    D. O'Shea
#   Name: Name, dtype: object,
#   235405,
#   [0.7612779443371147, 0.5738745047210702]],
#  [99175    A. Callens
#   Name: Name, dtype: object,
#   211522,
#   [0.7300815895454372, 0.6338933240484357]],
#  [100916    D. Gugganig
#   Name: Name, dtype: object,
#   250780,
#   [0.8061345149045736, 0.4836524043124336]],
#  [95438    R. Araujo
#   Name: Name, dtype: object,
#   253163,
#   [0.6822588494972541, 0.7273868303849722]],
#  [101041    J. Gundersen
#   Name: Name, dtype: object,
#   228238,
#   [0.8546538918646792, 0.386225932286885]],
#  [101649    P. Lemonnier
#   Name: Name, dtype: object,
#   223880,
#   [0.8335891557853604, 0.42692751376915433]],
#  [102320    D. Bettella
#   Name: Name, dtype: object,
#   248171,
#   [0.8655829947823203, 0.36367275197862264]],
#  [99759    S. van Beek
#   Name: Name, dtype: object,
#   213000,
#   [0.7500168598972434, 0.5882149573635769]],
#  [95324    J. Vestergaard
#   Name: Name, dtype: object,
#   202849,
#   [0.6864098435432614, 0.7130254459753907]],
#  [102099    E. Capradossi
#   Name: Name, dtype: object,
#   215376,
#   [0.7833728504018717, 0.5210982445072951]],
#  [101861    Z. Šarlija
#   Name: Name, dtype: object,
#   251343,
#   [0.8678506043613473, 0.35414241671504276]],
#  [100278    J. Müller
#   Name: Name, dtype: object,
#   234381,
#   [0.8023004368080555, 0.48218059549784154]],
#  [98780    M. Lovato
#   Name: Name, dtype: object,
#   258946,
#   [0.750704117831688, 0.5820536088933344]],
#  [89888    J. Gouweleeuw
#   Name: Name, dtype: object,
#   202201,
#   [0.6786770485359496, 0.7232945395423054]],
#  [96711    I. Diveev
#   Name: Name, dtype: object,
#   245703,
#   [0.7063465714636841, 0.6677423972993434]],
#  [99005    G. Corujo
#   Name: Name, dtype: object,
#   253289,
#   [0.7647109440370341, 0.5497941901860952]],
#  [98451    M. Kumbulla
#   Name: Name, dtype: object,
#   245426,
#   [0.7257316955440112, 0.6259554273394261]],
#  [100542    M. Erlić
#   Name: Name, dtype: object,
#   244456,
#   [0.7482355327643029, 0.581144974669271]],
#  [94661    A. Christensen
#   Name: Name, dtype: object,
#   213661,
#   [0.6335493133586004, 0.8072234535444746]],
#  [98778    J. Fitzwater
#   Name: Name, dtype: object,
#   231139,
#   [0.798113063102045, 0.48201620600580614]],
#  [97222    Domingos Duarte
#   Name: Name, dtype: object,
#   234835,
#   [0.6619324277337214, 0.7501447200620424]],
#  [101731    M. Franke
#   Name: Name, dtype: object,
#   203161,
#   [0.8045473183082674, 0.46766736889591837]],
#  [95471    B. Valdez
#   Name: Name, dtype: object,
#   228729,
#   [0.7178852511135131, 0.63446744686757]],
#  [101384    J. Tucker
#   Name: Name, dtype: object,
#   241507,
#   [0.8107504243847174, 0.4496340509951691]],
#  [101434    C. Zimmermann
#   Name: Name, dtype: object,
#   239322,
#   [0.7740123763265128, 0.5216095796854273]],
#  [100320    N. Paz
#   Name: Name, dtype: object,
#   219451,
#   [0.7930615811126737, 0.4830550950381213]],
#  [96069    F. Uduokhai
#   Name: Name, dtype: object,
#   232144,
#   [0.680805953346195, 0.7026510539381479]],
#  [102048    C. Vidal
#   Name: Name, dtype: object,
#   244476,
#   [0.8490766026539103, 0.3694149603127379]],
#  [99512    I. Höhn
#   Name: Name, dtype: object,
#   205588,
#   [0.7551346011185166, 0.5518246637942233]],
#  [95066    B. Behrendt
#   Name: Name, dtype: object,
#   207954,
#   [0.7481381912198545, 0.5620442876638332]],
#  [96915    K. Günter
#   Name: Name, dtype: object,
#   204451,
#   [0.6794349821576006, 0.6970606532736852]],
#  [102573    J. García
#   Name: Name, dtype: object,
#   229985,
#   [0.8738524645068869, 0.31337099420251185]],
#  [102038    A. Ławniczak
#   Name: Name, dtype: object,
#   257649,
#   [0.8565628026287085, 0.3473832759830239]],
#  [100951    J. Storey
#   Name: Name, dtype: object,
#   235464,
#   [0.7832634715626734, 0.4918366157059203]],
#  [98656    D. Khocholava
#   Name: Name, dtype: object,
#   239904,
#   [0.7479496451700485, 0.5613320221397214]],
#  [98634    Jorge Cuenca
#   Name: Name, dtype: object,
#   237522,
#   [0.7136764662140144, 0.6285538709766274]],
#  [99846    21 A. Kızıldağ
#   Name: Name, dtype: object,
#   252753,
#   [0.8336115687100473, 0.3909705199357998]],
#  [101713    Kim Jae Woo
#   Name: Name, dtype: object,
#   242082,
#   [0.9467012831132327, 0.16665646118023464]],
#  [102542    N. Kastenhofer
#   Name: Name, dtype: object,
#   243042,
#   [0.8900945486528069, 0.277356703833853]],
#  [102889    N. Datković
#   Name: Name, dtype: object,
#   221985,
#   [0.8244239567987935, 0.4065438471757224]],
#  [98014    C. Richards
#   Name: Name, dtype: object,
#   250954,
#   [0.7322581715314206, 0.5883521632718633]],
#  [99369    Unai Núñez
#   Name: Name, dtype: object,
#   240900,
#   [0.6432504720883876, 0.763454027790991]],
#  [101658    R. Thelander
#   Name: Name, dtype: object,
#   209711,
#   [0.7839031843689366, 0.4840929285185342]],
#  [101456    21 H. Ouro-Sama
#   Name: Name, dtype: object,
#   244528,
#   [0.8158333761766094, 0.4203754098198016]],
#  [101489    G. Ferrari
#   Name: Name, dtype: object,
#   224808,
#   [0.7176310149338806, 0.612484052881006]],
#  [102714    M. Suver
#   Name: Name, dtype: object,
#   261437,
#   [0.9436186866624603, 0.16397121656482794]],
#  [102812    18 J. Vergara
#   Name: Name, dtype: object,
#   219184,
#   [0.8083063458400314, 0.4300973393938822]],
#  [99441    N. Maksimović
#   Name: Name, dtype: object,
#   215466,
#   [0.6981070913971545, 0.6467812421997842]],
#  [93122    S. Ingason
#   Name: Name, dtype: object,
#   221422,
#   [0.6894538229908211, 0.6635992315150667]],
#  [101554    Kim Dae Jung
#   Name: Name, dtype: object,
#   222051,
#   [0.8419174251114416, 0.36204285895061816]],
#  [103257    F. Delli Carri
#   Name: Name, dtype: object,
#   237612,
#   [0.8682232107823373, 0.30873423927123905]],
#  [94478    S. Taniguchi
#   Name: Name, dtype: object,
#   233225,
#   [0.702133801870819, 0.6334390601990362]],
#  [90375    Rúben Vezo
#   Name: Name, dtype: object,
#   215399,
#   [0.6549768833400489, 0.7254407288694443]],
#  [97096    Kim Won Sik
#   Name: Name, dtype: object,
#   206520,
#   [0.7983947532128544, 0.4423861837430732]],
#  [96795    21 M. Leverbe
#   Name: Name, dtype: object,
#   240543,
#   [0.7470056114243062, 0.5428002915184296]],
#  [102307    20 H. Weigelt
#   Name: Name, dtype: object,
#   238131,
#   [0.8381187401400692, 0.36269441553035137]],
#  [100054    A. Nukan
#   Name: Name, dtype: object,
#   200065,
#   [0.7381078317625623, 0.5580602054127688]],
#  [101272    Kike Hermoso
#   Name: Name, dtype: object,
#   240997,
#   [0.7932359397762622, 0.44608298566583426]],
#  [101637    Jorge Silva
#   Name: Name, dtype: object,
#   256404,
#   [0.8043247353937215, 0.4233043807139484]],
#  [102461    R. Diarra
#   Name: Name, dtype: object,
#   229450,
#   [0.8646139866235801, 0.30424405264619425]],
#  [99507    F. Russo
#   Name: Name, dtype: object,
#   245156,
#   [0.7265955999359546, 0.5755143136989247]],
#  [102370    R. Cundy
#   Name: Name, dtype: object,
#   229182,
#   [0.85465877128539, 0.32197279078637]],
#  [101748    D. Pines
#   Name: Name, dtype: object,
#   247031,
#   [0.7924884879706322, 0.4398201188112972]],
#  [97714    B. Kouyaté
#   Name: Name, dtype: object,
#   247019,
#   [0.7182019101355022, 0.5828308477558989]],
#  [96369    21 M. Zaldivia
#   Name: Name, dtype: object,
#   215053,
#   [0.701602094202881, 0.6129482195901748]],
#  [95256    Gabriel
#   Name: Name, dtype: object,
#   232580,
#   [0.6233849258587693, 0.7639885979228046]],
#  [102699    21 A. Çelebi
#   Name: Name, dtype: object,
#   245369,
#   [0.9005284438126687, 0.21667691443807335]],
#  [94397    D. Ćaleta-Car
#   Name: Name, dtype: object,
#   225263,
#   [0.6138223594490044, 0.7818918758814188]],
#  [100166    E. Mihaj
#   Name: Name, dtype: object,
#   251446,
#   [0.7837752116452168, 0.4464597670122154]],
#  [102486    M. Oikonomou
#   Name: Name, dtype: object,
#   216523,
#   [0.7638231126082817, 0.483992343006168]],
#  [94274    S. Luperto
#   Name: Name, dtype: object,
#   220534,
#   [0.69600702334547, 0.6166739702186516]],
#  [100266    W. Troost-Ekong
#   Name: Name, dtype: object,
#   213414,
#   [0.7360061457107356, 0.5363574587973857]],
#  [98558    G. Magnani
#   Name: Name, dtype: object,
#   242392,
#   [0.7035911059410674, 0.5989930578695831]],
#  [97889    I. Cristea
#   Name: Name, dtype: object,
#   248021,
#   [0.7330238663457121, 0.5399093108743828]],
#  [100557    G. Taft
#   Name: Name, dtype: object,
#   203145,
#   [0.8076196434050699, 0.3908829120975137]],
#  [101716    João Queirós
#   Name: Name, dtype: object,
#   239949,
#   [0.7964862149097479, 0.41258513622821447]],
#  [102485    T. Cissokho
#   Name: Name, dtype: object,
#   246807,
#   [0.8728355904881493, 0.25605884938373524]],
#  [98069    G. Aguirre
#   Name: Name, dtype: object,
#   232316,
#   [0.7746644119619894, 0.4484023949073982]],
#  [101183    M. Awoudja
#   Name: Name, dtype: object,
#   245100,
#   [0.7993252212683528, 0.3993380436884038]],
#  [97613    V. Ghiță
#   Name: Name, dtype: object,
#   248105,
#   [0.7725160964596323, 0.4510640468620724]],
#  [102100    D. Csóka
#   Name: Name, dtype: object,
#   242731,
#   [0.8210513779780239, 0.35379331489652777]],
#  [101527    D. Solomons
#   Name: Name, dtype: object,
#   251807,
#   [0.8115787387727775, 0.37151265742947215]],
#  [98522    P. Jaeckel
#   Name: Name, dtype: object,
#   242958,
#   [0.7185708616544518, 0.5539267946523508]],
#  [101873    Y. Cabral
#   Name: Name, dtype: object,
#   221990,
#   [0.7569869296119575, 0.47663829707257643]],
#  [98530    16 Felipe Santana
#   Name: Name, dtype: object,
#   176957,
#   [0.7667665914848157, 0.45521272799205786]],
#  [100115    A. Borkovic
#   Name: Name, dtype: object,
#   235995,
#   [0.7691245707935418, 0.45026952654070773]],
#  [98521    21 G. Conti
#   Name: Name, dtype: object,
#   221219,
#   [0.6968626769053419, 0.5926501102366041]],
#  [101382    Bueno
#   Name: Name, dtype: object,
#   232872,
#   [0.7888938267230813, 0.40679353295981385]],
#  [99870    V. Haroyan
#   Name: Name, dtype: object,
#   206423,
#   [0.6943542894372765, 0.5923253516170385]],
#  [97389    Fabiano Sonta
#   Name: Name, dtype: object,
#   230218,
#   [0.6903852903799997, 0.5999504596953832]],
#  [98763    D. Fry
#   Name: Name, dtype: object,
#   229682,
#   [0.69528418418019, 0.5899565557747433]],
#  [99273    H. Darling
#   Name: Name, dtype: object,
#   236551,
#   [0.7661500658026746, 0.44984463648463696]],
#  [100777    Philipe Sampaio
#   Name: Name, dtype: object,
#   224376,
#   [0.7239538910220756, 0.5308697538683471]],
#  [102360    K. Jameson
#   Name: Name, dtype: object,
#   238073,
#   [0.866613282986348, 0.2482392148262972]],
#  [95297    R. Holding
#   Name: Name, dtype: object,
#   228295,
#   [0.6114672508866471, 0.7496254646719794]],
#  [95733    D. Heintz
#   Name: Name, dtype: object,
#   206198,
#   [0.6491041116920703, 0.674821591328879]],
#  [100753    H. Souttar
#   Name: Name, dtype: object,
#   229901,
#   [0.7004422419693951, 0.5731365453385608]],
#  [98234    Juninho
#   Name: Name, dtype: object,
#   231104,
#   [0.7036097364372088, 0.566842374131201]],
#  [100211    N. Isimat-Mirin
#   Name: Name, dtype: object,
#   198868,
#   [0.7054365817612805, 0.5625715020911749]],
#  [99489    I. Conté
#   Name: Name, dtype: object,
#   236279,
#   [0.7769516046817143, 0.4195239689465062]],
#  [94340    M. Lacroix
#   Name: Name, dtype: object,
#   244067,
#   [0.6091520462028698, 0.7477702706788745]],
#  [99662    20 A. Öztürk
#   Name: Name, dtype: object,
#   229362,
#   [0.7588161590905927, 0.4497197610464136]],
#  [101016    H. McGahey
#   Name: Name, dtype: object,
#   220038,
#   [0.7965972871958233, 0.3741352469668717]],
#  [98271    21 F. Balbuena
#   Name: Name, dtype: object,
#   228229,
#   [0.6577032822986106, 0.64806684977423]],
#  [95686    Luan Peres
#   Name: Name, dtype: object,
#   234791,
#   [0.6542086513903724, 0.6540526291115513]],
#  [98220    A. Hoffmann
#   Name: Name, dtype: object,
#   199779,
#   [0.673450522361294, 0.615098794216953]],
#  [95533    P. Jones
#   Name: Name, dtype: object,
#   194957,
#   [0.647016061299044, 0.6660474055249317]],
#  [96272    21 F. Meza
#   Name: Name, dtype: object,
#   214136,
#   [0.6349160067025443, 0.6895652288202386]],
#  [93146    P. Dawidowicz
#   Name: Name, dtype: object,
#   213404,
#   [0.6444327342099422, 0.6701142447855816]],
#  [101647    21 M. Guanini
#   Name: Name, dtype: object,
#   228893,
#   [0.7720180680345924, 0.416419812968922]],
#  [97581    B. Šutalo
#   Name: Name, dtype: object,
#   255891,
#   [0.6744651046151469, 0.60703294854759]],
#  [96703    Eric Curbelo
#   Name: Name, dtype: object,
#   237442,
#   [0.6755511582056318, 0.6039493810012361]],
#  [95014    J. El Yamiq
#   Name: Name, dtype: object,
#   241775,
#   [0.672563926779964, 0.6096206757190538]],
#  [101850    P. Bochniewicz
#   Name: Name, dtype: object,
#   220230,
#   [0.7039568604038214, 0.5449826171763655]],
#  [96186    S. Beukema
#   Name: Name, dtype: object,
#   262394,
#   [0.6945250208125222, 0.5635773804086258]],
#  [101218    N. Ueda
#   Name: Name, dtype: object,
#   232870,
#   [0.7091691417710136, 0.5342743048981783]],
#  [95744    N. Araújo
#   Name: Name, dtype: object,
#   192041,
#   [0.6299312327961918, 0.6900112151123188]],
#  [99886    T. Hadebe
#   Name: Name, dtype: object,
#   239438,
#   [0.7874470388487479, 0.37826893761905767]],
#  [90223    16 Rodrigo Caio
#   Name: Name, dtype: object,
#   203324,
#   [0.6244477546928247, 0.6997201185644206]],
#  [96689    Leo Coelho
#   Name: Name, dtype: object,
#   253305,
#   [0.6981726523788312, 0.5540995327518647]],
#  [102255    J. Jones
#   Name: Name, dtype: object,
#   257865,
#   [0.8231931931696782, 0.3051364321173774]],
#  [95919    20 A. Abdennour
#   Name: Name, dtype: object,
#   198076,
#   [0.7066494869771471, 0.5342654818950446]],
#  [101451    C. Klarer
#   Name: Name, dtype: object,
#   242386,
#   [0.7316215552342976, 0.48457908213287665]],
#  [100061    L. Osaki
#   Name: Name, dtype: object,
#   245098,
#   [0.7250380688219354, 0.49657572812299505]],
#  [98891    D. Guidi
#   Name: Name, dtype: object,
#   244460,
#   [0.7440915168770352, 0.45810371536930766]],
#  [99468    O. Bjørtuft
#   Name: Name, dtype: object,
#   242623,
#   [0.7350533731009238, 0.475460403106976]],
#  [97590    21 Jemerson
#   Name: Name, dtype: object,
#   215792,
#   [0.6583843067589191, 0.6253654440517735]],
#  [88397    Éder Militão
#   Name: Name, dtype: object,
#   240130,
#   [0.5524719986199509, 0.8332986387094051]],
#  [101710    R. Tafazolli
#   Name: Name, dtype: object,
#   200697,
#   [0.7524494557742484, 0.438517423161258]],
#  [90045    J. Denayer
#   Name: Name, dtype: object,
#   220182,
#   [0.5635150477190886, 0.8094785362705206]],
#  [101962    L. Jones
#   Name: Name, dtype: object,
#   215301,
#   [0.7759426361538717, 0.38947638268416374]],
#  [100992    J. van der Werff
#   Name: Name, dtype: object,
#   242562,
#   [0.7627918366738314, 0.4146559240776593]],
#  [101692    K. Dimitrov
#   Name: Name, dtype: object,
#   252738,
#   [0.759796299876762, 0.4200603178568616]],
#  [99582    Artur Jorge
#   Name: Name, dtype: object,
#   236505,
#   [0.6830429207404413, 0.5705712839916376]],
#  [99584    S. Coulibaly
#   Name: Name, dtype: object,
#   231872,
#   [0.7296179063023841, 0.4778714417473075]],
#  [102204    B. Cooper
#   Name: Name, dtype: object,
#   237316,
#   [0.8189871177513861, 0.3012305085258216]],
#  [101184    J. Daland
#   Name: Name, dtype: object,
#   256459,
#   [0.7390371338844861, 0.45761788643895307]],
#  [100525    L. Perrin
#   Name: Name, dtype: object,
#   243449,
#   [0.69920710488364, 0.5353280782930794]],
#  [99250    A. Disasi
#   Name: Name, dtype: object,
#   229942,
#   [0.6190344467960018, 0.6930560983600474]],
#  [96345    D. Rosero
#   Name: Name, dtype: object,
#   215067,
#   [0.7128153599330816, 0.5066360796162684]],
#  [100407    G. Valsvik
#   Name: Name, dtype: object,
#   203363,
#   [0.7465236432190623, 0.43664475882478687]],
#  [99051    M. Robinson
#   Name: Name, dtype: object,
#   237255,
#   [0.6947467767311253, 0.5357788955569505]],
#  [102023    F. Horsfall
#   Name: Name, dtype: object,
#   230677,
#   [0.7775282078474602, 0.3724299875692772]],
#  [98798    21 J. Rhyner
#   Name: Name, dtype: object,
#   229727,
#   [0.732814155033056, 0.46037067771524415]],
#  [97302    20 Tiago Ferreira
#   Name: Name, dtype: object,
#   205845,
#   [0.7106728662982561, 0.5033401580387137]],
#  [101128    L. Rosić
#   Name: Name, dtype: object,
#   235002,
#   [0.6866901262497512, 0.5505542401265083]],
#  [102090    20 G. Andonian
#   Name: Name, dtype: object,
#   211690,
#   [0.772147735322782, 0.3813795813696113]],
#  [89839    E. Tapsoba
#   Name: Name, dtype: object,
#   247263,
#   [0.5400599072795297, 0.8389549322750532]],
#  [95929    G. Shoji
#   Name: Name, dtype: object,
#   232869,
#   [0.6497896357636145, 0.6221628780865391]],
#  [100815    Mario Hernández
#   Name: Name, dtype: object,
#   241479,
#   [0.7624881705013246, 0.3994517574960328]],
#  [99827    A. Mawson
#   Name: Name, dtype: object,
#   208534,
#   [0.6605727499534835, 0.5977943692697683]],
#  [92015    N. Elvedi
#   Name: Name, dtype: object,
#   221491,
#   [0.5860782908871354, 0.7447545077120448]],
#  [100980    B. Cabango
#   Name: Name, dtype: object,
#   248687,
#   [0.6897580847013334, 0.5395297909496605]],
#  [100303    L. Abubakar
#   Name: Name, dtype: object,
#   237214,
#   [0.6997237908725751, 0.5197849038461292]],
#  [94262    M. Simakan
#   Name: Name, dtype: object,
#   243854,
#   [0.6159196280364609, 0.6830499333628387]],
#  [92514    A. Bastoni
#   Name: Name, dtype: object,
#   237383,
#   [0.5564206995559813, 0.8000799306293234]],
#  [95609    19 Maurício
#   Name: Name, dtype: object,
#   187324,
#   [0.665921782189636, 0.5840064309942102]],
#  [101356    J. DeZart
#   Name: Name, dtype: object,
#   256320,
#   [0.7680377536632104, 0.3817959020719574]],
#  [100555    C. Carter-Vickers
#   Name: Name, dtype: object,
#   228174,
#   [0.6773241055106893, 0.5596306640510557]],
#  [97013    B. Engels
#   Name: Name, dtype: object,
#   210828,
#   [0.6150323851084567, 0.6822718414118832]],
#  [88648    N. Aké
#   Name: Name, dtype: object,
#   208920,
#   [0.5562291599901793, 0.7965579275771113]],
#  [100385    P. Wiśniewski
#   Name: Name, dtype: object,
#   243185,
#   [0.7231448075086173, 0.46625078887482596]],
#  [102282    T. Grivosti
#   Name: Name, dtype: object,
#   251178,
#   [0.7776760980604553, 0.35669086726891336]],
#  [94922    21 Bastos
#   Name: Name, dtype: object,
#   216655,
#   [0.5951890272588065, 0.7148369234310008]],
#  [97067    H. Türkmen
#   Name: Name, dtype: object,
#   243244,
#   [0.7071029578640041, 0.4939480051179328]],
#  [100397    T. Holmes
#   Name: Name, dtype: object,
#   241411,
#   [0.6986960405264977, 0.5099692805188082]],
#  [88988    A. Mandi
#   Name: Name, dtype: object,
#   201143,
#   [0.5264925756843299, 0.8495056213570515]],
#  [91387    J. Teze
#   Name: Name, dtype: object,
#   245211,
#   [0.6202619255669466, 0.664341399020305]],
#  [90407    M. Sarr
#   Name: Name, dtype: object,
#   235454,
#   [0.6092118651713778, 0.685972866154961]],
#  [96683    Catena
#   Name: Name, dtype: object,
#   243976,
#   [0.6302642445922605, 0.6423445827798161]],
#  [102130    X. Arreaga
#   Name: Name, dtype: object,
#   246406,
#   [0.7149027233110277, 0.4732871048518363]],
#  [94793    D. Grétarsson
#   Name: Name, dtype: object,
#   226510,
#   [0.7086665851407732, 0.48531806770808905]],
#  [97108    Paulo Oliveira
#   Name: Name, dtype: object,
#   210679,
#   [0.6128930108567973, 0.6729335431389978]],
#  [98452    21 D. Plechatý
#   Name: Name, dtype: object,
#   247345,
#   [0.6582495416035545, 0.5833427234403289]],
#  [101269    Jeong Tae Wook
#   Name: Name, dtype: object,
#   238576,
#   [0.7337921591053518, 0.4327801843782654]],
#  [90763    J. Tarkowski
#   Name: Name, dtype: object,
#   202695,
#   [0.5430719208362957, 0.8082641185915663]],
#  [99342    A. Pierre
#   Name: Name, dtype: object,
#   203809,
#   [0.7424458091537293, 0.414265175310109]],
#  [102273    T. Datković
#   Name: Name, dtype: object,
#   253147,
#   [0.7427392873784562, 0.4104931146452094]],
#  [92126    Antônio Chiamuloira
#   Name: Name, dtype: object,
#   230212,
#   [0.5746410025830021, 0.7420454414496057]],
#  [99426    C. Kobald
#   Name: Name, dtype: object,
#   244491,
#   [0.662757678361917, 0.5678062446912683]],
#  [98606    M. McKenzie
#   Name: Name, dtype: object,
#   242195,
#   [0.6384448577837547, 0.6150290837172754]],
#  [93090    W. Hoedt
#   Name: Name, dtype: object,
#   216774,
#   [0.5932894099398616, 0.7022099278982713]],
#  [89615    P. Schuurs
#   Name: Name, dtype: object,
#   241854,
#   [0.5861651567265314, 0.7148061317420481]],
#  [99427    G. Wüthrich
#   Name: Name, dtype: object,
#   220665,
#   [0.6782608949437035, 0.5322269233954169]],
#  [100631    S. Fortes
#   Name: Name, dtype: object,
#   219582,
#   [0.67560894105195, 0.53719773758906]],
#  [89593    E. Álvarez
#   Name: Name, dtype: object,
#   235844,
#   [0.5566415851570438, 0.7706931370432335]],
#  [102380    Víctor Chust
#   Name: Name, dtype: object,
#   259173,
#   [0.7429463416988912, 0.4030765146291085]],
#  [99300    L. Bessilé
#   Name: Name, dtype: object,
#   250976,
#   [0.7320015842892341, 0.4243934992931255]],
#  [101206    B. Benamar
#   Name: Name, dtype: object,
#   260295,
#   [0.7305264958110793, 0.4272030776542533]],
#  [99899    S. Kersten
#   Name: Name, dtype: object,
#   251754,
#   [0.6763345258546114, 0.5338714694441307]],
#  [98185    M. Veljković
#   Name: Name, dtype: object,
#   221354,
#   [0.6199199185185676, 0.6445260399765981]],
#  [95413    B. Djimsiti
#   Name: Name, dtype: object,
#   208165,
#   [0.5639198387504178, 0.752869459365147]],
#  [101609    J. Baffo
#   Name: Name, dtype: object,
#   192070,
#   [0.7756939893329067, 0.3341856652514398]],
#  [102846    C. Ezekwem
#   Name: Name, dtype: object,
#   262899,
#   [0.7820537896037646, 0.3215518129136086]],
#  [102622    G. Corbo
#   Name: Name, dtype: object,
#   243513,
#   [0.7719712812931382, 0.34076154207405746]],
#  [99799    S. Salcedo
#   Name: Name, dtype: object,
#   228730,
#   [0.7164183131559051, 0.4495328659975448]],
#  [101997    P. Farquharson
#   Name: Name, dtype: object,
#   260818,
#   [0.7840626223590035, 0.3146692328009294]],
#  [102339    21 T. Cordner
#   Name: Name, dtype: object,
#   239673,
#   [0.802202851439373, 0.27881695543404744]],
#  [98888    K. Mavropanos
#   Name: Name, dtype: object,
#   242000,
#   [0.6512685358882376, 0.5765234397328796]],
#  [102004    W. Aimson
#   Name: Name, dtype: object,
#   218576,
#   [0.7824886063408555, 0.3168779122255704]],
#  [99865    F. Romagna
#   Name: Name, dtype: object,
#   226108,
#   [0.6454068522790953, 0.5859522313876946]],
#  [93828    M. Nastasić
#   Name: Name, dtype: object,
#   205362,
#   [0.5928239831575952, 0.6892339728629753]],
#  [101673    E. Goldaniga
#   Name: Name, dtype: object,
#   223524,
#   [0.6552857781661715, 0.5658798414851284]],
#  [89681    André Ramalho
#   Name: Name, dtype: object,
#   210007,
#   [0.5865314779763239, 0.6985580081833089]],
#  [95442    16 Pedro Geromel
#   Name: Name, dtype: object,
#   170802,
#   [0.5763196974111222, 0.7172044923007139]],
#  [100273    Antônio Carlos
#   Name: Name, dtype: object,
#   209597,
#   [0.6821524392697239, 0.5080870637348129]],
#  [95572    A. Ahmedhodžić
#   Name: Name, dtype: object,
#   236524,
#   [0.5845854261176987, 0.7005150650262059]],
#  [99729    A. Seko
#   Name: Name, dtype: object,
#   247264,
#   [0.6702454317625013, 0.5297317847169789]],
#  [99062    K. Bonifazi
#   Name: Name, dtype: object,
#   235290,
#   [0.6188366243779229, 0.6289369657067435]],
#  [101421    I. Gaponov
#   Name: Name, dtype: object,
#   248213,
#   [0.7053971645625339, 0.45784778665629955]],
#  [97763    G. Ortíz
#   Name: Name, dtype: object,
#   215070,
#   [0.6410692231356112, 0.5842626918789856]],
#  [102420    D. Happe
#   Name: Name, dtype: object,
#   238179,
#   [0.7760148340059415, 0.3180137813004228]],
#  [102030    L. Kitching
#   Name: Name, dtype: object,
#   246873,
#   [0.7339751270795054, 0.40084941687207065]],
#  [91373    T. Kehrer
#   Name: Name, dtype: object,
#   226229,
#   [0.5691217593710896, 0.7258929896048054]],
#  [101567    H. Davis
#   Name: Name, dtype: object,
#   194790,
#   [0.7731828072048912, 0.32217100985405095]],
#  [98196    20 M. Capuano
#   Name: Name, dtype: object,
#   201529,
#   [0.6562099693076061, 0.5523461245654665]],
#  [102342    21 M. Komar
#   Name: Name, dtype: object,
#   251100,
#   [0.7627264189639311, 0.34174748501169255]],
#  [101535    A. Maldonado
#   Name: Name, dtype: object,
#   233780,
#   [0.7017140742442365, 0.4617526100780283]],
#  [102688    P. Pinto
#   Name: Name, dtype: object,
#   253086,
#   [0.8151612877834398, 0.23738531604202148]],
#  [102287    A. Ortíz
#   Name: Name, dtype: object,
#   211074,
#   [0.7526987527453616, 0.3599039174046203]],
#  [95367    D. Granli
#   Name: Name, dtype: object,
#   222472,
#   [0.6704317871465684, 0.5212355061460903]],
#  [99645    P. Ziereis
#   Name: Name, dtype: object,
#   209196,
#   [0.6572306280623252, 0.5466886942559281]],
#  [102541    S. Nattestad
#   Name: Name, dtype: object,
#   217718,
#   [0.7513123231861687, 0.35794579336140847]],
#  [88457    F. Schär
#   Name: Name, dtype: object,
#   210047,
#   [0.5526525693224297, 0.747501017691289]],
#  [100382    20 M. Marcjanik
#   Name: Name, dtype: object,
#   234704,
#   [0.7182610222635885, 0.4205328707840347]],
#  [94100    Kwon Kyung Won
#   Name: Name, dtype: object,
#   212778,
#   [0.6269561608178369, 0.6005676311965985]],
#  [101006    C. McCarthy
#   Name: Name, dtype: object,
#   229771,
#   [0.7178594747254248, 0.4207348796800183]],
#  [97702    N. Rapp
#   Name: Name, dtype: object,
#   227511,
#   [0.6312066180287187, 0.5916914212811665]],
#  [100643    J. Canale
#   Name: Name, dtype: object,
#   253238,
#   [0.6833050692377217, 0.48871181485892645]],
#  [92193    P. Dummett
#   Name: Name, dtype: object,
#   204355,
#   [0.5634067865874103, 0.7221052428054295]],
#  [101991    M. Bokele
#   Name: Name, dtype: object,
#   262709,
#   [0.7716901244773391, 0.30989253210637246]],
#  [99231    B. Cargill
#   Name: Name, dtype: object,
#   215211,
#   [0.7002429103620008, 0.45062545592282743]],
#  [99444    D. Dumić
#   Name: Name, dtype: object,
#   193706,
#   [0.6772345540189281, 0.49483003825816024]],
#  [87655    D. Alaba
#   Name: Name, dtype: object,
#   197445,
#   [0.45659572366243667, 0.9276538741486968]],
#  [101813    S. Simič
#   Name: Name, dtype: object,
#   219591,
#   [0.6397230924102456, 0.5653797273459992]],
#  [90188    C. Lenglet
#   Name: Name, dtype: object,
#   220440,
#   [0.5023712109870249, 0.8355193432563369]],
#  [96930    Jang Hyeon Soo
#   Name: Name, dtype: object,
#   211005,
#   [0.5868604083334238, 0.6685907175556517]],
#  [101541    V. Gembalies
#   Name: Name, dtype: object,
#   247755,
#   [0.7730106230358472, 0.30117497970560236]],
#  [99878    M. Gillesphey
#   Name: Name, dtype: object,
#   228366,
#   [0.6838456250380607, 0.4770590204163559]],
#  [97252    P. Retsos
#   Name: Name, dtype: object,
#   234986,
#   [0.5731823288649552, 0.6926074624705076]],
#  [98288    F. Kalig
#   Name: Name, dtype: object,
#   228508,
#   [0.6843857677990659, 0.4731024926656748]],
#  [89974    Yeray
#   Name: Name, dtype: object,
#   227950,
#   [0.4981157762296906, 0.8389348562587347]],
#  [97941    C. Luyindama
#   Name: Name, dtype: object,
#   237556,
#   [0.6041437944844172, 0.6278583792160958]],
#  [99455    Clemente
#   Name: Name, dtype: object,
#   244394,
#   [0.6260637774398236, 0.5825305347967931]],
#  [99944    M. Cestor
#   Name: Name, dtype: object,
#   197904,
#   [0.6876661288732339, 0.460216098808761]],
#  [100411    N. Fukumori
#   Name: Name, dtype: object,
#   246442,
#   [0.7315873510176112, 0.3722325734932641]],
#  [102294    M. Steinwender
#   Name: Name, dtype: object,
#   245233,
#   [0.7290621546037618, 0.3770925978781327]],
#  [94531    B. Davies
#   Name: Name, dtype: object,
#   213017,
#   [0.5898362542822221, 0.6504455959266008]],
#  [94578    21 B. Kuscevic
#   Name: Name, dtype: object,
#   225236,
#   [0.6069667496319704, 0.6161156021966142]],
#  [101009    Elton Monteiro
#   Name: Name, dtype: object,
#   202801,
#   [0.7064489354200899, 0.41959038180496044]],
#  [94506    A. Rrahmani
#   Name: Name, dtype: object,
#   244263,
#   [0.5796024701991457, 0.6694020191652922]],
#  [97434    A. Sørensen
#   Name: Name, dtype: object,
#   221024,
#   [0.6373677022712319, 0.5554203111967606]],
#  [102355    21 David Cardoso
#   Name: Name, dtype: object,
#   247198,
#   [0.7893534659098721, 0.25538072989550126]],
#  [94651    R. Koch
#   Name: Name, dtype: object,
#   236532,
#   [0.5420582063467491, 0.7419978857395281]],
#  [99483    21 J. Chancellor
#   Name: Name, dtype: object,
#   234059,
#   [0.6689780960477522, 0.4905097067111339]],
#  [93795    M. Kamiński
#   Name: Name, dtype: object,
#   199761,
#   [0.6124568988784012, 0.6008656896428224]],
#  [102406    I. Tapia
#   Name: Name, dtype: object,
#   236677,
#   [0.7486682340527512, 0.3319466355269491]],
#  [93473    J. Andersen
#   Name: Name, dtype: object,
#   224221,
#   [0.524886755649126, 0.7726673239837638]],
#  [98524    Iago
#   Name: Name, dtype: object,
#   224537,
#   [0.6275032780887908, 0.5696797793177273]],
#  [102173    E. Ferigra
#   Name: Name, dtype: object,
#   245689,
#   [0.7228153067991576, 0.37971321861108326]],
#  [102116    R. Malone
#   Name: Name, dtype: object,
#   257147,
#   [0.7339833060070923, 0.3576118830322838]],
#  [94682    A. Toșca
#   Name: Name, dtype: object,
#   233512,
#   [0.5993927746737479, 0.6224510298358583]],
#  [101423    T. Odusina
#   Name: Name, dtype: object,
#   233687,
#   [0.753462469135362, 0.3181960704469318]],
#  [98042    M. Hołownia
#   Name: Name, dtype: object,
#   245129,
#   [0.6903747967751592, 0.4425059432389767]],
#  [95977    Kim Min Jae
#   Name: Name, dtype: object,
#   237086,
#   [0.5780958822929573, 0.6610867709581146]],
#  [101988    David Carmo
#   Name: Name, dtype: object,
#   251616,
#   [0.6217513332371455, 0.5749463924138338]],
#  [101102    T. Eastman
#   Name: Name, dtype: object,
#   199916,
#   [0.6923939465927824, 0.43528123340049957]],
#  [98232    T. Adarabioyo
#   Name: Name, dtype: object,
#   222104,
#   [0.5632683005390737, 0.689581226477703]],
#  [94854    Vanderleiton
#   Name: Name, dtype: object,
#   230407,
#   [0.5991150963240962, 0.6174817192171944]],
#  [99719    S. Agouzoul
#   Name: Name, dtype: object,
#   251751,
#   [0.6464074372203791, 0.5236552311700682]],
#  [97504    S. Gartenmann
#   Name: Name, dtype: object,
#   229436,
#   [0.6345080088092837, 0.5471047222548748]],
#  [90425    Josué Chiamulera
#   Name: Name, dtype: object,
#   230375,
#   [0.4975978327798606, 0.8170128265816963]],
#  [102837    21 Unai Dufur
#   Name: Name, dtype: object,
#   259363,
#   [0.7695182391935544, 0.2804938142915618]],
#  [98781    D. Baumgartner
#   Name: Name, dtype: object,
#   229818,
#   [0.6301631495124086, 0.5540548172835866]],
#  [89233    H. Maguire
#   Name: Name, dtype: object,
#   203263,
#   [0.46178578791279157, 0.8849099166984377]],
#  [98135    H. Wahl
#   Name: Name, dtype: object,
#   230855,
#   [0.5800501852910851, 0.6514108970209365]],
#  [96990    A. Trusty
#   Name: Name, dtype: object,
#   235755,
#   [0.6506079492945407, 0.5101762175964457]],
#  [95492    M. Demiral
#   Name: Name, dtype: object,
#   238160,
#   [0.5710298318421305, 0.6668809457224415]],
#  [95903    Ramalho
#   Name: Name, dtype: object,
#   189576,
#   [0.5990180391059226, 0.6115389626767677]],
#  [101574    L. Olivas
#   Name: Name, dtype: object,
#   259866,
#   [0.7593284178652734, 0.29509201069150504]],
#  [96868    Ferro
#   Name: Name, dtype: object,
#   242236,
#   [0.5419561410178386, 0.7238254253552039]],
#  [93397    Z. Vanheusden
#   Name: Name, dtype: object,
#   241103,
#   [0.5497892741923605, 0.7078449076014405]],
#  [100625    A. Stewart
# ...
#  [96871    A. Soumaoro
#   Name: Name, dtype: object,
#   200353,
#   [0.41593960183719825, 0.6762043537259317]],
#  [99310    L. Šatka
#   Name: Name, dtype: object,
#   209232,
#   [0.4516811661286803, 0.604153908087648]],
#  [95365    L. Balerdi
#   Name: Name, dtype: object,
#   242835,
#   [0.3948369223011564, 0.7140813614394081]],
#  [99133    N. Röseler
#   Name: Name, dtype: object,
#   205045,
#   [0.4817905369359493, 0.5422972162645391]],
#  [99859    M. Barbieri
#   Name: Name, dtype: object,
#   233292,
#   [0.4884614550611902, 0.5272429752754899]],
#  [102025    A. Barry
#   Name: Name, dtype: object,
#   258625,
#   [0.5869115550349746, 0.3324614056432226]],
#  [101061    C. Kipré
#   Name: Name, dtype: object,
#   235458,
#   [0.5102505505114256, 0.48335819690797704]],
#  [102225    M. Malec
#   Name: Name, dtype: object,
#   244755,
#   [0.5483904479719084, 0.40753648790564617]],
#  [93637    Tiago Djaló
#   Name: Name, dtype: object,
#   252339,
#   [0.41258470864379193, 0.6751276140080139]],
#  [102617    M. Rossmann
#   Name: Name, dtype: object,
#   239523,
#   [0.5441644240192806, 0.4133628761632134]],
#  [97455    M. Dyrestam
#   Name: Name, dtype: object,
#   191157,
#   [0.4996273211157887, 0.5007901729741918]],
#  [101735    F. Kelleher
#   Name: Name, dtype: object,
#   227948,
#   [0.5535824787659333, 0.39403809234706794]],
#  [100113    N. Dussenne
#   Name: Name, dtype: object,
#   201841,
#   [0.46293703950504406, 0.5722373595237347]],
#  [100681    J. Whatmough
#   Name: Name, dtype: object,
#   211166,
#   [0.5032487449301247, 0.4922877906404443]],
#  [98076    L. Mühl
#   Name: Name, dtype: object,
#   233960,
#   [0.4546257299202392, 0.5873817863709582]],
#  [88614    N. Mukiele
#   Name: Name, dtype: object,
#   226166,
#   [0.3343921907470878, 0.823862958974672]],
#  [97512    S. Breitkreuz
#   Name: Name, dtype: object,
#   234278,
#   [0.5048060587127545, 0.486746382518842]],
#  [96489    Diego González
#   Name: Name, dtype: object,
#   227106,
#   [0.4430590104620669, 0.608105275495018]],
#  [100332    J. Bamert
#   Name: Name, dtype: object,
#   231650,
#   [0.5024017268691889, 0.49088065014137494]],
#  [97840    F. Kunze
#   Name: Name, dtype: object,
#   251429,
#   [0.4393060175048319, 0.6145496440025153]],
#  [99314    R. Pirrello
#   Name: Name, dtype: object,
#   230676,
#   [0.5113704001815659, 0.4709588658787877]],
#  [102197    L. Grace
#   Name: Name, dtype: object,
#   231303,
#   [0.5169425186822404, 0.459562611525158]],
#  [102331    20 C. Pérez
#   Name: Name, dtype: object,
#   231711,
#   [0.5469952852567904, 0.39976179935707934]],
#  [102123    R. Delaney
#   Name: Name, dtype: object,
#   231284,
#   [0.5486278059390907, 0.3958632875988823]],
#  [97673    J. Nyholm
#   Name: Name, dtype: object,
#   237226,
#   [0.474211851328, 0.5406607567291031]],
#  [91919    B. Rovira
#   Name: Name, dtype: object,
#   225812,
#   [0.4390969325055074, 0.6097706765916725]],
#  [91553    D. Djené
#   Name: Name, dtype: object,
#   217940,
#   [0.3234886955381382, 0.8367020114013427]],
#  [101429    19 G. Modica
#   Name: Name, dtype: object,
#   234380,
#   [0.5437660749907061, 0.4015755727595206]],
#  [101571    21 R. Ziegele
#   Name: Name, dtype: object,
#   234861,
#   [0.5369128289722839, 0.4129231126237716]],
#  [98309    Y. Kimoto
#   Name: Name, dtype: object,
#   237789,
#   [0.46723096484594656, 0.5486204104542096]],
#  [98902    U. Godwin-Malife
#   Name: Name, dtype: object,
#   247073,
#   [0.5185590620939331, 0.4469367728549822]],
#  [92802    16 R. Strasser
#   Name: Name, dtype: object,
#   190604,
#   [0.4524493711174969, 0.577293104982484]],
#  [101321    H. Kessler
#   Name: Name, dtype: object,
#   255110,
#   [0.45736206257785567, 0.566405573948231]],
#  [98408    F. Eboa Eboa
#   Name: Name, dtype: object,
#   239210,
#   [0.49098325156870515, 0.49965669654461187]],
#  [100355    D. Arslanagic
#   Name: Name, dtype: object,
#   204352,
#   [0.40789528752313164, 0.6599016018776183]],
#  [98685    C. González
#   Name: Name, dtype: object,
#   236020,
#   [0.48003869885068323, 0.5174433374809511]],
#  [99419    M. Sørensen
#   Name: Name, dtype: object,
#   234472,
#   [0.4528107176136064, 0.5710752331080639]],
#  [98645    L. Gugganig
#   Name: Name, dtype: object,
#   228058,
#   [0.5311074180081246, 0.4155535718190198]],
#  [96430    21 J. Hardeveld
#   Name: Name, dtype: object,
#   221986,
#   [0.45450240656509655, 0.5656702349021999]],
#  [102840    21 C. Montgomery
#   Name: Name, dtype: object,
#   247510,
#   [0.6093548666561157, 0.25962860752911276]],
#  [99976    L. Pinckert
#   Name: Name, dtype: object,
#   262591,
#   [0.5368077820841302, 0.40264087711457247]],
#  [93843    Tuta
#   Name: Name, dtype: object,
#   247182,
#   [0.38959454794503784, 0.692338202312746]],
#  [99733    T. Iwanami
#   Name: Name, dtype: object,
#   232894,
#   [0.4323309909994582, 0.6075454270607792]],
#  [100761    S. Radić
#   Name: Name, dtype: object,
#   260874,
#   [0.4617300446852807, 0.5495212333850752]],
#  [98909    V. Bondar
#   Name: Name, dtype: object,
#   248698,
#   [0.458361778875141, 0.5557228684702071]],
#  [100067    R. Takao
#   Name: Name, dtype: object,
#   248810,
#   [0.4886412643361017, 0.4958119949016314]],
#  [102045    Tachi
#   Name: Name, dtype: object,
#   238446,
#   [0.4610207239126098, 0.5490932986593028]],
#  [101950    21 E. Caicedo
#   Name: Name, dtype: object,
#   227398,
#   [0.5648597230690082, 0.34390578595289295]],
#  [101027    T. Siersleben
#   Name: Name, dtype: object,
#   258812,
#   [0.5176421900037405, 0.4362584533803438]],
#  [96949    J. Moore-Taylor
#   Name: Name, dtype: object,
#   208645,
#   [0.5016077935299874, 0.46654880874105353]],
#  [101467    Pedrão
#   Name: Name, dtype: object,
#   258356,
#   [0.4855816738974451, 0.4957393648805564]],
#  [102154    A. Maciel
#   Name: Name, dtype: object,
#   240457,
#   [0.5462732514133808, 0.37530558363175187]],
#  [98869    Diogo Leite
#   Name: Name, dtype: object,
#   234575,
#   [0.4118905109801358, 0.6401068832976252]],
#  [98527    M. Ihiekwe
#   Name: Name, dtype: object,
#   205584,
#   [0.48122017983573, 0.5021229779686928]],
#  [97911    J. Lascelles
#   Name: Name, dtype: object,
#   203487,
#   [0.3864563593569149, 0.6883547524793193]],
#  [97625    José Fontán
#   Name: Name, dtype: object,
#   258728,
#   [0.439694161052808, 0.583087782417087]],
#  [98825    C. Starfelt
#   Name: Name, dtype: object,
#   220821,
#   [0.4264621045405375, 0.6087386968320659]],
#  [101725    K. Kraus
#   Name: Name, dtype: object,
#   201925,
#   [0.5221343717214643, 0.41924578524096406]],
#  [90563    E. Ndicka
#   Name: Name, dtype: object,
#   236403,
#   [0.32744214177713904, 0.8024694854359301]],
#  [100167    J. Guthrie
#   Name: Name, dtype: object,
#   208188,
#   [0.49854605157359266, 0.4645937160919828]],
#  [98870    R. Bennett
#   Name: Name, dtype: object,
#   204554,
#   [0.5015334326714123, 0.45744215541914557]],
#  [101349    M. Pineda
#   Name: Name, dtype: object,
#   255273,
#   [0.46193568231824444, 0.5354498741139236]],
#  [101133    A. Mora
#   Name: Name, dtype: object,
#   242427,
#   [0.46792364026775585, 0.5235268608918594]],
#  [102572    A. Cissoko
#   Name: Name, dtype: object,
#   262781,
#   [0.57626513723851, 0.3094738291684013]],
#  [95754    Pol García
#   Name: Name, dtype: object,
#   211323,
#   [0.4159459759379549, 0.6237233225664499]],
#  [95887    Kauã Zanson
#   Name: Name, dtype: object,
#   230221,
#   [0.48441529089711144, 0.48827705701693147]],
#  [97677    S. Findlay
#   Name: Name, dtype: object,
#   227945,
#   [0.4600868102944313, 0.5346822388390013]],
#  [93227    Jean
#   Name: Name, dtype: object,
#   236303,
#   [0.382908158503664, 0.6865250941986456]],
#  [99559    18 M. Bloom
#   Name: Name, dtype: object,
#   216801,
#   [0.4918138215950497, 0.4713367957877192]],
#  [100811    Ivanildo Fernandes
#   Name: Name, dtype: object,
#   244963,
#   [0.439084542133312, 0.5753151191180964]],
#  [94374    D. Lenihan
#   Name: Name, dtype: object,
#   211009,
#   [0.40836151509658014, 0.6337416662744301]],
#  [97728    L. Quintana
#   Name: Name, dtype: object,
#   210653,
#   [0.4255387696871715, 0.5995135837116353]],
#  [90365    G. Silva
#   Name: Name, dtype: object,
#   220702,
#   [0.3886337459307455, 0.6720568119221633]],
#  [96037    P. Struijk
#   Name: Name, dtype: object,
#   239360,
#   [0.35843746831795187, 0.7308753916819718]],
#  [97384    M. Rose
#   Name: Name, dtype: object,
#   212487,
#   [0.4332230164781701, 0.5830750624512617]],
#  [97768    Adri Castellano
#   Name: Name, dtype: object,
#   231123,
#   [0.44413414449430794, 0.5608368435365112]],
#  [101646    R. Sykes
#   Name: Name, dtype: object,
#   235572,
#   [0.4944947539217265, 0.4603829958921393]],
#  [96946    M. Hofmann
#   Name: Name, dtype: object,
#   215370,
#   [0.43118587841931794, 0.5851226547250999]],
#  [102310    Aitor Paredes
#   Name: Name, dtype: object,
#   259524,
#   [0.5195935023452033, 0.4104665895104712]],
#  [100514    C. Hountondji
#   Name: Name, dtype: object,
#   219680,
#   [0.3973934486501991, 0.6506532708872895]],
#  [101513    M. Pérez
#   Name: Name, dtype: object,
#   255333,
#   [0.5163549074280933, 0.4149991317753083]],
#  [95559    D. Williams
#   Name: Name, dtype: object,
#   203398,
#   [0.424336100931515, 0.5957915260778315]],
#  [97295    Thiago Martins
#   Name: Name, dtype: object,
#   233790,
#   [0.42284784335324105, 0.5979760451600384]],
#  [98893    E. Palmer-Brown
#   Name: Name, dtype: object,
#   219461,
#   [0.46919023170412116, 0.5064786422922261]],
#  [99952    Pedro Henrique
#   Name: Name, dtype: object,
#   219258,
#   [0.3924573882182596, 0.6563974400909095]],
#  [90861    R. Rojas
#   Name: Name, dtype: object,
#   246914,
#   [0.40430214771679807, 0.6312444113188327]],
#  [98716    A. Krivotsyuk
#   Name: Name, dtype: object,
#   263034,
#   [0.479967980623066, 0.48023737510289416]],
#  [95759    I. Cissé
#   Name: Name, dtype: object,
#   225532,
#   [0.46610424940077033, 0.5067185301350504]],
#  [100646    I. Łasicki
#   Name: Name, dtype: object,
#   220531,
#   [0.500293820104456, 0.43773360559590896]],
#  [97030    S. Lewkot
#   Name: Name, dtype: object,
#   258902,
#   [0.4866218497031273, 0.46207521099910726]],
#  [97417    J. Elvedi
#   Name: Name, dtype: object,
#   256705,
#   [0.44106163963065953, 0.5517738466479034]],
#  [100693    Álex Martín
#   Name: Name, dtype: object,
#   236914,
#   [0.4472150845947865, 0.5389625371048896]],
#  [100003    S. Babić
#   Name: Name, dtype: object,
#   235589,
#   [0.44378977753101206, 0.5456886012316281]],
#  [88925    K. Ayhan
#   Name: Name, dtype: object,
#   207790,
#   [0.33063923767696535, 0.7682750734110525]],
#  [101069    Y. Salmier
#   Name: Name, dtype: object,
#   235553,
#   [0.42509772049978667, 0.5816315228410132]],
#  [102249    J. Aspropotamitis
#   Name: Name, dtype: object,
#   228191,
#   [0.5117163665866895, 0.41068346141246603]],
#  [99864    H. Martínez
#   Name: Name, dtype: object,
#   235665,
#   [0.46173781513319884, 0.5090632393993528]],
#  [94106    Aritz Elustondo
#   Name: Name, dtype: object,
#   226221,
#   [0.3083352157146368, 0.811152217975143]],
#  [98992    B. Kopacz
#   Name: Name, dtype: object,
#   201081,
#   [0.46861368954250954, 0.49261595340428777]],
#  [102268    N. Hoffmann
#   Name: Name, dtype: object,
#   231379,
#   [0.5047653430870847, 0.41830643312490345]],
#  [100962    21 J. Aja
#   Name: Name, dtype: object,
#   235280,
#   [0.49583257056619606, 0.4350294519663441]],
#  [96881    21 A. Wisdom
#   Name: Name, dtype: object,
#   201908,
#   [0.39258821002502986, 0.6376657319275202]],
#  [102677    M. Feeney
#   Name: Name, dtype: object,
#   233782,
#   [0.5539878698616048, 0.31910762797652104]],
#  [101914    16 R. Calvet
#   Name: Name, dtype: object,
#   205392,
#   [0.5641602841560049, 0.29882728688463545]],
#  [94781    A. Pelmard
#   Name: Name, dtype: object,
#   247412,
#   [0.3795126145839469, 0.660419851255142]],
#  [99509    L. Boeder
#   Name: Name, dtype: object,
#   225636,
#   [0.4769748893345194, 0.46701726375189767]],
#  [98119    A. Sharahili
#   Name: Name, dtype: object,
#   221658,
#   [0.43789429639430477, 0.5412574266588515]],
#  [102013    20 D. Maldonado
#   Name: Name, dtype: object,
#   255316,
#   [0.5009476392796373, 0.41669092366128613]],
#  [97372    J. de Wijs
#   Name: Name, dtype: object,
#   224186,
#   [0.42913827149910566, 0.556770163171125]],
#  [100234    D. Scarr
#   Name: Name, dtype: object,
#   237943,
#   [0.4899859859796628, 0.43540346184211387]],
#  [101166    S. Jhingan
#   Name: Name, dtype: object,
#   223763,
#   [0.5102597449605597, 0.3949576497872004]],
#  [90775    J. Foyth
#   Name: Name, dtype: object,
#   237221,
#   [0.32647373213959346, 0.7574721597952845]],
#  [100065    B. Utvik
#   Name: Name, dtype: object,
#   213864,
#   [0.46411815654164834, 0.48549758797877673]],
#  [95497    S. Nsoki
#   Name: Name, dtype: object,
#   241941,
#   [0.40776853328399504, 0.5962011045295852]],
#  [97974    G. Guiffrey
#   Name: Name, dtype: object,
#   244851,
#   [0.4383235611581888, 0.535381899552285]],
#  [100265    20 M. Sarr
#   Name: Name, dtype: object,
#   212628,
#   [0.4986896876296573, 0.4162360996789705]],
#  [99306    21 J. Ortíz
#   Name: Name, dtype: object,
#   242763,
#   [0.4459595009179394, 0.5200086949783431]],
#  [94381    T. Chalobah
#   Name: Name, dtype: object,
#   230918,
#   [0.34265472115469947, 0.7229883594275376]],
#  [94177    V. Vevatne
#   Name: Name, dtype: object,
#   214650,
#   [0.42629057742749266, 0.5575074159118215]],
#  [95117    S. Cáceres
#   Name: Name, dtype: object,
#   253257,
#   [0.3810757766920367, 0.6462636232963048]],
#  [96259    A. Milošević
#   Name: Name, dtype: object,
#   202605,
#   [0.4140043425191977, 0.5802938378009658]],
#  [99401    J. Sánchez Purata
#   Name: Name, dtype: object,
#   244448,
#   [0.47817912502762894, 0.45336167451731413]],
#  [99861    D. Aimar
#   Name: Name, dtype: object,
#   236267,
#   [0.39705432933629903, 0.6112674051087353]],
#  [94694    A. Obispo
#   Name: Name, dtype: object,
#   241171,
#   [0.37386538439250094, 0.6567385064305904]],
#  [100785    H. Matriciani
#   Name: Name, dtype: object,
#   262212,
#   [0.5099049083861551, 0.38636684431166857]],
#  [97638    J. Tverskov
#   Name: Name, dtype: object,
#   224067,
#   [0.39176264365704716, 0.6192293676402958]],
#  [98449    D. Sanderson
#   Name: Name, dtype: object,
#   243612,
#   [0.4664282223527737, 0.4711546924228707]],
#  [96323    J. Rasmussen
#   Name: Name, dtype: object,
#   234827,
#   [0.3568809243998299, 0.6870084670258628]],
#  [102382    L. Racic
#   Name: Name, dtype: object,
#   245076,
#   [0.5043456622435557, 0.39374770448632934]],
#  [99884    M. Diaby
#   Name: Name, dtype: object,
#   248831,
#   [0.36798682144257516, 0.6623114128302103]],
#  [93987    Bustinza
#   Name: Name, dtype: object,
#   224869,
#   [0.32962062029156947, 0.7376126963213414]],
#  [102444    A. Abqar
#   Name: Name, dtype: object,
#   245628,
#   [0.5021218439208606, 0.39678687479869323]],
#  [96727    Fábio Cardoso
#   Name: Name, dtype: object,
#   213917,
#   [0.3542417176920675, 0.6833492794683278]],
#  [96726    T. St. Jago
#   Name: Name, dtype: object,
#   253376,
#   [0.3906271322470646, 0.6083974644901086]],
#  [100447    E. Bergström
#   Name: Name, dtype: object,
#   202060,
#   [0.43036062203070635, 0.5298677830312637]],
#  [102350    21 B. Moltenis
#   Name: Name, dtype: object,
#   247101,
#   [0.4997102379376743, 0.3927259209480385]],
#  [101619    19 E. Suagher
#   Name: Name, dtype: object,
#   216789,
#   [0.4617656838933473, 0.4658977565559054]],
#  [94850    A. Hughes
#   Name: Name, dtype: object,
#   214906,
#   [0.3990139204092595, 0.5879463700090177]],
#  [102269    S. Stubbs
#   Name: Name, dtype: object,
#   237341,
#   [0.5101530112386403, 0.36855373569206645]],
#  [90753    Li Ang
#   Name: Name, dtype: object,
#   224690,
#   [0.4190134529804871, 0.5471254586167177]],
#  [99202    M. Wallace
#   Name: Name, dtype: object,
#   208024,
#   [0.4185800335912362, 0.547509760393485]],
#  [101340    21 K. da Graca
#   Name: Name, dtype: object,
#   225770,
#   [0.45577752375586494, 0.4740734874407637]],
#  [95157    Z. Al Sahafi
#   Name: Name, dtype: object,
#   231821,
#   [0.42464787165922896, 0.5342449828143868]],
#  [101638    E. Moore
#   Name: Name, dtype: object,
#   235263,
#   [0.4516832686571158, 0.48015610938033987]],
#  [101339    A. Doldán
#   Name: Name, dtype: object,
#   255240,
#   [0.4300238607414614, 0.5225349148730933]],
#  [92313    H. Ishihara
#   Name: Name, dtype: object,
#   242568,
#   [0.42205711653505024, 0.537941642483842]],
#  [96706    Jorge Meré
#   Name: Name, dtype: object,
#   223033,
#   [0.3507311099050313, 0.6783286192961931]],
#  [102375    Rafael Santos
#   Name: Name, dtype: object,
#   262562,
#   [0.42732801423051175, 0.5265696944190339]],
#  [98291    A. Buongiorno
#   Name: Name, dtype: object,
#   243241,
#   [0.4571459734067322, 0.4664452022546891]],
#  ...]

# %%
get_player_recs(df_22_std,"FC Barcelona",["CB"],Def_essential_ft,def_weights_per_club)
# Out:
# [[89061    M. Ginter
#   Name: Name, dtype: object,
#   207862,
#   [0.9759302281700118, 0.8815359970174212]],
#  [88397    Éder Militão
#   Name: Name, dtype: object,
#   240130,
#   [0.9443736657572159, 0.8360099497017297]],
#  [89840    J. Koundé
#   Name: Name, dtype: object,
#   241486,
#   [0.9283980436334522, 0.8575857652502339]],
#  [89398    M. Akanji
#   Name: Name, dtype: object,
#   229237,
#   [0.9548722052327286, 0.8011019133323763]],
#  [90733    J. Matip
#   Name: Name, dtype: object,
#   197061,
#   [0.9092702490742487, 0.8771277788852602]],
#  [94661    A. Christensen
#   Name: Name, dtype: object,
#   213661,
#   [0.9425134429495874, 0.8064332169161973]],
#  [89095    J. Stones
#   Name: Name, dtype: object,
#   203574,
#   [0.9006823275542403, 0.8842783284417025]],
#  [87655    D. Alaba
#   Name: Name, dtype: object,
#   197445,
#   [0.8956115712394193, 0.8819776988975037]],
#  [91623    M. Keane
#   Name: Name, dtype: object,
#   207599,
#   [0.933722338572113, 0.7955934672923592]],
#  [93404    N. Aguerd
#   Name: Name, dtype: object,
#   244749,
#   [0.9690168051264813, 0.7223708497336903]],
#  [93617    A. Romagnoli
#   Name: Name, dtype: object,
#   210413,
#   [0.902101163952656, 0.8399363761493199]],
#  [88495    Mario Hermoso
#   Name: Name, dtype: object,
#   229668,
#   [0.893771047482795, 0.8513555684218739]],
#  [94922    21 Bastos
#   Name: Name, dtype: object,
#   216655,
#   [0.9672590128703021, 0.7026884613030838]],
#  [92281    J. Gomez
#   Name: Name, dtype: object,
#   225100,
#   [0.911142571328123, 0.8125663540820616]],
#  [90045    J. Denayer
#   Name: Name, dtype: object,
#   220182,
#   [0.9138857292294537, 0.79860627670178]],
#  [94814    Luiz Felipe
#   Name: Name, dtype: object,
#   236355,
#   [0.936048512164467, 0.7484191646385243]],
#  [94795    K. Akpoguma
#   Name: Name, dtype: object,
#   211856,
#   [0.9817103546635183, 0.6413588045627793]],
#  [90881    S. de Vrij
#   Name: Name, dtype: object,
#   198176,
#   [0.8630523704610765, 0.8694515540215185]],
#  [98634    Jorge Cuenca
#   Name: Name, dtype: object,
#   237522,
#   [0.9779849347548283, 0.6350866212133754]],
#  [88988    A. Mandi
#   Name: Name, dtype: object,
#   201143,
#   [0.8775964708050829, 0.823401372877517]],
#  [92193    P. Dummett
#   Name: Name, dtype: object,
#   204355,
#   [0.9414909494412719, 0.6890221078359349]],
#  [93319    M. Senesi
#   Name: Name, dtype: object,
#   236506,
#   [0.8888863502252369, 0.7852491778460513]],
#  [94420    J. Egan
#   Name: Name, dtype: object,
#   204936,
#   [0.9257470087216887, 0.7110426652751461]],
#  [88648    N. Aké
#   Name: Name, dtype: object,
#   208920,
#   [0.8938208143522871, 0.7717768125162336]],
#  [94478    S. Taniguchi
#   Name: Name, dtype: object,
#   233225,
#   [0.9548495134418051, 0.6483615713052823]],
#  [95297    R. Holding
#   Name: Name, dtype: object,
#   228295,
#   [0.9086814580028252, 0.7383979911503663]],
#  [92514    A. Bastoni
#   Name: Name, dtype: object,
#   237383,
#   [0.8703970917323325, 0.8101896446917645]],
#  [89974    Yeray
#   Name: Name, dtype: object,
#   227950,
#   [0.8663607075225339, 0.8156285381069011]],
#  [89839    E. Tapsoba
#   Name: Name, dtype: object,
#   247263,
#   [0.8502091505981859, 0.8467830258567065]],
#  [99250    A. Disasi
#   Name: Name, dtype: object,
#   229942,
#   [0.9181159299236322, 0.7116029893222295]],
#  [99310    L. Šatka
#   Name: Name, dtype: object,
#   209232,
#   [0.9778320261315381, 0.5892980038376702]],
#  [92015    N. Elvedi
#   Name: Name, dtype: object,
#   221491,
#   [0.8924702782407685, 0.7571987396568021]],
#  [98418    T. Phete
#   Name: Name, dtype: object,
#   231688,
#   [0.9600091035078409, 0.623573655633359]],
#  [94558    David García
#   Name: Name, dtype: object,
#   225341,
#   [0.8792906757223967, 0.7787638607824704]],
#  [96325    Vincente Dourado
#   Name: Name, dtype: object,
#   230285,
#   [0.894411428697582, 0.7488971931603272]],
#  [94651    R. Koch
#   Name: Name, dtype: object,
#   236532,
#   [0.8990425401151787, 0.7396783763984286]],
#  [100097    B. Gibson
#   Name: Name, dtype: object,
#   200408,
#   [0.9630837224166482, 0.6112890564810359]],
#  [89233    H. Maguire
#   Name: Name, dtype: object,
#   203263,
#   [0.8136511440990604, 0.9006594770477887]],
#  [90602    N. Stark
#   Name: Name, dtype: object,
#   212977,
#   [0.9048853913721913, 0.7199176722024359]],
#  [93880    J. Stephens
#   Name: Name, dtype: object,
#   202697,
#   [0.925299561362497, 0.6777449495735944]],
#  [100015    J. Rodon
#   Name: Name, dtype: object,
#   229266,
#   [0.9497900210054226, 0.6283492365153723]],
#  [89547    Diego Carlos
#   Name: Name, dtype: object,
#   219693,
#   [0.8516949562789161, 0.8215457135899743]],
#  [97108    Paulo Oliveira
#   Name: Name, dtype: object,
#   210679,
#   [0.9211034114712541, 0.6801971591616217]],
#  [94262    M. Simakan
#   Name: Name, dtype: object,
#   243854,
#   [0.9061404064796131, 0.7001672944067824]],
#  [91553    D. Djené
#   Name: Name, dtype: object,
#   217940,
#   [0.8407341318598335, 0.8291729462596699]],
#  [89615    P. Schuurs
#   Name: Name, dtype: object,
#   241854,
#   [0.9085393634106981, 0.6942054209816104]],
#  [94274    S. Luperto
#   Name: Name, dtype: object,
#   220534,
#   [0.9470552433392991, 0.6174848166252714]],
#  [93668    Sergi Gómez
#   Name: Name, dtype: object,
#   199577,
#   [0.8879733046902062, 0.7338456354040706]],
#  [96324    D. Rugani
#   Name: Name, dtype: object,
#   211320,
#   [0.8915350883421695, 0.7244746496562162]],
#  [91543    E. Konsa
#   Name: Name, dtype: object,
#   227678,
#   [0.8726228847338379, 0.7613891008266142]],
#  [93997    T. Tomiyasu
#   Name: Name, dtype: object,
#   232938,
#   [0.9180265669657446, 0.6717148389194558]],
#  [90775    J. Foyth
#   Name: Name, dtype: object,
#   237221,
#   [0.9001906016731165, 0.7055299962873298]],
#  [97128    João Basso
#   Name: Name, dtype: object,
#   236255,
#   [0.9554615206264437, 0.5943821555822528]],
#  [99108    Javi Sánchez
#   Name: Name, dtype: object,
#   245238,
#   [0.9337444608391716, 0.633440336414076]],
#  [97702    N. Rapp
#   Name: Name, dtype: object,
#   227511,
#   [0.9592376502996783, 0.5813447409163687]],
#  [95977    Kim Min Jae
#   Name: Name, dtype: object,
#   237086,
#   [0.9210168231846573, 0.6560393212978753]],
#  [90421    M. Holgate
#   Name: Name, dtype: object,
#   225024,
#   [0.8560754402924082, 0.7812925242510705]],
#  [89216    P. Kimpembe
#   Name: Name, dtype: object,
#   225850,
#   [0.8049573764426784, 0.8815619591984548]],
#  [93416    L. Dunk
#   Name: Name, dtype: object,
#   199915,
#   [0.8552762520246444, 0.7813096367536418]],
#  [95256    Gabriel
#   Name: Name, dtype: object,
#   232580,
#   [0.8497828121701313, 0.7873783345291694]],
#  [90375    Rúben Vezo
#   Name: Name, dtype: object,
#   215399,
#   [0.8875437779937513, 0.710314800739407]],
#  [88614    N. Mukiele
#   Name: Name, dtype: object,
#   226166,
#   [0.84141172700641, 0.7989974819652936]],
#  [89857    Andrei Girotto
#   Name: Name, dtype: object,
#   226515,
#   [0.8666048323227844, 0.7468829062315843]],
#  [100753    H. Souttar
#   Name: Name, dtype: object,
#   229901,
#   [0.9548210087652013, 0.5707911571233845]],
#  [97548    Maracás
#   Name: Name, dtype: object,
#   251681,
#   [0.9198334562093395, 0.6368901466339948]],
#  [96915    K. Günter
#   Name: Name, dtype: object,
#   204451,
#   [0.8992889754948347, 0.6764556290472367]],
#  [96930    Jang Hyeon Soo
#   Name: Name, dtype: object,
#   211005,
#   [0.8874323551210098, 0.6957000660107794]],
#  [96069    F. Uduokhai
#   Name: Name, dtype: object,
#   232144,
#   [0.8678443638339415, 0.7288625145890755]],
#  [101008    B. Wilmot
#   Name: Name, dtype: object,
#   238389,
#   [0.9609666579115569, 0.5442364692275925]],
#  [96926    L. Cooper
#   Name: Name, dtype: object,
#   189456,
#   [0.8856746450745671, 0.6921531151523445]],
#  [94340    M. Lacroix
#   Name: Name, dtype: object,
#   244067,
#   [0.8598167923735787, 0.7427710441157999]],
#  [94625    21 Bruno Viana
#   Name: Name, dtype: object,
#   234226,
#   [0.8634734964496532, 0.7278745191143319]],
#  [96182    21 V. Jovanović
#   Name: Name, dtype: object,
#   233219,
#   [0.8970395150764772, 0.658960756814587]],
#  [98316    J. Nilsson
#   Name: Name, dtype: object,
#   210802,
#   [0.8969482405712924, 0.6551275130433508]],
#  [100032    Montero
#   Name: Name, dtype: object,
#   244938,
#   [0.9174924776572971, 0.6117018183837261]],
#  [95211    B. Chardonnet
#   Name: Name, dtype: object,
#   215410,
#   [0.896074479788134, 0.6466464304526852]],
#  [90425    Josué Chiamulera
#   Name: Name, dtype: object,
#   230375,
#   [0.7898284391657977, 0.8525664392901507]],
#  [97773    S. Magkeev
#   Name: Name, dtype: object,
#   252235,
#   [0.9215461366116389, 0.586114005212676]],
#  [88770    20 S. Wuytens
#   Name: Name, dtype: object,
#   188416,
#   [0.8611322577239986, 0.7042019732630974]],
#  [91387    J. Teze
#   Name: Name, dtype: object,
#   245211,
#   [0.8895369781671852, 0.6462436611377363]],
#  [89591    P. McNair
#   Name: Name, dtype: object,
#   213697,
#   [0.8882174943181462, 0.6478925863868479]],
#  [93637    Tiago Djaló
#   Name: Name, dtype: object,
#   252339,
#   [0.8822764220525813, 0.6583870624547545]],
#  [97581    B. Šutalo
#   Name: Name, dtype: object,
#   255891,
#   [0.8992857128201416, 0.6240468538479913]],
#  [90863    Patric
#   Name: Name, dtype: object,
#   206098,
#   [0.8557663827865808, 0.7085543730797741]],
#  [97488    R. Dickie
#   Name: Name, dtype: object,
#   223159,
#   [0.9111959287280377, 0.5986558663809558]],
#  [93146    P. Dawidowicz
#   Name: Name, dtype: object,
#   213404,
#   [0.8673577216680581, 0.6847189014832588]],
#  [89681    André Ramalho
#   Name: Name, dtype: object,
#   210007,
#   [0.851175538957783, 0.7157022312760454]],
#  [94682    A. Toșca
#   Name: Name, dtype: object,
#   233512,
#   [0.9120264190892201, 0.5943986485689706]],
#  [90763    J. Tarkowski
#   Name: Name, dtype: object,
#   202695,
#   [0.7969795688224335, 0.82058102880542]],
#  [89378    M. Tisserand
#   Name: Name, dtype: object,
#   216247,
#   [0.866836655151627, 0.6814402846375092]],
#  [90563    E. Ndicka
#   Name: Name, dtype: object,
#   236403,
#   [0.8241582430399299, 0.7650709441905171]],
#  [90093    A. Rüdiger
#   Name: Name, dtype: object,
#   205452,
#   [0.7769339873596555, 0.8577861927528602]],
#  [97252    P. Retsos
#   Name: Name, dtype: object,
#   234986,
#   [0.8639972050434672, 0.6850373502334745]],
#  [94130    Marcão
#   Name: Name, dtype: object,
#   234426,
#   [0.837809537539505, 0.7330472651200769]],
#  [89593    E. Álvarez
#   Name: Name, dtype: object,
#   235844,
#   [0.8265824100941643, 0.7550844813368911]],
#  [91243    J. Veltman
#   Name: Name, dtype: object,
#   208004,
#   [0.8128739873073524, 0.7816072637812257]],
#  [88494    L. Hernández
#   Name: Name, dtype: object,
#   220814,
#   [0.7764945522344061, 0.8527883996094365]],
#  [98089    Unai Bilbao
#   Name: Name, dtype: object,
#   229360,
#   [0.9016903272719562, 0.6053687469034011]],
#  [94381    T. Chalobah
#   Name: Name, dtype: object,
#   230918,
#   [0.8720686970759275, 0.6636144459070359]],
#  [95733    D. Heintz
#   Name: Name, dtype: object,
#   206198,
#   [0.8663359983990638, 0.6744694842255278]],
#  [98076    L. Mühl
#   Name: Name, dtype: object,
#   233960,
#   [0.9233377272065483, 0.5614483545548756]],
#  [96672    B. White
#   Name: Name, dtype: object,
#   231936,
#   [0.8431974421792908, 0.7194045384116624]],
#  [97222    Domingos Duarte
#   Name: Name, dtype: object,
#   234835,
#   [0.8176666495525067, 0.7683280570588003]],
#  [88925    K. Ayhan
#   Name: Name, dtype: object,
#   207790,
#   [0.837310069917667, 0.7270141031979815]],
#  [88457    F. Schär
#   Name: Name, dtype: object,
#   210047,
#   [0.8280809059275197, 0.7449641063329868]],
#  [88009    M. Halstenberg
#   Name: Name, dtype: object,
#   210665,
#   [0.8258574834336176, 0.748148888134083]],
#  [99729    A. Seko
#   Name: Name, dtype: object,
#   247264,
#   [0.9366284122005556, 0.5287846872583627]],
#  [96703    Eric Curbelo
#   Name: Name, dtype: object,
#   237442,
#   [0.8965121943825567, 0.6077268748357797]],
#  [98475    A. Ismajli
#   Name: Name, dtype: object,
#   258782,
#   [0.8833612826609473, 0.6301947728010502]],
#  [89091    K. Laifis
#   Name: Name, dtype: object,
#   234774,
#   [0.8445284551466853, 0.7052610531664701]],
#  [87691    T. Delaney
#   Name: Name, dtype: object,
#   193283,
#   [0.7728293423457766, 0.8464252597356088]],
#  [101464    H. Araki
#   Name: Name, dtype: object,
#   247266,
#   [0.9193276076459517, 0.5565823148445843]],
#  [89985    K. Amian
#   Name: Name, dtype: object,
#   231235,
#   [0.8730495924399132, 0.6476452369068434]],
#  [97948    21 V. Regini
#   Name: Name, dtype: object,
#   193686,
#   [0.9104721985073456, 0.5723852456629202]],
#  [97802    R. Oxford
#   Name: Name, dtype: object,
#   225908,
#   [0.898703523770023, 0.5950957167882291]],
#  [96340    N. Süle
#   Name: Name, dtype: object,
#   212190,
#   [0.7794212412919473, 0.8290781710384999]],
#  [90738    Calero
#   Name: Name, dtype: object,
#   240289,
#   [0.8342373932715768, 0.7197902737203474]],
#  [92711    S. Gigot
#   Name: Name, dtype: object,
#   219581,
#   [0.8190743180708916, 0.7491120689897122]],
#  [96999    E. Tercero
#   Name: Name, dtype: object,
#   239822,
#   [0.9298046530848417, 0.52592104994439]],
#  [89354    L. Romo
#   Name: Name, dtype: object,
#   243015,
#   [0.8166830201083767, 0.7476127224890508]],
#  [95744    N. Araújo
#   Name: Name, dtype: object,
#   192041,
#   [0.8466714655949927, 0.685574727318826]],
#  [98978    S. Hatanaka
#   Name: Name, dtype: object,
#   245785,
#   [0.8888379925133943, 0.6022558307120219]],
#  [97056    D. Biraschi
#   Name: Name, dtype: object,
#   213938,
#   [0.8741483687158524, 0.6306810584122787]],
#  [89999    K. Zouma
#   Name: Name, dtype: object,
#   204311,
#   [0.793004584988501, 0.7887397899831933]],
#  [97522    Z. Vyner
#   Name: Name, dtype: object,
#   225072,
#   [0.923640408339974, 0.5293257035996217]],
#  [94535    S. Botman
#   Name: Name, dtype: object,
#   251809,
#   [0.8063621843190762, 0.7588183752737117]],
#  [98424    D. O'Shea
#   Name: Name, dtype: object,
#   235405,
#   [0.8913988946403094, 0.5905353839758243]],
#  [91942    P. Wiesinger
#   Name: Name, dtype: object,
#   239090,
#   [0.866633459349446, 0.6377151501179756]],
#  [95866    S. Schonlau
#   Name: Name, dtype: object,
#   214948,
#   [0.8625679324825664, 0.6447025332026735]],
#  [96363    W. Harding
#   Name: Name, dtype: object,
#   228225,
#   [0.9327636993207801, 0.5050305276721204]],
#  [99255    J. Hoogma
#   Name: Name, dtype: object,
#   231823,
#   [0.8837222055956045, 0.6016482785737177]],
#  [98780    M. Lovato
#   Name: Name, dtype: object,
#   258946,
#   [0.8890882206933552, 0.5909348721228819]],
#  [98185    M. Veljković
#   Name: Name, dtype: object,
#   221354,
#   [0.8541175394521902, 0.6589212289443209]],
#  [90198    D. Amartey
#   Name: Name, dtype: object,
#   212883,
#   [0.8239132350987882, 0.7180945975227719]],
#  [96706    Jorge Meré
#   Name: Name, dtype: object,
#   223033,
#   [0.8639180413103229, 0.6391096053625693]],
#  [92163    H. Magnússon
#   Name: Name, dtype: object,
#   208522,
#   [0.8479188047262748, 0.6704946062929641]],
#  [94676    J. O'Connell
#   Name: Name, dtype: object,
#   212300,
#   [0.8269887921407082, 0.7112844585150457]],
#  [96279    Murilo
#   Name: Name, dtype: object,
#   240115,
#   [0.8385917583031445, 0.6880527525495996]],
#  [88253    D. Zakaria
#   Name: Name, dtype: object,
#   229261,
#   [0.7753003302827896, 0.8127337973839864]],
#  [91739    J. Bijol
#   Name: Name, dtype: object,
#   244238,
#   [0.8651042289449485, 0.6352149756987826]],
#  [90223    16 Rodrigo Caio
#   Name: Name, dtype: object,
#   203324,
#   [0.824706109062589, 0.7137524005510313]],
#  [90028    A. Diallo
#   Name: Name, dtype: object,
#   225711,
#   [0.7867033401435102, 0.7879159669565277]],
#  [96951    Dani Calvo
#   Name: Name, dtype: object,
#   219180,
#   [0.8804429743792261, 0.6029666815752233]],
#  [89065    D. Hancko
#   Name: Name, dtype: object,
#   247103,
#   [0.8283867374899049, 0.704749839947408]],
#  [90407    M. Sarr
#   Name: Name, dtype: object,
#   235454,
#   [0.843037023161468, 0.6757958786414214]],
#  [99716    H. Moukoudi
#   Name: Name, dtype: object,
#   228732,
#   [0.8454861044145364, 0.6695943179187964]],
#  [93501    D. Sánchez
#   Name: Name, dtype: object,
#   220793,
#   [0.7880264907373619, 0.7761202675731613]],
#  [96940    José Amo
#   Name: Name, dtype: object,
#   231320,
#   [0.8947495160848343, 0.5643413733792739]],
#  [97737    A. Pieper
#   Name: Name, dtype: object,
#   246836,
#   [0.8419101680408131, 0.6676052612509024]],
#  [97803    H. Delcroix
#   Name: Name, dtype: object,
#   237440,
#   [0.8633339574312671, 0.6248942974014386]],
#  [91237    B. Godfrey
#   Name: Name, dtype: object,
#   225793,
#   [0.8212871111630896, 0.7069326474206875]],
#  [95413    B. Djimsiti
#   Name: Name, dtype: object,
#   208165,
#   [0.7836156594141617, 0.780734394684871]],
#  [93553    M. Niakhaté
#   Name: Name, dtype: object,
#   225859,
#   [0.8285715160110778, 0.6900286013601978]],
#  [93580    N. Cozza
#   Name: Name, dtype: object,
#   239136,
#   [0.8619378579678277, 0.623129513185792]],
#  [93473    J. Andersen
#   Name: Name, dtype: object,
#   224221,
#   [0.7895700603848945, 0.7648807536749692]],
#  [95138    I. Reyes
#   Name: Name, dtype: object,
#   252008,
#   [0.9143553754910821, 0.5180807116965204]],
#  [95238    J. Knight
#   Name: Name, dtype: object,
#   237213,
#   [0.8960649735451189, 0.5538561692797008]],
#  [94099    Robson Bambu
#   Name: Name, dtype: object,
#   256343,
#   [0.8763310379167892, 0.5923918772422936]],
#  [87912    R. Tapia
#   Name: Name, dtype: object,
#   220673,
#   [0.7726801371396135, 0.7943832716547223]],
#  [93397    Z. Vanheusden
#   Name: Name, dtype: object,
#   241103,
#   [0.8299080574594553, 0.6785548877677998]],
#  [87750    W. McKennie
#   Name: Name, dtype: object,
#   238744,
#   [0.7756299461464095, 0.785432163284952]],
#  [91480    Edgar Ié
#   Name: Name, dtype: object,
#   210520,
#   [0.8447393253095696, 0.6479989943560296]],
#  [100192    Vitao
#   Name: Name, dtype: object,
#   253400,
#   [0.8877267135610029, 0.5624117648029706]],
#  [98674    E. Roco
#   Name: Name, dtype: object,
#   212225,
#   [0.847747127039739, 0.6410948620549685]],
#  [100514    C. Hountondji
#   Name: Name, dtype: object,
#   219680,
#   [0.8554717020887536, 0.6257058921099082]],
#  [98135    H. Wahl
#   Name: Name, dtype: object,
#   230855,
#   [0.84205983145708, 0.6510358233783776]],
#  [97998    José León
#   Name: Name, dtype: object,
#   223120,
#   [0.9077350854696602, 0.5213383638353136]],
#  [94578    21 B. Kuscevic
#   Name: Name, dtype: object,
#   225236,
#   [0.852113730419841, 0.6304378326217288]],
#  [95587    21 Nélson Monte
#   Name: Name, dtype: object,
#   222598,
#   [0.8665865154444585, 0.6018241102131706]],
#  [93205    Javi Hernández
#   Name: Name, dtype: object,
#   244523,
#   [0.8805929839333455, 0.5737407590558483]],
#  [92358    Rúben Semedo
#   Name: Name, dtype: object,
#   216778,
#   [0.801726654662973, 0.7280544500425395]],
#  [98220    A. Hoffmann
#   Name: Name, dtype: object,
#   199779,
#   [0.8485440715976115, 0.6356337035445891]],
#  [96803    J. Lucumí
#   Name: Name, dtype: object,
#   231207,
#   [0.8246131324167869, 0.6824307165608939]],
#  [94531    B. Davies
#   Name: Name, dtype: object,
#   213017,
#   [0.846560279863154, 0.6389100943914512]],
#  [91835    F. Miguel
#   Name: Name, dtype: object,
#   226130,
#   [0.858321258058033, 0.6156784876866233]],
#  [93843    Tuta
#   Name: Name, dtype: object,
#   247182,
#   [0.8380066038485088, 0.6548882188323292]],
#  [91259    T. Mings
#   Name: Name, dtype: object,
#   212419,
#   [0.7766692100324384, 0.7756560706002931]],
#  [93070    J. Todibo
#   Name: Name, dtype: object,
#   245388,
#   [0.8095524321335074, 0.7100494495894997]],
#  [98040    J. Tah
#   Name: Name, dtype: object,
#   213331,
#   [0.7989755166005591, 0.7306848255075572]],
#  [99369    Unai Núñez
#   Name: Name, dtype: object,
#   240900,
#   [0.7800676836404089, 0.7668900714566539]],
#  [95622    M. Lode
#   Name: Name, dtype: object,
#   242160,
#   [0.8722572820496466, 0.5849621878753519]],
#  [96609    C. Mepham
#   Name: Name, dtype: object,
#   233201,
#   [0.8474107568521844, 0.6336481680314873]],
#  [99375    D. Hyam
#   Name: Name, dtype: object,
#   221281,
#   [0.8823826507844685, 0.5645744847746946]],
#  [89504    D. Bronn
#   Name: Name, dtype: object,
#   235565,
#   [0.8156683899549209, 0.6961761130363373]],
#  [93890    J. Gradit
#   Name: Name, dtype: object,
#   221284,
#   [0.8221798287635559, 0.6831504516537633]],
#  [95117    S. Cáceres
#   Name: Name, dtype: object,
#   253257,
#   [0.8434518524036003, 0.6408375959138944]],
#  [94397    D. Ćaleta-Car
#   Name: Name, dtype: object,
#   225263,
#   [0.775287905195537, 0.7745140673329486]],
#  [93233    Joaquín
#   Name: Name, dtype: object,
#   232132,
#   [0.8119380412450182, 0.7008457677595331]],
#  [99901    F. Kent
#   Name: Name, dtype: object,
#   220140,
#   [0.9078897179242444, 0.5109794986049481]],
#  [95250    M. Friedrich
#   Name: Name, dtype: object,
#   222493,
#   [0.7924912142142473, 0.7383439651635342]],
#  [93778    F. Medina
#   Name: Name, dtype: object,
#   236804,
#   [0.8213288138082788, 0.6801946137382788]],
#  [101201    M. Bauer
#   Name: Name, dtype: object,
#   245347,
#   [0.8948778213863452, 0.5332907730012311]],
#  [95464    I. Konaté
#   Name: Name, dtype: object,
#   237678,
#   [0.7789668524533255, 0.7608432809190532]],
#  [97885    21 V. Lystsov
#   Name: Name, dtype: object,
#   212341,
#   [0.9066565175018932, 0.5067002087898628]],
#  [91373    T. Kehrer
#   Name: Name, dtype: object,
#   226229,
#   [0.8087830698740481, 0.6993296850015224]],
#  [100361    Martínez
#   Name: Name, dtype: object,
#   234781,
#   [0.8656881782984795, 0.5870246189674954]],
#  [96683    Catena
#   Name: Name, dtype: object,
#   243976,
#   [0.8378825996054149, 0.6394040652658424]],
#  [92653    B. Perlaza
#   Name: Name, dtype: object,
#   226747,
#   [0.8338892164863687, 0.6471427347695046]],
#  [92701    T. Kolodziejczak
#   Name: Name, dtype: object,
#   190034,
#   [0.8268697850093857, 0.6599878139715908]],
#  [91701    C. Mbemba
#   Name: Name, dtype: object,
#   210897,
#   [0.7785024829325753, 0.7531912276233851]],
#  [97902    Rodri Tarín
#   Name: Name, dtype: object,
#   228828,
#   [0.8635734417047666, 0.5808776934045627]],
#  [92565    Bruno Fuchs
#   Name: Name, dtype: object,
#   258370,
#   [0.8208034189780612, 0.6637062732457544]],
#  [88377    I. Sangaré
#   Name: Name, dtype: object,
#   235173,
#   [0.7934255016832271, 0.7172567416954252]],
#  [93062    F. Tomori
#   Name: Name, dtype: object,
#   232756,
#   [0.7777966242901282, 0.7476706599485142]],
#  [99379    M. Blažič
#   Name: Name, dtype: object,
#   238945,
#   [0.850772394842401, 0.6026965644148126]],
#  [88220    R. Bensebaini
#   Name: Name, dtype: object,
#   224196,
#   [0.759973311299845, 0.7817978749788524]],
#  [99861    D. Aimar
#   Name: Name, dtype: object,
#   236267,
#   [0.8586942619570765, 0.5868254785811812]],
#  [100555    C. Carter-Vickers
#   Name: Name, dtype: object,
#   228174,
#   [0.8695280160036626, 0.5640181089982186]],
#  [99202    M. Wallace
#   Name: Name, dtype: object,
#   208024,
#   [0.8878984984378322, 0.5271847108375662]],
#  [93122    S. Ingason
#   Name: Name, dtype: object,
#   221422,
#   [0.820216117480348, 0.6585419896441114]],
#  [97275    P. Lienhart
#   Name: Name, dtype: object,
#   231366,
#   [0.7945196390787787, 0.7088028390570421]],
#  [97481    D. Burn
#   Name: Name, dtype: object,
#   198032,
#   [0.8028237402273928, 0.691359759862407]],
#  [97434    A. Sørensen
#   Name: Name, dtype: object,
#   221024,
#   [0.8612118460003273, 0.575675532812534]],
#  [89888    J. Gouweleeuw
#   Name: Name, dtype: object,
#   202201,
#   [0.7817558892657651, 0.7312766746184426]],
#  [98781    D. Baumgartner
#   Name: Name, dtype: object,
#   229818,
#   [0.8676734728488844, 0.5608162431174744]],
#  [96784    A. Webster
#   Name: Name, dtype: object,
#   207616,
#   [0.7944971093625285, 0.7049132366826272]],
#  [93333    J. Elez
#   Name: Name, dtype: object,
#   218341,
#   [0.8613341677280989, 0.5725478972751361]],
#  [100765    Jesiel
#   Name: Name, dtype: object,
#   230776,
#   [0.8578323560914495, 0.5791657165325891]],
#  [98462    Vítor Tormena
#   Name: Name, dtype: object,
#   246098,
#   [0.8037591229028874, 0.6855829022987886]],
#  [91935    C. Goldson
#   Name: Name, dtype: object,
#   199580,
#   [0.7761406107204553, 0.7372137523845002]],
#  [92396    A. Tuanzebe
#   Name: Name, dtype: object,
#   231485,
#   [0.7923608861884148, 0.7023401753088815]],
#  [95109    Vallejo
#   Name: Name, dtype: object,
#   225161,
#   [0.7776756063288747, 0.7300342901217719]],
#  [90102    L. Tousart
#   Name: Name, dtype: object,
#   227234,
#   [0.7729068733053347, 0.739442820949566]],
#  [99131    R. Burke
#   Name: Name, dtype: object,
#   221456,
#   [0.8763568748256204, 0.5332841329220771]],
#  [97840    F. Kunze
#   Name: Name, dtype: object,
#   251429,
#   [0.8350807582373532, 0.6132963321990207]],
#  [100061    L. Osaki
#   Name: Name, dtype: object,
#   245098,
#   [0.8839131940374363, 0.5166454628510597]],
#  [90142    A. Scholz
#   Name: Name, dtype: object,
#   212253,
#   [0.782802919186005, 0.7160891975159536]],
#  [94871    Róber
#   Name: Name, dtype: object,
#   213063,
#   [0.8140491498206543, 0.6543459835809632]],
#  [88965    Kaimo Lima
#   Name: Name, dtype: object,
#   230381,
#   [0.7865097968928707, 0.7066542031368503]],
#  [94850    A. Hughes
#   Name: Name, dtype: object,
#   214906,
#   [0.8501744831312354, 0.5785000816858009]],
#  [98606    M. McKenzie
#   Name: Name, dtype: object,
#   242195,
#   [0.8348351029871501, 0.6079021503378753]],
#  [97826    G. Rea
#   Name: Name, dtype: object,
#   215570,
#   [0.8364173688031414, 0.603184403645438]],
#  [98232    T. Adarabioyo
#   Name: Name, dtype: object,
#   222104,
#   [0.7986877355821562, 0.6768168128772735]],
#  [98370    J. van Aken
#   Name: Name, dtype: object,
#   216271,
#   [0.8449034794817178, 0.5844453865266034]],
#  [94971    O. Solet
#   Name: Name, dtype: object,
#   242238,
#   [0.8238235796945533, 0.6230900241072146]],
#  [94908    E. Cömert
#   Name: Name, dtype: object,
#   233885,
#   [0.8431216659028772, 0.5847369568188704]],
#  [99841    Insua
#   Name: Name, dtype: object,
#   207431,
#   [0.8269659287842968, 0.6161672896984443]],
#  [99309    21 G. Gül
#   Name: Name, dtype: object,
#   229173,
#   [0.9091305296340767, 0.4533983898710947]],
#  [95126    A. Walkes
#   Name: Name, dtype: object,
#   232252,
#   [0.8667326609351005, 0.5350001834509474]],
#  [96243    M. Kilman
#   Name: Name, dtype: object,
#   245336,
#   [0.8269243080648996, 0.6115937383453592]],
#  [97487    J. Komar
#   Name: Name, dtype: object,
#   222428,
#   [0.7973813096969582, 0.6681676562666756]],
#  [95206    K. Itakura
#   Name: Name, dtype: object,
#   233152,
#   [0.8050983021673844, 0.652797196973575]],
#  [95898    A. Maxsø
#   Name: Name, dtype: object,
#   212287,
#   [0.7963908780304689, 0.6689964881343922]],
#  [90313    L. Fomba
#   Name: Name, dtype: object,
#   236721,
#   [0.8086530897505427, 0.6414024770811269]],
#  [94106    Aritz Elustondo
#   Name: Name, dtype: object,
#   226221,
#   [0.7445782702535505, 0.7678021412244505]],
#  [98784    R. Le Normand
#   Name: Name, dtype: object,
#   233486,
#   [0.7770776768298223, 0.7035145412244983]],
#  [96175    F. Ceccherini
#   Name: Name, dtype: object,
#   210964,
#   [0.8161275489229437, 0.6247665252818695]],
#  [97671    E. Martínez
#   Name: Name, dtype: object,
#   253278,
#   [0.8557459863468138, 0.5465483149307695]],
#  [97436    Bremer
#   Name: Name, dtype: object,
#   239580,
#   [0.7794966973912203, 0.6939149946931205]],
#  [98376    R. Knoche
#   Name: Name, dtype: object,
#   203030,
#   [0.7689382577898374, 0.712981995835351]],
#  [100067    R. Takao
#   Name: Name, dtype: object,
#   248810,
#   [0.8872057065081728, 0.4786069840966565]],
#  [91024    A. Djiku
#   Name: Name, dtype: object,
#   212219,
#   [0.7737792414617344, 0.7012924107520763]],
#  [94799    M. Agu
#   Name: Name, dtype: object,
#   209984,
#   [0.8228519400281163, 0.6031075515904176]],
#  [99218    L. Dietz
#   Name: Name, dtype: object,
#   241995,
#   [0.8660913256885737, 0.516028165808826]],
#  [93661    Lucas Veríssimo
#   Name: Name, dtype: object,
#   235688,
#   [0.7395497687763738, 0.7651309022792725]],
#  [95056    N. Milenković
#   Name: Name, dtype: object,
#   238095,
#   [0.7738621682953399, 0.6968469496100105]],
#  [95365    L. Balerdi
#   Name: Name, dtype: object,
#   242835,
#   [0.7752453650914944, 0.6933861677249644]],
#  [99763    L. Kilian
#   Name: Name, dtype: object,
#   248878,
#   [0.8315572947038982, 0.5822815919837163]],
#  [95442    16 Pedro Geromel
#   Name: Name, dtype: object,
#   170802,
#   [0.7550451169738093, 0.7300529311040104]],
#  [99586    T. Sibbick
#   Name: Name, dtype: object,
#   236244,
#   [0.8857891173654605, 0.4700869183571714]],
#  [87895    T. Holeš
#   Name: Name, dtype: object,
#   251116,
#   [0.7341819629108142, 0.7671395546544246]],
#  [95711    Duirval Diniz
#   Name: Name, dtype: object,
#   230401,
#   [0.7807099629584349, 0.6746977952172295]],
#  [99865    F. Romagna
#   Name: Name, dtype: object,
#   226108,
#   [0.8295755627179667, 0.5780278749615969]],
#  [97295    Thiago Martins
#   Name: Name, dtype: object,
#   233790,
#   [0.8431578432322296, 0.5503853772540355]],
#  [96845    L. Giannetti
#   Name: Name, dtype: object,
#   215147,
#   [0.7971113622378414, 0.6406937784405534]],
#  [92497    P. Hatzidiakos
#   Name: Name, dtype: object,
#   229150,
#   [0.7906686846986263, 0.6528974091972236]],
#  [98402    Pablo Marí
#   Name: Name, dtype: object,
#   206654,
#   [0.7530279146051725, 0.7253720541718777]],
#  [97450    M. Fofana
#   Name: Name, dtype: object,
#   235849,
#   [0.8173627547819774, 0.5965797550190373]],
#  [99419    M. Sørensen
#   Name: Name, dtype: object,
#   234472,
#   [0.8305763266127905, 0.5691626809383614]],
#  [95759    I. Cissé
#   Name: Name, dtype: object,
#   225532,
#   [0.8703912957038114, 0.49016703818065127]],
#  [94722    K. Hause
#   Name: Name, dtype: object,
#   210635,
#   [0.7848792088688237, 0.6579685531650726]],
#  [95686    Luan Peres
#   Name: Name, dtype: object,
#   234791,
#   [0.8038618162859433, 0.6202108527645485]],
#  [99704    E. Segura
#   Name: Name, dtype: object,
#   237245,
#   [0.8151798896203586, 0.5953376070527561]],
#  [99999    Ignasi Miquel
#   Name: Name, dtype: object,
#   196935,
#   [0.8012378755623747, 0.6227059544216282]],
#  [96711    I. Diveev
#   Name: Name, dtype: object,
#   245703,
#   [0.7747669727637165, 0.6739197295790825]],
#  [99169    K. Guessoum
#   Name: Name, dtype: object,
#   241506,
#   [0.8525658165636985, 0.5202842769199574]],
#  [95367    D. Granli
#   Name: Name, dtype: object,
#   222472,
#   [0.8587823758626135, 0.5070147529286003]],
#  [93795    M. Kamiński
#   Name: Name, dtype: object,
#   199761,
#   [0.8229362670308978, 0.5763907380809138]],
#  [95699    J. Brooks
#   Name: Name, dtype: object,
#   204082,
#   [0.7209628872507877, 0.7770019074231577]],
#  [100708    N. Pérez
#   Name: Name, dtype: object,
#   244206,
#   [0.7702625676337603, 0.679316087702926]],
#  [91130    21 M. Musacchio
#   Name: Name, dtype: object,
#   186547,
#   [0.741176598563597, 0.7350852915713906]],
#  [95929    G. Shoji
#   Name: Name, dtype: object,
#   232869,
#   [0.7922941896147554, 0.6337344476388128]],
#  [99401    J. Sánchez Purata
#   Name: Name, dtype: object,
#   244448,
#   [0.8935686299718557, 0.43328833661778493]],
#  [96538    S. O'Neill
#   Name: Name, dtype: object,
#   211581,
#   [0.8596817993400123, 0.4999290773487238]],
#  [92566    C. Montes
#   Name: Name, dtype: object,
#   229980,
#   [0.7570887864810201, 0.70227678566526]],
#  [98623    Tomás Ribeiro
#   Name: Name, dtype: object,
#   253378,
#   [0.8095034622655959, 0.5980998041736738]],
#  [96323    J. Rasmussen
#   Name: Name, dtype: object,
#   234827,
#   [0.7716843042220735, 0.67257540702576]],
#  [97118    Pablo Iñiguez
#   Name: Name, dtype: object,
#   206546,
#   [0.8284107187874207, 0.5594566219646518]],
#  [90721    18 Mauro
#   Name: Name, dtype: object,
#   203434,
#   [0.7576544057328304, 0.6943611693959313]],
#  [98882    T. Baumgartl
#   Name: Name, dtype: object,
#   223641,
#   [0.7989408889670252, 0.6126379010765047]],
#  [90875    Bernardo
#   Name: Name, dtype: object,
#   232805,
#   [0.7950705555720703, 0.6192598943314047]],
#  [95119    M. Leitsch
#   Name: Name, dtype: object,
#   234843,
#   [0.8041083929182863, 0.601406634173414]],
#  [96037    P. Struijk
#   Name: Name, dtype: object,
#   239360,
#   [0.757767291346518, 0.6912104187058999]],
#  [97070    V. Alvarado
#   Name: Name, dtype: object,
#   209758,
#   [0.8316197720201838, 0.5453016068391413]],
#  [96302    I. Diop
#   Name: Name, dtype: object,
#   231633,
#   [0.7503709907495374, 0.7043488371169743]],
#  [99847    Rodrigo Becão
#   Name: Name, dtype: object,
#   238621,
#   [0.7615686816462156, 0.6801384013420293]],
#  [93318    C. Hérelle
#   Name: Name, dtype: object,
#   208449,
#   [0.7525063107791713, 0.69517252663091]],
#  [99667    A. Miron
#   Name: Name, dtype: object,
#   248002,
#   [0.8550465685001999, 0.49258734033133544]],
#  [92538    B. Schmitz
#   Name: Name, dtype: object,
#   222692,
#   [0.8187983588917769, 0.563203095876506]],
#  [89937    F. Guilbert
#   Name: Name, dtype: object,
#   227222,
#   [0.7528457529220336, 0.6932951083151399]],
#  [99507    F. Russo
#   Name: Name, dtype: object,
#   245156,
#   [0.8211356180352218, 0.5573023778261322]],
#  [101135    R. Nartey
#   Name: Name, dtype: object,
#   238187,
#   [0.8981153792291782, 0.4026658914519751]],
#  [94910    R. Khedira
#   Name: Name, dtype: object,
#   211999,
#   [0.7497540541693056, 0.6948126039546539]],
#  [99051    M. Robinson
#   Name: Name, dtype: object,
#   237255,
#   [0.8209277429159205, 0.554141706583565]],
#  [99107    Berrocal
#   Name: Name, dtype: object,
#   240859,
#   [0.8392586166522589, 0.516834240679405]],
#  [87902    Melvin Parrela
#   Name: Name, dtype: object,
#   230251,
#   [0.6916507716370195, 0.8071791403939489]],
#  [99299    G. Maripán
#   Name: Name, dtype: object,
#   219145,
#   [0.7302902591873794, 0.7307025265009922]],
#  [91239    E. Sviatchenko
#   Name: Name, dtype: object,
#   199745,
#   [0.7506097013938804, 0.690188121759611]],
#  [94781    A. Pelmard
#   Name: Name, dtype: object,
#   247412,
#   [0.8002772861834946, 0.5920794495071585]],
#  [98133    Relu
#   Name: Name, dtype: object,
#   248070,
#   [0.8630000716096021, 0.46658491890280124]],
#  [92679    J. Okumu
#   Name: Name, dtype: object,
#   253073,
#   [0.7832021427405732, 0.6232834679046902]],
#  [90171    M. Corozo
#   Name: Name, dtype: object,
#   253321,
#   [0.7933306089355584, 0.6030949288010252]],
#  [98514    F. Gattoni
#   Name: Name, dtype: object,
#   241930,
#   [0.8096728046406616, 0.5691544721774635]],
#  [93987    Bustinza
#   Name: Name, dtype: object,
#   224869,
#   [0.7416265692202602, 0.7031270471820449]],
#  [99207    I. Ogbu
#   Name: Name, dtype: object,
#   242635,
#   [0.8767624066458745, 0.434804209669868]],
#  [95434    E. Pinnock
#   Name: Name, dtype: object,
#   238717,
#   [0.7642671053421229, 0.6563312717766727]],
#  [88259    Palhinha
#   Name: Name, dtype: object,
#   229391,
#   [0.6587321653180835, 0.8628073581558429]],
#  [95648    A. Izzo
#   Name: Name, dtype: object,
#   216145,
#   [0.7074399841439409, 0.7628613594628124]],
#  [99872    K. Schlotterbeck
#   Name: Name, dtype: object,
#   244068,
#   [0.7836624219207361, 0.6121278019045132]],
#  [98053    W. Faes
#   Name: Name, dtype: object,
#   235036,
#   [0.7590335384975667, 0.6605110416391102]],
#  [96029    D. Michalski
#   Name: Name, dtype: object,
#   251764,
#   [0.8766711550787802, 0.4280801902007765]],
#  [95702    P. Chato
#   Name: Name, dtype: object,
#   244489,
#   [0.8500527562890378, 0.4774942535865896]],
#  [98552    A. Hack
#   Name: Name, dtype: object,
#   231111,
#   [0.7730300927321514, 0.6269026672367413]],
#  [92887    Diego Llorente
#   Name: Name, dtype: object,
#   212602,
#   [0.7010287773217448, 0.7685506630871765]],
#  [93684    A. Andrade
#   Name: Name, dtype: object,
#   252873,
#   [0.7936417621593661, 0.585041294638891]],
#  [98775    N. Schlotterbeck
#   Name: Name, dtype: object,
#   247819,
#   [0.7800694644311579, 0.6108504241315807]],
#  [92807    V. Nelsson
#   Name: Name, dtype: object,
#   235658,
#   [0.7662045880268264, 0.637250760289854]],
#  [92181    J. Galván
#   Name: Name, dtype: object,
#   226616,
#   [0.7607861293377658, 0.6413556717741651]],
#  [98880    21 S. Mambo
#   Name: Name, dtype: object,
#   251385,
#   [0.8481119918020139, 0.46749394759337687]],
#  [93828    M. Nastasić
#   Name: Name, dtype: object,
#   205362,
#   [0.7367634493512901, 0.6856771061102122]],
#  [99322    J. Bednarek
#   Name: Name, dtype: object,
#   220570,
#   [0.7333153425254294, 0.692188593505489]],
#  [91461    C. Söyüncü
#   Name: Name, dtype: object,
#   232119,
#   [0.6794438081008911, 0.7982283549298194]],
#  [101339    A. Doldán
#   Name: Name, dtype: object,
#   255240,
#   [0.8320926344707136, 0.495693761042381]],
#  [98405    W. Riveros
#   Name: Name, dtype: object,
#   240138,
#   [0.7939059669659759, 0.5670583970778331]],
#  [99567    G. Hall
#   Name: Name, dtype: object,
#   204761,
#   [0.8140632721437687, 0.5268800060650338]],
#  [101195    T. Borevković
#   Name: Name, dtype: object,
#   244377,
#   [0.7890947513908529, 0.5758227516967539]],
#  [90365    G. Silva
#   Name: Name, dtype: object,
#   220702,
#   [0.7629387362188825, 0.6268702853535804]],
#  [98309    Y. Kimoto
#   Name: Name, dtype: object,
#   237789,
#   [0.8179501215144898, 0.5178246075238273]],
#  [98763    D. Fry
#   Name: Name, dtype: object,
#   229682,
#   [0.774037274600364, 0.6042909197696791]],
#  [88092    M. Hinteregger
#   Name: Name, dtype: object,
#   201922,
#   [0.6695060901630024, 0.8077640179861657]],
#  [100355    D. Arslanagic
#   Name: Name, dtype: object,
#   204352,
#   [0.7549048378877808, 0.6391667514854825]],
#  [99455    Clemente
#   Name: Name, dtype: object,
#   244394,
#   [0.7909336182637944, 0.5672150670721177]],
#  [101321    H. Kessler
#   Name: Name, dtype: object,
#   255110,
#   [0.809202222471839, 0.5294255548717841]],
#  [89003    E. Dier
#   Name: Name, dtype: object,
#   202335,
#   [0.6729486135464057, 0.7982186270370945]],
#  [101076    Rodrigo Ely
#   Name: Name, dtype: object,
#   202445,
#   [0.752210089746507, 0.6405679757363728]],
#  [93822    M. Friedl
#   Name: Name, dtype: object,
#   237595,
#   [0.7412901537841605, 0.659205964780458]],
#  [99584    S. Coulibaly
#   Name: Name, dtype: object,
#   231872,
#   [0.8426189321662221, 0.45795367847144614]],
#  [99821    D. O'Shaughnessy
#   Name: Name, dtype: object,
#   221486,
#   [0.8254271237154748, 0.49007694864421086]],
#  [100540    M. Miazga
#   Name: Name, dtype: object,
#   215565,
#   [0.748366324314162, 0.6419902437927921]],
#  [92123    E. Balanta
#   Name: Name, dtype: object,
#   213899,
#   [0.7190740656025714, 0.6990643677499919]],
#  [96305    D. Doekhi
#   Name: Name, dtype: object,
#   232658,
#   [0.7595470169683944, 0.6184562227434909]],
#  [97455    M. Dyrestam
#   Name: Name, dtype: object,
#   191157,
#   [0.8282160906451073, 0.4826854154368289]],
#  [99512    I. Höhn
#   Name: Name, dtype: object,
#   205588,
#   [0.7955382909029024, 0.5460927645308288]],
#  [94113    M. Heyer
#   Name: Name, dtype: object,
#   238593,
#   [0.7617204716700979, 0.6118919751153152]],
#  [101512    A. MacDonald
#   Name: Name, dtype: object,
#   205655,
#   [0.8296441032379044, 0.47648147344458647]],
#  [100100    Queirós
#   Name: Name, dtype: object,
#   234576,
#   [0.7852680275917097, 0.5634115202297246]],
#  [96160    J. Riedel
#   Name: Name, dtype: object,
#   201815,
#   [0.7989998793827007, 0.5342431852728607]],
#  [96341    T. Hübers
#   Name: Name, dtype: object,
#   234727,
#   [0.7705205839318126, 0.5865837881644361]],
#  [99733    T. Iwanami
#   Name: Name, dtype: object,
#   232894,
#   [0.7714848192312604, 0.5815385447025061]],
#  [95157    Z. Al Sahafi
#   Name: Name, dtype: object,
#   231821,
#   [0.8050413297646325, 0.5151860481368283]],
#  [91283    M. Martínez
#   Name: Name, dtype: object,
#   226798,
#   [0.7304678293060909, 0.6597937438679312]],
#  [98558    G. Magnani
#   Name: Name, dtype: object,
#   242392,
#   [0.7468219811627734, 0.6258184716396177]],
#  [94238    Y. Mina
#   Name: Name, dtype: object,
#   220523,
#   [0.6715045966581968, 0.7735290756708818]],
#  [99714    H. Marcelin
#   Name: Name, dtype: object,
#   242603,
#   [0.7761456222913216, 0.5668820013499276]],
#  [97768    Adri Castellano
#   Name: Name, dtype: object,
#   231123,
#   [0.8056459526215144, 0.5083547512780106]],
#  [97013    B. Engels
#   Name: Name, dtype: object,
#   210828,
#   [0.7079748469860307, 0.6981672048439209]],
#  [96123    B. Tuiloma
#   Name: Name, dtype: object,
#   220886,
#   [0.780938187936493, 0.5487317301934476]],
#  [96897    Lluís López
#   Name: Name, dtype: object,
#   234032,
#   [0.7522952322091406, 0.6045795891377048]],
#  [100537    A. Shabanov
#   Name: Name, dtype: object,
#   244381,
#   [0.7576392958534054, 0.5920923501848682]],
#  [99645    P. Ziereis
#   Name: Name, dtype: object,
#   209196,
#   [0.7778964514904801, 0.5504322247833858]],
#  [92313    H. Ishihara
#   Name: Name, dtype: object,
#   242568,
#   [0.8106530706990606, 0.48501658620453064]],
#  [99042    J. Lawrence
#   Name: Name, dtype: object,
#   245768,
#   [0.7563421933047957, 0.590860513648069]],
#  [95559    D. Williams
#   Name: Name, dtype: object,
#   203398,
#   [0.7740092186428753, 0.5540006108231407]],
#  [97974    G. Guiffrey
#   Name: Name, dtype: object,
#   244851,
#   [0.7920163181849768, 0.5180276627146078]],
#  [94177    V. Vevatne
#   Name: Name, dtype: object,
#   214650,
#   [0.7858511064824877, 0.5289442823119443]],
#  [94694    A. Obispo
#   Name: Name, dtype: object,
#   241171,
#   [0.7417609046245167, 0.6159132233309736]],
#  [99660    Juande
#   Name: Name, dtype: object,
#   255158,
#   [0.7827392360265394, 0.5344176975745186]],
#  [99008    Frederico Venâncio
#   Name: Name, dtype: object,
#   211107,
#   [0.7323780254576499, 0.6336408484396294]],
#  [93147    M. Matvienko
#   Name: Name, dtype: object,
#   229528,
#   [0.7230211924063502, 0.6501667666495102]],
#  [94619    D. Van den Buijs
#   Name: Name, dtype: object,
#   225531,
#   [0.7973264261375613, 0.5032658091050228]],
#  [100525    L. Perrin
#   Name: Name, dtype: object,
#   243449,
#   [0.7703597998159945, 0.555228655359935]],
#  [98042    M. Hołownia
#   Name: Name, dtype: object,
#   245129,
#   [0.8284350816248395, 0.44009718217474697]],
#  [99153    R. Marchizza
#   Name: Name, dtype: object,
#   236308,
#   [0.7950101098244324, 0.5059190442345175]],
#  [94491    L. Takács
#   Name: Name, dtype: object,
#   253695,
#   [0.7297448606864583, 0.6344827059010905]],
#  [94641    T. Kalas
#   Name: Name, dtype: object,
#   201122,
#   [0.7395048460693904, 0.6139488738767382]],
#  [94510    A. Frías
#   Name: Name, dtype: object,
#   251886,
#   [0.7058846398915156, 0.6792001892421338]],
#  [100940    S. Hausner
#   Name: Name, dtype: object,
#   237930,
#   [0.7987390153939506, 0.4939809023775056]],
#  [96727    Fábio Cardoso
#   Name: Name, dtype: object,
#   213917,
#   [0.7008964465357149, 0.6858569930125397]],
#  [95900    J. Duverne
#   Name: Name, dtype: object,
#   229705,
#   [0.7388679196718154, 0.610033037413913]],
#  [98371    A. Chindriș
#   Name: Name, dtype: object,
#   248004,
#   [0.7844142107993418, 0.5174628933773362]],
#  [98825    C. Starfelt
#   Name: Name, dtype: object,
#   220821,
#   [0.7543885673943428, 0.5747221386474528]],
#  [98100    Willyan
#   Name: Name, dtype: object,
#   251901,
#   [0.7196141784744745, 0.6412719568757413]],
#  [94793    D. Grétarsson
#   Name: Name, dtype: object,
#   226510,
#   [0.8007306865131233, 0.4811448521679029]],
#  [95572    A. Ahmedhodžić
#   Name: Name, dtype: object,
#   236524,
#   [0.7128871753749157, 0.6523387295177628]],
#  [93735    P. Ciss
#   Name: Name, dtype: object,
#   250858,
#   [0.7306343135053338, 0.6160520129478892]],
#  [101755    21 F. Vicari
#   Name: Name, dtype: object,
#   215433,
#   [0.7428103008143874, 0.5905802464325547]],
#  [100128    J. Laporte
#   Name: Name, dtype: object,
#   228290,
#   [0.7557427819324095, 0.563838610053119]],
#  [96708    J. Föhrenbach
#   Name: Name, dtype: object,
#   229277,
#   [0.8006728491988369, 0.4751269017052875]],
#  [98452    21 D. Plechatý
#   Name: Name, dtype: object,
#   247345,
#   [0.7585897178299428, 0.5578767932282688]],
#  [97726    M. Salisu
#   Name: Name, dtype: object,
#   244915,
#   [0.7032168371692621, 0.666233561906237]],
#  [100054    A. Nukan
#   Name: Name, dtype: object,
#   200065,
#   [0.7438581967895895, 0.584751475706679]],
#  [90561    Y. Barbet
#   Name: Name, dtype: object,
#   224189,
#   [0.726860129892723, 0.6162041806250428]],
#  [100850    T. Inukai
#   Name: Name, dtype: object,
#   237754,
#   [0.766245064181506, 0.538411828663463]],
#  [94304    J. Rodríguez
#   Name: Name, dtype: object,
#   244950,
#   [0.6896581644310511, 0.6804027146672683]],
#  [100320    N. Paz
#   Name: Name, dtype: object,
#   219451,
#   [0.7728296484277966, 0.5150767515264689]],
#  [97030    S. Lewkot
#   Name: Name, dtype: object,
#   258902,
#   [0.8181449805932833, 0.4230650840148604]],
#  [99084    A. Karazor
#   Name: Name, dtype: object,
#   239096,
#   [0.7225885583688915, 0.6113971502878004]],
#  [92126    Antônio Chiamuloira
#   Name: Name, dtype: object,
#   230212,
#   [0.6504603320459951, 0.7513534439498815]],
#  [98091    Manu Hernando
#   Name: Name, dtype: object,
#   243155,
#   [0.7993100000830666, 0.45703640042332516]],
#  [100824    J. Worrall
#   Name: Name, dtype: object,
#   230708,
#   [0.7389599178813163, 0.575899385334458]],
#  [99930    N. Ramírez
#   Name: Name, dtype: object,
#   232189,
#   [0.7545331464927731, 0.5428878788385021]],
#  [98344    21 K. Enghardt
#   Name: Name, dtype: object,
#   234502,
#   [0.7727304986307715, 0.5037477455350616]],
#  [100403    T. Sanuç
#   Name: Name, dtype: object,
#   242919,
#   [0.7921380357744102, 0.46412313851287196]],
#  [99191    P. Bauer
#   Name: Name, dtype: object,
#   204496,
#   [0.7137083140773425, 0.618285084864751]],
#  [101239    D. Ballard
#   Name: Name, dtype: object,
#   243908,
#   [0.753282606003773, 0.5399808268602936]],
#  [98703    21 N. Dieng
#   Name: Name, dtype: object,
#   244155,
#   [0.7944533522157782, 0.45857864462946607]],
#  [95903    Ramalho
#   Name: Name, dtype: object,
#   189576,
#   [0.7222694616839869, 0.5993147231362114]],
#  [98639    21 E. Velázquez
#   Name: Name, dtype: object,
#   225299,
#   [0.7127518693480621, 0.6176264612832096]],
#  [91964    F. Ricca
#   Name: Name, dtype: object,
#   232437,
#   [0.7067365030376346, 0.6291546508207199]],
#  [98299    A. Jones
#   Name: Name, dtype: object,
#   236315,
#   [0.7729579393972724, 0.4976222907400785]],
#  [97645    I. Kutepov
#   Name: Name, dtype: object,
#   210468,
#   [0.6977334221728293, 0.6452795781713918]],
#  [99328    M. Cacutalua
#   Name: Name, dtype: object,
#   220878,
#   [0.7779772593410934, 0.4861765412523149]],
#  [98867    M. Sagnan
#   Name: Name, dtype: object,
#   241708,
#   [0.6914248508396634, 0.6561113427303951]],
#  [96726    T. St. Jago
#   Name: Name, dtype: object,
#   253376,
#   [0.7297753824910816, 0.5795919240967243]],
#  [89236    Núrio Fortuna
#   Name: Name, dtype: object,
#   221994,
#   [0.7109404629276745, 0.6163720853311145]],
#  [96599    A. Çalık
#   Name: Name, dtype: object,
#   223046,
#   [0.7363513154959219, 0.566101947994097]],
#  [101388    D. Reyes
#   Name: Name, dtype: object,
#   192012,
#   [0.7385559710242529, 0.5589870513363024]],
#  [96580    Ibañez
#   Name: Name, dtype: object,
#   247257,
#   [0.6687891237474315, 0.6913921288027273]],
#  [101275    H. Ekdal
#   Name: Name, dtype: object,
#   252316,
#   [0.7896977500571658, 0.4515373883605306]],
#  [93727    N. Breitenbruch
#   Name: Name, dtype: object,
#   224049,
#   [0.7318080748168102, 0.5645843505106073]],
#  [95754    Pol García
#   Name: Name, dtype: object,
#   211323,
#   [0.7162053673914147, 0.5930938438805305]],
#  [102132    M. Bani
#   Name: Name, dtype: object,
#   224378,
#   [0.7188519042785895, 0.5873885897643089]],
#  [97780    21 F. Sørensen
#   Name: Name, dtype: object,
#   201342,
#   [0.6971644919927582, 0.6290527707105912]],
#  [98620    B. Galloway
#   Name: Name, dtype: object,
#   209852,
#   [0.7870582930456715, 0.45139486916972926]],
#  [99358    J. Cooper
#   Name: Name, dtype: object,
#   216481,
#   [0.7111677666058035, 0.6002146072008575]],
#  [99188    J. Simpson
#   Name: Name, dtype: object,
#   230882,
#   [0.7481987147383428, 0.5260177545597251]],
#  [101218    N. Ueda
#   Name: Name, dtype: object,
#   232870,
#   [0.7369538692480748, 0.5470822860070391]],
#  [93182    S. Bornauw
#   Name: Name, dtype: object,
#   242663,
#   [0.6502434412047688, 0.7159384641185856]],
#  [98018    J. Vollert
#   Name: Name, dtype: object,
#   239668,
#   [0.7961509674430582, 0.42791420168337696]],
#  [95588    J. Gorenc Stanković
#   Name: Name, dtype: object,
#   226129,
#   [0.6804726413698796, 0.6550551419448424]],
#  [97915    V. Trummer
#   Name: Name, dtype: object,
#   253145,
#   [0.7923540531170854, 0.43405346685730417]],
#  [96881    21 A. Wisdom
#   Name: Name, dtype: object,
#   201908,
#   [0.7233581075628621, 0.569813006528351]],
#  [102152    21 Javi Jiménez
#   Name: Name, dtype: object,
#   237032,
#   [0.7711102872401653, 0.4732677631488463]],
#  [100202    G. Miura
#   Name: Name, dtype: object,
#   237429,
#   [0.7218846779997896, 0.5702070172384688]],
#  [97302    20 Tiago Ferreira
#   Name: Name, dtype: object,
#   205845,
#   [0.7526193794986755, 0.5090472958231459]],
#  [100125    J. Dunne
#   Name: Name, dtype: object,
#   235156,
#   [0.7232491419776181, 0.5668591091826546]],
#  [97952    D. Abels
#   Name: Name, dtype: object,
#   250805,
#   [0.7312526117920797, 0.5493807796767388]],
#  [95732    O. Haddadi
#   Name: Name, dtype: object,
#   237548,
#   [0.7269623300919593, 0.5571089682813274]],
#  [95736    M. Helik
#   Name: Name, dtype: object,
#   219293,
#   [0.7006057593809738, 0.6087579178162417]],
#  [98451    M. Kumbulla
#   Name: Name, dtype: object,
#   245426,
#   [0.667483333438432, 0.6740147621310653]],
#  [98291    A. Buongiorno
#   Name: Name, dtype: object,
#   243241,
#   [0.784254299952188, 0.4417020048015148]],
#  [90912    M. Pouraliganji
#   Name: Name, dtype: object,
#   227921,
#   [0.7069894719705624, 0.5939503205659877]],
#  [95180    M. Villanueva
#   Name: Name, dtype: object,
#   233329,
#   [0.7024006499176566, 0.6019329257271226]],
# ...
#   215466,
#   [0.4951773644320726, 0.6675957678716967]],
#  [98939    Rúben Ramos
#   Name: Name, dtype: object,
#   252080,
#   [0.5993180216778063, 0.46184123552086]],
#  [96932    Lourival Dinisco
#   Name: Name, dtype: object,
#   230415,
#   [0.5481361429402454, 0.5627822643740258]],
#  [93316    M. Udol
#   Name: Name, dtype: object,
#   229236,
#   [0.5220441068199242, 0.6134618355106227]],
#  [99805    L. Kwadwo
#   Name: Name, dtype: object,
#   251400,
#   [0.6330040387712461, 0.39153967142945195]],
#  [99397    E. Ávalos
#   Name: Name, dtype: object,
#   261813,
#   [0.655046402223821, 0.3476882702183508]],
#  [97970    L. Maloney
#   Name: Name, dtype: object,
#   240669,
#   [0.6077025526864157, 0.44024850349120703]],
#  [94155    M. Loum
#   Name: Name, dtype: object,
#   245021,
#   [0.49808465363598586, 0.6558696887467572]],
#  [100385    P. Wiśniewski
#   Name: Name, dtype: object,
#   243185,
#   [0.587924601378939, 0.4785498709209666]],
#  [97856    R. McKenzie
#   Name: Name, dtype: object,
#   231411,
#   [0.6019862492601749, 0.4502932005085445]],
#  [93188    21 Fabiano
#   Name: Name, dtype: object,
#   221403,
#   [0.5355177924780513, 0.5803288707178609]],
#  [90632    San Emeterio
#   Name: Name, dtype: object,
#   223654,
#   [0.5049461218686048, 0.6404934836689039]],
#  [99101    T. Baack
#   Name: Name, dtype: object,
#   229184,
#   [0.6261104057938073, 0.40117662376888613]],
#  [99998    21 C. Stokes
#   Name: Name, dtype: object,
#   227880,
#   [0.6141047440236351, 0.4247023657652603]],
#  [101290    E. Haugan
#   Name: Name, dtype: object,
#   223253,
#   [0.6088074910615064, 0.43291834550393254]],
#  [100695    21 Paolito Serra
#   Name: Name, dtype: object,
#   230393,
#   [0.49971050517787313, 0.648131582514755]],
#  [99814    W. Biedrzycki
#   Name: Name, dtype: object,
#   244254,
#   [0.6204113560451028, 0.40955256694814446]],
#  [100820    Bruno Wilson
#   Name: Name, dtype: object,
#   236924,
#   [0.5443461570203633, 0.5589097710762625]],
#  [98271    21 F. Balbuena
#   Name: Name, dtype: object,
#   228229,
#   [0.47624159084227186, 0.6910127247346812]],
#  [99830    D. Bain
#   Name: Name, dtype: object,
#   208019,
#   [0.5231293283093861, 0.5983381951766736]],
#  [100641    J. Šutalo
#   Name: Name, dtype: object,
#   256325,
#   [0.5625244163311941, 0.5189269398553903]],
#  [101340    21 K. da Graca
#   Name: Name, dtype: object,
#   225770,
#   [0.5946971047468036, 0.45453382380316215]],
#  [91603    S. Mustafi
#   Name: Name, dtype: object,
#   192227,
#   [0.48096521527032077, 0.678922504787919]],
#  [100193    F. Aksoy
#   Name: Name, dtype: object,
#   240908,
#   [0.5544560043665748, 0.5335366944474301]],
#  [97096    Kim Won Sik
#   Name: Name, dtype: object,
#   206520,
#   [0.5998369350761884, 0.4426473743934513]],
#  [101384    J. Tucker
#   Name: Name, dtype: object,
#   241507,
#   [0.586008176926618, 0.46929743055780776]],
#  [102003    15 S. Faure
#   Name: Name, dtype: object,
#   190163,
#   [0.6797102576002338, 0.2842691596940052]],
#  [96978    19 H. Matthys
#   Name: Name, dtype: object,
#   223931,
#   [0.5841422465446927, 0.4706759435832547]],
#  [101352    S. Kennedy
#   Name: Name, dtype: object,
#   258361,
#   [0.5957124184921078, 0.4478302295079014]],
#  [102285    J. Löfgren
#   Name: Name, dtype: object,
#   247042,
#   [0.6386198133085198, 0.3630785970374566]],
#  [96283    Roberto Soira
#   Name: Name, dtype: object,
#   236190,
#   [0.4920162371812021, 0.6510483716770437]],
#  [101375    G. Goñi
#   Name: Name, dtype: object,
#   235966,
#   [0.5804585902742289, 0.4755795394472613]],
#  [90281    L. Krejčí
#   Name: Name, dtype: object,
#   252064,
#   [0.4590768451864143, 0.7144800056202398]],
#  [101813    S. Simič
#   Name: Name, dtype: object,
#   219591,
#   [0.5321225043856994, 0.5688521729427554]],
#  [94888    A. Briançon
#   Name: Name, dtype: object,
#   223138,
#   [0.49357634976823805, 0.6447024783291952]],
#  [100596    B. Ampuero
#   Name: Name, dtype: object,
#   225396,
#   [0.5617312782040836, 0.5091633873016065]],
#  [99548    S. Knežević
#   Name: Name, dtype: object,
#   234817,
#   [0.5448493741072828, 0.5424268240725695]],
#  [97160    M. Diakhaby
#   Name: Name, dtype: object,
#   230578,
#   [0.48711504630703373, 0.6555222433148135]],
#  [97721    21 M. Barać
#   Name: Name, dtype: object,
#   244648,
#   [0.5301321459327127, 0.5692208573358871]],
#  [93410    M. Bălașa
#   Name: Name, dtype: object,
#   220521,
#   [0.5463213158300222, 0.537031827614959]],
#  [100283    E. Godoy
#   Name: Name, dtype: object,
#   215178,
#   [0.5502904747753805, 0.5272179468469359]],
#  [100910    M. Ekpiteta
#   Name: Name, dtype: object,
#   250810,
#   [0.5841135407583224, 0.45894027564260514]],
#  [101297    S. McLoughlin
#   Name: Name, dtype: object,
#   241534,
#   [0.5970479883388939, 0.4317974251248918]],
#  [102323    Martín
#   Name: Name, dtype: object,
#   244919,
#   [0.5773416926407563, 0.46788574207420325]],
#  [102100    D. Csóka
#   Name: Name, dtype: object,
#   242731,
#   [0.6354963654806487, 0.3511217223267729]],
#  [91297    18 E. Makeev
#   Name: Name, dtype: object,
#   192155,
#   [0.5250080868273347, 0.568638429705923]],
#  [97616    A. Pérez
#   Name: Name, dtype: object,
#   221312,
#   [0.5242606047295245, 0.5687971031850252]],
#  [100557    G. Taft
#   Name: Name, dtype: object,
#   203145,
#   [0.6107277386360672, 0.3973425957505822]],
#  [96469    M. Fraser
#   Name: Name, dtype: object,
#   211096,
#   [0.588717313212724, 0.4400688569004801]],
#  [97082    R. Becker
#   Name: Name, dtype: object,
#   229610,
#   [0.5824372010868741, 0.45091971277416115]],
#  [93215    20 Renato Neto
#   Name: Name, dtype: object,
#   199663,
#   [0.5064398513883327, 0.6000191665676488]],
#  [93227    Jean
#   Name: Name, dtype: object,
#   236303,
#   [0.5025302449253244, 0.6070884880936042]],
#  [95132    J. Torunarigha
#   Name: Name, dtype: object,
#   236947,
#   [0.4798583420155924, 0.6511221995321573]],
#  [98709    J. Abu Hanna
#   Name: Name, dtype: object,
#   233514,
#   [0.5708338525422116, 0.4711911330390343]],
#  [90931    L. Donnelly
#   Name: Name, dtype: object,
#   215820,
#   [0.5497398007296042, 0.5114765596059851]],
#  [97657    G. Kilama
#   Name: Name, dtype: object,
#   245092,
#   [0.5732152633886739, 0.464748406889717]],
#  [98361    Óscar Gil
#   Name: Name, dtype: object,
#   216461,
#   [0.5593234328005203, 0.4920466795675973]],
#  [99765    K. Miller
#   Name: Name, dtype: object,
#   247648,
#   [0.5536746239723017, 0.5029601974932478]],
#  [92413    R. Yates
#   Name: Name, dtype: object,
#   235642,
#   [0.5058837094205514, 0.5960651574350558]],
#  [99819    S. Graves
#   Name: Name, dtype: object,
#   242690,
#   [0.5690842542571057, 0.47082761323697486]],
#  [97292    L. Østigård
#   Name: Name, dtype: object,
#   238516,
#   [0.5171154486219571, 0.5703796598033095]],
#  [99576    M. Siby
#   Name: Name, dtype: object,
#   246549,
#   [0.5788652412304162, 0.44693251408652546]],
#  [99727    G. Edmundson
#   Name: Name, dtype: object,
#   228888,
#   [0.5580288618053764, 0.4871766878163665]],
#  [96568    J. Beyer
#   Name: Name, dtype: object,
#   242660,
#   [0.5201802168463837, 0.5616486630856342]],
#  [100162    M. Šverko
#   Name: Name, dtype: object,
#   235800,
#   [0.5790712165132202, 0.44403916385600406]],
#  [93245    20 U. Agbo
#   Name: Name, dtype: object,
#   226289,
#   [0.5120233263440349, 0.5757668095320464]],
#  [98870    R. Bennett
#   Name: Name, dtype: object,
#   204554,
#   [0.5813679088418177, 0.438180438234669]],
#  [100971    I. Acero
#   Name: Name, dtype: object,
#   246090,
#   [0.6356374313452102, 0.3282474182039982]],
#  [94506    A. Rrahmani
#   Name: Name, dtype: object,
#   244263,
#   [0.46005172682403483, 0.6738541397882473]],
#  [95616    T. Campanini
#   Name: Name, dtype: object,
#   235558,
#   [0.5453027822098933, 0.5043625039292946]],
#  [99286    T. Kacharaba
#   Name: Name, dtype: object,
#   260314,
#   [0.4905378690714476, 0.6123000854791101]],
#  [99133    N. Röseler
#   Name: Name, dtype: object,
#   205045,
#   [0.5318964244851755, 0.5303990477083953]],
#  [99802    G. Johnston
#   Name: Name, dtype: object,
#   240912,
#   [0.5649678625666933, 0.4649109275895532]],
#  [95368    H. Mendes
#   Name: Name, dtype: object,
#   234856,
#   [0.5362478170700129, 0.5206700517708863]],
#  [102311    P. Kalambayi
#   Name: Name, dtype: object,
#   233383,
#   [0.6128785763223883, 0.36846326971513277]],
#  [98190    A. Lewis
#   Name: Name, dtype: object,
#   233793,
#   [0.6115430991955007, 0.37070033747805387]],
#  [100264    C. Gogoua
#   Name: Name, dtype: object,
#   253144,
#   [0.5498786081895852, 0.4923252988855244]],
#  [100397    T. Holmes
#   Name: Name, dtype: object,
#   241411,
#   [0.5493623440335768, 0.4894257488033437]],
#  [95569    21 K. Mets
#   Name: Name, dtype: object,
#   226506,
#   [0.5336211270891074, 0.5201866491003743]],
#  [100736    21 P. Gouano
#   Name: Name, dtype: object,
#   204886,
#   [0.49194356254308813, 0.6023627292453305]],
#  [96386    Y. Songo'o
#   Name: Name, dtype: object,
#   203210,
#   [0.5518288605451527, 0.4841298052359958]],
#  [98493    E. Zehir
#   Name: Name, dtype: object,
#   242319,
#   [0.5678557501068142, 0.45130821131059484]],
#  [101820    M. Kreuzriegler
#   Name: Name, dtype: object,
#   256967,
#   [0.5779311934101963, 0.4307217830509562]],
#  [97417    J. Elvedi
#   Name: Name, dtype: object,
#   256705,
#   [0.5349038372393158, 0.5143675470390355]],
#  [102462    S. Sabetkar
#   Name: Name, dtype: object,
#   261452,
#   [0.6101743668656467, 0.3655864360031122]],
#  [97759    Jiang Guangtai
#   Name: Name, dtype: object,
#   200741,
#   [0.5480173987116653, 0.48779977681837305]],
#  [91375    Cris Laranjeiros
#   Name: Name, dtype: object,
#   230295,
#   [0.445970115126097, 0.6887015094913203]],
#  [98005    L. Schneider
#   Name: Name, dtype: object,
#   243959,
#   [0.581543820036224, 0.42111188094873464]],
#  [101924    D. Bates
#   Name: Name, dtype: object,
#   235729,
#   [0.544593076959327, 0.49390563371375024]],
#  [96371    S. Ajayi
#   Name: Name, dtype: object,
#   207952,
#   [0.48877929168279977, 0.6039448208204758]],
#  [94875    A. Erlingmark
#   Name: Name, dtype: object,
#   238270,
#   [0.5134472587914569, 0.5546532886034954]],
#  [101673    E. Goldaniga
#   Name: Name, dtype: object,
#   223524,
#   [0.5060526901820368, 0.5685731332474486]],
#  [99330    C. Salcedo
#   Name: Name, dtype: object,
#   212888,
#   [0.4683944058812347, 0.6426996950760225]],
#  [98964    D. Lavalée
#   Name: Name, dtype: object,
#   236712,
#   [0.5135905091542541, 0.5512851268919501]],
#  [94947    I. Cissé
#   Name: Name, dtype: object,
#   208309,
#   [0.5229624429664818, 0.5323781536103694]],
#  [93902    J. Van den Bergh
#   Name: Name, dtype: object,
#   246716,
#   [0.49707546481223125, 0.5831499460662926]],
#  [98379    A. Groiß
#   Name: Name, dtype: object,
#   245719,
#   [0.535202026478714, 0.5072652842045506]],
#  [101850    P. Bochniewicz
#   Name: Name, dtype: object,
#   220230,
#   [0.5089025639542156, 0.5587982077029188]],
#  [101366    J. Cascante
#   Name: Name, dtype: object,
#   242533,
#   [0.5185721342522592, 0.5395097622102873]],
#  [101272    Kike Hermoso
#   Name: Name, dtype: object,
#   240997,
#   [0.5719199237315262, 0.4322777452660015]],
#  [100113    N. Dussenne
#   Name: Name, dtype: object,
#   201841,
#   [0.49675905112205915, 0.5795079085787879]],
#  [100986    M. Leš
#   Name: Name, dtype: object,
#   258945,
#   [0.5908614439859611, 0.3909230303233576]],
#  [90939    J. Portillo
#   Name: Name, dtype: object,
#   259788,
#   [0.4947465662508319, 0.5791859455828668]],
#  [96689    Leo Coelho
#   Name: Name, dtype: object,
#   253305,
#   [0.5134870304120542, 0.5421378227080732]],
#  [96972    N. Stierlin
#   Name: Name, dtype: object,
#   242328,
#   [0.5498746475458128, 0.4703052069179556]],
#  [98152    L. Segovia
#   Name: Name, dtype: object,
#   253344,
#   [0.5326865918749596, 0.5041239879251745]],
#  [99289    J. McCart
#   Name: Name, dtype: object,
#   227951,
#   [0.5260891126652324, 0.5161160887576056]],
#  [94937    21 Alex Pinto
#   Name: Name, dtype: object,
#   238759,
#   [0.5105247107145877, 0.5461055931680944]],
#  [101456    21 H. Ouro-Sama
#   Name: Name, dtype: object,
#   244528,
#   [0.5769557954282521, 0.41461920572410693]],
#  [98377    I. Näsberg
#   Name: Name, dtype: object,
#   216114,
#   [0.5378922693048207, 0.49164720548234936]],
#  [98066    A. Costa
#   Name: Name, dtype: object,
#   261097,
#   [0.516090984926139, 0.5326911565036143]],
#  [102445    A. Halme
#   Name: Name, dtype: object,
#   234290,
#   [0.5315021476428267, 0.5006990271978906]],
#  [101346    Eduardo
#   Name: Name, dtype: object,
#   232581,
#   [0.5737233611227243, 0.4172401985239921]],
#  [99274    21 Roderick Miranda
#   Name: Name, dtype: object,
#   193143,
#   [0.49991603899822057, 0.5622315521510839]],
#  [91899    H. Choudhury
#   Name: Name, dtype: object,
#   228332,
#   [0.4427745168109354, 0.6741734642349271]],
#  [99582    Artur Jorge
#   Name: Name, dtype: object,
#   236505,
#   [0.4865771531581982, 0.5865314984083695]],
#  [101363    Dinis Almeida
#   Name: Name, dtype: object,
#   234665,
#   [0.5086974607332692, 0.5420720935123785]],
#  [91788    J. Murillo
#   Name: Name, dtype: object,
#   201377,
#   [0.4104328992518076, 0.7358637848315798]],
#  [99761    N. Phillips
#   Name: Name, dtype: object,
#   240926,
#   [0.46306100542332007, 0.6320004745910238]],
#  [102273    T. Datković
#   Name: Name, dtype: object,
#   253147,
#   [0.5736871418798751, 0.41331973813728223]],
#  [95186    R. Pröpper
#   Name: Name, dtype: object,
#   208462,
#   [0.50312670495295, 0.550327012314085]],
#  [91919    B. Rovira
#   Name: Name, dtype: object,
#   225812,
#   [0.4976961706532757, 0.560777793897866]],
#  [91797    20 L. Hyam
#   Name: Name, dtype: object,
#   194792,
#   [0.518569683713752, 0.5184442662822714]],
#  [100608    Ygor Nogueira
#   Name: Name, dtype: object,
#   225386,
#   [0.49214487197800916, 0.570307585960873]],
#  [98396    21 E. Dabo
#   Name: Name, dtype: object,
#   228836,
#   [0.5661642759045935, 0.4241706561746618]],
#  [100811    Ivanildo Fernandes
#   Name: Name, dtype: object,
#   244963,
#   [0.4861016498503304, 0.579496954088432]],
#  [99748    M. Heylen
#   Name: Name, dtype: object,
#   212120,
#   [0.48785079045212704, 0.5755266472146233]],
#  [102336    21 L. Morante
#   Name: Name, dtype: object,
#   257076,
#   [0.5658730571468811, 0.4213010578549189]],
#  [101038    T. Ominami
#   Name: Name, dtype: object,
#   232704,
#   [0.5785882621327563, 0.3951041485232699]],
#  [99425    J. Bager
#   Name: Name, dtype: object,
#   222328,
#   [0.5381104670894661, 0.4745003895046123]],
#  [95533    P. Jones
#   Name: Name, dtype: object,
#   194957,
#   [0.43127194159133353, 0.6849041280662265]],
#  [101426    N. Tafari
#   Name: Name, dtype: object,
#   256024,
#   [0.5599576687278979, 0.43099159758112177]],
#  [94630    S. Memišević
#   Name: Name, dtype: object,
#   235544,
#   [0.46374828949982333, 0.620540466280864]],
#  [96610    J. van Hecke
#   Name: Name, dtype: object,
#   258908,
#   [0.48585451940775887, 0.5739229456999643]],
#  [102540    A. Bærtelsen
#   Name: Name, dtype: object,
#   243347,
#   [0.632002873339735, 0.28526026470693416]],
#  [99045    J. Grayson
#   Name: Name, dtype: object,
#   239222,
#   [0.6002029963890895, 0.347602236836697]],
#  [101861    Z. Šarlija
#   Name: Name, dtype: object,
#   251343,
#   [0.5539277903169956, 0.43693587059957245]],
#  [92613    I. Šunjić
#   Name: Name, dtype: object,
#   244271,
#   [0.4553115040839792, 0.6312166403241264]],
#  [100842    S. Nakatani
#   Name: Name, dtype: object,
#   232571,
#   [0.5313423472025125, 0.47973800671121153]],
#  [98909    V. Bondar
#   Name: Name, dtype: object,
#   248698,
#   [0.5085798631145692, 0.524548003516518]],
#  [97218    21 I. Paurević
#   Name: Name, dtype: object,
#   197893,
#   [0.4732827546504446, 0.5935894038826133]],
#  [100562    C. Dunkley
#   Name: Name, dtype: object,
#   226102,
#   [0.5326885742466034, 0.47609384769213586]],
#  [99205    C. Brown
#   Name: Name, dtype: object,
#   242541,
#   [0.5705751470956894, 0.40090418736493655]],
#  [99236    S. Barreto
#   Name: Name, dtype: object,
#   241872,
#   [0.49462713155277593, 0.5504765034950572]],
#  [97813    N. Sundberg
#   Name: Name, dtype: object,
#   219950,
#   [0.5244625720704107, 0.4902639669525516]],
#  [90666    A. Vallci
#   Name: Name, dtype: object,
#   243661,
#   [0.4701939445028292, 0.5966749883220626]],
#  [99012    S. Piesinger
#   Name: Name, dtype: object,
#   210482,
#   [0.5055614434979986, 0.5258424830063997]],
#  [94533    Abdu Conté
#   Name: Name, dtype: object,
#   247180,
#   [0.5281430276163565, 0.4798354792048509]],
#  [96735    G. Jung
#   Name: Name, dtype: object,
#   223751,
#   [0.49191784686334555, 0.5512635871539275]],
#  [102846    C. Ezekwem
#   Name: Name, dtype: object,
#   262899,
#   [0.5893761837527786, 0.3584266141506141]],
#  ...]

# %%
df_17["Lindel" in df_17["Name"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/sklearn-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/sklearn-env/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/sklearn-env/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/keshav/Documents/academics/recsys/Scoutify2/Scoutify/PlayerRec_actual.ipynb Cell 134 in 1
# ----> <a href='vscode-notebook-cell:/Users/keshav/Documents/academics/recsys/Scoutify2/Scoutify/PlayerRec_actual.ipynb#Y250sZmlsZQ%3D%3D?line=0'>1</a> df_17["Lindel" in df_17["Name"]]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/sklearn-env/lib/python3.9/site-packages/pandas/core/frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/sklearn-env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: False
